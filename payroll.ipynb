# %%
import requests

# %%
import pandas as pd

# %%
import numpy as np

# %%
import json

# %%
pd.read_json("../rows.json")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-8c175a696c22> in <module>()
# ----> 1 pd.read_json("../rows.json")
#
# /usr/lib/python3/dist-packages/pandas/io/json/json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, lines, chunksize, compression)
#     364         return json_reader
#     365
# --> 366     return json_reader.read()
#     367
#     368
#
# /usr/lib/python3/dist-packages/pandas/io/json/json.py in read(self)
#     465             )
#     466         else:
# --> 467             obj = self._get_object_parser(self.data)
#     468         self.close()
#     469         return obj
#
# /usr/lib/python3/dist-packages/pandas/io/json/json.py in _get_object_parser(self, json)
#     482         obj = None
#     483         if typ == 'frame':
# --> 484             obj = FrameParser(json, **kwargs).parse()
#     485
#     486         if typ == 'series' or obj is None:
#
# /usr/lib/python3/dist-packages/pandas/io/json/json.py in parse(self)
#     574
#     575         else:
# --> 576             self._parse_no_numpy()
#     577
#     578         if self.obj is None:
#
# /usr/lib/python3/dist-packages/pandas/io/json/json.py in _parse_no_numpy(self)
#     791         if orient == "columns":
#     792             self.obj = DataFrame(
# --> 793                 loads(json, precise_float=self.precise_float), dtype=None)
#     794         elif orient == "split":
#     795             decoded = dict((str(k), v)
#
# ValueError: Unmatched ''"' when when decoding 'string'

# %%
data = json.load("../rows.json")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-018213c2308d> in <module>()
# ----> 1 data = json.load("../rows.json")
#
# /usr/lib/python3.6/json/__init__.py in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     294
#     295     """
# --> 296     return loads(fp.read(),
#     297         cls=cls, object_hook=object_hook,
#     298         parse_float=parse_float, parse_int=parse_int,
#
# AttributeError: 'str' object has no attribute 'read'

# %%
with open('../data.json') as data_file:
# Out:
#   File "<ipython-input-8-a03d39a47c5d>", line 1
#     with open('../data.json') as data_file:
#                                            ^
# SyntaxError: unexpected EOF while parsing

# %%
import json
with open('../rows.json') as data_file:    
data = json.load(data_file)
# Out:
#   File "<ipython-input-9-47f3e8314421>", line 3
#     data = json.load(data_file)
#        ^
# IndentationError: expected an indented block

# %%
with open('../rows.json') as data_file:
# Out:
#   File "<ipython-input-10-ce705e7553cc>", line 1
#     with open('../rows.json') as data_file:
#                                               ^
# SyntaxError: unexpected EOF while parsing

# %%
with open('../rows.json') as data_file:    
    data = json.load(data_file)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-11-10c4c01c02b7> in <module>()
#       1 with open('../rows.json') as data_file:
# ----> 2     data = json.load(data_file)
#
# /usr/lib/python3.6/json/__init__.py in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     297         cls=cls, object_hook=object_hook,
#     298         parse_float=parse_float, parse_int=parse_int,
# --> 299         parse_constant=parse_constant, object_pairs_hook=object_pairs_hook, **kw)
#     300
#     301
#
# /usr/lib/python3.6/json/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     352             parse_int is None and parse_float is None and
#     353             parse_constant is None and object_pairs_hook is None and not kw):
# --> 354         return _default_decoder.decode(s)
#     355     if cls is None:
#     356         cls = JSONDecoder
#
# /usr/lib/python3.6/json/decoder.py in decode(self, s, _w)
#     337
#     338         """
# --> 339         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     340         end = _w(s, end).end()
#     341         if end != len(s):
#
# /usr/lib/python3.6/json/decoder.py in raw_decode(self, s, idx)
#     353         """
#     354         try:
# --> 355             obj, end = self.scan_once(s, idx)
#     356         except StopIteration as err:
#     357             raise JSONDecodeError("Expecting value", s, err.value) from None
#
# JSONDecodeError: Unterminated string starting at: line 1230862 column 14 (char 443477457)

# %%
data = pd.read_json('../rows.json')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-866d24d8a928> in <module>()
# ----> 1 data = pd.read_json('../rows.json')
#
# /usr/lib/python3/dist-packages/pandas/io/json/json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, lines, chunksize, compression)
#     364         return json_reader
#     365
# --> 366     return json_reader.read()
#     367
#     368
#
# /usr/lib/python3/dist-packages/pandas/io/json/json.py in read(self)
#     465             )
#     466         else:
# --> 467             obj = self._get_object_parser(self.data)
#     468         self.close()
#     469         return obj
#
# /usr/lib/python3/dist-packages/pandas/io/json/json.py in _get_object_parser(self, json)
#     482         obj = None
#     483         if typ == 'frame':
# --> 484             obj = FrameParser(json, **kwargs).parse()
#     485
#     486         if typ == 'series' or obj is None:
#
# /usr/lib/python3/dist-packages/pandas/io/json/json.py in parse(self)
#     574
#     575         else:
# --> 576             self._parse_no_numpy()
#     577
#     578         if self.obj is None:
#
# /usr/lib/python3/dist-packages/pandas/io/json/json.py in _parse_no_numpy(self)
#     791         if orient == "columns":
#     792             self.obj = DataFrame(
# --> 793                 loads(json, precise_float=self.precise_float), dtype=None)
#     794         elif orient == "split":
#     795             decoded = dict((str(k), v)
#
# ValueError: Unmatched ''"' when when decoding 'string'

# %%
a = open('../rows.json')

# %%
a
# Out:
# <_io.TextIOWrapper name='../rows.json' mode='r' encoding='UTF-8'>

# %%
b = jsons(a)['data']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-3f8db2bf41df> in <module>()
# ----> 1 b = jsons(a)['data']
#
# NameError: name 'jsons' is not defined

# %%
b = json.loads(a)['data']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-0b26952ccb95> in <module>()
# ----> 1 b = json.loads(a)['data']
#
# /usr/lib/python3.6/json/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     346         if not isinstance(s, (bytes, bytearray)):
#     347             raise TypeError('the JSON object must be str, bytes or bytearray, '
# --> 348                             'not {!r}'.format(s.__class__.__name__))
#     349         s = s.decode(detect_encoding(s), 'surrogatepass')
#     350
#
# TypeError: the JSON object must be str, bytes or bytearray, not 'TextIOWrapper'

# %%
a
# Out:
# <_io.TextIOWrapper name='../rows.json' mode='r' encoding='UTF-8'>

# %%
a
# Out:
# <_io.TextIOWrapper name='../rows.json' mode='r' encoding='UTF-8'>

# %%
b = open(a, "r", encoding="utf-8")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-aa73eacf498d> in <module>()
# ----> 1 b = open(a, "r", encoding="utf-8")
#
# TypeError: expected str, bytes or os.PathLike object, not _io.TextIOWrapper

# %%
with open(a, 'r') as f2:
    new_data = f2.read()
    print(data)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-2a7b04aaa657> in <module>()
# ----> 1 with open(a, 'r') as f2:
#       2     new_data = f2.read()
#       3     print(data)
#
# TypeError: expected str, bytes or os.PathLike object, not _io.TextIOWrapper

# %%
from pandas.io.json import json_normalize

# %%
 with open('../rows,json','w') as f:
    json.dump(data, f, indent=3, sort_keys=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-933e38c0b90e> in <module>()
#       1 with open('../rows,json','w') as f:
# ----> 2    json.dump(data, f, indent=3, sort_keys=True)
#
# NameError: name 'data' is not defined

# %%
import yaml

# %%
yaml.load('../rows.json')
# Out:
# '../rows.json'

# %%
yamlstuff = yaml.load('../rows.json')

# %%
yamlstuff
# Out:
# '../rows.json'

# %%
file = pd.read_json("../rows.json")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-8b116226ce46> in <module>()
# ----> 1 file = pd.read_json("../rows.json")
#
# /usr/lib/python3/dist-packages/pandas/io/json/json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, lines, chunksize, compression)
#     364         return json_reader
#     365
# --> 366     return json_reader.read()
#     367
#     368
#
# /usr/lib/python3/dist-packages/pandas/io/json/json.py in read(self)
#     465             )
#     466         else:
# --> 467             obj = self._get_object_parser(self.data)
#     468         self.close()
#     469         return obj
#
# /usr/lib/python3/dist-packages/pandas/io/json/json.py in _get_object_parser(self, json)
#     482         obj = None
#     483         if typ == 'frame':
# --> 484             obj = FrameParser(json, **kwargs).parse()
#     485
#     486         if typ == 'series' or obj is None:
#
# /usr/lib/python3/dist-packages/pandas/io/json/json.py in parse(self)
#     574
#     575         else:
# --> 576             self._parse_no_numpy()
#     577
#     578         if self.obj is None:
#
# /usr/lib/python3/dist-packages/pandas/io/json/json.py in _parse_no_numpy(self)
#     791         if orient == "columns":
#     792             self.obj = DataFrame(
# --> 793                 loads(json, precise_float=self.precise_float), dtype=None)
#     794         elif orient == "split":
#     795             decoded = dict((str(k), v)
#
# ValueError: Unexpected character found when decoding array value (2)

# %%
with open('../rows.json') as data_file:    
    data = json.load(data_file)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-29-10c4c01c02b7> in <module>()
#       1 with open('../rows.json') as data_file:
# ----> 2     data = json.load(data_file)
#
# /usr/lib/python3.6/json/__init__.py in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     297         cls=cls, object_hook=object_hook,
#     298         parse_float=parse_float, parse_int=parse_int,
# --> 299         parse_constant=parse_constant, object_pairs_hook=object_pairs_hook, **kw)
#     300
#     301
#
# /usr/lib/python3.6/json/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     352             parse_int is None and parse_float is None and
#     353             parse_constant is None and object_pairs_hook is None and not kw):
# --> 354         return _default_decoder.decode(s)
#     355     if cls is None:
#     356         cls = JSONDecoder
#
# /usr/lib/python3.6/json/decoder.py in decode(self, s, _w)
#     337
#     338         """
# --> 339         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     340         end = _w(s, end).end()
#     341         if end != len(s):
#
# /usr/lib/python3.6/json/decoder.py in raw_decode(self, s, idx)
#     353         """
#     354         try:
# --> 355             obj, end = self.scan_once(s, idx)
#     356         except StopIteration as err:
#     357             raise JSONDecodeError("Expecting value", s, err.value) from None
#
# JSONDecodeError: Expecting ',' delimiter: line 1230864 column 1 (char 443477446)

# %%
s = '../rows.json'

# %%
while True:
    try:
        result = json.loads(s)   # try to parse...
        break                    # parsing worked -> exit loop
    except Exception as e:
        # "Expecting , delimiter: line 34 column 54 (char 1158)"
        # position of unexpected character after '"'
        unexp = int(re.findall(r'\(char (\d+)\)', str(e))[0])
        # position of unescaped '"' before that
        unesc = s.rfind(r'"', 0, unexp)
        s = s[:unesc] + r'\"' + s[unesc+1:]
        # position of correspondig closing '"' (+2 for inserted '\')
        closg = s.find(r'"', unesc + 2)
        s = s[:closg] + r'\"' + s[closg+1:]
print result
# Out:
#   File "<ipython-input-31-da0009cbd8a7>", line 15
#     print result
#                ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(result)?

# %%
import json, re

# %%
with open('../rows.json', 'r') as jf:
    weatherData = json.load(jf)
    print weatherData
# Out:
#   File "<ipython-input-37-387d1d5e292e>", line 3
#     print weatherData
#                     ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(weatherData)?

# %%
import pdb

# %%
a
# Out:
# <_io.TextIOWrapper name='../rows.json' mode='r' encoding='UTF-8'>

# %%
a.info()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-47-ea9be6f27180> in <module>()
# ----> 1 a.info()
#
# AttributeError: '_io.TextIOWrapper' object has no attribute 'info'

# %%
a.attribute
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-48-9673fdd1375e> in <module>()
# ----> 1 a.attribute
#
# AttributeError: '_io.TextIOWrapper' object has no attribute 'attribute'

# %%
a.attributes
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-49-4aff07502fd9> in <module>()
# ----> 1 a.attributes
#
# AttributeError: '_io.TextIOWrapper' object has no attribute 'attributes'

# %%
a.read(5)
# Out:
# ''

# %%
a.read(10000)
# Out:
# ''

# %%
for line in a:
    print(line, end="")

# %%
a.readlines()
# Out:
# []

# %%
a = open('../rows.json')

# %%
a
# Out:
# <_io.BufferedRandom name='../rows.json'>

# %%
a = open('../rows.json', mode='r', encoding='utf-8')

# %%
a
# Out:
# <_io.TextIOWrapper name='../rows.json' mode='r' encoding='utf-8'>

# %%
a.read(100)
# Out:
# '{\n  "meta" : {\n    "view" : {\n      "id" : "k397-673e",\n      "name" : "Citywide Payroll Data (Fisca'

# %%
a.read(10000)
# Out:
# 'l Year)",\n      "attribution" : "Office of Payroll Administration (OPA)",\n      "averageRating" : 0,\n      "category" : "City Government",\n      "createdAt" : 1446308121,\n      "description" : "City employee Base and Overtime Salary by Fiscal Year.",\n      "displayType" : "table",\n      "downloadCount" : 3274,\n      "hideFromCatalog" : false,\n      "hideFromDataJson" : false,\n      "indexUpdatedAt" : 1507730111,\n      "newBackend" : false,\n      "numberOfComments" : 0,\n      "oid" : 26501493,\n      "provenance" : "official",\n      "publicationAppendEnabled" : false,\n      "publicationDate" : 1501609968,\n      "publicationGroup" : 5224251,\n      "publicationStage" : "published",\n      "rowClass" : "",\n      "rowsUpdatedAt" : 1501609541,\n      "rowsUpdatedBy" : "7pdm-vrjs",\n      "tableId" : 14369379,\n      "totalTimesRated" : 0,\n      "viewCount" : 34856,\n      "viewLastModified" : 1507729916,\n      "viewType" : "tabular",\n      "columns" : [ {\n        "id" : -1,\n        "name" : "sid",\n        "dataTypeName" : "meta_data",\n        "fieldName" : ":sid",\n        "position" : 0,\n        "renderTypeName" : "meta_data",\n        "format" : { },\n        "flags" : [ "hidden" ]\n      }, {\n        "id" : -1,\n        "name" : "id",\n        "dataTypeName" : "meta_data",\n        "fieldName" : ":id",\n        "position" : 0,\n        "renderTypeName" : "meta_data",\n        "format" : { },\n        "flags" : [ "hidden" ]\n      }, {\n        "id" : -1,\n        "name" : "position",\n        "dataTypeName" : "meta_data",\n        "fieldName" : ":position",\n        "position" : 0,\n        "renderTypeName" : "meta_data",\n        "format" : { },\n        "flags" : [ "hidden" ]\n      }, {\n        "id" : -1,\n        "name" : "created_at",\n        "dataTypeName" : "meta_data",\n        "fieldName" : ":created_at",\n        "position" : 0,\n        "renderTypeName" : "meta_data",\n        "format" : { },\n        "flags" : [ "hidden" ]\n      }, {\n        "id" : -1,\n        "name" : "created_meta",\n        "dataTypeName" : "meta_data",\n        "fieldName" : ":created_meta",\n        "position" : 0,\n        "renderTypeName" : "meta_data",\n        "format" : { },\n        "flags" : [ "hidden" ]\n      }, {\n        "id" : -1,\n        "name" : "updated_at",\n        "dataTypeName" : "meta_data",\n        "fieldName" : ":updated_at",\n        "position" : 0,\n        "renderTypeName" : "meta_data",\n        "format" : { },\n        "flags" : [ "hidden" ]\n      }, {\n        "id" : -1,\n        "name" : "updated_meta",\n        "dataTypeName" : "meta_data",\n        "fieldName" : ":updated_meta",\n        "position" : 0,\n        "renderTypeName" : "meta_data",\n        "format" : { },\n        "flags" : [ "hidden" ]\n      }, {\n        "id" : -1,\n        "name" : "meta",\n        "dataTypeName" : "meta_data",\n        "fieldName" : ":meta",\n        "position" : 0,\n        "renderTypeName" : "meta_data",\n        "format" : { },\n        "flags" : [ "hidden" ]\n      }, {\n        "id" : 313818908,\n        "name" : "Fiscal Year",\n        "dataTypeName" : "number",\n        "fieldName" : "fiscal_year",\n        "position" : 1,\n        "renderTypeName" : "number",\n        "tableColumnId" : 37771976,\n        "width" : 85,\n        "cachedContents" : {\n          "largest" : "2017",\n          "non_null" : 2194488,\n          "average" : "2015.528516902348",\n          "null" : 0,\n          "top" : [ {\n            "item" : "2016",\n            "count" : 20\n          }, {\n            "item" : "2015",\n            "count" : 19\n          }, {\n            "item" : "2014",\n            "count" : 18\n          }, {\n            "item" : "2017",\n            "count" : 17\n          } ],\n          "smallest" : "2014",\n          "sum" : "4423053144"\n        },\n        "format" : {\n          "precisionStyle" : "standard",\n          "noCommas" : "true",\n          "align" : "right"\n        } ...

# %%
a
# Out:
# <_io.TextIOWrapper name='../rows.json' mode='r' encoding='utf-8'>

# %%
open(a)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-64-e6ecad3e27bd> in <module>()
# ----> 1 open(a)
#
# TypeError: expected str, bytes or os.PathLike object, not _io.TextIOWrapper

# %%
    for i, line in enumerate(1):
        if i == 25:
            # 26th line
        elif i == 29:
            # 30th line
        elif i > 29:
            break
# Out:
#   File "<ipython-input-65-f6d1b2faff6f>", line 4
#     elif i == 29:
#        ^
# IndentationError: expected an indented block

# %%
import linecache

# %%
theline = linecache.getline('../rows.json', 1000)

# %%
theline
# Out:
# '            "count" : 3\n'

# %%
theline = linecache.getline('../rows.json', 1230864)

# %%
theline
# Out:
# ''

# %%
with open('../rows.json') as data_file:    
    data = json.load(data_file)

# %%
with open('../rows.json') as data_file:    
    data = json.load(data_file)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-10c4c01c02b7> in <module>()
#       1 with open('../rows.json') as data_file:
# ----> 2     data = json.load(data_file)
#
# NameError: name 'json' is not defined

# %%
require json
# Out:
#   File "<ipython-input-2-bf1d7933bddc>", line 1
#     require json
#                ^
# SyntaxError: invalid syntax

# %%
from sodapy import Socrata
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-c650cb88f157> in <module>()
# ----> 1 from sodapy import Socrata
#
# ModuleNotFoundError: No module named 'sodapy'

# %%
from sodapy import Socrata
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-c650cb88f157> in <module>()
# ----> 1 from sodapy import Socrata
#
# /usr/local/lib/python3.6/dist-packages/sodapy/__init__.py in <module>()
#       1 from __future__ import absolute_import
# ----> 2 from future import standard_library
#       3
#       4 standard_library.install_aliases()
#       5
#
# ModuleNotFoundError: No module named 'future'

# %%
from sodapy import Socrata
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-5-c650cb88f157> in <module>()
# ----> 1 from sodapy import Socrata
#
# /usr/local/lib/python3.6/dist-packages/sodapy/__init__.py in <module>()
#       1 from __future__ import absolute_import
# ----> 2 from future import standard_library
#       3
#       4 standard_library.install_aliases()
#       5
#
# ModuleNotFoundError: No module named 'future'

# %%
from sodapy import Socrata

# %%
client = Socrata("data.cityofnewyork.us", "1vscl5xBtxiCI6ReKRmVwa0zt")

# %%
print("Domain: {domain:}\nSession: {session:}\nURI Prefix: {uri_prefix:}".format(**client.__dict__))
# Out:
# Domain: data.cityofnewyork.us
# Session: <requests.sessions.Session object at 0x7fded0cf9d68>
# URI Prefix: https://

# %%
results = client.get("k397-673e")
# Out:
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# /usr/lib/python3/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     386                     # otherwise it looks like a programming error was the cause.
# --> 387                     six.raise_from(e, None)
#     388         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# /usr/lib/python3/dist-packages/six.py in raise_from(value, from_value)
#
# /usr/lib/python3/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     382                 try:
# --> 383                     httplib_response = conn.getresponse()
#     384                 except Exception as e:
#
# /usr/lib/python3.6/http/client.py in getresponse(self)
#    1330             try:
# -> 1331                 response.begin()
#    1332             except ConnectionError:
#
# /usr/lib/python3.6/http/client.py in begin(self)
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#
# /usr/lib/python3.6/http/client.py in _read_status(self)
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#
# /usr/lib/python3.6/socket.py in readinto(self, b)
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#
# /usr/lib/python3.6/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1008                   self.__class__)
# -> 1009             return self.read(nbytes, buffer)
#    1010         else:
#
# /usr/lib/python3.6/ssl.py in read(self, len, buffer)
#     870         try:
# --> 871             return self._sslobj.read(len, buffer)
#     872         except SSLError as x:
#
# /usr/lib/python3.6/ssl.py in read(self, len, buffer)
#     630         if buffer is not None:
# --> 631             v = self._sslobj.read(len, buffer)
#     632         else:
#
# timeout: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# ReadTimeoutError                          Traceback (most recent call last)
# /usr/lib/python3/dist-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     439                     retries=self.max_retries,
# --> 440                     timeout=timeout
#     441                 )
#
# /usr/lib/python3/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     638             retries = retries.increment(method, url, error=e, _pool=self,
# --> 639                                         _stacktrace=sys.exc_info()[2])
#     640             retries.sleep()
#
# /usr/lib/python3/dist-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     356             if read is False or not self._is_method_retryable(method):
# --> 357                 raise six.reraise(type(error), error, _stacktrace)
#     358             elif read is not None:
#
# /usr/lib/python3/dist-packages/six.py in reraise(tp, value, tb)
#     692                 raise value.with_traceback(tb)
# --> 693             raise value
#     694         finally:
#
# /usr/lib/python3/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     600                                                   body=body, headers=headers,
# --> 601                                                   chunked=chunked)
#     602
#
# /usr/lib/python3/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     388         except (SocketTimeout, BaseSSLError, SocketError) as e:
# --> 389             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#     390             raise
#
# /usr/lib/python3/dist-packages/urllib3/connectionpool.py in _raise_timeout(self, err, url, timeout_value)
#     308         if isinstance(err, SocketTimeout):
# --> 309             raise ReadTimeoutError(self, url, "Read timed out. (read timeout=%s)" % timeout_value)
#     310
#
# ReadTimeoutError: HTTPSConnectionPool(host='data.cityofnewyork.us', port=443): Read timed out. (read timeout=10)
#
# During handling of the above exception, another exception occurred:
#
# ReadTimeout                               Traceback (most recent call last)
# <ipython-input-9-042b1de561cb> in <module>()
# ----> 1 results = client.get("k397-673e")
#
# /usr/local/lib/python3.6/dist-packages/sodapy/__init__.py in get(self, dataset_identifier, content_type, **kwargs)
#     250
#     251         response = self._perform_request("get", resource, headers=headers,
# --> 252                                          params=params)
#     253         return response
#     254
#
# /usr/local/lib/python3.6/dist-packages/sodapy/__init__.py in _perform_request(self, request_type, resource, **kwargs)
#     361         kwargs["timeout"] = self.timeout
#     362
# --> 363         response = getattr(self.session, request_type)(uri, **kwargs)
#     364
#     365         # handle errors
#
# /usr/lib/python3/dist-packages/requests/sessions.py in get(self, url, **kwargs)
#     519
#     520         kwargs.setdefault('allow_redirects', True)
# --> 521         return self.request('GET', url, **kwargs)
#     522
#     523     def options(self, url, **kwargs):
#
# /usr/lib/python3/dist-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     506         }
#     507         send_kwargs.update(settings)
# --> 508         resp = self.send(prep, **send_kwargs)
#     509
#     510         return resp
#
# /usr/lib/python3/dist-packages/requests/sessions.py in send(self, request, **kwargs)
#     616
#     617         # Send the request
# --> 618         r = adapter.send(request, **kwargs)
#     619
#     620         # Total elapsed time of the request (approximately)
#
# /usr/lib/python3/dist-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     519                 raise SSLError(e, request=request)
#     520             elif isinstance(e, ReadTimeoutError):
# --> 521                 raise ReadTimeout(e, request=request)
#     522             else:
#     523                 raise
#
# ReadTimeout: HTTPSConnectionPool(host='data.cityofnewyork.us', port=443): Read timed out. (read timeout=10)

# %%
results

# %%
df = pd.DataFrame.from_dict(results)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-9d02c509ba34> in <module>()
# ----> 1 df = pd.DataFrame.from_dict(results)
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd

# %%
df = pd.DataFrame.from_dict(results)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-9d02c509ba34> in <module>()
# ----> 1 df = pd.DataFrame.from_dict(results)
#
# NameError: name 'results' is not defined

# %%
results = client.get("k397-673e")

# %%
df = pd.DataFrame.from_dict(results)

# %%
df.head()
# Out:
#                       agency_name    agency_start_date base_salary  \
# 0  ADMIN FOR CHILDREN'S SVCS       2016-03-21T00:00:00    51315.00
# 1  ADMIN FOR CHILDREN'S SVCS       2016-08-08T00:00:00    51315.00
# 2  ADMIN FOR CHILDREN'S SVCS       2008-02-11T00:00:00    54720.00
# 3  ADMIN FOR CHILDREN'S SVCS       2014-10-20T00:00:00    54720.00
# 4  ADMIN FOR CHILDREN'S SVCS       2013-02-04T00:00:00    44409.00
#
#    first_name fiscal_year     last_name leave_status_as_of_july_31 mid_init  \
# 0      TERESA        2017         AARON                     ACTIVE      NaN
# 1     CAMELIA        2017        AARONS                     ACTIVE        M
# 2      MODUPE        2017         ABDUL                     ACTIVE      NaN
# 3  ABDUL AZIZ        2017  ABDUL RAHMAN                     ACTIVE        I
# 4    MONSURAT        2017   ABDULGANIYU                     ACTIVE        A
#
#   ot_hours   pay_basis regular_gross_paid regular_hours  \
# 0   588.00   per Annum           51709.59       1825.00
# 1   121.75   per Annum           41960.18       1595.55
# 2    54.75   per Annum           56298.93       1825.00
# 3   273.00   per Annum           55346.09       1825.00
# 4   815.50   per Annum           44157.49       1762.00
#
#                                    title_description total_ot_paid  \
# 0  CHILD PROTECTIVE SPECIALIST                   ...      22374.31
# 1  CHILD PROTECTIVE SPECIALIST                   ...       3892.19
# 2  CHILD PROTECTIVE SPECIALIST                   ...       2455.88
# 3  CHILD PROTECTIVE SPECIALIST                   ...      11069.41
# 4  JUVENILE COUNSELOR                            ...      27878.15
#
#   total_other_pay work_location_borough
# 0          639.66         BRONX
# 1          108.25         BROOKLYN
# 2         3938.75         BROOKLYN
# 3         1124.51         MANHATTAN
# 4         2019.34         BRONX

# %%
df
# Out:
#                         agency_name    agency_start_date base_salary  \
# 0    ADMIN FOR CHILDREN'S SVCS       2016-03-21T00:00:00    51315.00
# 1    ADMIN FOR CHILDREN'S SVCS       2016-08-08T00:00:00    51315.00
# 2    ADMIN FOR CHILDREN'S SVCS       2008-02-11T00:00:00    54720.00
# 3    ADMIN FOR CHILDREN'S SVCS       2014-10-20T00:00:00    54720.00
# 4    ADMIN FOR CHILDREN'S SVCS       2013-02-04T00:00:00    44409.00
# 5    ADMIN FOR CHILDREN'S SVCS       2015-10-19T00:00:00    67980.00
# 6    ADMIN FOR CHILDREN'S SVCS       2011-07-04T00:00:00    44409.00
# 7    ADMIN FOR CHILDREN'S SVCS       1998-12-14T00:00:00    54720.00
# 8    ADMIN FOR CHILDREN'S SVCS       2001-04-30T00:00:00    67984.00
# 9    ADMIN FOR CHILDREN'S SVCS       1996-06-23T00:00:00    83248.00
# 10   ADMIN FOR CHILDREN'S SVCS       1997-02-02T00:00:00    98028.00
# 11   ADMIN FOR CHILDREN'S SVCS       2016-11-14T00:00:00   105000.00
# 12   ADMIN FOR CHILDREN'S SVCS       2017-05-22T00:00:00    47250.00
# 13   ADMIN FOR CHILDREN'S SVCS       1996-06-23T00:00:00    58631.00
# 14   ADMIN FOR CHILDREN'S SVCS       2016-04-25T00:00:00   111369.00
# 15   ADMIN FOR CHILDREN'S SVCS       1996-06-23T00:00:00    55349.00
# 16   ADMIN FOR CHILDREN'S SVCS       1996-06-23T00:00:00    74226.00
# 17   ADMIN FOR CHILDREN'S SVCS       2007-06-04T00:00:00    54720.00
# 18   ADMIN FOR CHILDREN'S SVCS       2014-12-01T00:00:00    67523.00
# 19   ADMIN FOR CHILDREN'S SVCS       2009-05-18T00:00:00    62734.00
# 20   ADMIN FOR CHILDREN'S SVCS       1996-06-23T00:00:00    83248.00
# 21   ADMIN FOR CHILDREN'S SVCS       2015-02-09T00:00:00    54720.00
# 22   ADMIN FOR CHILDREN'S SVCS       2017-05-22T00:00:00    47250.00
# 23   ADMIN FOR CHILDREN'S SVCS       2011-08-30T00:00:00    54720.00
# 24   ADMIN FOR CHILDREN'S SVCS       2016-08-29T00:00:00    37251.00
# 25   ADMIN FOR CHILDREN'S SVCS       2007-06-04T00:00:00    54720.00
# 26   ADMIN FOR CHILDREN'S SVCS       2016-03-21T00:00:00    45874.00
# 27   ADMIN FOR CHILDREN'S SVCS       2013-02-11T00:00:00    54720.00
# 28   ADMIN FOR CHILDREN'S SVCS       2017-05-22T00:00:00    47250.00
# 29   ADMIN FOR CHILDREN'S SVCS       2006-11-20T00:00:00    62192.00
# ..                              ...                  ...         ...
# 970  ADMIN FOR CHILDREN'S SVCS       1996-06-23T00:00:00   128776.00
# 971  ADMIN FOR CHILDREN'S SVCS       2000-10-23T00:00:00    78177.00
# 972  ADMIN FOR CHILDREN'S SVCS       2007-04-16T00:00:00    54720.00
# 973  ADMIN FOR CHILDREN'S SVCS       1996-06-23T00:00:00    79518.00
# 974  ADMIN FOR CHILDREN'S SVCS       2009-02-01T00:00:00      373.03
# 975  ADMIN FOR CHILDREN'S SVCS       2017-02-21T00:00:00    67980.00
# 976  ADMIN FOR CHILDREN'S SVCS       2004-06-28T00:00:00    62549.00
# 977  ADMIN FOR CHILDREN'S SVCS       1996-06-23T00:00:00    86772.00
# 978  ADMIN FOR CHILDREN'S SVCS       2005-09-19T00:00:00    80146.00
# 979  ADMIN FOR CHILDREN'S SVCS       2004-07-26T00:00:00    50828.00
# 980  ADMIN FOR CHILDREN'S SVCS       2016-01-11T00:00:00   113300.00
# 981  ADMIN FOR CHILDREN'S SVCS       1996-06-23T00:00:00    64506.00
# 982  ADMIN FOR CHILDREN'S SVCS       2015-05-18T00:00:00   109069.00
# 983  ADMIN FOR CHILDREN'S SVCS       1999-08-02T00:00:00    73598.00
# 984  ADMIN FOR CHILDREN'S SVCS       2016-10-17T00:00:00    75520.00
# 985  ADMIN FOR CHILDREN'S SVCS       2017-05-22T00:00:00    47250.00
# 986  ADMIN FOR CHILDREN'S SVCS       1997-07-06T00:00:00    55470.00
# 987  ADMIN FOR CHILDREN'S SVCS       2006-05-08T00:00:00    47536.00
# 988  ADMIN FOR CHILDREN'S SVCS       2000-03-13T00:00:00    84491.00
# 989  ADMIN FOR CHILDREN'S SVCS       2008-03-31T00:00:00    85029.00
# 990  ADMIN FOR CHILDREN'S SVCS       2005-08-01T00:00:00    54720.00
# 991  ADMIN FOR CHILDREN'S SVCS       2009-08-10T00:00:00    80146.00
# 992  ADMIN FOR CHILDREN'S SVCS       1997-02-02T00:00:00    48433.00
# 993  ADMIN FOR CHILDREN'S SVCS       1996-06-23T00:00:00    45217.00
# 994  ADMIN FOR CHILDREN'S SVCS       2016-09-12T00:00:00    57944.00
# 995  ADMIN FOR CHILDREN'S SVCS       2009-06-15T00:00:00    80146.00
# 996  ADMIN FOR CHILDREN'S SVCS       2000-01-10T00:00:00    51994.00
# 997  ADMIN FOR CHILDREN'S SVCS       2017-05-22T00:00:00    47250.00
# 998  ADMIN FOR CHILDREN'S SVCS       2001-08-27T00:00:00   113300.00
# 999  ADMIN FOR CHILDREN'S SVCS       1999-09-13T00:00:00    81715.00
#
#      first_name fiscal_year        last_name leave_status_as_of_july_31  \
# 0        TERESA        2017            AARON                     ACTIVE
# 1       CAMELIA        2017           AARONS                     ACTIVE
# 2        MODUPE        2017            ABDUL                     ACTIVE
# 3    ABDUL AZIZ        2017     ABDUL RAHMAN                     ACTIVE
# 4      MONSURAT        2017      ABDULGANIYU                     ACTIVE
# 5       NADIYAH        2017         ABDULLAH                     ACTIVE
# 6         AZIZA        2017     ABDUL-WAHHAB                     ACTIVE
# 7        KHALIL        2017     ABDUS-SHAHID                     ACTIVE
# 8       KERLINE        2017  ABELLARD-ROSEAU                     ACTIVE
# 9       COMFORT        2017         ABENGOWE                     ACTIVE
# 10      JEANINE        2017        ABERNATHY                     ACTIVE
# 11      TANISHA        2017        ABERNATHY                     ACTIVE
# 12        YOSEF        2017           ABERRA                     ACTIVE
# 13      NARRESH        2017      ABICHANDANI                     ACTIVE
# 14        KEREN        2017            ABINA                     ACTIVE
# 15      VICENTE        2017        ABOLENCIA                     ACTIVE
# 16      ABRAHAM        2017          ABRAHAM                     ACTIVE
# 17       FENISE        2017          ABRAHAM                   ON LEAVE
# 18       VAYOLA        2017          ABRAHAM                     ACTIVE
# 19         ZULY        2017          ABRAHAM                     ACTIVE
# 20       ALTHEA        2017         ABRAHAMS                     ACTIVE
# 21      BRANDON        2017            ABREU                     CEASED
# 22     JINSELLY        2017       ABREU ROSA                     ACTIVE
# 23      MELISSA        2017          ABSALON                     ACTIVE
# 24       NAJEEB        2017         ABUBAKAR                     CEASED
# 25         MAHA        2017         ABULABAN                     ACTIVE
# 26       ALEXIS        2017          ACEVEDO                     CEASED
# 27       ASHLEE        2017          ACEVEDO                     ACTIVE
# 28      DIAMOND        2017          ACEVEDO                     ACTIVE
# 29    FRANCISCO        2017          ACEVEDO                     ACTIVE
# ..          ...         ...              ...                        ...
# 970     ALMARIE        2017       BUDDINGTON                     ACTIVE
# 971      GERALD        2017     BUENAVENTURA                     ACTIVE
# 972    MILAGROS        2017            BUENO                     ACTIVE
# 973         KIM        2017            BUGGS                     ACTIVE
# 974       YURIY        2017          BULBAKH                     ACTIVE
# 975     HUGHTON        2017           BULLEN                     ACTIVE
# 976     LATONYA        2017          BULLOCK                     ACTIVE
# 977     THERESA        2017          BULLOCK                     ACTIVE
# 978      AMENDA        2017            BUNCH                     ACTIVE
# 979      CALVIN        2017            BUNCH                     ACTIVE
# 980     FELICIA        2017            BURCH                     ACTIVE
# 981     STEPHAN        2017            BURCH                     ACTIVE
# 982      KAILEY        2017           BURGER                     ACTIVE
# 983    GEOFFREY        2017          BURGESS                     ACTIVE
# 984      SHERIE        2017          BURGESS                     ACTIVE
# 985       SONJA        2017          BURGESS                     ACTIVE
# 986      YVONNE        2017          BURGESS                     ACTIVE
# 987       ERNIE        2017           BURGOS                     ACTIVE
# 988       KEVIN        2017            BURKE                     ACTIVE
# 989    MICHELLE        2017            BURKE                     ACTIVE
# 990        ROSE        2017            BURKE                     CEASED
# 991       TASHA        2017            BURKE                     ACTIVE
# 992      SONDRA        2017   BURKES-OLUDIPE                     ACTIVE
# 993     CYNTHIA        2017            BURKS                     ACTIVE
# 994       KELLY        2017          BURNETT                     ACTIVE
# 995     RENARTA        2017         BURNETTE                     ACTIVE
# 996    CHARIECE        2017            BURNS                     ACTIVE
# 997   CHRISTINA        2017            BURNS                     ACTIVE
# 998      KELLEY        2017            BURNS                     ACTIVE
# 999      JOANNE        2017        BURROUGHS                     ACTIVE
#
#     mid_init ot_hours   pay_basis regular_gross_paid regular_hours  \
# 0        NaN   588.00   per Annum           51709.59       1825.00
# 1          M   121.75   per Annum           41960.18       1595.55
# 2        NaN    54.75   per Annum           56298.93       1825.00
# 3          I   273.00   per Annum           55346.09       1825.00
# 4          A   815.50   per Annum           44157.49       1762.00
# 5          S    56.25   per Annum           69941.54       1825.00
# 6          S    97.00   per Annum           18708.16        798.82
# 7        NaN   316.75   per Annum           56298.93       1825.00
# 8        NaN     0.00   per Annum           68920.14       1825.00
# 9          U   181.50   per Annum           85649.98       1825.00
# 10         E     0.00   per Annum          100872.36       1755.00
# 11       NaN     0.00   per Annum           64438.40       1150.00
# 12         B     7.00   per Annum            4530.82        204.50
# 13       NaN   102.75   per Annum           60317.51       1825.00
# 14       NaN     0.00   per Annum          108009.73       1825.00
# 15       NaN     0.00   per Annum           56940.98       1825.00
# 16         T   193.50   per Annum           76362.47       1825.00
# 17       NaN   295.75   per Annum           45634.00       1413.75
# 18         K     0.00   per Annum           65455.25       1825.00
# 19         E   143.75   per Annum           58296.96       1825.00
# 20       NaN   119.75   per Annum           85649.98       1825.00
# 21         J   222.50   per Annum           26702.27        745.00
# 22       NaN     0.00   per Annum            4491.98        203.50
# 23       NaN   284.00   per Annum           55792.70       1807.67
# 24         S    53.50   per Annum           27111.19       1328.75
# 25         A   136.75   per Annum           56298.93       1825.00
# 26         R    20.25   per Annum            9711.67        262.00
# 27         M   282.50   per Annum           56298.93       1825.00
# 28         C     9.00   per Annum            4530.82        205.00
# 29         E     0.00   per Annum           66805.32       2085.72
# ..       ...      ...         ...                ...           ...
# 970      NaN     0.00   per Annum          132512.28       1825.00
# 971        M     0.00   per Annum           83620.37       1825.00
# 972      NaN     0.00   per Annum           56298.93       1825.00
# 973      NaN     0.00   per Annum           80308.12       1825.00
# 974        M   968.00     per Day          104632.31       1825.00
# 975        C     0.00   per Annum           22675.49        638.75
# 976        S    46.25   per Annum           59886.49       1769.37
# 977      NaN    22.50   per Annum           88761.27       1825.00
# 978        D   563.25   per Annum           82458.64       1825.00
# 979      NaN    50.50   per Annum           51400.85       1825.00
# 980      NaN     0.00   per Annum          116587.30       1825.00
# 981      NaN   651.25   per Annum           66367.23       1825.00
# 982        A     0.00   per Annum           99731.64       1825.00
# 983        F   592.00   per Annum           75716.43       1825.00
# 984        L     0.00   per Annum           51063.97       1264.00
# 985        M     0.00   per Annum            4530.82        189.75
# 986      NaN     0.00   per Annum           56096.65       1825.00
# 987        A     0.00   per Annum           47084.30       1755.00
# 988        C     0.00   per Annum           86942.46       1825.00
# 989      NaN     0.00   per Annum           87591.10       1825.00
# 990        L   116.75   per Annum           43108.15       1254.25
# 991        J   612.00   per Annum           87112.59       1825.00
# 992      NaN    79.00   per Annum           49030.89       2085.72
# 993        G    99.75   per Annum           46516.49       1825.00
# 994        M     0.75   per Annum           45521.76       1463.75
# 995        O   109.00   per Annum           96689.90       1822.00
# 996      NaN     0.00   per Annum           53488.92       1825.00
# 997        F     0.00   per Annum            4524.35        204.75
# 998        A     0.00   per Annum          112051.59       1825.00
# 999      NaN     0.00   per Annum           87123.11       1461.48
#
#                                      title_description total_ot_paid  \
# 0    CHILD PROTECTIVE SPECIALIST                   ...      22374.31
# 1    CHILD PROTECTIVE SPECIALIST                   ...       3892.19
# 2    CHILD PROTECTIVE SPECIALIST                   ...       2455.88
# 3    CHILD PROTECTIVE SPECIALIST                   ...      11069.41
# 4    JUVENILE COUNSELOR                            ...      27878.15
# 5    CHILD AND FAMILY SPECIALIST                   ...       2311.76
# 6    JUVENILE COUNSELOR                            ...       3451.00
# 7    CHILD PROTECTIVE SPECIALIST                   ...      14183.59
# 8    STAFF ANALYST                                 ...          0.00
# 9    CHILD AND FAMILY SPECIALIST                   ...       9416.42
# 10   DIRECTOR OF FIELD OPERATIONS                  ...          0.00
# 11   ADMINISTRATIVE PUBLIC INFORMATION SPECIALIST  ...          0.00
# 12   CHILD PROTECTIVE SPECIALIST                   ...        129.31
# 13   CHILD PROTECTIVE SPECIALIST                   ...       3535.42
# 14   ADMINISTRATIVE DIRECTOR OF SOCIAL SERVICES    ...          0.00
# 15   CHILD WELFARE SPECIALIST                      ...          0.00
# 16   CHILD WELFARE SPECIALIST                      ...       9705.63
# 17   CHILD PROTECTIVE SPECIALIST                   ...      13324.57
# 18   AGENCY ATTORNEY                               ...          0.00
# 19   CHILD PROTECTIVE SPECIALIST SUPERVISOR        ...       5022.61
# 20   CHILD AND FAMILY SPECIALIST                   ...       6987.44
# 21   CHILD PROTECTIVE SPECIALIST                   ...      10546.50
# 22   CHILD PROTECTIVE SPECIALIST                   ...          0.00
# 23   CHILD PROTECTIVE SPECIALIST                   ...      10774.41
# 24           CLERICAL ASSOCIATE                              1255.48
# 25   CHILD PROTECTIVE SPECIALIST                   ...       5037.24
# 26   CHILD PROTECTIVE SPECIALIST                   ...        803.49
# 27   CHILD PROTECTIVE SPECIALIST                   ...      12636.61
# 28   CHILD PROTECTIVE SPECIALIST                   ...        287.07
# 29   PROTECTION AGENT                              ...          0.00
# ..                                                 ...           ...
# 970  DIRECTOR OF FIELD OPERATIONS                  ...          0.00
# 971  CHILD AND FAMILY SPECIALIST                   ...        -12.41
# 972  CHILD PROTECTIVE SPECIALIST                   ...          0.00
# 973  CHILD WELFARE SPECIALIST SUPERVISOR           ...          0.00
# 974  ELECTRICIAN                                   ...      83836.75
# 975  CHILD AND FAMILY SPECIALIST                   ...          0.00
# 976  COMMUNITY COORDINATOR                         ...       2061.92
# 977  ADMINISTRATIVE DIRECTOR OF SOCIAL SERVICES    ...       1057.50
# 978  CHILD PROTECTIVE SPECIALIST SUPERVISOR        ...      37164.53
# 979                 PRINCIPAL ADMINISTRATIVE ASSOCIATE       1317.57
# 980  ADMINISTRATIVE DIRECTOR OF SOCIAL SERVICES    ...          0.00
# 981  SUPERVISOR OF CHILD CARE                      ...      31658.69
# 982  ADMINISTRATIVE DIRECTOR OF SOCIAL SERVICES    ...          0.00
# 983  CHILD PROTECTIVE SPECIALIST                   ...      39089.35
# 984  CHILD WELFARE SPECIALIST SUPERVISOR           ...          0.00
# 985  CHILD PROTECTIVE SPECIALIST                   ...          0.00
# 986                 PRINCIPAL ADMINISTRATIVE ASSOCIATE          0.00
# 987  COMPUTER AIDE-NON-SPVR                        ...          0.00
# 988  ADMINISTRATIVE DIRECTOR OF SOCIAL SERVICES    ...          0.00
# 989  AGENCY ATTORNEY                               ...          0.00
# 990  CHILD PROTECTIVE SPECIALIST                   ...       4542.82
# 991  CHILD PROTECTIVE SPECIALIST SUPERVISOR        ...      39991.16
# 992  CUSTODIAN                                     ...       2748.21
# 993  COMMUNITY ASSOCIATE                           ...       2805.49
# 994  AGENCY ATTORNEY INTERNE                       ...          0.00
# 995  CHILD PROTECTIVE SPECIALIST SUPERVISOR        ...       8535.95
# 996  CHILD WELFARE SPECIALIST                      ...          0.00
# 997  CHILD PROTECTIVE SPECIALIST                   ...          0.00
# 998  EXECUTIVE AGENCY COUNSEL                      ...        235.98
# 999  PROGRAM EVALUATOR                             ...          0.00
#
#     total_other_pay work_location_borough
# 0            639.66         BRONX
# 1            108.25         BROOKLYN
# 2           3938.75         BROOKLYN
# 3           1124.51         MANHATTAN
# 4           2019.34         BRONX
# 5            125.73         MANHATTAN
# 6           2530.17         BROOKLYN
# 7           6840.68         MANHATTAN
# 8           5624.01         MANHATTAN
# 9            547.22         QUEENS
# 10             0.00         BRONX
# 11             0.00         MANHATTAN
# 12             5.17         QUEENS
# 13          4674.54         QUEENS
# 14             0.00         MANHATTAN
# 15          4541.17         MANHATTAN
# 16          5010.23         QUEENS
# 17          4267.47         MANHATTAN
# 18          2896.17         QUEENS
# 19          4636.13         BRONX
# 20           421.95         QUEENS
# 21           543.72         RICHMOND
# 22            19.09         MANHATTAN
# 23          2922.92         MANHATTAN
# 24          2603.55         MANHATTAN
# 25          3793.68         MANHATTAN
# 26            57.75         BRONX
# 27          4032.36         MANHATTAN
# 28            25.22         MANHATTAN
# 29           469.68         BRONX
# ..              ...                   ...
# 970            0.00         BRONX
# 971         -920.37         MANHATTAN
# 972         3598.48         MANHATTAN
# 973         4631.92         QUEENS
# 974         6015.70         MANHATTAN
# 975            8.25         MANHATTAN
# 976          211.37         MANHATTAN
# 977          163.26         BROOKLYN
# 978         7882.99         BROOKLYN
# 979         1688.93         MANHATTAN
# 980            0.00         MANHATTAN
# 981         8162.33         MANHATTAN
# 982          250.00         MANHATTAN
# 983         9137.54         MANHATTAN
# 984            0.00         MANHATTAN
# 985          142.95         BRONX
# 986         4063.42         MANHATTAN
# 987         4600.06         MANHATTAN
# 988          500.00         MANHATTAN
# 989         6892.95         MANHATTAN
# 990         2791.67         QUEENS
# 991         3404.23         BROOKLYN
# 992         1466.18         MANHATTAN
# 993         1199.73         MANHATTAN
# 994          355.25         BRONX
# 995         3506.08         BROOKLYN
# 996         4541.17         BROOKLYN
# 997           10.34         MANHATTAN
# 998         1897.17         MANHATTAN
# 999          473.04         MANHATTAN
#
# [1000 rows x 16 columns]

# %%
identified = "k397-673e"

# %%
meta= client.get_metadata(identified)
[x['name'] for x in metadata['columns']]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-142eed0d0ec9> in <module>()
#       1
#       2 meta= client.get_metadata(identified)
# ----> 3 [x['name'] for x in metadata['columns']]
#
# NameError: name 'metadata' is not defined

# %%
meta= client.get_metadata(identified)

# %%
[x['name'] for x in meta['columns']]
# Out:
# ['Fiscal Year',
#  'Agency Name',
#  'Last Name',
#  'First Name',
#  'Mid Init',
#  'Agency Start Date',
#  'Work Location Borough',
#  'Title Description',
#  'Leave Status as of June 30',
#  'Base Salary',
#  'Pay Basis',
#  'Regular Hours',
#  'Regular Gross Paid',
#  'OT Hours',
#  'Total OT Paid',
#  'Total Other Pay']

# %%
meta_amount = [x for x in meta['columns'] if x['name'] == 'AMOUNT'][0]
meta_amount
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-21-438d41ebfab5> in <module>()
# ----> 1 meta_amount = [x for x in meta['columns'] if x['name'] == 'AMOUNT'][0]
#       2 meta_amount
#
# IndexError: list index out of range

# %%
meta_amount = [x for x in meta['columns'] if x['name'] == 'Fiscal Year'][0]
meta_amount
# Out:
# {'id': 313818908,
#  'name': 'Fiscal Year',
#  'dataTypeName': 'number',
#  'fieldName': 'fiscal_year',
#  'position': 1,
#  'renderTypeName': 'number',
#  'tableColumnId': 37771976,
#  'width': 85,
#  'cachedContents': {'largest': '2017',
#   'non_null': 2194488,
#   'average': '2015.528516902348',
#   'null': 0,
#   'top': [{'item': '2016', 'count': 20},
#    {'item': '2015', 'count': 19},
#    {'item': '2014', 'count': 18},
#    {'item': '2017', 'count': 17}],
#   'smallest': '2014',
#   'sum': '4423053144'},
#  'format': {'precisionStyle': 'standard',
#   'noCommas': 'true',
#   'align': 'right'}}

# %%
meta_amount['cachedContents']['average']
# Out:
# '2015.528516902348'

# %%
results = client.get(identified, limit=6)
results
# Out:
# [{'agency_name': 'DISTRICT ATTORNEY-MANHATTAN   ',
#   'pay_basis': ' per Annum',
#   'agency_start_date': '2003-07-14T00:00:00',
#   'title_description': 'COMMUNITY ASSOCIATE                                         ',
#   'last_name': "ABA'AHMID",
#   'regular_hours': '1830.00',
#   'ot_hours': '2.25',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '47166.03',
#   'work_location_borough': 'MANHATTAN    ',
#   'base_salary': '47678.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2016',
#   'total_ot_paid': '57.28',
#   'mid_init': 'E',
#   'first_name': 'RAHASHEEM'},
#  {'agency_name': 'DISTRICT ATTORNEY-MANHATTAN   ',
#   'pay_basis': ' per Annum',
#   'agency_start_date': '1995-06-12T00:00:00',
#   'title_description': 'ADMINISTRATIVE ACCOUNTANT                                   ',
#   'last_name': 'ABENSUR',
#   'regular_hours': '1831.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '119042.50',
#   'work_location_borough': 'MANHATTAN    ',
#   'base_salary': '119959.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2016',
#   'total_ot_paid': '0.00',
#   'first_name': 'MARGARET'},
#  {'agency_name': 'DISTRICT ATTORNEY-MANHATTAN   ',
#   'pay_basis': ' per Annum',
#   'agency_start_date': '2011-10-11T00:00:00',
#   'title_description': 'COMMUNITY ASSOCIATE                                         ',
#   'last_name': 'ABOUNAOUM',
#   'regular_hours': '1181.68',
#   'ot_hours': '1.00',
#   'leave_status_as_of_july_31': 'ON LEAVE',
#   'regular_gross_paid': '27452.62',
#   'work_location_borough': 'MANHATTAN    ',
#   'base_salary': '39966.00',
#   'total_other_pay': '33.00',
#   'fiscal_year': '2016',
#   'total_ot_paid': '21.34',
#   'mid_init': 'L',
#   'first_name': 'ANDREA'},
#  {'agency_name': 'DISTRICT ATTORNEY-MANHATTAN   ',
#   'pay_basis': ' per Annum',
#   'agency_start_date': '2014-12-01T00:00:00',
#   'title_description': 'COMPUTER SYSTEMS MANAGER                                    ',
#   'last_name': 'ABRAHAM',
#   'regular_hours': '1831.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '115104.57',
#   'work_location_borough': 'MANHATTAN    ',
#   'base_salary': '116000.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2016',
#   'total_ot_paid': '0.00',
#   'mid_init': 'J',
#   'first_name': 'JONATHAN'},
#  {'agency_name': 'DISTRICT ATTORNEY-MANHATTAN   ',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2015-05-21T00:00:00',
#   'title_description': 'COLLEGE AIDE                                                ',
#   'last_name': 'ABRAMS',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'CEASED',
#   'regular_gross_paid': '3500.00',
#   'work_location_borough': 'MANHATTAN    ',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2016',
#   'total_ot_paid': '0.00',
#   'first_name': 'JOSEPH'},
#  {'agency_name': 'DISTRICT ATTORNEY-MANHATTAN   ',
#   'pay_basis': ' per Annum',
#   'agency_start_date': '2012-09-04T00:00:00',
#   'title_description': 'ASSISTANT DISTRICT ATTORNEY                                 ',
#   'last_name': 'ABREU',
#   'regular_hours': '1831.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '71967.34',
#   'work_location_borough': 'MANHATTAN    ',
#   'base_salary': '71500.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2016',
#   'total_ot_paid': '0.00',
#   'first_name': 'JENNIFER'}]

# %%
results = client.get(socrata_dataset_identifier, limit=2000, select="name, amount")
results
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-9ef9ecdad12b> in <module>()
# ----> 1 results = client.get(socrata_dataset_identifier, limit=2000, select="name, amount")
#       2 results
#
# NameError: name 'socrata_dataset_identifier' is not defined

# %%
results = client.get(identified, limit=6, select="name, amount")
results
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-26-19b2a1807452> in <module>()
# ----> 1 results = client.get(identified, limit=6, select="name, amount")
#       2 results
#
# /usr/local/lib/python3.6/dist-packages/sodapy/__init__.py in get(self, dataset_identifier, content_type, **kwargs)
#     250
#     251         response = self._perform_request("get", resource, headers=headers,
# --> 252                                          params=params)
#     253         return response
#     254
#
# /usr/local/lib/python3.6/dist-packages/sodapy/__init__.py in _perform_request(self, request_type, resource, **kwargs)
#     365         # handle errors
#     366         if response.status_code not in (200, 202):
# --> 367             _raise_for_status(response)
#     368
#     369         # when responses have no content body (ie. delete, set_permission),
#
# /usr/local/lib/python3.6/dist-packages/sodapy/__init__.py in _raise_for_status(response)
#     419         if more_info and more_info.lower() != response.reason.lower():
#     420             http_error_msg += ".\n\t{0}".format(more_info)
# --> 421         raise requests.exceptions.HTTPError(http_error_msg, response=response)
#     422
#     423
#
# HTTPError: 400 Client Error: Bad Request.
# 	SoQL Error: column amount was not found in the parent view.

# %%
results = client.get(identified, limit=6)
results
# Out:
# [{'agency_name': 'DISTRICT ATTORNEY-MANHATTAN   ',
#   'pay_basis': ' per Annum',
#   'agency_start_date': '2003-07-14T00:00:00',
#   'title_description': 'COMMUNITY ASSOCIATE                                         ',
#   'last_name': "ABA'AHMID",
#   'regular_hours': '1830.00',
#   'ot_hours': '2.25',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '47166.03',
#   'work_location_borough': 'MANHATTAN    ',
#   'base_salary': '47678.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2016',
#   'total_ot_paid': '57.28',
#   'mid_init': 'E',
#   'first_name': 'RAHASHEEM'},
#  {'agency_name': 'DISTRICT ATTORNEY-MANHATTAN   ',
#   'pay_basis': ' per Annum',
#   'agency_start_date': '1995-06-12T00:00:00',
#   'title_description': 'ADMINISTRATIVE ACCOUNTANT                                   ',
#   'last_name': 'ABENSUR',
#   'regular_hours': '1831.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '119042.50',
#   'work_location_borough': 'MANHATTAN    ',
#   'base_salary': '119959.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2016',
#   'total_ot_paid': '0.00',
#   'first_name': 'MARGARET'},
#  {'agency_name': 'DISTRICT ATTORNEY-MANHATTAN   ',
#   'pay_basis': ' per Annum',
#   'agency_start_date': '2011-10-11T00:00:00',
#   'title_description': 'COMMUNITY ASSOCIATE                                         ',
#   'last_name': 'ABOUNAOUM',
#   'regular_hours': '1181.68',
#   'ot_hours': '1.00',
#   'leave_status_as_of_july_31': 'ON LEAVE',
#   'regular_gross_paid': '27452.62',
#   'work_location_borough': 'MANHATTAN    ',
#   'base_salary': '39966.00',
#   'total_other_pay': '33.00',
#   'fiscal_year': '2016',
#   'total_ot_paid': '21.34',
#   'mid_init': 'L',
#   'first_name': 'ANDREA'},
#  {'agency_name': 'DISTRICT ATTORNEY-MANHATTAN   ',
#   'pay_basis': ' per Annum',
#   'agency_start_date': '2014-12-01T00:00:00',
#   'title_description': 'COMPUTER SYSTEMS MANAGER                                    ',
#   'last_name': 'ABRAHAM',
#   'regular_hours': '1831.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '115104.57',
#   'work_location_borough': 'MANHATTAN    ',
#   'base_salary': '116000.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2016',
#   'total_ot_paid': '0.00',
#   'mid_init': 'J',
#   'first_name': 'JONATHAN'},
#  {'agency_name': 'DISTRICT ATTORNEY-MANHATTAN   ',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2015-05-21T00:00:00',
#   'title_description': 'COLLEGE AIDE                                                ',
#   'last_name': 'ABRAMS',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'CEASED',
#   'regular_gross_paid': '3500.00',
#   'work_location_borough': 'MANHATTAN    ',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2016',
#   'total_ot_paid': '0.00',
#   'first_name': 'JOSEPH'},
#  {'agency_name': 'DISTRICT ATTORNEY-MANHATTAN   ',
#   'pay_basis': ' per Annum',
#   'agency_start_date': '2012-09-04T00:00:00',
#   'title_description': 'ASSISTANT DISTRICT ATTORNEY                                 ',
#   'last_name': 'ABREU',
#   'regular_hours': '1831.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '71967.34',
#   'work_location_borough': 'MANHATTAN    ',
#   'base_salary': '71500.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2016',
#   'total_ot_paid': '0.00',
#   'first_name': 'JENNIFER'}]

# %%
results = client.get(identified, limit=2000)
results
# Out:
# [{'agency_name': 'DISTRICT ATTORNEY-MANHATTAN   ',
#   'pay_basis': ' per Annum',
#   'agency_start_date': '2003-07-14T00:00:00',
#   'title_description': 'COMMUNITY ASSOCIATE                                         ',
#   'last_name': "ABA'AHMID",
#   'regular_hours': '1830.00',
#   'ot_hours': '2.25',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '47166.03',
#   'work_location_borough': 'MANHATTAN    ',
#   'base_salary': '47678.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2016',
#   'total_ot_paid': '57.28',
#   'mid_init': 'E',
#   'first_name': 'RAHASHEEM'},
#  {'agency_name': 'DISTRICT ATTORNEY-MANHATTAN   ',
#   'pay_basis': ' per Annum',
#   'agency_start_date': '1995-06-12T00:00:00',
#   'title_description': 'ADMINISTRATIVE ACCOUNTANT                                   ',
#   'last_name': 'ABENSUR',
#   'regular_hours': '1831.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '119042.50',
#   'work_location_borough': 'MANHATTAN    ',
#   'base_salary': '119959.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2016',
#   'total_ot_paid': '0.00',
#   'first_name': 'MARGARET'},
#  {'agency_name': 'DISTRICT ATTORNEY-MANHATTAN   ',
#   'pay_basis': ' per Annum',
#   'agency_start_date': '2011-10-11T00:00:00',
#   'title_description': 'COMMUNITY ASSOCIATE                                         ',
#   'last_name': 'ABOUNAOUM',
#   'regular_hours': '1181.68',
#   'ot_hours': '1.00',
#   'leave_status_as_of_july_31': 'ON LEAVE',
#   'regular_gross_paid': '27452.62',
#   'work_location_borough': 'MANHATTAN    ',
#   'base_salary': '39966.00',
#   'total_other_pay': '33.00',
#   'fiscal_year': '2016',
#   'total_ot_paid': '21.34',
#   'mid_init': 'L',
#   'first_name': 'ANDREA'},
#  {'agency_name': 'DISTRICT ATTORNEY-MANHATTAN   ',
#   'pay_basis': ' per Annum',
#   'agency_start_date': '2014-12-01T00:00:00',
#   'title_description': 'COMPUTER SYSTEMS MANAGER                                    ',
#   'last_name': 'ABRAHAM',
#   'regular_hours': '1831.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '115104.57',
#   'work_location_borough': 'MANHATTAN    ',
#   'base_salary': '116000.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2016',
#   'total_ot_paid': '0.00',
#   'mid_init': 'J',
#   'first_name': 'JONATHAN'},
#  {'agency_name': 'DISTRICT ATTORNEY-MANHATTAN   ',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2015-05-21T00:00:00',
#   'title_description': 'COLLEGE AIDE                                                ',
#   'last_name': 'ABRAMS',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'CEASED',
#   'regular_gross_paid': '3500.00',
#   'work_location_borough': 'MANHATTAN    ',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2016',
#   'total_ot_paid': '0.00',
#   'first_name': 'JOSEPH'},
#  {'agency_name': 'DISTRICT ATTORNEY-MANHATTAN   ',
#   'pay_basis': ' per Annum',
#   'agency_start_date': '2012-09-04T00:00:00',
#   'title_description': 'ASSISTANT DISTRICT ATTORNEY                                 ',
#   'last_name': 'ABREU',
#   'regular_hours': '1831.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '71967.34',
#   'work_location_borough': 'MANHATTAN    ',
#   'base_salary': '71500.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2016',
#   'total_ot_paid': '0.00',
#   'first_name': 'JENNIFER'},
#  {'agency_name': 'DISTRICT ATTORNEY-MANHATTAN   ',
#   'pay_basis': ' per Annum',
#   'agency_start_date': '2007-09-04T00:00:00',
#   'title_description': 'ASSISTANT DISTRICT ATTORNEY                                 ',
#   'last_name': 'ABREU',
#   'regular_hours': '1831.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '87614.01',
#   'work_location_borough': 'MANHATTAN    ',
#   'base_salary': '88000.00',
#   'total_other_pay': '750.00',
#   'fiscal_year': '2016',
#   'total_ot_paid': '0.00',
#   'mid_init': 'D',
#   'first_name': 'JUAN'},
#  {'agency_name': 'DISTRICT ATTORNEY-MANHATTAN   ',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2016-06-06T00:00:00',
#   'title_description': 'COLLEGE AIDE                                                ',
#   'last_name': 'ACEVEDO',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '500.00',
#   'work_location_borough': 'MANHATTAN    ',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2016',
#   'total_ot_paid': '0.00',
#   'first_name': 'JENNIFER'},
#  {'agency_name': 'DISTRICT ATTORNEY-MANHATTAN   ',
#   'pay_basis': ' per Annum',
#   'agency_start_date': '2014-09-02T00:00:00',
#   'title_description': 'COMMUNITY ASSOCIATE                                         ',
#   'last_name': 'ACOCELLA',
#   'regular_hours': '349.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'CEASED',
#   'regular_gross_paid': '9507.15',
#   'work_location_borough': 'MANHATTAN    ',
#   'base_salary': '41000.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2016',
#   'total_ot_paid': '0.00',
#   'mid_init': 'J',
#   'first_name': 'MATTHEW'},
#  {'agency_name': 'DISTRICT ATTORNEY-MANHATTAN   ',
#   'pay_basis': ' per Annum',
#   'agency_start_date': '1978-05-31T00:00:00',
#   'title_description': 'PRINCIPAL ADMINISTRATIVE ASSOCIATE    ',
#   'last_name': 'ACOSTA',
#   'regular_hours': '1830.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '64357.12',
#   'work_location_borough': 'MANHATTAN    ',
#   'base_salary': '66035.00',
#   'total_other_pay': '3824.72',
#   'fiscal_year': '2016',
#   'total_ot_paid': '0.00',
#   'mid_init': 'E',
#   'first_name': 'RITA'},
#  {'agency_name': 'DISTRICT ATTORNEY-MANHATTAN   ',
#   'pay_basis': ' per Annum',
#   'agency_start_date': '2013-04-22T00:00:00',
#   'title_description': 'COMMUNITY ASSOCIATE                                         ',
#   'last_name': 'ADAMS',
#   'regular_hours': '200.70',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'CEASED',
#   'regular_gross_paid': '6073.13',
#   'work_location_borough': 'MANHATTAN    ',
#   'base_salary': '38869.00',
#   'total_other_pay': '8.25',
#   'fiscal_year': '2016',
#   'total_ot_paid': '0.00',
#   'mid_init': 'J',
#   'first_name': 'KATHERINE'},
#  {'agency_name': 'DISTRICT ATTORNEY-MANHATTAN   ',
#   'pay_basis': ' per Annum',
#   'agency_start_date': '2014-08-25T00:00:00',
#   'title_description': 'COMMUNITY ASSOCIATE                                         ',
#   'last_name': 'ADAMS',
#   'regular_hours': '1830.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '39895.79',
#   'work_location_borough': 'MANHATTAN    ',
#   'base_salary': '42075.00',
#   'total_other_pay': '74.25',
#   'fiscal_year': '2016',
#   'total_ot_paid': '0.00',
#   'first_name': 'NEERESHA'},
#  {'agency_name': 'DISTRICT ATTORNEY-MANHATTAN   ',
#   'pay_basis': ' per Annum',
#   'agency_start_date': '2014-01-13T00:00:00',
#   'title_description': 'COMMUNITY COORDINATOR                                       ',
#   'last_name': 'ADEGBORO',
#   'regular_hours': '1830.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '65909.63',
#   'work_location_borough': 'MANHATTAN    ',
#   'base_salary': '66625.00',
#   'total_other_pay': '33.00',
#   'fiscal_year': '2016',
#   'total_ot_paid': '0.00',
#   'mid_init': 'F',
#   'first_name': 'OYINDAMOLA'},
#  {'agency_name': 'DISTRICT ATTORNEY-MANHATTAN   ',
#   'pay_basis': ' per Annum',
#   'agency_start_date': '2005-03-28T00:00:00',
#   'title_description': 'PRINCIPAL ACCOUNTANT INVESTIGATOR                           ',
#   'last_name': 'AGGARWAL',
#   'regular_hours': '1831.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '111806.82',
#   'work_location_borough': 'MANHATTAN    ',
#   'base_salary': '112592.00',
#   'total_other_pay': '500.00',
#   'fiscal_year': '2016',
#   'total_ot_paid': '0.00',
#   'mid_init': 'J',
#   'first_name': 'SANCHITA'},
#  {'agency_name': 'DISTRICT ATTORNEY-MANHATTAN   ',
#   'pay_basis': ' per Annum',
#   'agency_start_date': '2009-11-09T00:00:00',
#   'title_description': 'COMMUNITY ASSOCIATE                                         ',
#   'last_name': 'AGUILAR',
#   'regular_hours': '1830.00',
#   'ot_hours': '716.25',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '51890.77',
#   'work_location_borough': 'MANHATTAN    ',
#   'base_salary': '52548.00',
#   'total_other_pay': '747.93',
#   'fiscal_year': '2016',
#   'total_ot_paid': '25943.55',
#   'first_name': 'YAMIRA'},
#  {'agency_name': 'DISTRICT ATTORNEY-MANHATTAN   ',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2015-05-21T00:00:00',
#   'title_description': 'COLLEGE AIDE                                                ',
#   'last_name': 'AGUIRRE',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'CEASED',
#   'regular_gross_paid': '3500.00',
#   'work_location_borough': 'MANHATTAN    ',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2016',
#   'total_ot_paid': '0.00',
#   'first_name': 'JORDAN'},
#  {'agency_name': 'DISTRICT ATTORNEY-MANHATTAN   ',
#   'pay_basis': ' per Annum',
#   'agency_start_date': '2014-04-28T00:00:00',
#   'title_description': 'COMMUNITY ASSISTANT                                         ',
#   'last_name': 'AHMETAJ',
#   'regular_hours': '1830.00',
#   'ot_hours': '51.75',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '40052.01',
#   'work_location_borough': 'MANHATTAN    ',
#   'base_salary': '43299.00',
#   'total_other_pay': '526.11',
#   'fiscal_year': '2016',
#   'total_ot_paid': '1413.40',
#   'first_name': 'ARTEMIS'},
#  {'agency_name': 'DISTRICT ATTORNEY-MANHATTAN   ',
#   'pay_basis': ' per Annum',
#   'agency_start_date': '2004-09-07T00:00:00',
#   'title_description': 'ASSISTANT DISTRICT ATTORNEY                                 ',
#   'last_name': 'AHN',
#   'regular_hours': '1076.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '59023.02',
#   'work_location_borough': 'MANHATTAN    ',
#   'base_salary': '102500.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2016',
#   'total_ot_paid': '0.00',
#   'mid_init': 'H',
#   'first_name': 'HELEN'},
#  {'agency_name': 'DISTRICT ATTORNEY-MANHATTAN   ',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2015-05-21T00:00:00',
#   'title_description': 'COLLEGE AIDE                                                ',
#   'last_name': 'ALCAIDE',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'CEASED',
#   'regular_gross_paid': '3500.00',
#   'work_location_borough': 'MANHATTAN    ',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2016',
#   'total_ot_paid': '0.00',
#   'first_name': 'SANDRA'},
#  {'agency_name': 'DISTRICT ATTORNEY-MANHATTAN   ',
#   'pay_basis': ' per Annum',
#   'agency_start_date': '2007-01-19T00:00:00',
#   'title_description': 'COMMUNITY ASSOCIATE                                         ',
#   'last_name': 'ALCANTARA',
#   'regular_hours': '1830.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '39866.21',
#   'work_location_borough': 'MANHATTAN    ',
#   'base_salary': '40299.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2016',
#   'total_ot_paid': '0.00',
#   'first_name': 'DANIEL'},
#  {'agency_name': 'DISTRICT ATTORNEY-MANHATTAN   ',
#   'pay_basis': ' per Annum',
#   'agency_start_date': '2014-09-02T00:00:00',
#   'title_description': 'ASSISTANT DISTRICT ATTORNEY                                 ',
#   'last_name': 'ALEXANDER',
#   'regular_hours': '1509.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '64498.36',
#   'work_location_borough': 'MANHATTAN    ',
#   'base_salary': '78000.00',
#   'total_other_pay': '1750.00',
#   'fiscal_year': '2016',
#   'total_ot_paid': '0.00',
#   'mid_init': 'L',
#   'first_name': 'ERIN'},
#  {'agency_name': 'DISTRICT ATTORNEY-MANHATTAN   ',
#   'pay_basis': ' per Day',
#   'agency_start_date': '2008-09-21T00:00:00',
#   'title_description': 'CARPENTER                                                   ',
#   'last_name': 'ALFLEN',
#   'regular_hours': '1830.00',
#   'ot_hours': '408.75',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '139072.14',
#   'work_location_borough': 'MANHATTAN    ',
#   'base_salary': '370.16',
#   'total_other_pay': '5060.37',
#   'fiscal_year': '2016',
#   'total_ot_paid': '50546.28',
#   'mid_init': 'R',
#   'first_name': 'PAUL'},
#  {'agency_name': 'DISTRICT ATTORNEY-MANHATTAN   ',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2016-06-06T00:00:00',
#   'title_description': 'COLLEGE AIDE                                                ',
#   'last_name': 'ALI',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '1000.00',
#   'work_location_borough': 'MANHATTAN    ',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2016',
#   'total_ot_paid': '0.00',
#   'first_name': 'SHEHARYAR'},
#  {'agency_name': 'DISTRICT ATTORNEY-MANHATTAN   ',
#   'pay_basis': ' per Day',
#   'agency_start_date': '2009-03-02T00:00:00',
#   'title_description': "ELECTRICIAN'S HELPER                                        ",
#   'last_name': 'ALI',
#   'regular_hours': '1830.00',
#   'ot_hours': '173.75',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '56602.00',
#   'work_location_borough': 'MANHATTAN    ',
#   'base_salary': '217.70',
#   'total_other_pay': '7424.72',
#   'fiscal_year': '2016',
#   'total_ot_paid': '8991.82',
#   'mid_init': 'A',
#   'first_name': 'SYEED'},
#  {'agency_name': 'DISTRICT ATTORNEY-MANHATTAN   ',
#   'pay_basis': ' per Annum',
#   'agency_start_date': '2015-06-08T00:00:00',
#   'title_description': 'COMMUNITY ASSOCIATE                                         ',
#   'last_name': 'AL-KAABAH II',
#   'regular_hours': '1829.75',
#   'ot_hours': '276.50',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '46271.84',
#   'work_location_borough': 'MANHATTAN    ',
#   'base_salary': '53366.00',
#   'total_other_pay': '755.84',
#   'fiscal_year': '2016',
#   'total_ot_paid': '7757.06',
#   'mid_init': 'I',
#   'first_name': 'JEFFREY'},
#  {'agency_name': 'DISTRICT ATTORNEY-MANHATTAN   ',
#   'pay_basis': ' per Annum',
#   'agency_start_date': '2010-08-16T00:00:00',
#   'title_description': 'COMMUNITY ASSOCIATE                                         ',
#   'last_name': 'ALKHAFAJEE',
#   'regular_hours': '38.10',
#   'ot_hours': '1.00',
#   'leave_status_as_of_july_31': 'CEASED',
#   'regular_gross_paid': '4661.03',
#   'work_location_borough': 'MANHATTAN    ',
#   'base_salary': '45985.00',
#   'total_other_pay': '94.40',
#   'fiscal_year': '2016',
#   'total_ot_paid': '169.90',
#   'mid_init': 'K',
#   'first_name': 'ABEER'},
#  {'agency_name': 'DISTRICT ATTORNEY-MANHATTAN   ',
#   'pay_basis': ' per Annum',
#   'agency_start_date': '2008-01-14T00:00:00',
#   'title_description': 'COMMUNITY ASSISTANT                                         ',
#   'last_name': 'ALKHAFAJEE',
#   'regular_hours': '1830.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '35765.73',
#   'work_location_borough': 'MANHATTAN    ',
#   'base_salary': '36154.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2016',
#   'total_ot_paid': '0.00',
#   'first_name': 'SHAIMAA'},
#  {'agency_name': 'DISTRICT ATTORNEY-MANHATTAN   ',
#   'pay_basis': ' per Annum',
#   'agency_start_date': '2014-10-20T00:00:00',
#   'title_description': 'COMMUNITY COORDINATOR                                       ',
#   'last_name': 'ALLEN',
#   'regular_hours': '1830.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '64895.59',
#   'work_location_borough': 'MANHATTAN    ',
#   'base_salary': '65600.00',
#   'total_other_pay': '99.50',
#   'fiscal_year': '2016',
#   'total_ot_paid': '0.00',
#   'mid_init': 'L',
#   'first_name': 'BENNETT'},
#  {'agency_name': 'DISTRICT ATTORNEY-MANHATTAN   ',
#   'pay_basis': ' per Annum',
#   'agency_start_date': '1980-01-21T00:00:00',
#   'title_description': 'CLERICAL ASSOCIATE                          ',
#   'last_name': 'ALLEN',
#   'regular_hours': '1830.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '55411.18',
#   'work_location_borough': 'MANHATTAN    ',
#   'base_salary': '56017.00',
#   'total_other_pay': '4424.50',
#   'fiscal_year': '2016',
#   'total_ot_paid': '0.00',
#   'mid_init': 'K',
#   'first_name': 'ROBERT'},
#  {'agency_name': 'DISTRICT ATTORNEY-MANHATTAN   ',
#   'pay_basis': ' per Annum',
#   'agency_start_date': '2015-09-28T00:00:00',
#   'title_description': 'COMMUNITY ASSOCIATE                                         ',
#   'last_name': 'ALMONTE-ALMANZA',
#   'regular_hours': '1383.00',
#   'ot_hours': '0.75',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '26422.22',
#   'work_location_borough': 'MANHATTAN    ',
#   'base_salary': '37541.00',
#   'total_other_pay': '24.75',
#   'fiscal_year': '2016',
#   'total_ot_paid': '15.41',
#   'first_name': 'MARISOL'},
#  {'agency_name': 'DISTRICT ATTORNEY-MANHATTAN   ',
#   'pay_basis': ' per Annum',
#   'agency_start_date': '2012-09-04T00:00:00',
#   'title_description': 'ASSISTANT DISTRICT ATTORNEY                                 ',
#   'last_name': 'ALMUDALLAL',
#   'regular_hours': '1830.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '71525.45',
#   'work_location_borough': 'MANHATTAN    ',
#   'base_salary': '71500.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2016',
#   'total_ot_paid': '0.00',
#   'first_name': 'AHMED'},
#  {'agency_name': 'DISTRICT ATTORNEY-MANHATTAN   ',
#   'pay_basis': ' per Annum',
#   'agency_start_date': '2006-09-11T00:00:00',
#   'title_description': 'COMMUNITY COORDINATOR                                       ',
#   'last_name': 'ALPEROVICH',
#   'regular_hours': '1830.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '104059.31',
#   'work_location_borough': 'MANHATTAN    ',
#   'base_salary': '105189.00',
#   'total_other_pay': '1000.00',
#   'fiscal_year': '2016',
#   'total_ot_paid': '0.00',
#   'first_name': 'ALEXANDER'},
#  {'agency_name': 'DISTRICT ATTORNEY-MANHATTAN   ',
#   'pay_basis': ' per Annum',
#   'agency_start_date': '2009-09-08T00:00:00',
#   'title_description': 'ASSISTANT DISTRICT ATTORNEY                                 ',
#   'last_name': 'ALPERT',
#   'regular_hours': '1830.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '88581.46',
#   'work_location_borough': 'MANHATTAN    ',
#   'base_salary': '88500.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2016',
#   'total_ot_paid': '0.00',
#   'mid_init': 'J',
#   'first_name': 'TAMI'},
#  {'agency_name': 'DISTRICT ATTORNEY-MANHATTAN   ',
#   'pay_basis': ' per Annum',
#   'agency_start_date': '2012-06-18T00:00:00',
#   'title_description': 'COMMUNITY ASSOCIATE                                         ',
#   'last_name': 'ALTONJI',
#   'regular_hours': '557.00',
#   'ot_hours': '7.50',
#   'leave_status_as_of_july_31': 'CEASED',
#   'regular_gross_paid': '19642.29',
#   'work_location_borough': 'MANHATTAN    ',
#   'base_salary': '57239.00',
#   'total_other_pay': '8.25',
#   'fiscal_year': '2016',
#   'total_ot_paid': '416.82',
#   'mid_init': 'C',
#   'first_name': 'MARY'},
#  {'agency_name': 'DISTRICT ATTORNEY-MANHATTAN   ',
#   'pay_basis': ' per Annum',
#   'agency_start_date': '2007-03-26T00:00:00',
#   'title_description': 'COMMUNITY COORDINATOR                                       ',
#   'last_name': 'ALVARADO',
#   'regular_hours': '1830.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '64375.36',
#   'work_location_borough': 'MANHATTAN    ',
#   'base_salary': '70403.00',
#   'total_other_pay': '10.75',
#   'fiscal_year': '2016',
#   'total_ot_paid': '0.00',
#   'mid_init': 'R',
#   'first_name': 'FARID'},
#  {'agency_name': 'DISTRICT ATTORNEY-MANHATTAN   ',
#   'pay_basis': ' per Annum',
#   'agency_start_date': '2014-11-17T00:00:00',
#   'title_description': 'COMMUNITY ASSOCIATE                                         ',
#   'last_name': 'ALVAREZ',
#   'regular_hours': '1688.87',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'CEASED',
#   'regular_gross_paid': '47113.19',
#   'work_location_borough': 'MANHATTAN    ',
#   'base_salary': '50458.00',
#   'total_other_pay': '8.25',
#   'fiscal_year': '2016',
#   'total_ot_paid': '0.00',
#   'first_name': 'DENISE'},
#  {'agency_name': 'DISTRICT ATTORNEY-MANHATTAN   ',
#   'pay_basis': ' per Annum',
#   'agency_start_date': '2014-03-10T00:00:00',
#   'title_description': 'COMMUNITY ASSOCIATE                                         ',
#   'last_name': 'ALVAREZ',
#   'regular_hours': '381.00',
#   'ot_hours': '12.00',
#   'leave_status_as_of_july_31': 'CEASED',
#   'regular_gross_paid': '9361.24',
#   'work_location_borough': 'MANHATTAN    ',
#   'base_salary': '37541.00',
#   'total_other_pay': '96.69',
#   'fiscal_year': '2016',
#   'total_ot_paid': '904.56',
#   'mid_init': 'M',
#   'first_name': 'STEPHANIE'},
#  {'agency_name': 'DISTRICT ATTORNEY-MANHATTAN   ',
#   'pay_basis': ' per Annum',
#   'agency_start_date': '2013-11-04T00:00:00',
#   'title_description': 'COMMUNITY ASSOCIATE                                         ',
#   'last_name': 'AMADOR',
#   'regular_hours': '1830.00',
#   'ot_hours': '31.25',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '39413.06',
#   'work_location_borough': 'MANHATTAN    ',
#   'base_salary': '39841.00',
#   'total_other_pay': '49.50',
#   'fiscal_year': '2016',
#   'total_ot_paid': '760.06',
#   'mid_init': 'D',
#   'first_name': 'ARLENE'},
#  {'agency_name': 'DISTRICT ATTORNEY-MANHATTAN   ',
#   'pay_basis': ' per Annum',
#   'agency_start_date': '2012-09-04T00:00:00',
#   'title_description': 'ASSISTANT DISTRICT ATTORNEY                                 ',
#   'last_name': 'AMINOFF',
#   'regular_hours': '1831.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '71668.08',
#   'work_location_borough': 'MANHATTAN    ',
#   'base_salary': '71500.00',
#   'total_other_pay': '500.00',
#   'fiscal_year': '2016',
#   'total_ot_paid': '0.00',
#   'mid_init': 'T',
#   'first_name': 'ANTHONY'},
#  {'agency_name': 'DISTRICT ATTORNEY-MANHATTAN   ',
#   'pay_basis': ' per Annum',
#   'agency_start_date': '2007-09-04T00:00:00',
#   'title_description': 'ASSISTANT DISTRICT ATTORNEY                                 ',
#   'last_name': 'AMLIN',
#   'regular_hours': '1831.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '86719.37',
#   'work_location_borough': 'MANHATTAN    ',
#   'base_salary': '87000.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2016',
#   'total_ot_paid': '0.00',
#   'first_name': 'TATIANA'},
#  {'agency_name': 'DISTRICT ATTORNEY-MANHATTAN   ',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2016-06-06T00:00:00',
#   'title_description': 'COLLEGE AIDE                                                ',
#   'last_name': 'AMOROSO',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '1000.00',
#   'work_location_borough': 'MANHATTAN    ',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2016',
#   'total_ot_paid': '0.00',
#   'mid_init': 'M',
#   'first_name': 'ALYSSA'},
#  {'agency_name': 'DISTRICT ATTORNEY-MANHATTAN   ',
#   'pay_basis': ' per Annum',
#   'agency_start_date': '1988-09-11T00:00:00',
#   'title_description': 'COMMUNITY ASSOCIATE                                         ',
#   'last_name': 'ANCRUM',
#   'regular_hours': '1830.00',
#   'ot_hours': '177.50',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '38074.40',
#   'work_location_borough': 'MANHATTAN    ',
#   'base_salary': '38492.00',
#   'total_other_pay': '5349.08',
#   'fiscal_year': '2016',
#   'total_ot_paid': '4599.16',
#   'first_name': 'ANTOINETTE'},
#  {'agency_name': 'DISTRICT ATTORNEY-MANHATTAN   ',
#   'pay_basis': ' per Annum',
#   'agency_start_date': '2015-08-31T00:00:00',
#   'title_description': 'COMMUNITY ASSOCIATE                                         ',
#   'last_name': 'ANDREWES',
#   'regular_hours': '1530.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '36699.13',
#   'work_location_borough': 'MANHATTAN    ',
#   'base_salary': '46817.00',
#   'total_other_pay': '950.12',
#   'fiscal_year': '2016',
#   'total_ot_paid': '0.00',
#   'mid_init': 'T',
#   'first_name': 'WILLIAM'},
#  {'agency_name': 'DISTRICT ATTORNEY-MANHATTAN   ',
#   'pay_basis': ' per Annum',
#   'agency_start_date': '2014-09-02T00:00:00',
#   'title_description': 'ASSISTANT DISTRICT ATTORNEY                                 ',
#   'last_name': 'ANDRYUSHCHENKO',
#   'regular_hours': '1830.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '65833.38',
#   'work_location_borough': 'MANHATTAN    ',
#   'base_salary': '65000.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2016',
#   'total_ot_paid': '0.00',
#   'mid_init': 'A',
#   'first_name': 'DARIA'},
#  {'agency_name': 'DISTRICT ATTORNEY-MANHATTAN   ',
#   'pay_basis': ' per Annum',
#   'agency_start_date': '2008-09-02T00:00:00',
#   'title_description': 'ASSISTANT DISTRICT ATTORNEY                                 ',
#   'last_name': 'ANGELO',
#   'regular_hours': '1494.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '66293.62',
#   'work_location_borough': 'MANHATTAN    ',
#   'base_salary': '82000.00',
#   'total_other_pay': '1312.50',
#   'fiscal_year': '2016',
#   'total_ot_paid': '0.00',
#   'first_name': 'LAUREN'},
#  {'agency_name': 'DISTRICT ATTORNEY-MANHATTAN   ',
#   'pay_basis': ' per Annum',
#   'agency_start_date': '2015-09-08T00:00:00',
#   'title_description': 'ASSISTANT DISTRICT ATTORNEY                                 ',
#   'last_name': 'ANGLADE',
#   'regular_hours': '1488.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '48775.09',
#   'work_location_borough': 'MANHATTAN    ',
#   'base_salary': '62500.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2016',
#   'total_ot_paid': '0.00',
#   'mid_init': 'M',
#   'first_name': 'DOMINIQUE'},
#  {'agency_name': 'DISTRICT ATTORNEY-MANHATTAN   ',
#   'pay_basis': ' per Annum',
#   'agency_start_date': '1989-08-21T00:00:00',
#   'title_description': 'ASSISTANT DISTRICT ATTORNEY                                 ',
#   'last_name': 'ANTE',
#   'regular_hours': '1830.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '150567.36',
#   'work_location_borough': 'MANHATTAN    ',
#   'base_salary': '151750.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2016',
#   'total_ot_paid': '0.00',
#   'mid_init': 'F',
#   'first_name': 'CHRISTINA'},
#  {'agency_name': 'DISTRICT ATTORNEY-MANHATTAN   ',
#   'pay_basis': ' per Annum',
#   'agency_start_date': '2014-01-21T00:00:00',
#   'title_description': 'COMMUNITY ASSOCIATE                                         ',
#   'last_name': 'ANTENOR',
#   'regular_hours': '694.90',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'CEASED',
#   'regular_gross_paid': '16960.27',
#   'work_location_borough': 'MANHATTAN    ',
#   'base_salary': '41295.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2016',
#   'total_ot_paid': '0.00',
#   'first_name': 'SANDY'},
#  {'agency_name': 'DISTRICT ATTORNEY-MANHATTAN   ',
#   'pay_basis': ' per Annum',
#   'agency_start_date': '2014-12-01T00:00:00',
#   'title_description': 'COMMUNITY ASSOCIATE                                         ',
#   'last_name': 'ANYAH',
#   'regular_hours': '1695.42',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'CEASED',
#   'regular_gross_paid': '36148.43',
#   'work_location_borough': 'MANHATTAN    ',
#   'base_salary': '40075.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2016',
#   'total_ot_paid': '0.00',
#   'mid_init': 'C',
#   'first_name': 'APRIL'},
#  {'agency_name': 'DISTRICT ATTORNEY-MANHATTAN   ',
#   'pay_basis': ' per Annum',
#   'agency_start_date': '2014-05-27T00:00:00',
#   'title_description': 'COMMUNITY ASSOCIATE                                         ',
#   'last_name': 'APONTE',
#   'regular_hours': '1830.00',
#   'ot_hours': '15.25',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '43271.69',
#   'work_location_borough': 'MANHATTAN    ',
#   'base_salary': '45888.00',
#   'total_other_pay': '49.50',
#   'fiscal_year': '2016',
#   'total_ot_paid': '380.73',
#   'mid_init': 'L',
#   'first_name': 'CANDEY'},
#  {'agency_name': 'DISTRICT ATTORNEY-MANHATTAN   ',
#   'pay_basis': ' per Annum',
#   'agency_start_date': '1999-09-07T00:00:00',
#   'title_description': 'ASSISTANT DISTRICT ATTORNEY                                 ',
#   'last_name': 'APPARICIO',
#   'regular_hours': '1830.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '137294.94',
#   'work_location_borough': 'MANHATTAN    ',
#   'base_salary': '138500.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2016',
#   'total_ot_paid': '0.00',
#   'mid_init': 'C',
#   'first_name': 'TANYA'},
#  {'agency_name': 'DISTRICT ATTORNEY-MANHATTAN   ',
#   'pay_basis': ' per Annum',
#   'agency_start_date': '2015-04-06T00:00:00',
#   'title_description': 'COMMUNITY ASSOCIATE                                         ',
#   'last_name': 'ARAUJO',
#   'regular_hours': '1830.00',
#   'ot_hours': '73.75',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '46016.79',
#   'work_location_borough': 'MANHATTAN    ',
#   'base_salary': '46817.00',
#   'total_other_pay': '665.50',
#   'fiscal_year': '2016',
#   'total_ot_paid': '2312.70',
#   'mid_init': 'D',
#   'first_name': 'JENNIFER'},
#  {'agency_name': 'DISTRICT ATTORNEY-MANHATTAN   ',
#   'pay_basis': ' per Annum',
#   'agency_start_date': '2010-11-15T00:00:00',
#   'title_description': 'COMMUNITY ASSOCIATE                                         ',
#   'last_name': 'ARCHER',
#   'regular_hours': '1830.00',
#   'ot_hours': '310.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '51387.10',
#   'work_location_borough': 'MANHATTAN    ',
#   'base_salary': '56135.00',
#   'total_other_pay': '1228.40',
#   'fiscal_year': '2016',
#   'total_ot_paid': '9482.70',
#   'mid_init': 'L',
#   'first_name': 'ADRIAN'},
#  {'agency_name': 'DISTRICT ATTORNEY-MANHATTAN   ',
#   'pay_basis': ' per Annum',
#   'agency_start_date': '2006-07-31T00:00:00',
#   'title_description': 'ADMINISTRATIVE CHIEF                                        ',
#   'last_name': 'ARGYROS',
#   'regular_hours': '1831.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '163658.93',
#   'work_location_borough': 'MANHATTAN    ',
#   'base_salary': '165000.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2016',
#   'total_ot_paid': '0.00',
#   'mid_init': 'A',
#   'first_name': 'GEORGE'},
#  {'agency_name': 'DISTRICT ATTORNEY-MANHATTAN   ',
#   'pay_basis': ' per Annum',
#   'agency_start_date': '2009-09-08T00:00:00',
#   'title_description': 'ASSISTANT DISTRICT ATTORNEY                                 ',
#   'last_name': 'ARNOW',
#   'regular_hours': '1830.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '80304.21',
#   'work_location_borough': 'MANHATTAN    ',
#   'base_salary': '80500.00',
#   'total_other_pay': '500.00',
#   'fiscal_year': '2016',
#   'total_ot_paid': '0.00',
#   'mid_init': 'L',
#   'first_name': 'SHIRA'},
#  {'agency_name': 'DISTRICT ATTORNEY-MANHATTAN   ',
#   'pay_basis': ' per Annum',
#   'agency_start_date': '2015-08-03T00:00:00',
#   'title_description': 'COMMUNITY ASSOCIATE                                         ',
#   'last_name': 'AROUTIOUNIAN',
#   'regular_hours': '1670.00',
#   'ot_hours': '1.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '32229.70',
#   'work_location_borough': 'MANHATTAN    ',
#   'base_salary': '37541.00',
#   'total_other_pay': '1275.91',
#   'fiscal_year': '2016',
#   'total_ot_paid': '20.55',
#   'mid_init': 'H',
#   'first_name': 'JOHN'},
#  {'agency_name': 'DISTRICT ATTORNEY-MANHATTAN   ',
#   'pay_basis': ' per Annum',
#   'agency_start_date': '1998-02-23T00:00:00',
#   'title_description': 'COMMUNITY ASSOCIATE                                         ',
#   'last_name': 'ARROYO',
#   'regular_hours': '1830.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '37859.68',
#   'work_location_borough': 'MANHATTAN    ',
#   'base_salary': '38275.00',
#   'total_other_pay': '795.70',
#   'fiscal_year': '2016',
#   'total_ot_paid': '0.00',
#   'mid_init': 'A',
#   'first_name': 'MICHAEL'},
#  {'agency_name': 'DISTRICT ATTORNEY-MANHATTAN   ',
#   'pay_basis': ' per Annum',
#   'agency_start_date': '2013-04-29T00:00:00',
#   'title_description': 'COMMUNITY ASSOCIATE                                         ',
#   'last_name': 'ARSENAULT',
#   'regular_hours': '116.68',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'CEASED',
#   'regular_gross_paid': '4879.14',
#   'work_location_borough': 'MANHATTAN    ',
#   'base_salary': '44225.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2016',
#   'total_ot_paid': '0.00',
#   'mid_init': 'G',
#   'first_name': 'WILLIAM'},
#  {'agency_name': 'DISTRICT ATTORNEY-MANHATTAN   ',
#   'pay_basis': ' per Annum',
#   'agency_start_date': '2008-10-12T00:00:00',
#   'title_description': 'ASSISTANT DISTRICT ATTORNEY                                 ',
#   'last_name': 'ASCHER',
#   'regular_hours': '1831.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '130607.04',
#   'work_location_borough': 'MANHATTAN    ',
#   'base_salary': '130500.00',
#   'total_other_pay': '3000.00',
#   'fiscal_year': '2016',
#   'total_ot_paid': '0.00',
#   'mid_init': 'A',
#   'first_name': 'CRAIG'},
#  {'agency_name': 'DISTRICT ATTORNEY-MANHATTAN   ',
#   'pay_basis': ' per Annum',
#   'agency_start_date': '2013-03-18T00:00:00',
#   'title_description': 'COMMUNITY ASSOCIATE                                         ',
#   'last_name': 'ASENCIO',
#   'regular_hours': '1830.00',
#   'ot_hours': '28.75',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '40000.58',
#   'work_location_borough': 'MANHATTAN    ',
#   'base_salary': '42571.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2016',
#   'total_ot_paid': '604.83',
#   'mid_init': 'C',
#   'first_name': 'JACQUELINE'},
#  {'agency_name': 'DISTRICT ATTORNEY-MANHATTAN   ',
#   'pay_basis': ' per Annum',
#   'agency_start_date': '1996-11-18T00:00:00',
#   'title_description': 'COMMUNITY ASSOCIATE                                         ',
#   'last_name': 'ASHBY',
#   'regular_hours': '1646.67',
#   'ot_hours': '23.50',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '34660.52',
#   'work_location_borough': 'MANHATTAN    ',
#   'base_salary': '38963.00',
#   'total_other_pay': '793.31',
#   'fiscal_year': '2016',
#   'total_ot_paid': '560.42',
#   'mid_init': 'N',
#   'first_name': 'MICHELLE'},
#  {'agency_name': 'DISTRICT ATTORNEY-MANHATTAN   ',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2016-06-06T00:00:00',
#   'title_description': 'COLLEGE AIDE                                                ',
#   'last_name': 'ASTARITA',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '500.00',
#   'work_location_borough': 'MANHATTAN    ',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2016',
#   'total_ot_paid': '0.00',
#   'mid_init': 'D',
#   'first_name': 'JULIANNA'},
#  {'agency_name': 'DISTRICT ATTORNEY-MANHATTAN   ',
#   'pay_basis': ' per Annum',
#   'agency_start_date': '2015-04-06T00:00:00',
#   'title_description': 'COMMUNITY ASSOCIATE                                         ',
#   'last_name': 'AU',
#   'regular_hours': '468.50',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'CEASED',
#   'regular_gross_paid': '16197.20',
#   'work_location_borough': 'MANHATTAN    ',
#   'base_salary': '54504.00',
#   'total_other_pay': '66.00',
#   'fiscal_year': '2016',
#   'total_ot_paid': '0.00',
#   'mid_init': 'M',
#   'first_name': 'VICKY'},
#  {'agency_name': 'DISTRICT ATTORNEY-MANHATTAN   ',
#   'pay_basis': ' per Annum',
#   'agency_start_date': '2015-06-29T00:00:00',
#   'title_description': 'COMMUNITY ASSOCIATE                                         ',
#   'last_name': 'AUGUSTINE',
#   'regular_hours': '1830.00',
#   'ot_hours': '2.50',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '35732.92',
#   'work_location_borough': 'MANHATTAN    ',
#   'base_salary': '37541.00',
#   'total_other_pay': '1283.00',
#   'fiscal_year': '2016',
#   'total_ot_paid': '50.74',
#   'mid_init': 'K',
#   'first_name': 'ERIK'},
#  {'agency_name': 'DISTRICT ATTORNEY-MANHATTAN   ',
#   'pay_basis': ' per Annum',
#   'agency_start_date': '2010-07-12T00:00:00',
#   'title_description': 'COMMUNITY ASSOCIATE                                         ',
#   'last_name': 'AVILES',
#   'regular_hours': '1832.45',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ON SEPARATION LEAVE',
#   'regular_gross_paid': '49283.96',
#   'work_location_borough': 'MANHATTAN    ',
#   'base_salary': '49819.00',
#   'total_other_pay': '68.50',
#   'fiscal_year': '2016',
#   'total_ot_paid': '0.00',
#   'first_name': 'AMANDA'},
#  {'agency_name': 'DISTRICT ATTORNEY-MANHATTAN   ',
#   'pay_basis': ' per Annum',
#   'agency_start_date': '1995-02-05T00:00:00',
#   'title_description': 'ASSISTANT DISTRICT ATTORNEY                                 ',
#   'last_name': 'AXELROD',
#   'regular_hours': '1831.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '173692.75',
#   'work_location_borough': 'MANHATTAN    ',
#   'base_salary': '170000.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2016',
#   'total_ot_paid': '0.00',
#   'first_name': 'SUSAN'},
#  {'agency_name': 'DISTRICT ATTORNEY-MANHATTAN   ',
#   'pay_basis': ' per Annum',
#   'agency_start_date': '2002-03-11T00:00:00',
#   'title_description': 'COMMUNITY ASSOCIATE                                         ',
#   'last_name': 'BADAGLIACCO',
#   'regular_hours': '1830.00',
#   'ot_hours': '144.50',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '43754.03',
#   'work_location_borough': 'MANHATTAN    ',
#   'base_salary': '49452.00',
#   'total_other_pay': '13.19',
#   'fiscal_year': '2016',
#   'total_ot_paid': '3390.72',
#   'first_name': 'RICHARD J'},
#  {'agency_name': 'DISTRICT ATTORNEY-MANHATTAN   ',
#   'pay_basis': ' per Annum',
#   'agency_start_date': '1989-03-26T00:00:00',
#   'title_description': 'PHOTOGRAPHER                                                ',
#   'last_name': 'BADGER',
#   'regular_hours': '1830.00',
#   'ot_hours': '436.50',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '65560.56',
#   'work_location_borough': 'MANHATTAN    ',
#   'base_salary': '63952.00',
#   'total_other_pay': '2945.97',
#   'fiscal_year': '2016',
#   'total_ot_paid': '19623.58',
#   'mid_init': 'J',
#   'first_name': 'LAURA'},
#  {'agency_name': 'DISTRICT ATTORNEY-MANHATTAN   ',
#   'pay_basis': ' per Annum',
#   'agency_start_date': '2014-07-28T00:00:00',
#   'title_description': 'COMMUNITY ASSOCIATE                                         ',
#   'last_name': 'BAEZ',
#   'regular_hours': '1830.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '51446.94',
#   'work_location_borough': 'MANHATTAN    ',
#   'base_salary': '54736.00',
#   'total_other_pay': '2008.25',
#   'fiscal_year': '2016',
#   'total_ot_paid': '0.00',
#   'mid_init': 'R',
#   'first_name': 'OLGA'},
#  {'agency_name': 'DISTRICT ATTORNEY-MANHATTAN   ',
#   'pay_basis': ' per Annum',
#   'agency_start_date': '1986-08-25T00:00:00',
#   'title_description': 'ASSISTANT DISTRICT ATTORNEY                                 ',
#   'last_name': 'BAILEY',
#   'regular_hours': '1830.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '185049.90',
#   'work_location_borough': 'MANHATTAN    ',
#   'base_salary': '178000.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2016',
#   'total_ot_paid': '0.00',
#   'mid_init': 'J',
#   'first_name': 'PATRICIA'},
#  {'agency_name': 'DISTRICT ATTORNEY-MANHATTAN   ',
#   'pay_basis': ' per Annum',
#   'agency_start_date': '2012-09-04T00:00:00',
#   'title_description': 'ASSISTANT DISTRICT ATTORNEY                                 ',
#   'last_name': 'BALACHANDRAN',
#   'regular_hours': '523.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'CEASED',
#   'regular_gross_paid': '22101.84',
#   'work_location_borough': 'MANHATTAN    ',
#   'base_salary': '66500.00',
#   'total_other_pay': '250.00',
#   'fiscal_year': '2016',
#   'total_ot_paid': '0.00',
#   'mid_init': 'K',
#   'first_name': 'MANU'},
#  {'agency_name': 'DISTRICT ATTORNEY-MANHATTAN   ',
#   'pay_basis': ' per Annum',
#   'agency_start_date': '2015-04-06T00:00:00',
#   'title_description': 'ASSISTANT DISTRICT ATTORNEY                                 ',
#   'last_name': 'BALBERT',
#   'regular_hours': '1831.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '152054.96',
#   'work_location_borough': 'MANHATTAN    ',
#   'base_salary': '153000.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2016',
#   'total_ot_paid': '0.00',
#   'first_name': 'COLEEN'},
#  {'agency_name': 'DISTRICT ATTORNEY-MANHATTAN   ',
#   'pay_basis': ' per Annum',
#   'agency_start_date': '2015-09-08T00:00:00',
#   'title_description': 'ASSISTANT DISTRICT ATTORNEY                                 ',
#   'last_name': 'BALDWIN',
#   'regular_hours': '1753.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '60622.09',
#   'work_location_borough': 'MANHATTAN    ',
#   'base_salary': '62500.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2016',
#   'total_ot_paid': '0.00',
#   'mid_init': 'B',
#   'first_name': 'GARRETT'},
#  {'agency_name': 'DISTRICT ATTORNEY-MANHATTAN   ',
#   'pay_basis': ' per Annum',
#   'agency_start_date': '2014-09-08T00:00:00',
#   'title_description': 'COMMUNITY ASSOCIATE                                         ',
#   'last_name': 'BAMBU ALEXANDER',
#   'regular_hours': '1830.00',
#   'ot_hours': '26.50',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '42227.09',
#   'work_location_borough': 'MANHATTAN    ',
#   'base_salary': '43102.00',
#   'total_other_pay': '8.25',
#   'fiscal_year': '2016',
#   'total_ot_paid': '472.82',
#   'first_name': 'GERARDO'},
#  {'agency_name': 'DISTRICT ATTORNEY-MANHATTAN   ',
#   'pay_basis': ' per Annum',
#   'agency_start_date': '2002-09-03T00:00:00',
#   'title_description': 'ASSISTANT DISTRICT ATTORNEY                                 ',
#   'last_name': 'BANDLER',
#   'regular_hours': '659.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'CEASED',
#   'regular_gross_paid': '46157.74',
#   'work_location_borough': 'MANHATTAN    ',
#   'base_salary': '113500.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2016',
#   'total_ot_paid': '0.00',
#   'mid_init': 'T',
#   'first_name': 'JOHN'},
#  {'agency_name': 'DISTRICT ATTORNEY-MANHATTAN   ',
#   'pay_basis': ' per Annum',
#   'agency_start_date': '1976-11-29T00:00:00',
#   'title_description': 'CLERICAL ASSOCIATE                          ',
#   'last_name': 'BANKHEADPRIDDEE',
#   'regular_hours': '1830.00',
#   'ot_hours': '167.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '40911.67',
#   'work_location_borough': 'MANHATTAN    ',
#   'base_salary': '41360.00',
#   'total_other_pay': '4474.71',
#   'fiscal_year': '2016',
#   'total_ot_paid': '4139.81',
#   'mid_init': 'E',
#   'first_name': 'SANDRA'},
#  {'agency_name': 'DISTRICT ATTORNEY-MANHATTAN   ',
#   'pay_basis': ' per Annum',
#   'agency_start_date': '2010-09-07T00:00:00',
#   'title_description': 'ASSISTANT DISTRICT ATTORNEY                                 ',
#   'last_name': 'BARAIOLA',
#   'regular_hours': '1830.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '77790.90',
#   'work_location_borough': 'MANHATTAN    ',
#   'base_salary': '78000.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2016',
#   'total_ot_paid': '0.00',
#   'mid_init': 'M',
#   'first_name': 'KRISTEN'},
#  {'agency_name': 'DISTRICT ATTORNEY-MANHATTAN   ',
#   'pay_basis': ' per Annum',
#   'agency_start_date': '2016-03-07T00:00:00',
#   'title_description': 'ASSISTANT DISTRICT ATTORNEY                                 ',
#   'last_name': 'BARCA III',
#   'regular_hours': '585.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '21976.27',
#   'work_location_borough': 'MANHATTAN    ',
#   'base_salary': '82000.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2016',
#   'total_ot_paid': '0.00',
#   'mid_init': 'A',
#   'first_name': 'JOSEPH'},
#  {'agency_name': 'DISTRICT ATTORNEY-MANHATTAN   ',
#   'pay_basis': ' per Annum',
#   'agency_start_date': '2014-08-04T00:00:00',
#   'title_description': 'COMMUNITY ASSOCIATE                                         ',
#   'last_name': 'BARD',
#   'regular_hours': '1830.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '51446.94',
#   'work_location_borough': 'MANHATTAN    ',
#   'base_salary': '54736.00',
#   'total_other_pay': '8.25',
#   'fiscal_year': '2016',
#   'total_ot_paid': '0.00',
#   'mid_init': 'E',
#   'first_name': 'NICOLE'},
#  {'agency_name': 'DISTRICT ATTORNEY-MANHATTAN   ',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2015-05-21T00:00:00',
#   'title_description': 'COLLEGE AIDE                                                ',
#   'last_name': 'BARDAVID',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'CEASED',
#   'regular_gross_paid': '3500.00',
#   'work_location_borough': 'MANHATTAN    ',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2016',
#   'total_ot_paid': '0.00',
#   'mid_init': 'V',
#   'first_name': 'DANIA'},
#  {'agency_name': 'DISTRICT ATTORNEY-MANHATTAN   ',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2015-06-15T00:00:00',
#   'title_description': 'COLLEGE AIDE                                                ',
#   'last_name': 'BARLEE',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'CEASED',
#   'regular_gross_paid': '2250.00',
#   'work_location_borough': 'MANHATTAN    ',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2016',
#   'total_ot_paid': '0.00',
#   'mid_init': 'F',
#   'first_name': 'PETESO'},
#  {'agency_name': 'DISTRICT ATTORNEY-MANHATTAN   ',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2015-05-21T00:00:00',
#   'title_description': 'COLLEGE AIDE                                                ',
#   'last_name': 'BARNES',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'CEASED',
#   'regular_gross_paid': '3500.00',
#   'work_location_borough': 'MANHATTAN    ',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2016',
#   'total_ot_paid': '0.00',
#   'mid_init': 'T',
#   'first_name': 'NICHOLAS'},
#  {'agency_name': 'DISTRICT ATTORNEY-MANHATTAN   ',
#   'pay_basis': ' per Annum',
#   'agency_start_date': '1981-08-10T00:00:00',
#   'title_description': 'SPECIAL ASSISTANT TO DA                                     ',
#   'last_name': 'BARNETT',
#   'regular_hours': '1830.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '182066.01',
#   'work_location_borough': 'MANHATTAN    ',
#   'base_salary': '175000.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2016',
#   'total_ot_paid': '0.00',
#   'first_name': 'MARY'},
#  {'agency_name': 'DISTRICT ATTORNEY-MANHATTAN   ',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2015-05-21T00:00:00',
#   'title_description': 'COLLEGE AIDE                                                ',
#   'last_name': 'BARRETT',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'CEASED',
#   'regular_gross_paid': '3500.00',
#   'work_location_borough': 'MANHATTAN    ',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2016',
#   'total_ot_paid': '0.00',
#   'mid_init': 'M',
#   'first_name': 'KATHERINE'},
#  {'agency_name': 'DISTRICT ATTORNEY-MANHATTAN   ',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2015-05-21T00:00:00',
#   'title_description': 'COLLEGE AIDE                                                ',
#   'last_name': 'BARROW',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'CEASED',
#   'regular_gross_paid': '1750.00',
#   'work_location_borough': 'MANHATTAN    ',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2016',
#   'total_ot_paid': '0.00',
#   'mid_init': 'M',
#   'first_name': 'LATOYA'},
#  {'agency_name': 'DISTRICT ATTORNEY-MANHATTAN   ',
# ...
#   'fiscal_year': '2016',
#   'total_ot_paid': '0.00',
#   'mid_init': 'M',
#   'first_name': 'JAMES'},
#  {'agency_name': 'DISTRICT ATTORNEY-MANHATTAN   ',
#   'pay_basis': ' per Annum',
#   'agency_start_date': '2008-09-02T00:00:00',
#   'title_description': 'ASSISTANT DISTRICT ATTORNEY                                 ',
#   'last_name': 'MCDONALD',
#   'regular_hours': '1831.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '80351.38',
#   'work_location_borough': 'MANHATTAN    ',
#   'base_salary': '81000.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2016',
#   'total_ot_paid': '0.00',
#   'mid_init': 'M',
#   'first_name': 'MEGAN'},
#  {'agency_name': 'DISTRICT ATTORNEY-MANHATTAN   ',
#   'pay_basis': ' per Annum',
#   'agency_start_date': '2015-09-08T00:00:00',
#   'title_description': 'ASSISTANT DISTRICT ATTORNEY                                 ',
#   'last_name': 'MCDONALD',
#   'regular_hours': '1488.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '47797.00',
#   'work_location_borough': 'MANHATTAN    ',
#   'base_salary': '63000.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2016',
#   'total_ot_paid': '0.00',
#   'mid_init': 'J',
#   'first_name': 'OLIVER'},
#  {'agency_name': 'DISTRICT ATTORNEY-MANHATTAN   ',
#   'pay_basis': ' per Day',
#   'agency_start_date': '2011-10-03T00:00:00',
#   'title_description': 'PAINTER                                                     ',
#   'last_name': 'MCEVOY',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'CEASED',
#   'regular_gross_paid': '445.90',
#   'work_location_borough': 'MANHATTAN    ',
#   'base_salary': '247.45',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2016',
#   'total_ot_paid': '0.00',
#   'first_name': 'DARREN'},
#  {'agency_name': 'DISTRICT ATTORNEY-MANHATTAN   ',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2016-06-06T00:00:00',
#   'title_description': 'COLLEGE AIDE                                                ',
#   'last_name': 'MCEVOY',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '500.00',
#   'work_location_borough': 'MANHATTAN    ',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2016',
#   'total_ot_paid': '0.00',
#   'mid_init': 'C',
#   'first_name': 'RYAN'},
#  {'agency_name': 'DISTRICT ATTORNEY-MANHATTAN   ',
#   'pay_basis': ' per Annum',
#   'agency_start_date': '2015-09-28T00:00:00',
#   'title_description': 'COMMUNITY COORDINATOR                                       ',
#   'last_name': 'MCGHEE',
#   'regular_hours': '1390.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '49535.60',
#   'work_location_borough': 'MANHATTAN    ',
#   'base_salary': '70000.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2016',
#   'total_ot_paid': '0.00',
#   'mid_init': 'D',
#   'first_name': 'CHRISTOPHER'},
#  {'agency_name': 'DISTRICT ATTORNEY-MANHATTAN   ',
#   'pay_basis': ' per Annum',
#   'agency_start_date': '2013-09-03T00:00:00',
#   'title_description': 'ASSISTANT DISTRICT ATTORNEY                                 ',
#   'last_name': 'MCGINN',
#   'regular_hours': '1831.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '77353.51',
#   'work_location_borough': 'MANHATTAN    ',
#   'base_salary': '78000.00',
#   'total_other_pay': '2000.00',
#   'fiscal_year': '2016',
#   'total_ot_paid': '0.00',
#   'mid_init': 'B',
#   'first_name': 'NATALIA'},
#  {'agency_name': 'DISTRICT ATTORNEY-MANHATTAN   ',
#   'pay_basis': ' per Annum',
#   'agency_start_date': '2013-04-15T00:00:00',
#   'title_description': 'COMMUNITY ASSOCIATE                                         ',
#   'last_name': 'MCGRATH',
#   'regular_hours': '1830.00',
#   'ot_hours': '99.50',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '44844.10',
#   'work_location_borough': 'MANHATTAN    ',
#   'base_salary': '45331.00',
#   'total_other_pay': '44.35',
#   'fiscal_year': '2016',
#   'total_ot_paid': '2581.01',
#   'mid_init': 'M',
#   'first_name': 'ANNE'},
#  {'agency_name': 'DISTRICT ATTORNEY-MANHATTAN   ',
#   'pay_basis': ' per Annum',
#   'agency_start_date': '2005-09-06T00:00:00',
#   'title_description': 'ASSISTANT DISTRICT ATTORNEY                                 ',
#   'last_name': 'MCGUIRE',
#   'regular_hours': '1137.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '60855.82',
#   'work_location_borough': 'MANHATTAN    ',
#   'base_salary': '99000.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2016',
#   'total_ot_paid': '0.00',
#   'mid_init': 'A',
#   'first_name': 'LAURIE'},
#  {'agency_name': 'DISTRICT ATTORNEY-MANHATTAN   ',
#   'pay_basis': ' per Annum',
#   'agency_start_date': '2015-09-14T00:00:00',
#   'title_description': 'COMMUNITY COORDINATOR                                       ',
#   'last_name': 'MCGUIRK',
#   'regular_hours': '1460.00',
#   'ot_hours': '22.50',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '43844.78',
#   'work_location_borough': 'MANHATTAN    ',
#   'base_salary': '58781.00',
#   'total_other_pay': '16.50',
#   'fiscal_year': '2016',
#   'total_ot_paid': '293.58',
#   'mid_init': 'K',
#   'first_name': 'ROSEMARY'},
#  {'agency_name': 'DISTRICT ATTORNEY-MANHATTAN   ',
#   'pay_basis': ' per Annum',
#   'agency_start_date': '1992-09-08T00:00:00',
#   'title_description': 'ASSISTANT DISTRICT ATTORNEY                                 ',
#   'last_name': 'MCINTOSH',
#   'regular_hours': '1831.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '132713.72',
#   'work_location_borough': 'MANHATTAN    ',
#   'base_salary': '133750.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2016',
#   'total_ot_paid': '0.00',
#   'mid_init': 'A',
#   'first_name': 'MICHAEL'},
#  {'agency_name': 'DISTRICT ATTORNEY-MANHATTAN   ',
#   'pay_basis': ' per Annum',
#   'agency_start_date': '1982-05-24T00:00:00',
#   'title_description': 'ADMINISTRATIVE PROJECT MANAGER                              ',
#   'last_name': 'MCKENNA',
#   'regular_hours': '1831.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '128076.83',
#   'work_location_borough': 'MANHATTAN    ',
#   'base_salary': '129042.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2016',
#   'total_ot_paid': '0.00',
#   'first_name': 'MICHELE'},
#  {'agency_name': 'DISTRICT ATTORNEY-MANHATTAN   ',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2016-06-06T00:00:00',
#   'title_description': 'COLLEGE AIDE                                                ',
#   'last_name': 'MCKEON',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '500.00',
#   'work_location_borough': 'MANHATTAN    ',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2016',
#   'total_ot_paid': '0.00',
#   'mid_init': 'A',
#   'first_name': 'MAURA'},
#  {'agency_name': 'DISTRICT ATTORNEY-MANHATTAN   ',
#   'pay_basis': ' per Annum',
#   'agency_start_date': '1992-08-03T00:00:00',
#   'title_description': 'COMMUNITY COORDINATOR                                       ',
#   'last_name': 'MCKEVITZ',
#   'regular_hours': '762.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'CEASED',
#   'regular_gross_paid': '36655.96',
#   'work_location_borough': 'MANHATTAN    ',
#   'base_salary': '79086.00',
#   'total_other_pay': '386.86',
#   'fiscal_year': '2016',
#   'total_ot_paid': '0.00',
#   'mid_init': 'L',
#   'first_name': 'MARY'},
#  {'agency_name': 'DISTRICT ATTORNEY-MANHATTAN   ',
#   'pay_basis': ' per Annum',
#   'agency_start_date': '2013-08-05T00:00:00',
#   'title_description': 'COMMUNITY ASSOCIATE                                         ',
#   'last_name': 'MCLAREN II',
#   'regular_hours': '59.52',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'CEASED',
#   'regular_gross_paid': '3103.45',
#   'work_location_borough': 'MANHATTAN    ',
#   'base_salary': '39236.00',
#   'total_other_pay': '19.02',
#   'fiscal_year': '2016',
#   'total_ot_paid': '0.00',
#   'mid_init': 'D',
#   'first_name': 'CAMPBELL'},
#  {'agency_name': 'DISTRICT ATTORNEY-MANHATTAN   ',
#   'pay_basis': ' per Day',
#   'agency_start_date': '2008-11-14T00:00:00',
#   'title_description': 'CARPENTER                                                   ',
#   'last_name': 'MCMAHON',
#   'regular_hours': '1830.00',
#   'ot_hours': '160.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '106168.90',
#   'work_location_borough': 'MANHATTAN    ',
#   'base_salary': '349.16',
#   'total_other_pay': '2875.90',
#   'fiscal_year': '2016',
#   'total_ot_paid': '23738.84',
#   'mid_init': 'P',
#   'first_name': 'FRANCIS'},
#  {'agency_name': 'DISTRICT ATTORNEY-MANHATTAN   ',
#   'pay_basis': ' per Annum',
#   'agency_start_date': '2007-09-04T00:00:00',
#   'title_description': 'ASSISTANT DISTRICT ATTORNEY                                 ',
#   'last_name': 'MCMAHON',
#   'regular_hours': '1830.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '92391.10',
#   'work_location_borough': 'MANHATTAN    ',
#   'base_salary': '93000.00',
#   'total_other_pay': '500.00',
#   'fiscal_year': '2016',
#   'total_ot_paid': '0.00',
#   'mid_init': 'M',
#   'first_name': 'SHAWN'},
#  {'agency_name': 'DISTRICT ATTORNEY-MANHATTAN   ',
#   'pay_basis': ' per Annum',
#   'agency_start_date': '2011-09-06T00:00:00',
#   'title_description': 'ASSISTANT DISTRICT ATTORNEY                                 ',
#   'last_name': 'MCNABNEY',
#   'regular_hours': '1831.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '83183.21',
#   'work_location_borough': 'MANHATTAN    ',
#   'base_salary': '84000.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2016',
#   'total_ot_paid': '0.00',
#   'mid_init': 'L',
#   'first_name': 'JUSTIN'},
#  {'agency_name': 'DISTRICT ATTORNEY-MANHATTAN   ',
#   'pay_basis': ' per Annum',
#   'agency_start_date': '2015-03-09T00:00:00',
#   'title_description': 'SENIOR ACCOUNTANT INVESTIGATOR                              ',
#   'last_name': 'MCNICHOL',
#   'regular_hours': '1830.00',
#   'ot_hours': '62.25',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '80903.65',
#   'work_location_borough': 'MANHATTAN    ',
#   'base_salary': '70000.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2016',
#   'total_ot_paid': '3372.86',
#   'mid_init': 'J',
#   'first_name': 'DANIEL'},
#  {'agency_name': 'DISTRICT ATTORNEY-MANHATTAN   ',
#   'pay_basis': ' per Annum',
#   'agency_start_date': '2015-11-09T00:00:00',
#   'title_description': 'COMMUNITY ASSOCIATE                                         ',
#   'last_name': 'MEDINA',
#   'regular_hours': '1180.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '24901.68',
#   'work_location_borough': 'MANHATTAN    ',
#   'base_salary': '42000.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2016',
#   'total_ot_paid': '0.00',
#   'mid_init': 'M',
#   'first_name': 'SAMANTHA'},
#  {'agency_name': 'DISTRICT ATTORNEY-MANHATTAN   ',
#   'pay_basis': ' per Annum',
#   'agency_start_date': '2016-06-06T00:00:00',
#   'title_description': 'COMMUNITY ASSOCIATE                                         ',
#   'last_name': 'MEEHAN',
#   'regular_hours': '123.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '718.00',
#   'work_location_borough': 'MANHATTAN    ',
#   'base_salary': '37541.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2016',
#   'total_ot_paid': '0.00',
#   'mid_init': 'E',
#   'first_name': 'JEFFREY'},
#  {'agency_name': 'DISTRICT ATTORNEY-MANHATTAN   ',
#   'pay_basis': ' per Annum',
#   'agency_start_date': '2015-05-26T00:00:00',
#   'title_description': 'ASSISTANT DISTRICT ATTORNEY                                 ',
#   'last_name': 'MEEHAN',
#   'regular_hours': '1831.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '79747.91',
#   'work_location_borough': 'MANHATTAN    ',
#   'base_salary': '80500.00',
#   'total_other_pay': '2099.45',
#   'fiscal_year': '2016',
#   'total_ot_paid': '0.00',
#   'mid_init': 'E',
#   'first_name': 'LAURA'},
#  {'agency_name': 'DISTRICT ATTORNEY-MANHATTAN   ',
#   'pay_basis': ' per Annum',
#   'agency_start_date': '2015-03-09T00:00:00',
#   'title_description': 'COMMUNITY ASSOCIATE                                         ',
#   'last_name': 'MEJIA',
#   'regular_hours': '1830.00',
#   'ot_hours': '4.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '38194.49',
#   'work_location_borough': 'MANHATTAN    ',
#   'base_salary': '41296.00',
#   'total_other_pay': '41.25',
#   'fiscal_year': '2016',
#   'total_ot_paid': '200.96',
#   'mid_init': 'N',
#   'first_name': 'ESTEFANIA'},
#  {'agency_name': 'DISTRICT ATTORNEY-MANHATTAN   ',
#   'pay_basis': ' per Annum',
#   'agency_start_date': '2007-08-20T00:00:00',
#   'title_description': 'COMMUNITY ASSISTANT                                         ',
#   'last_name': 'MELENDEZ',
#   'regular_hours': '1830.00',
#   'ot_hours': '51.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '39782.51',
#   'work_location_borough': 'MANHATTAN    ',
#   'base_salary': '46750.00',
#   'total_other_pay': '345.37',
#   'fiscal_year': '2016',
#   'total_ot_paid': '1959.33',
#   'first_name': 'ISAAC'},
#  {'agency_name': 'DISTRICT ATTORNEY-MANHATTAN   ',
#   'pay_basis': ' per Annum',
#   'agency_start_date': '2014-03-17T00:00:00',
#   'title_description': 'COMMUNITY ASSOCIATE                                         ',
#   'last_name': 'MENDOZA',
#   'regular_hours': '1830.00',
#   'ot_hours': '250.50',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '46016.79',
#   'work_location_borough': 'MANHATTAN    ',
#   'base_salary': '46817.00',
#   'total_other_pay': '369.54',
#   'fiscal_year': '2016',
#   'total_ot_paid': '7274.60',
#   'mid_init': 'J',
#   'first_name': 'ILEANA'},
#  {'agency_name': 'DISTRICT ATTORNEY-MANHATTAN   ',
#   'pay_basis': ' per Annum',
#   'agency_start_date': '2009-09-08T00:00:00',
#   'title_description': 'ASSISTANT DISTRICT ATTORNEY                                 ',
#   'last_name': 'MERCER',
#   'regular_hours': '1831.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '79250.71',
#   'work_location_borough': 'MANHATTAN    ',
#   'base_salary': '80000.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2016',
#   'total_ot_paid': '0.00',
#   'mid_init': 'L',
#   'first_name': 'ANDREW'},
#  {'agency_name': 'DISTRICT ATTORNEY-MANHATTAN   ',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2016-06-06T00:00:00',
#   'title_description': 'COLLEGE AIDE                                                ',
#   'last_name': 'MERRITT',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '500.00',
#   'work_location_borough': 'MANHATTAN    ',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2016',
#   'total_ot_paid': '0.00',
#   'mid_init': 'P',
#   'first_name': 'BRIANA'},
#  {'agency_name': 'DISTRICT ATTORNEY-MANHATTAN   ',
#   'pay_basis': ' per Annum',
#   'agency_start_date': '1986-01-13T00:00:00',
#   'title_description': 'COMMUNITY ASSOCIATE                                         ',
#   'last_name': 'MESSAM',
#   'regular_hours': '1830.00',
#   'ot_hours': '21.50',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '56140.21',
#   'work_location_borough': 'MANHATTAN    ',
#   'base_salary': '56754.00',
#   'total_other_pay': '795.70',
#   'fiscal_year': '2016',
#   'total_ot_paid': '606.41',
#   'mid_init': 'M',
#   'first_name': 'WINSOME'},
#  {'agency_name': 'DISTRICT ATTORNEY-MANHATTAN   ',
#   'pay_basis': ' per Annum',
#   'agency_start_date': '1982-09-27T00:00:00',
#   'title_description': 'REPORTER/ STENOGRAPHER                                      ',
#   'last_name': 'MESSINA - SANDE',
#   'regular_hours': '1830.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '89504.66',
#   'work_location_borough': 'MANHATTAN    ',
#   'base_salary': '86381.00',
#   'total_other_pay': '5476.70',
#   'fiscal_year': '2016',
#   'total_ot_paid': '0.00',
#   'first_name': 'JEANINE'},
#  ...]

# %%
results = client.get(identified, limit=1200000)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-29-b929bccaced8> in <module>()
# ----> 1 results = client.get(identified, limit=1200000)
#
# /usr/local/lib/python3.6/dist-packages/sodapy/__init__.py in get(self, dataset_identifier, content_type, **kwargs)
#     250
#     251         response = self._perform_request("get", resource, headers=headers,
# --> 252                                          params=params)
#     253         return response
#     254
#
# /usr/local/lib/python3.6/dist-packages/sodapy/__init__.py in _perform_request(self, request_type, resource, **kwargs)
#     365         # handle errors
#     366         if response.status_code not in (200, 202):
# --> 367             _raise_for_status(response)
#     368
#     369         # when responses have no content body (ie. delete, set_permission),
#
# /usr/local/lib/python3.6/dist-packages/sodapy/__init__.py in _raise_for_status(response)
#     419         if more_info and more_info.lower() != response.reason.lower():
#     420             http_error_msg += ".\n\t{0}".format(more_info)
# --> 421         raise requests.exceptions.HTTPError(http_error_msg, response=response)
#     422
#     423
#
# HTTPError: 400 Client Error: Bad Request.
# 	length must be <= 50000

# %%
1200000/50000
# Out:
# 24.0

# %%
df = pd.DataFrame()

# %%
for i in range(2):
    results = client.get(identified, limit=50000, offset=50000*i)
    df.append(results)

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
results = client.get(identified, limit=50000, offset=50000*0)

# %%
df = pd.read_json(results, lines=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-d19c6baa11fa> in <module>()
# ----> 1 df = pd.read_json(results, lines=True)
#
# /usr/lib/python3/dist-packages/pandas/io/json/json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, lines, chunksize, compression)
#     350     compression = _infer_compression(path_or_buf, compression)
#     351     filepath_or_buffer, _, compression = get_filepath_or_buffer(
# --> 352         path_or_buf, encoding=encoding, compression=compression,
#     353     )
#     354
#
# /usr/lib/python3/dist-packages/pandas/io/common.py in get_filepath_or_buffer(filepath_or_buffer, encoding, compression)
#     209     if not is_file_like(filepath_or_buffer):
#     210         msg = "Invalid file path or buffer object type: {_type}"
# --> 211         raise ValueError(msg.format(_type=type(filepath_or_buffer)))
#     212
#     213     return filepath_or_buffer, None, compression
#
# ValueError: Invalid file path or buffer object type: <class 'list'>

# %%
df.append(results)
# Out:
#                           agency_name    agency_start_date base_salary  \
# 0      DISTRICT ATTORNEY-MANHATTAN     2003-07-14T00:00:00    47678.00
# 1      DISTRICT ATTORNEY-MANHATTAN     1995-06-12T00:00:00   119959.00
# 2      DISTRICT ATTORNEY-MANHATTAN     2011-10-11T00:00:00    39966.00
# 3      DISTRICT ATTORNEY-MANHATTAN     2014-12-01T00:00:00   116000.00
# 4      DISTRICT ATTORNEY-MANHATTAN     2015-05-21T00:00:00        1.00
# 5      DISTRICT ATTORNEY-MANHATTAN     2012-09-04T00:00:00    71500.00
# 6      DISTRICT ATTORNEY-MANHATTAN     2007-09-04T00:00:00    88000.00
# 7      DISTRICT ATTORNEY-MANHATTAN     2016-06-06T00:00:00        1.00
# 8      DISTRICT ATTORNEY-MANHATTAN     2014-09-02T00:00:00    41000.00
# 9      DISTRICT ATTORNEY-MANHATTAN     1978-05-31T00:00:00    66035.00
# 10     DISTRICT ATTORNEY-MANHATTAN     2013-04-22T00:00:00    38869.00
# 11     DISTRICT ATTORNEY-MANHATTAN     2014-08-25T00:00:00    42075.00
# 12     DISTRICT ATTORNEY-MANHATTAN     2014-01-13T00:00:00    66625.00
# 13     DISTRICT ATTORNEY-MANHATTAN     2005-03-28T00:00:00   112592.00
# 14     DISTRICT ATTORNEY-MANHATTAN     2009-11-09T00:00:00    52548.00
# 15     DISTRICT ATTORNEY-MANHATTAN     2015-05-21T00:00:00        1.00
# 16     DISTRICT ATTORNEY-MANHATTAN     2014-04-28T00:00:00    43299.00
# 17     DISTRICT ATTORNEY-MANHATTAN     2004-09-07T00:00:00   102500.00
# 18     DISTRICT ATTORNEY-MANHATTAN     2015-05-21T00:00:00        1.00
# 19     DISTRICT ATTORNEY-MANHATTAN     2007-01-19T00:00:00    40299.00
# 20     DISTRICT ATTORNEY-MANHATTAN     2014-09-02T00:00:00    78000.00
# 21     DISTRICT ATTORNEY-MANHATTAN     2008-09-21T00:00:00      370.16
# 22     DISTRICT ATTORNEY-MANHATTAN     2016-06-06T00:00:00        1.00
# 23     DISTRICT ATTORNEY-MANHATTAN     2009-03-02T00:00:00      217.70
# 24     DISTRICT ATTORNEY-MANHATTAN     2015-06-08T00:00:00    53366.00
# 25     DISTRICT ATTORNEY-MANHATTAN     2010-08-16T00:00:00    45985.00
# 26     DISTRICT ATTORNEY-MANHATTAN     2008-01-14T00:00:00    36154.00
# 27     DISTRICT ATTORNEY-MANHATTAN     2014-10-20T00:00:00    65600.00
# 28     DISTRICT ATTORNEY-MANHATTAN     1980-01-21T00:00:00    56017.00
# 29     DISTRICT ATTORNEY-MANHATTAN     2015-09-28T00:00:00    37541.00
# ...                               ...                  ...         ...
# 49970               POLICE DEPARTMENT  2005-09-26T00:00:00    39868.00
# 49971               POLICE DEPARTMENT  2009-02-02T00:00:00    39164.00
# 49972               POLICE DEPARTMENT  2005-07-20T00:00:00    78026.00
# 49973               POLICE DEPARTMENT  2010-07-06T00:00:00    42395.00
# 49974               POLICE DEPARTMENT  2005-01-10T00:00:00    78026.00
# 49975               POLICE DEPARTMENT  1996-07-26T00:00:00   118902.00
# 49976               POLICE DEPARTMENT  1998-08-31T00:00:00    78026.00
# 49977               POLICE DEPARTMENT  2011-07-06T00:00:00    57747.00
# 49978               POLICE DEPARTMENT  2006-07-10T00:00:00    78026.00
# 49979               POLICE DEPARTMENT  2015-07-08T00:00:00    42819.00
# 49980               POLICE DEPARTMENT  2015-01-07T00:00:00    42819.00
# 49981               POLICE DEPARTMENT  2001-07-02T00:00:00    78026.00
# 49982               POLICE DEPARTMENT  2016-01-06T00:00:00    42819.00
# 49983               POLICE DEPARTMENT  1994-02-28T00:00:00   117145.00
# 49984               POLICE DEPARTMENT  2012-07-11T00:00:00    54341.00
# 49985               POLICE DEPARTMENT  1998-12-20T00:00:00    38044.00
# 49986               POLICE DEPARTMENT  1990-10-15T00:00:00   102054.00
# 49987               POLICE DEPARTMENT  1989-07-05T00:00:00   103517.00
# 49988               POLICE DEPARTMENT  2010-07-06T00:00:00    78026.00
# 49989               POLICE DEPARTMENT  1995-04-30T00:00:00    78026.00
# 49990               POLICE DEPARTMENT  1991-04-30T00:00:00    88151.00
# 49991               POLICE DEPARTMENT  2011-07-06T00:00:00    57747.00
# 49992               POLICE DEPARTMENT  2014-07-09T00:00:00    44521.00
# 49993               POLICE DEPARTMENT  1991-04-30T00:00:00    77253.00
# 49994               POLICE DEPARTMENT  2004-01-20T00:00:00   108748.00
# 49995               POLICE DEPARTMENT  1980-12-31T00:00:00    38319.00
# 49996               POLICE DEPARTMENT  1993-08-30T00:00:00    78026.00
# 49997               POLICE DEPARTMENT  1992-06-30T00:00:00    99053.00
# 49998               POLICE DEPARTMENT  2005-07-25T00:00:00    37821.00
# 49999               POLICE DEPARTMENT  2006-07-10T00:00:00    78026.00
#
#        first_name fiscal_year        last_name leave_status_as_of_july_31  \
# 0       RAHASHEEM        2016        ABA'AHMID                     ACTIVE
# 1        MARGARET        2016          ABENSUR                     ACTIVE
# 2          ANDREA        2016        ABOUNAOUM                   ON LEAVE
# 3        JONATHAN        2016          ABRAHAM                     ACTIVE
# 4          JOSEPH        2016           ABRAMS                     CEASED
# 5        JENNIFER        2016            ABREU                     ACTIVE
# 6            JUAN        2016            ABREU                     ACTIVE
# 7        JENNIFER        2016          ACEVEDO                     ACTIVE
# 8         MATTHEW        2016         ACOCELLA                     CEASED
# 9            RITA        2016           ACOSTA                     ACTIVE
# 10      KATHERINE        2016            ADAMS                     CEASED
# 11       NEERESHA        2016            ADAMS                     ACTIVE
# 12     OYINDAMOLA        2016         ADEGBORO                     ACTIVE
# 13       SANCHITA        2016         AGGARWAL                     ACTIVE
# 14         YAMIRA        2016          AGUILAR                     ACTIVE
# 15         JORDAN        2016          AGUIRRE                     CEASED
# 16        ARTEMIS        2016          AHMETAJ                     ACTIVE
# 17          HELEN        2016              AHN                     ACTIVE
# 18         SANDRA        2016          ALCAIDE                     CEASED
# 19         DANIEL        2016        ALCANTARA                     ACTIVE
# 20           ERIN        2016        ALEXANDER                     ACTIVE
# 21           PAUL        2016           ALFLEN                     ACTIVE
# 22      SHEHARYAR        2016              ALI                     ACTIVE
# 23          SYEED        2016              ALI                     ACTIVE
# 24        JEFFREY        2016     AL-KAABAH II                     ACTIVE
# 25          ABEER        2016       ALKHAFAJEE                     CEASED
# 26        SHAIMAA        2016       ALKHAFAJEE                     ACTIVE
# 27        BENNETT        2016            ALLEN                     ACTIVE
# 28         ROBERT        2016            ALLEN                     ACTIVE
# 29        MARISOL        2016  ALMONTE-ALMANZA                     ACTIVE
# ...           ...         ...              ...                        ...
# 49970      SELENA        2016           PALMER                     ACTIVE
# 49971   SHANIELLE        2016           PALMER                     ACTIVE
# 49972     VINCENT        2016           PALMER                     ACTIVE
# 49973     WILLIAM        2016           PALMER                     CEASED
# 49974     WILLIAM        2016           PALMER                     ACTIVE
# 49975      THOMAS        2016        PALMER JR                   ON LEAVE
# 49976       CHRIS        2016          PALMERI                     ACTIVE
# 49977      JOSEPH        2016          PALMERI                     ACTIVE
# 49978     MATTHEW        2016        PALMERINI                     ACTIVE
# 49979        JOHN        2016          PALMESE                     CEASED
# 49980      JOSEPH        2016          PALMESE                     ACTIVE
# 49981     MICHAEL        2016          PALMESE                     ACTIVE
# 49982       SCOTT        2016          PALMESE                     ACTIVE
# 49983       COSMO        2016         PALMIERI                     CEASED
# 49984    CRISTINA        2016         PALMIERI                     ACTIVE
# 49985        DAWN        2016         PALMIERI                     CEASED
# 49986     DOROTHY        2016         PALMIERI                     CEASED
# 49987        JOHN        2016         PALMIERI                     CEASED
# 49988     MATTHEW        2016         PALMIERI                     ACTIVE
# 49989      REGINA        2016         PALMIERI                     CEASED
# 49990      DENISE        2016       PALMINTERI                     CEASED
# 49991        PAUL        2016       PALMINTERI                     ACTIVE
# 49992        RYAN        2016       PALMINTERI                     ACTIVE
# 49993      PIERRE        2016        PALMIOTTI                     CEASED
# 49994      JOSEPH        2016        PALMIOTTO                     ACTIVE
# 49995    GENEVIEV        2016          PALOMBA                     ACTIVE
# 49996     MICHAEL        2016          PALOMBO                     ACTIVE
# 49997        PAUL        2016          PALOMBO                     CEASED
# 49998       RALPH        2016          PALOMBO                     ACTIVE
# 49999       OSCAR        2016         PALOMINO                     ACTIVE
#
#       mid_init ot_hours   pay_basis regular_gross_paid regular_hours  \
# 0            E     2.25   per Annum           47166.03       1830.00
# 1          NaN     0.00   per Annum          119042.50       1831.00
# 2            L     1.00   per Annum           27452.62       1181.68
# 3            J     0.00   per Annum          115104.57       1831.00
# 4          NaN     0.00    per Hour            3500.00          0.00
# 5          NaN     0.00   per Annum           71967.34       1831.00
# 6            D     0.00   per Annum           87614.01       1831.00
# 7          NaN     0.00    per Hour             500.00          0.00
# 8            J     0.00   per Annum            9507.15        349.00
# 9            E     0.00   per Annum           64357.12       1830.00
# 10           J     0.00   per Annum            6073.13        200.70
# 11         NaN     0.00   per Annum           39895.79       1830.00
# 12           F     0.00   per Annum           65909.63       1830.00
# 13           J     0.00   per Annum          111806.82       1831.00
# 14         NaN   716.25   per Annum           51890.77       1830.00
# 15         NaN     0.00    per Hour            3500.00          0.00
# 16         NaN    51.75   per Annum           40052.01       1830.00
# 17           H     0.00   per Annum           59023.02       1076.00
# 18         NaN     0.00    per Hour            3500.00          0.00
# 19         NaN     0.00   per Annum           39866.21       1830.00
# 20           L     0.00   per Annum           64498.36       1509.00
# 21           R   408.75     per Day          139072.14       1830.00
# 22         NaN     0.00    per Hour            1000.00          0.00
# 23           A   173.75     per Day           56602.00       1830.00
# 24           I   276.50   per Annum           46271.84       1829.75
# 25           K     1.00   per Annum            4661.03         38.10
# 26         NaN     0.00   per Annum           35765.73       1830.00
# 27           L     0.00   per Annum           64895.59       1830.00
# 28           K     0.00   per Annum           55411.18       1830.00
# 29         NaN     0.75   per Annum           26422.22       1383.00
# ...        ...      ...         ...                ...           ...
# 49970        M    44.25   per Annum           46174.73       2091.42
# 49971        A   593.00   per Annum           41886.35       2091.42
# 49972        M   261.28   per Annum           84324.25       2091.42
# 49973        E     0.00   per Annum              14.37          0.00
# 49974        G   356.00   per Annum           84251.63       2091.42
# 49975        J     0.00   per Annum          100022.63       2091.42
# 49976      NaN   313.85   per Annum           84324.25       2091.42
# 49977        I   136.00   per Annum           59201.58       2091.42
# 49978        L   289.92   per Annum           83933.75       2091.42
# 49979        T    67.53   per Annum           38607.43       1862.87
# 49980        J   110.15   per Annum           43336.90       2091.42
# 49981        A   145.00   per Annum           84324.25       2091.42
# 49982        T     0.00   per Annum           18484.76        988.57
# 49983        J    68.33   per Annum          103076.98       1742.85
# 49984      NaN   179.17   per Annum           53969.46       2091.42
# 49985        M     0.00   per Annum           18475.75        493.32
# 49986        B   194.40   per Annum           95400.41       1394.28
# 49987        L     0.00   per Annum               0.00          0.00
# 49988        C   466.62   per Annum           70403.18       2091.42
# 49989      NaN     0.00   per Annum            1515.30          0.00
# 49990        E     0.00   per Annum               0.00          0.00
# 49991        G   473.53   per Annum           59085.02       2091.42
# 49992        M   162.00   per Annum           44097.46       2091.42
# 49993        A     0.00   per Annum             572.44          0.00
# 49994        A   399.33   per Annum          106479.51       2091.42
# 49995        T     0.00   per Annum           37903.14       1830.00
# 49996        L   117.67   per Annum           84324.25       2091.42
# 49997      NaN     0.00   per Annum               0.00          0.00
# 49998      NaN     0.00   per Annum           37414.88       1830.00
# 49999      NaN   244.37   per Annum           83933.75       2091.42
#
#                                        title_description total_ot_paid  \
# 0      COMMUNITY ASSOCIATE                           ...         57.28
# 1      ADMINISTRATIVE ACCOUNTANT                     ...          0.00
# 2      COMMUNITY ASSOCIATE                           ...         21.34
# 3      COMPUTER SYSTEMS MANAGER                      ...          0.00
# 4      COLLEGE AIDE                                  ...          0.00
# 5      ASSISTANT DISTRICT ATTORNEY                   ...          0.00
# 6      ASSISTANT DISTRICT ATTORNEY                   ...          0.00
# 7      COLLEGE AIDE                                  ...          0.00
# 8      COMMUNITY ASSOCIATE                           ...          0.00
# 9                 PRINCIPAL ADMINISTRATIVE ASSOCIATE              0.00
# 10     COMMUNITY ASSOCIATE                           ...          0.00
# 11     COMMUNITY ASSOCIATE                           ...          0.00
# 12     COMMUNITY COORDINATOR                         ...          0.00
# 13     PRINCIPAL ACCOUNTANT INVESTIGATOR             ...          0.00
# 14     COMMUNITY ASSOCIATE                           ...      25943.55
# 15     COLLEGE AIDE                                  ...          0.00
# 16     COMMUNITY ASSISTANT                           ...       1413.40
# 17     ASSISTANT DISTRICT ATTORNEY                   ...          0.00
# 18     COLLEGE AIDE                                  ...          0.00
# 19     COMMUNITY ASSOCIATE                           ...          0.00
# 20     ASSISTANT DISTRICT ATTORNEY                   ...          0.00
# 21     CARPENTER                                     ...      50546.28
# 22     COLLEGE AIDE                                  ...          0.00
# 23     ELECTRICIAN'S HELPER                          ...       8991.82
# 24     COMMUNITY ASSOCIATE                           ...       7757.06
# 25     COMMUNITY ASSOCIATE                           ...        169.90
# 26     COMMUNITY ASSISTANT                           ...          0.00
# 27     COMMUNITY COORDINATOR                         ...          0.00
# 28          CLERICAL ASSOCIATE                                    0.00
# 29     COMMUNITY ASSOCIATE                           ...         15.41
# ...                                                  ...           ...
# 49970                                SCHOOL SAFETY AGENT       1143.36
# 49971                          TRAFFIC ENFORCEMENT AGENT      18481.54
# 49972                                     POLICE OFFICER      16567.29
# 49973                                     POLICE OFFICER          0.00
# 49974                                     POLICE OFFICER      25358.29
# 49975                                         LIEUTENANT         55.27
# 49976                                     POLICE OFFICER      21233.14
# 49977                                     POLICE OFFICER       5092.19
# 49978                                     POLICE OFFICER      23203.18
# 49979                                     POLICE OFFICER       2249.98
# 49980                                     POLICE OFFICER       3496.86
# 49981                                     POLICE OFFICER      11675.40
# 49982                                     POLICE OFFICER          0.00
# 49983                                         LIEUTENANT       7185.07
# 49984                                     POLICE OFFICER       7024.45
# 49985                                SCHOOL SAFETY AGENT        802.50
# 49986                POLICE OFFICER D/A DETECTIVE 2ND GR      18236.79
# 49987                                         LIEUTENANT          0.00
# 49988                                     POLICE OFFICER      26717.51
# 49989                                     POLICE OFFICER         89.71
# 49990                                    P.O. DA DET GR3          0.00
# 49991                                     POLICE OFFICER      20094.90
# 49992                                     POLICE OFFICER       4626.96
# 49993                                     POLICE OFFICER        216.93
# 49994                                         LIEUTENANT      32645.02
# 49995                         POLICE ADMINISTRATIVE AIDE          0.00
# 49996                                     POLICE OFFICER       9874.96
# 49997                POLICE OFFICER D/A DETECTIVE 2ND GR          0.00
# 49998                         POLICE ADMINISTRATIVE AIDE          0.00
# 49999                                     POLICE OFFICER      22913.54
#
#       total_other_pay work_location_borough
# 0                0.00         MANHATTAN
# 1                0.00         MANHATTAN
# 2               33.00         MANHATTAN
# 3                0.00         MANHATTAN
# 4                0.00         MANHATTAN
# 5                0.00         MANHATTAN
# 6              750.00         MANHATTAN
# 7                0.00         MANHATTAN
# 8                0.00         MANHATTAN
# 9             3824.72         MANHATTAN
# 10               8.25         MANHATTAN
# 11              74.25         MANHATTAN
# 12              33.00         MANHATTAN
# 13             500.00         MANHATTAN
# 14             747.93         MANHATTAN
# 15               0.00         MANHATTAN
# 16             526.11         MANHATTAN
# 17               0.00         MANHATTAN
# 18               0.00         MANHATTAN
# 19               0.00         MANHATTAN
# 20            1750.00         MANHATTAN
# 21            5060.37         MANHATTAN
# 22               0.00         MANHATTAN
# 23            7424.72         MANHATTAN
# 24             755.84         MANHATTAN
# 25              94.40         MANHATTAN
# 26               0.00         MANHATTAN
# 27              99.50         MANHATTAN
# 28            4424.50         MANHATTAN
# 29              24.75         MANHATTAN
# ...               ...                   ...
# 49970         1001.78             MANHATTAN
# 49971         3072.52             MANHATTAN
# 49972        13125.99              RICHMOND
# 49973            0.00             MANHATTAN
# 49974        17016.10              RICHMOND
# 49975        15291.80             MANHATTAN
# 49976        19202.84             MANHATTAN
# 49977         5284.23             MANHATTAN
# 49978        15761.20                 BRONX
# 49979         3629.91             MANHATTAN
# 49980         5934.76                QUEENS
# 49981        18823.03             MANHATTAN
# 49982            0.00             MANHATTAN
# 49983         3580.87             MANHATTAN
# 49984         4695.04                QUEENS
# 49985         1486.50             MANHATTAN
# 49986        12655.63             MANHATTAN
# 49987          128.60             MANHATTAN
# 49988        13351.94              BROOKLYN
# 49989          297.85             MANHATTAN
# 49990           40.50             MANHATTAN
# 49991         6313.97              BROOKLYN
# 49992         7506.25              BROOKLYN
# 49993          124.54             MANHATTAN
# 49994        15653.39              RICHMOND
# 49995         4424.50             MANHATTAN
# 49996        21765.80             MANHATTAN
# 49997           65.80             MANHATTAN
# 49998         2817.13             MANHATTAN
# 49999        17963.32              BROOKLYN
#
# [50000 rows x 16 columns]

# %%
for i in range(1,24):
    results = client.get(identified, limit=50000, offset=50000*i)
    df.append(results)

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
results = client.get(identified, limit=50000, offset=50000*24)

# %%
results
# Out:
# [{'agency_name': 'BOARD OF ELECTION POLL WORKERS',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2010-01-01T00:00:00',
#   'title_description': 'ELECTION WORKER                                             ',
#   'last_name': 'PARKER',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '780.00',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2014',
#   'total_ot_paid': '0.00',
#   'first_name': 'ROBERT'},
#  {'agency_name': 'BOARD OF ELECTION POLL WORKERS',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2010-01-01T00:00:00',
#   'title_description': 'ELECTION WORKER                                             ',
#   'last_name': 'PARKER',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '303.00',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2014',
#   'total_ot_paid': '0.00',
#   'mid_init': 'A',
#   'first_name': 'SHARON'},
#  {'agency_name': 'BOARD OF ELECTION POLL WORKERS',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2010-01-01T00:00:00',
#   'title_description': 'ELECTION WORKER                                             ',
#   'last_name': 'PARKER',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '493.29',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2014',
#   'total_ot_paid': '0.00',
#   'mid_init': 'N',
#   'first_name': 'SHAUNEILLE'},
#  {'agency_name': 'BOARD OF ELECTION POLL WORKERS',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2010-01-01T00:00:00',
#   'title_description': 'ELECTION WORKER                                             ',
#   'last_name': 'PARKER',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '300.00',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2014',
#   'total_ot_paid': '0.00',
#   'first_name': 'VERNICE'},
#  {'agency_name': 'BOARD OF ELECTION POLL WORKERS',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2010-01-01T00:00:00',
#   'title_description': 'ELECTION WORKER                                             ',
#   'last_name': 'PARKERSON',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '300.00',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2014',
#   'total_ot_paid': '0.00',
#   'first_name': 'JEAN'},
#  {'agency_name': 'BOARD OF ELECTION POLL WORKERS',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2010-01-01T00:00:00',
#   'title_description': 'ELECTION WORKER                                             ',
#   'last_name': 'PARKINSON',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '775.00',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2014',
#   'total_ot_paid': '0.00',
#   'mid_init': 'O',
#   'first_name': 'ROLAND'},
#  {'agency_name': 'BOARD OF ELECTION POLL WORKERS',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2010-01-01T00:00:00',
#   'title_description': 'ELECTION WORKER                                             ',
#   'last_name': 'PARKS',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '1100.00',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2014',
#   'total_ot_paid': '0.00',
#   'first_name': 'DIANNA'},
#  {'agency_name': 'BOARD OF ELECTION POLL WORKERS',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2010-01-01T00:00:00',
#   'title_description': 'ELECTION WORKER                                             ',
#   'last_name': 'PARMIGIANI',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '660.00',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2014',
#   'total_ot_paid': '0.00',
#   'mid_init': 'J',
#   'first_name': 'JOHN'},
#  {'agency_name': 'BOARD OF ELECTION POLL WORKERS',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2010-01-01T00:00:00',
#   'title_description': 'ELECTION WORKER                                             ',
#   'last_name': 'PARMIGIANI',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '778.00',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2014',
#   'total_ot_paid': '0.00',
#   'first_name': 'ROLINDA'},
#  {'agency_name': 'BOARD OF ELECTION POLL WORKERS',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2010-01-01T00:00:00',
#   'title_description': 'ELECTION WORKER                                             ',
#   'last_name': 'PARNES',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '784.00',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2014',
#   'total_ot_paid': '0.00',
#   'first_name': 'BELLA'},
#  {'agency_name': 'BOARD OF ELECTION POLL WORKERS',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2010-01-01T00:00:00',
#   'title_description': 'ELECTION WORKER                                             ',
#   'last_name': 'PARRA',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '775.00',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2014',
#   'total_ot_paid': '0.00',
#   'mid_init': 'E',
#   'first_name': 'MARIA'},
#  {'agency_name': 'BOARD OF ELECTION POLL WORKERS',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2010-01-01T00:00:00',
#   'title_description': 'ELECTION WORKER                                             ',
#   'last_name': 'PARRILLA',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '778.00',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2014',
#   'total_ot_paid': '0.00',
#   'mid_init': 'L',
#   'first_name': 'BEATRICE'},
#  {'agency_name': 'BOARD OF ELECTION POLL WORKERS',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2010-01-01T00:00:00',
#   'title_description': 'ELECTION WORKER                                             ',
#   'last_name': 'PARRIS',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '775.00',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2014',
#   'total_ot_paid': '0.00',
#   'mid_init': 'M',
#   'first_name': 'BERNICE'},
#  {'agency_name': 'BOARD OF ELECTION POLL WORKERS',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2010-01-01T00:00:00',
#   'title_description': 'ELECTION WORKER                                             ',
#   'last_name': 'PARRIS',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '781.00',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2014',
#   'total_ot_paid': '0.00',
#   'mid_init': 'R',
#   'first_name': 'JUDITH'},
#  {'agency_name': 'BOARD OF ELECTION POLL WORKERS',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2010-01-01T00:00:00',
#   'title_description': 'ELECTION WORKER                                             ',
#   'last_name': 'PARRIS',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '778.00',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2014',
#   'total_ot_paid': '0.00',
#   'mid_init': 'A',
#   'first_name': 'RONALD'},
#  {'agency_name': 'BOARD OF ELECTION POLL WORKERS',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2010-01-01T00:00:00',
#   'title_description': 'ELECTION WORKER                                             ',
#   'last_name': 'PARRIS',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '660.00',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2014',
#   'total_ot_paid': '0.00',
#   'mid_init': 'O',
#   'first_name': 'RUDOLPH'},
#  {'agency_name': 'BOARD OF ELECTION POLL WORKERS',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2010-01-01T00:00:00',
#   'title_description': 'ELECTION WORKER                                             ',
#   'last_name': 'PARRIS',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '775.00',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2014',
#   'total_ot_paid': '0.00',
#   'first_name': 'SHIRLEY'},
#  {'agency_name': 'BOARD OF ELECTION POLL WORKERS',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2010-01-01T00:00:00',
#   'title_description': 'ELECTION WORKER                                             ',
#   'last_name': 'PARRIS JR',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '300.00',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2014',
#   'total_ot_paid': '0.00',
#   'mid_init': 'W',
#   'first_name': 'JOHN'},
#  {'agency_name': 'BOARD OF ELECTION POLL WORKERS',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2010-01-01T00:00:00',
#   'title_description': 'ELECTION WORKER                                             ',
#   'last_name': 'PARRISH',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '784.00',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2014',
#   'total_ot_paid': '0.00',
#   'first_name': 'NATHANIEL'},
#  {'agency_name': 'BOARD OF ELECTION POLL WORKERS',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2010-01-01T00:00:00',
#   'title_description': 'ELECTION WORKER                                             ',
#   'last_name': 'PARTNOW',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '784.00',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2014',
#   'total_ot_paid': '0.00',
#   'mid_init': 'N',
#   'first_name': 'IRA'},
#  {'agency_name': 'BOARD OF ELECTION POLL WORKERS',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2010-01-01T00:00:00',
#   'title_description': 'ELECTION WORKER                                             ',
#   'last_name': 'PARTNOW',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '775.00',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2014',
#   'total_ot_paid': '0.00',
#   'first_name': 'ROCHELLE'},
#  {'agency_name': 'BOARD OF ELECTION POLL WORKERS',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2010-01-01T00:00:00',
#   'title_description': 'ELECTION WORKER                                             ',
#   'last_name': 'PARTSINEVELOS',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '778.00',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2014',
#   'total_ot_paid': '0.00',
#   'first_name': 'MARIA'},
#  {'agency_name': 'BOARD OF ELECTION POLL WORKERS',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2010-01-01T00:00:00',
#   'title_description': 'ELECTION WORKER                                             ',
#   'last_name': 'PARVATI',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '500.00',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2014',
#   'total_ot_paid': '0.00',
#   'first_name': 'UNKNOWN'},
#  {'agency_name': 'BOARD OF ELECTION POLL WORKERS',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2010-01-01T00:00:00',
#   'title_description': 'ELECTION WORKER                                             ',
#   'last_name': 'PARVIN',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '660.00',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2014',
#   'total_ot_paid': '0.00',
#   'first_name': 'MAHMUDA'},
#  {'agency_name': 'BOARD OF ELECTION POLL WORKERS',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2010-01-01T00:00:00',
#   'title_description': 'ELECTION WORKER                                             ',
#   'last_name': 'PASCAL',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '775.00',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2014',
#   'total_ot_paid': '0.00',
#   'mid_init': 'D',
#   'first_name': 'CATHERINE'},
#  {'agency_name': 'BOARD OF ELECTION POLL WORKERS',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2010-01-01T00:00:00',
#   'title_description': 'ELECTION WORKER                                             ',
#   'last_name': 'PASCAL',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '775.00',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2014',
#   'total_ot_paid': '0.00',
#   'mid_init': 'A',
#   'first_name': 'NEGUST'},
#  {'agency_name': 'BOARD OF ELECTION POLL WORKERS',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2010-01-01T00:00:00',
#   'title_description': 'ELECTION WORKER                                             ',
#   'last_name': 'PASCAL-SANDERS',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '775.00',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2014',
#   'total_ot_paid': '0.00',
#   'mid_init': 'S',
#   'first_name': 'VERNESTINE'},
#  {'agency_name': 'BOARD OF ELECTION POLL WORKERS',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2010-01-01T00:00:00',
#   'title_description': 'ELECTION WORKER                                             ',
#   'last_name': 'PASCALL',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '780.00',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2014',
#   'total_ot_paid': '0.00',
#   'mid_init': 'R',
#   'first_name': 'ELAINE'},
#  {'agency_name': 'BOARD OF ELECTION POLL WORKERS',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2010-01-01T00:00:00',
#   'title_description': 'ELECTION WORKER                                             ',
#   'last_name': 'PASCARELLI',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '780.00',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2014',
#   'total_ot_paid': '0.00',
#   'first_name': 'NICK'},
#  {'agency_name': 'BOARD OF ELECTION POLL WORKERS',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2010-01-01T00:00:00',
#   'title_description': 'ELECTION WORKER                                             ',
#   'last_name': 'PASHKOVSKAYA',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '500.00',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2014',
#   'total_ot_paid': '0.00',
#   'first_name': 'LIDIA'},
#  {'agency_name': 'BOARD OF ELECTION POLL WORKERS',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2010-01-01T00:00:00',
#   'title_description': 'ELECTION WORKER                                             ',
#   'last_name': 'PASKVITOVSKAYA',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '778.00',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2014',
#   'total_ot_paid': '0.00',
#   'first_name': 'LINA'},
#  {'agency_name': 'BOARD OF ELECTION POLL WORKERS',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2010-01-01T00:00:00',
#   'title_description': 'ELECTION WORKER                                             ',
#   'last_name': 'PASS',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '778.00',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2014',
#   'total_ot_paid': '0.00',
#   'mid_init': 'M',
#   'first_name': 'ZELDA'},
#  {'agency_name': 'BOARD OF ELECTION POLL WORKERS',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2010-01-01T00:00:00',
#   'title_description': 'ELECTION WORKER                                             ',
#   'last_name': 'PASTELAS',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '303.00',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2014',
#   'total_ot_paid': '0.00',
#   'first_name': 'ALEXANDRIA'},
#  {'agency_name': 'BOARD OF ELECTION POLL WORKERS',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2010-01-01T00:00:00',
#   'title_description': 'ELECTION WORKER                                             ',
#   'last_name': 'PASTENA',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '781.00',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2014',
#   'total_ot_paid': '0.00',
#   'first_name': 'RALPH'},
#  {'agency_name': 'BOARD OF ELECTION POLL WORKERS',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2010-01-01T00:00:00',
#   'title_description': 'ELECTION WORKER                                             ',
#   'last_name': 'PATANE',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '781.00',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2014',
#   'total_ot_paid': '0.00',
#   'mid_init': 'M',
#   'first_name': 'JOYCE'},
#  {'agency_name': 'BOARD OF ELECTION POLL WORKERS',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2010-01-01T00:00:00',
#   'title_description': 'ELECTION WORKER                                             ',
#   'last_name': 'PATEL',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '778.00',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2014',
#   'total_ot_paid': '0.00',
#   'mid_init': 'N',
#   'first_name': 'ANANDI'},
#  {'agency_name': 'BOARD OF ELECTION POLL WORKERS',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2010-01-01T00:00:00',
#   'title_description': 'ELECTION WORKER                                             ',
#   'last_name': 'PATEL',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '778.00',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2014',
#   'total_ot_paid': '0.00',
#   'mid_init': 'M',
#   'first_name': 'CHANDU'},
#  {'agency_name': 'BOARD OF ELECTION POLL WORKERS',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2010-01-01T00:00:00',
#   'title_description': 'ELECTION WORKER                                             ',
#   'last_name': 'PATEL',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '1100.00',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2014',
#   'total_ot_paid': '0.00',
#   'mid_init': 'V',
#   'first_name': 'DAMINI'},
#  {'agency_name': 'BOARD OF ELECTION POLL WORKERS',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2010-01-01T00:00:00',
#   'title_description': 'ELECTION WORKER                                             ',
#   'last_name': 'PATEL',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '775.00',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2014',
#   'total_ot_paid': '0.00',
#   'first_name': 'JASHBHAI'},
#  {'agency_name': 'BOARD OF ELECTION POLL WORKERS',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2010-01-01T00:00:00',
#   'title_description': 'ELECTION WORKER                                             ',
#   'last_name': 'PATEL',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '775.00',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2014',
#   'total_ot_paid': '0.00',
#   'mid_init': 'S',
#   'first_name': 'JAYA'},
#  {'agency_name': 'BOARD OF ELECTION POLL WORKERS',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2010-01-01T00:00:00',
#   'title_description': 'ELECTION WORKER                                             ',
#   'last_name': 'PATEL',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '775.00',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2014',
#   'total_ot_paid': '0.00',
#   'mid_init': 'F',
#   'first_name': 'JAYANTILAL'},
#  {'agency_name': 'BOARD OF ELECTION POLL WORKERS',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2010-01-01T00:00:00',
#   'title_description': 'ELECTION WORKER                                             ',
#   'last_name': 'PATEL',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '775.00',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2014',
#   'total_ot_paid': '0.00',
#   'mid_init': 'M',
#   'first_name': 'KIRIT'},
#  {'agency_name': 'BOARD OF ELECTION POLL WORKERS',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2010-01-01T00:00:00',
#   'title_description': 'ELECTION WORKER                                             ',
#   'last_name': 'PATEL',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '775.00',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2014',
#   'total_ot_paid': '0.00',
#   'mid_init': 'P',
#   'first_name': 'MINAXIBEN'},
#  {'agency_name': 'BOARD OF ELECTION POLL WORKERS',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2010-01-01T00:00:00',
#   'title_description': 'ELECTION WORKER                                             ',
#   'last_name': 'PATEL',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '775.00',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2014',
#   'total_ot_paid': '0.00',
#   'mid_init': 'P',
#   'first_name': 'MITA'},
#  {'agency_name': 'BOARD OF ELECTION POLL WORKERS',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2010-01-01T00:00:00',
#   'title_description': 'ELECTION WORKER                                             ',
#   'last_name': 'PATEL',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '500.00',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2014',
#   'total_ot_paid': '0.00',
#   'mid_init': 'P',
#   'first_name': 'NIKI'},
#  {'agency_name': 'BOARD OF ELECTION POLL WORKERS',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2010-01-01T00:00:00',
#   'title_description': 'ELECTION WORKER                                             ',
#   'last_name': 'PATEL',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '425.00',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2014',
#   'total_ot_paid': '0.00',
#   'first_name': 'NITABEN'},
#  {'agency_name': 'BOARD OF ELECTION POLL WORKERS',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2010-01-01T00:00:00',
#   'title_description': 'ELECTION WORKER                                             ',
#   'last_name': 'PATEL',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '775.00',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2014',
#   'total_ot_paid': '0.00',
#   'mid_init': 'K',
#   'first_name': 'RINA'},
#  {'agency_name': 'BOARD OF ELECTION POLL WORKERS',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2010-01-01T00:00:00',
#   'title_description': 'ELECTION WORKER                                             ',
#   'last_name': 'PATEL',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '225.00',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2014',
#   'total_ot_paid': '0.00',
#   'first_name': 'SHIRISH'},
#  {'agency_name': 'BOARD OF ELECTION POLL WORKERS',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2010-01-01T00:00:00',
#   'title_description': 'ELECTION WORKER                                             ',
#   'last_name': 'PATEL',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '775.00',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2014',
#   'total_ot_paid': '0.00',
#   'mid_init': 'N',
#   'first_name': 'VASUMATI'},
#  {'agency_name': 'BOARD OF ELECTION POLL WORKERS',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2010-01-01T00:00:00',
#   'title_description': 'ELECTION WORKER                                             ',
#   'last_name': 'PATEL',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '660.00',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2014',
#   'total_ot_paid': '0.00',
#   'mid_init': 'R',
#   'first_name': 'VEENA'},
#  {'agency_name': 'BOARD OF ELECTION POLL WORKERS',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2010-01-01T00:00:00',
#   'title_description': 'ELECTION WORKER                                             ',
#   'last_name': 'PATENT',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '778.00',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2014',
#   'total_ot_paid': '0.00',
#   'first_name': 'TATYANA'},
#  {'agency_name': 'BOARD OF ELECTION POLL WORKERS',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2010-01-01T00:00:00',
#   'title_description': 'ELECTION WORKER                                             ',
#   'last_name': 'PATINO',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '665.00',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2014',
#   'total_ot_paid': '0.00',
#   'first_name': 'JAIR'},
#  {'agency_name': 'BOARD OF ELECTION POLL WORKERS',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2010-01-01T00:00:00',
#   'title_description': 'ELECTION WORKER                                             ',
#   'last_name': 'PATOIR-SINGH',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '780.00',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2014',
#   'total_ot_paid': '0.00',
#   'first_name': 'BARBARA'},
#  {'agency_name': 'BOARD OF ELECTION POLL WORKERS',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2010-01-01T00:00:00',
#   'title_description': 'ELECTION WORKER                                             ',
#   'last_name': 'PATRICE',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '300.00',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2014',
#   'total_ot_paid': '0.00',
#   'mid_init': 'M',
#   'first_name': 'MIC-ARLEM'},
#  {'agency_name': 'BOARD OF ELECTION POLL WORKERS',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2010-01-01T00:00:00',
#   'title_description': 'ELECTION WORKER                                             ',
#   'last_name': 'PATRICE',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '500.00',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2014',
#   'total_ot_paid': '0.00',
#   'mid_init': 'L',
#   'first_name': 'VINCY'},
#  {'agency_name': 'BOARD OF ELECTION POLL WORKERS',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2010-01-01T00:00:00',
#   'title_description': 'ELECTION WORKER                                             ',
#   'last_name': 'PATRICK',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '775.00',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2014',
#   'total_ot_paid': '0.00',
#   'mid_init': 'A',
#   'first_name': 'GLORIA'},
#  {'agency_name': 'BOARD OF ELECTION POLL WORKERS',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2010-01-01T00:00:00',
#   'title_description': 'ELECTION WORKER                                             ',
#   'last_name': 'PATSALO',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '500.00',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2014',
#   'total_ot_paid': '0.00',
#   'first_name': 'NATALIYA'},
#  {'agency_name': 'BOARD OF ELECTION POLL WORKERS',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2010-01-01T00:00:00',
#   'title_description': 'ELECTION WORKER                                             ',
#   'last_name': 'PATSIS',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '775.00',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2014',
#   'total_ot_paid': '0.00',
#   'mid_init': 'J',
#   'first_name': 'ALEXANDRA'},
#  {'agency_name': 'BOARD OF ELECTION POLL WORKERS',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2010-01-01T00:00:00',
#   'title_description': 'ELECTION WORKER                                             ',
#   'last_name': 'PATT',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '775.00',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2014',
#   'total_ot_paid': '0.00',
#   'mid_init': 'J',
#   'first_name': 'MARCIA'},
#  {'agency_name': 'BOARD OF ELECTION POLL WORKERS',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2010-01-01T00:00:00',
#   'title_description': 'ELECTION WORKER                                             ',
#   'last_name': 'PATTERSON',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '775.00',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2014',
#   'total_ot_paid': '0.00',
#   'first_name': 'ALICE'},
#  {'agency_name': 'BOARD OF ELECTION POLL WORKERS',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2010-01-01T00:00:00',
#   'title_description': 'ELECTION WORKER                                             ',
#   'last_name': 'PATTERSON',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '300.00',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2014',
#   'total_ot_paid': '0.00',
#   'mid_init': 'A',
#   'first_name': 'BEVERLY'},
#  {'agency_name': 'BOARD OF ELECTION POLL WORKERS',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2010-01-01T00:00:00',
#   'title_description': 'ELECTION WORKER                                             ',
#   'last_name': 'PATTERSON',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '784.00',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2014',
#   'total_ot_paid': '0.00',
#   'first_name': 'CORA'},
#  {'agency_name': 'BOARD OF ELECTION POLL WORKERS',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2010-01-01T00:00:00',
#   'title_description': 'ELECTION WORKER                                             ',
#   'last_name': 'PATTERSON',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '300.00',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2014',
#   'total_ot_paid': '0.00',
#   'first_name': 'CORINE'},
#  {'agency_name': 'BOARD OF ELECTION POLL WORKERS',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2010-01-01T00:00:00',
#   'title_description': 'ELECTION WORKER                                             ',
#   'last_name': 'PATTERSON',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '425.00',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2014',
#   'total_ot_paid': '0.00',
#   'mid_init': 'M',
#   'first_name': 'DIANE'},
#  {'agency_name': 'BOARD OF ELECTION POLL WORKERS',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2010-01-01T00:00:00',
#   'title_description': 'ELECTION WORKER                                             ',
#   'last_name': 'PATTERSON',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '775.00',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2014',
#   'total_ot_paid': '0.00',
#   'mid_init': 'D',
#   'first_name': 'DOREEN'},
#  {'agency_name': 'BOARD OF ELECTION POLL WORKERS',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2010-01-01T00:00:00',
#   'title_description': 'ELECTION WORKER                                             ',
#   'last_name': 'PATTERSON',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '273.29',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2014',
#   'total_ot_paid': '0.00',
#   'mid_init': 'B',
#   'first_name': 'ESTEBAN'},
#  {'agency_name': 'BOARD OF ELECTION POLL WORKERS',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2010-01-01T00:00:00',
#   'title_description': 'ELECTION WORKER                                             ',
#   'last_name': 'PATTERSON',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '775.00',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2014',
#   'total_ot_paid': '0.00',
#   'mid_init': 'L',
#   'first_name': 'LIZA'},
#  {'agency_name': 'BOARD OF ELECTION POLL WORKERS',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2010-01-01T00:00:00',
#   'title_description': 'ELECTION WORKER                                             ',
#   'last_name': 'PATTERSON',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '778.00',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2014',
#   'total_ot_paid': '0.00',
#   'first_name': 'MARY'},
#  {'agency_name': 'BOARD OF ELECTION POLL WORKERS',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2010-01-01T00:00:00',
#   'title_description': 'ELECTION WORKER                                             ',
#   'last_name': 'PATTERSON',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '500.00',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2014',
#   'total_ot_paid': '0.00',
#   'first_name': 'NEIL'},
#  {'agency_name': 'BOARD OF ELECTION POLL WORKERS',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2010-01-01T00:00:00',
#   'title_description': 'ELECTION WORKER                                             ',
#   'last_name': 'PATTERSON',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '775.00',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2014',
#   'total_ot_paid': '0.00',
#   'mid_init': 'G',
#   'first_name': 'NEVILLE'},
#  {'agency_name': 'BOARD OF ELECTION POLL WORKERS',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2010-01-01T00:00:00',
#   'title_description': 'ELECTION WORKER                                             ',
#   'last_name': 'PATTERSON',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '780.00',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2014',
#   'total_ot_paid': '0.00',
#   'first_name': 'PATRICIA'},
#  {'agency_name': 'BOARD OF ELECTION POLL WORKERS',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2010-01-01T00:00:00',
#   'title_description': 'ELECTION WORKER                                             ',
#   'last_name': 'PATTERSON',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '778.00',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2014',
#   'total_ot_paid': '0.00',
#   'mid_init': 'F',
#   'first_name': 'PATRICIA'},
#  {'agency_name': 'BOARD OF ELECTION POLL WORKERS',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2010-01-01T00:00:00',
#   'title_description': 'ELECTION WORKER                                             ',
#   'last_name': 'PATTERSON',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '789.00',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2014',
#   'total_ot_paid': '0.00',
#   'first_name': 'PENELOPE'},
#  {'agency_name': 'BOARD OF ELECTION POLL WORKERS',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2010-01-01T00:00:00',
#   'title_description': 'ELECTION WORKER                                             ',
#   'last_name': 'PATTERSON',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '778.00',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2014',
#   'total_ot_paid': '0.00',
#   'first_name': 'ROXANNE'},
#  {'agency_name': 'BOARD OF ELECTION POLL WORKERS',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2010-01-01T00:00:00',
#   'title_description': 'ELECTION WORKER                                             ',
#   'last_name': 'PATTERSON',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '754.96',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2014',
#   'total_ot_paid': '0.00',
#   'first_name': 'SERETTA'},
#  {'agency_name': 'BOARD OF ELECTION POLL WORKERS',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2010-01-01T00:00:00',
#   'title_description': 'ELECTION WORKER                                             ',
#   'last_name': 'PATTERSON',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '500.00',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2014',
#   'total_ot_paid': '0.00',
#   'first_name': 'SHEILA'},
#  {'agency_name': 'BOARD OF ELECTION POLL WORKERS',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2010-01-01T00:00:00',
#   'title_description': 'ELECTION WORKER                                             ',
#   'last_name': 'PATTERSON',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '748.29',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2014',
#   'total_ot_paid': '0.00',
#   'mid_init': 'B',
#   'first_name': 'SHELLY'},
#  {'agency_name': 'BOARD OF ELECTION POLL WORKERS',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2010-01-01T00:00:00',
#   'title_description': 'ELECTION WORKER                                             ',
#   'last_name': 'PATTERSON',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '500.00',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2014',
#   'total_ot_paid': '0.00',
#   'mid_init': 'V',
#   'first_name': 'SHERILL'},
#  {'agency_name': 'BOARD OF ELECTION POLL WORKERS',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2010-01-01T00:00:00',
#   'title_description': 'ELECTION WORKER                                             ',
#   'last_name': 'PATTERSON',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '1250.00',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2014',
#   'total_ot_paid': '0.00',
#   'mid_init': 'M',
#   'first_name': 'SHIRLEY'},
#  {'agency_name': 'BOARD OF ELECTION POLL WORKERS',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2010-01-01T00:00:00',
#   'title_description': 'ELECTION WORKER                                             ',
#   'last_name': 'PATTERSON',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '500.00',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2014',
#   'total_ot_paid': '0.00',
#   'first_name': 'STEPHEN'},
#  {'agency_name': 'BOARD OF ELECTION POLL WORKERS',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2010-01-01T00:00:00',
#   'title_description': 'ELECTION WORKER                                             ',
#   'last_name': 'PATTON',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '775.00',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2014',
#   'total_ot_paid': '0.00',
#   'mid_init': 'L',
#   'first_name': 'ALFRED'},
#  {'agency_name': 'BOARD OF ELECTION POLL WORKERS',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2010-01-01T00:00:00',
#   'title_description': 'ELECTION WORKER                                             ',
#   'last_name': 'PATTON',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '775.00',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2014',
#   'total_ot_paid': '0.00',
#   'mid_init': 'J',
#   'first_name': 'EMMA'},
#  {'agency_name': 'BOARD OF ELECTION POLL WORKERS',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2010-01-01T00:00:00',
#   'title_description': 'ELECTION WORKER                                             ',
#   'last_name': 'PATTON',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '300.00',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2014',
#   'total_ot_paid': '0.00',
#   'first_name': 'ROBERT'},
#  {'agency_name': 'BOARD OF ELECTION POLL WORKERS',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2010-01-01T00:00:00',
#   'title_description': 'ELECTION WORKER                                             ',
#   'last_name': 'PATWARY',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '775.00',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2014',
#   'total_ot_paid': '0.00',
#   'mid_init': 'M',
#   'first_name': 'NOUSATH'},
#  {'agency_name': 'BOARD OF ELECTION POLL WORKERS',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2010-01-01T00:00:00',
#   'title_description': 'ELECTION WORKER                                             ',
#   'last_name': 'PATWARY',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '660.00',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2014',
#   'total_ot_paid': '0.00',
#   'mid_init': 'I',
#   'first_name': 'SHARIFUL'},
#  {'agency_name': 'BOARD OF ELECTION POLL WORKERS',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2010-01-01T00:00:00',
#   'title_description': 'ELECTION WORKER                                             ',
#   'last_name': 'PATWARY',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '775.00',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2014',
#   'total_ot_paid': '0.00',
#   'first_name': 'TAHER'},
#  {'agency_name': 'BOARD OF ELECTION POLL WORKERS',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2010-01-01T00:00:00',
#   'title_description': 'ELECTION WORKER                                             ',
#   'last_name': 'PAUL',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '788.00',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2014',
#   'total_ot_paid': '0.00',
#   'mid_init': 'D',
#   'first_name': 'CHARISSE'},
#  {'agency_name': 'BOARD OF ELECTION POLL WORKERS',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2010-01-01T00:00:00',
#   'title_description': 'ELECTION WORKER                                             ',
#   'last_name': 'PAUL',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '425.00',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2014',
#   'total_ot_paid': '0.00',
#   'mid_init': 'A',
#   'first_name': 'CLERILIA'},
#  {'agency_name': 'BOARD OF ELECTION POLL WORKERS',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2010-01-01T00:00:00',
#   'title_description': 'ELECTION WORKER                                             ',
#   'last_name': 'PAUL',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '775.00',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2014',
#   'total_ot_paid': '0.00',
#   'mid_init': 'P',
#   'first_name': 'DARLENE'},
#  {'agency_name': 'BOARD OF ELECTION POLL WORKERS',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2010-01-01T00:00:00',
#   'title_description': 'ELECTION WORKER                                             ',
#   'last_name': 'PAUL',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '778.00',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2014',
#   'total_ot_paid': '0.00',
#   'mid_init': 'M',
#   'first_name': 'DORIS'},
#  {'agency_name': 'BOARD OF ELECTION POLL WORKERS',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2010-01-01T00:00:00',
#   'title_description': 'ELECTION WORKER                                             ',
#   'last_name': 'PAUL',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '775.00',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2014',
#   'total_ot_paid': '0.00',
#   'mid_init': 'L',
#   'first_name': 'EDWARD'},
#  {'agency_name': 'BOARD OF ELECTION POLL WORKERS',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2010-01-01T00:00:00',
#   'title_description': 'ELECTION WORKER                                             ',
#   'last_name': 'PAUL',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '500.00',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2014',
#   'total_ot_paid': '0.00',
#   'mid_init': 'I',
#   'first_name': 'GLORIA'},
#  {'agency_name': 'BOARD OF ELECTION POLL WORKERS',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2010-01-01T00:00:00',
#   'title_description': 'ELECTION WORKER                                             ',
#   'last_name': 'PAUL',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '279.96',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2014',
#   'total_ot_paid': '0.00',
#   'first_name': 'GREGORY'},
#  {'agency_name': 'BOARD OF ELECTION POLL WORKERS',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2010-01-01T00:00:00',
#   'title_description': 'ELECTION WORKER                                             ',
#   'last_name': 'PAUL',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '775.00',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2014',
#   'total_ot_paid': '0.00',
#   'first_name': 'JEAN'},
#  {'agency_name': 'BOARD OF ELECTION POLL WORKERS',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2010-01-01T00:00:00',
#   'title_description': 'ELECTION WORKER                                             ',
#   'last_name': 'PAUL',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
# ...
#   'last_name': 'REID',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '780.00',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2014',
#   'total_ot_paid': '0.00',
#   'mid_init': 'M',
#   'first_name': 'ANNIE'},
#  {'agency_name': 'BOARD OF ELECTION POLL WORKERS',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2010-01-01T00:00:00',
#   'title_description': 'ELECTION WORKER                                             ',
#   'last_name': 'REID',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '778.00',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2014',
#   'total_ot_paid': '0.00',
#   'mid_init': 'R',
#   'first_name': 'CARMELITA'},
#  {'agency_name': 'BOARD OF ELECTION POLL WORKERS',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2010-01-01T00:00:00',
#   'title_description': 'ELECTION WORKER                                             ',
#   'last_name': 'REID',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '775.00',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2014',
#   'total_ot_paid': '0.00',
#   'mid_init': 'G',
#   'first_name': 'CHARMAINE'},
#  {'agency_name': 'BOARD OF ELECTION POLL WORKERS',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2010-01-01T00:00:00',
#   'title_description': 'ELECTION WORKER                                             ',
#   'last_name': 'REID',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '775.00',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2014',
#   'total_ot_paid': '0.00',
#   'first_name': 'DIANE'},
#  {'agency_name': 'BOARD OF ELECTION POLL WORKERS',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2010-01-01T00:00:00',
#   'title_description': 'ELECTION WORKER                                             ',
#   'last_name': 'REID',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '780.00',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2014',
#   'total_ot_paid': '0.00',
#   'mid_init': 'M',
#   'first_name': 'GERTHA'},
#  {'agency_name': 'BOARD OF ELECTION POLL WORKERS',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2010-01-01T00:00:00',
#   'title_description': 'ELECTION WORKER                                             ',
#   'last_name': 'REID',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '780.00',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2014',
#   'total_ot_paid': '0.00',
#   'mid_init': 'H',
#   'first_name': 'IVAN'},
#  {'agency_name': 'BOARD OF ELECTION POLL WORKERS',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2010-01-01T00:00:00',
#   'title_description': 'ELECTION WORKER                                             ',
#   'last_name': 'REID',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '769.62',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2014',
#   'total_ot_paid': '0.00',
#   'first_name': 'IVY'},
#  {'agency_name': 'BOARD OF ELECTION POLL WORKERS',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2010-01-01T00:00:00',
#   'title_description': 'ELECTION WORKER                                             ',
#   'last_name': 'REID',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '300.00',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2014',
#   'total_ot_paid': '0.00',
#   'mid_init': 'M',
#   'first_name': 'JESSIE'},
#  {'agency_name': 'BOARD OF ELECTION POLL WORKERS',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2010-01-01T00:00:00',
#   'title_description': 'ELECTION WORKER                                             ',
#   'last_name': 'REID',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '500.00',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2014',
#   'total_ot_paid': '0.00',
#   'mid_init': 'L',
#   'first_name': 'JUNLISA'},
#  {'agency_name': 'BOARD OF ELECTION POLL WORKERS',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2010-01-01T00:00:00',
#   'title_description': 'ELECTION WORKER                                             ',
#   'last_name': 'REID',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '775.00',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2014',
#   'total_ot_paid': '0.00',
#   'first_name': 'LEISA'},
#  {'agency_name': 'BOARD OF ELECTION POLL WORKERS',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2010-01-01T00:00:00',
#   'title_description': 'ELECTION WORKER                                             ',
#   'last_name': 'REID',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '775.00',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2014',
#   'total_ot_paid': '0.00',
#   'mid_init': 'I',
#   'first_name': 'LYDIA'},
#  {'agency_name': 'BOARD OF ELECTION POLL WORKERS',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2010-01-01T00:00:00',
#   'title_description': 'ELECTION WORKER                                             ',
#   'last_name': 'REID',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '506.00',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2014',
#   'total_ot_paid': '0.00',
#   'mid_init': 'O',
#   'first_name': 'MARCIA'},
#  {'agency_name': 'BOARD OF ELECTION POLL WORKERS',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2010-01-01T00:00:00',
#   'title_description': 'ELECTION WORKER                                             ',
#   'last_name': 'REID',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '500.00',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2014',
#   'total_ot_paid': '0.00',
#   'mid_init': 'T',
#   'first_name': 'ROMANO'},
#  {'agency_name': 'BOARD OF ELECTION POLL WORKERS',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2010-01-01T00:00:00',
#   'title_description': 'ELECTION WORKER                                             ',
#   'last_name': 'REID',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '778.00',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2014',
#   'total_ot_paid': '0.00',
#   'first_name': 'SADIQAH'},
#  {'agency_name': 'BOARD OF ELECTION POLL WORKERS',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2010-01-01T00:00:00',
#   'title_description': 'ELECTION WORKER                                             ',
#   'last_name': 'REID',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '784.00',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2014',
#   'total_ot_paid': '0.00',
#   'mid_init': 'L',
#   'first_name': 'SOPHIA'},
#  {'agency_name': 'BOARD OF ELECTION POLL WORKERS',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2010-01-01T00:00:00',
#   'title_description': 'ELECTION WORKER                                             ',
#   'last_name': 'REID',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '878.00',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2014',
#   'total_ot_paid': '0.00',
#   'mid_init': 'A',
#   'first_name': 'THEODORE'},
#  {'agency_name': 'BOARD OF ELECTION POLL WORKERS',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2010-01-01T00:00:00',
#   'title_description': 'ELECTION WORKER                                             ',
#   'last_name': 'REIDY',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '784.00',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2014',
#   'total_ot_paid': '0.00',
#   'first_name': 'MADDALENA'},
#  {'agency_name': 'BOARD OF ELECTION POLL WORKERS',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2010-01-01T00:00:00',
#   'title_description': 'ELECTION WORKER                                             ',
#   'last_name': 'REILLY',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '778.00',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2014',
#   'total_ot_paid': '0.00',
#   'mid_init': 'T',
#   'first_name': 'EDWARD'},
#  {'agency_name': 'BOARD OF ELECTION POLL WORKERS',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2010-01-01T00:00:00',
#   'title_description': 'ELECTION WORKER                                             ',
#   'last_name': 'REILLY',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '600.00',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2014',
#   'total_ot_paid': '0.00',
#   'first_name': 'TOM'},
#  {'agency_name': 'BOARD OF ELECTION POLL WORKERS',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2010-01-01T00:00:00',
#   'title_description': 'ELECTION WORKER                                             ',
#   'last_name': 'REIMONENQ-BAILE',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '500.00',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2014',
#   'total_ot_paid': '0.00',
#   'first_name': 'GAY'},
#  {'agency_name': 'BOARD OF ELECTION POLL WORKERS',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2010-01-01T00:00:00',
#   'title_description': 'ELECTION WORKER                                             ',
#   'last_name': 'REINER',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '784.00',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2014',
#   'total_ot_paid': '0.00',
#   'first_name': 'LAURA'},
#  {'agency_name': 'BOARD OF ELECTION POLL WORKERS',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2010-01-01T00:00:00',
#   'title_description': 'ELECTION WORKER                                             ',
#   'last_name': 'REINHART',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '1100.00',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2014',
#   'total_ot_paid': '0.00',
#   'mid_init': 'L',
#   'first_name': 'SUSAN'},
#  {'agency_name': 'BOARD OF ELECTION POLL WORKERS',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2010-01-01T00:00:00',
#   'title_description': 'ELECTION WORKER                                             ',
#   'last_name': 'REISCH',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '778.00',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2014',
#   'total_ot_paid': '0.00',
#   'first_name': 'BARBARA'},
#  {'agency_name': 'BOARD OF ELECTION POLL WORKERS',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2010-01-01T00:00:00',
#   'title_description': 'ELECTION WORKER                                             ',
#   'last_name': 'REITER',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '300.00',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2014',
#   'total_ot_paid': '0.00',
#   'first_name': 'KEITH'},
#  {'agency_name': 'BOARD OF ELECTION POLL WORKERS',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2010-01-01T00:00:00',
#   'title_description': 'ELECTION WORKER                                             ',
#   'last_name': 'REJAS',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '300.00',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2014',
#   'total_ot_paid': '0.00',
#   'first_name': 'MARINA'},
#  {'agency_name': 'BOARD OF ELECTION POLL WORKERS',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2010-01-01T00:00:00',
#   'title_description': 'ELECTION WORKER                                             ',
#   'last_name': 'RELIFORD',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '775.00',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2014',
#   'total_ot_paid': '0.00',
#   'first_name': 'DOROTHY'},
#  {'agency_name': 'BOARD OF ELECTION POLL WORKERS',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2010-01-01T00:00:00',
#   'title_description': 'ELECTION WORKER                                             ',
#   'last_name': 'RELLA',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '784.00',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2014',
#   'total_ot_paid': '0.00',
#   'mid_init': 'A',
#   'first_name': 'THERESA'},
#  {'agency_name': 'BOARD OF ELECTION POLL WORKERS',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2010-01-01T00:00:00',
#   'title_description': 'ELECTION WORKER                                             ',
#   'last_name': 'RELYEA',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '503.00',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2014',
#   'total_ot_paid': '0.00',
#   'mid_init': 'M',
#   'first_name': 'TINA'},
#  {'agency_name': 'BOARD OF ELECTION POLL WORKERS',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2010-01-01T00:00:00',
#   'title_description': 'ELECTION WORKER                                             ',
#   'last_name': 'REMBERT',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '875.00',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2014',
#   'total_ot_paid': '0.00',
#   'mid_init': 'C',
#   'first_name': 'CLIFFORD'},
#  {'agency_name': 'BOARD OF ELECTION POLL WORKERS',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2010-01-01T00:00:00',
#   'title_description': 'ELECTION WORKER                                             ',
#   'last_name': 'REMBERT',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '748.29',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2014',
#   'total_ot_paid': '0.00',
#   'first_name': 'LORRAINE'},
#  {'agency_name': 'BOARD OF ELECTION POLL WORKERS',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2010-01-01T00:00:00',
#   'title_description': 'ELECTION WORKER                                             ',
#   'last_name': 'REMER',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '778.00',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2014',
#   'total_ot_paid': '0.00',
#   'first_name': 'SYLVIA'},
#  {'agency_name': 'BOARD OF ELECTION POLL WORKERS',
#   'pay_basis': ' per Hour',
#   'agency_start_date': '2010-01-01T00:00:00',
#   'title_description': 'ELECTION WORKER                                             ',
#   'last_name': 'REMISZEWSKI',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '781.00',
#   'base_salary': '1.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2014',
#   'total_ot_paid': '0.00',
#   'mid_init': 'M',
#   'first_name': 'KAREN'},
#  ...]

# %%
df.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df = pd.DataFrame()

# %%
for i in range(2):
    results = client.get(identified, limit=50000, offset=50000*i)
    df.append(results)

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [raw]
# results.keys()

# %%
results = client.get(identified, limit=50000, offset=50000*0)

# %%
results.keys()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-48-a238dd3b274e> in <module>()
# ----> 1 results.keys()
#
# AttributeError: 'list' object has no attribute 'keys'

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df = pd.DataFrame()

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df.append(results)
# Out:
#                           agency_name    agency_start_date base_salary  \
# 0      DISTRICT ATTORNEY-MANHATTAN     2003-07-14T00:00:00    47678.00
# 1      DISTRICT ATTORNEY-MANHATTAN     1995-06-12T00:00:00   119959.00
# 2      DISTRICT ATTORNEY-MANHATTAN     2011-10-11T00:00:00    39966.00
# 3      DISTRICT ATTORNEY-MANHATTAN     2014-12-01T00:00:00   116000.00
# 4      DISTRICT ATTORNEY-MANHATTAN     2015-05-21T00:00:00        1.00
# 5      DISTRICT ATTORNEY-MANHATTAN     2012-09-04T00:00:00    71500.00
# 6      DISTRICT ATTORNEY-MANHATTAN     2007-09-04T00:00:00    88000.00
# 7      DISTRICT ATTORNEY-MANHATTAN     2016-06-06T00:00:00        1.00
# 8      DISTRICT ATTORNEY-MANHATTAN     2014-09-02T00:00:00    41000.00
# 9      DISTRICT ATTORNEY-MANHATTAN     1978-05-31T00:00:00    66035.00
# 10     DISTRICT ATTORNEY-MANHATTAN     2013-04-22T00:00:00    38869.00
# 11     DISTRICT ATTORNEY-MANHATTAN     2014-08-25T00:00:00    42075.00
# 12     DISTRICT ATTORNEY-MANHATTAN     2014-01-13T00:00:00    66625.00
# 13     DISTRICT ATTORNEY-MANHATTAN     2005-03-28T00:00:00   112592.00
# 14     DISTRICT ATTORNEY-MANHATTAN     2009-11-09T00:00:00    52548.00
# 15     DISTRICT ATTORNEY-MANHATTAN     2015-05-21T00:00:00        1.00
# 16     DISTRICT ATTORNEY-MANHATTAN     2014-04-28T00:00:00    43299.00
# 17     DISTRICT ATTORNEY-MANHATTAN     2004-09-07T00:00:00   102500.00
# 18     DISTRICT ATTORNEY-MANHATTAN     2015-05-21T00:00:00        1.00
# 19     DISTRICT ATTORNEY-MANHATTAN     2007-01-19T00:00:00    40299.00
# 20     DISTRICT ATTORNEY-MANHATTAN     2014-09-02T00:00:00    78000.00
# 21     DISTRICT ATTORNEY-MANHATTAN     2008-09-21T00:00:00      370.16
# 22     DISTRICT ATTORNEY-MANHATTAN     2016-06-06T00:00:00        1.00
# 23     DISTRICT ATTORNEY-MANHATTAN     2009-03-02T00:00:00      217.70
# 24     DISTRICT ATTORNEY-MANHATTAN     2015-06-08T00:00:00    53366.00
# 25     DISTRICT ATTORNEY-MANHATTAN     2010-08-16T00:00:00    45985.00
# 26     DISTRICT ATTORNEY-MANHATTAN     2008-01-14T00:00:00    36154.00
# 27     DISTRICT ATTORNEY-MANHATTAN     2014-10-20T00:00:00    65600.00
# 28     DISTRICT ATTORNEY-MANHATTAN     1980-01-21T00:00:00    56017.00
# 29     DISTRICT ATTORNEY-MANHATTAN     2015-09-28T00:00:00    37541.00
# ...                               ...                  ...         ...
# 49970               POLICE DEPARTMENT  2005-09-26T00:00:00    39868.00
# 49971               POLICE DEPARTMENT  2009-02-02T00:00:00    39164.00
# 49972               POLICE DEPARTMENT  2005-07-20T00:00:00    78026.00
# 49973               POLICE DEPARTMENT  2010-07-06T00:00:00    42395.00
# 49974               POLICE DEPARTMENT  2005-01-10T00:00:00    78026.00
# 49975               POLICE DEPARTMENT  1996-07-26T00:00:00   118902.00
# 49976               POLICE DEPARTMENT  1998-08-31T00:00:00    78026.00
# 49977               POLICE DEPARTMENT  2011-07-06T00:00:00    57747.00
# 49978               POLICE DEPARTMENT  2006-07-10T00:00:00    78026.00
# 49979               POLICE DEPARTMENT  2015-07-08T00:00:00    42819.00
# 49980               POLICE DEPARTMENT  2015-01-07T00:00:00    42819.00
# 49981               POLICE DEPARTMENT  2001-07-02T00:00:00    78026.00
# 49982               POLICE DEPARTMENT  2016-01-06T00:00:00    42819.00
# 49983               POLICE DEPARTMENT  1994-02-28T00:00:00   117145.00
# 49984               POLICE DEPARTMENT  2012-07-11T00:00:00    54341.00
# 49985               POLICE DEPARTMENT  1998-12-20T00:00:00    38044.00
# 49986               POLICE DEPARTMENT  1990-10-15T00:00:00   102054.00
# 49987               POLICE DEPARTMENT  1989-07-05T00:00:00   103517.00
# 49988               POLICE DEPARTMENT  2010-07-06T00:00:00    78026.00
# 49989               POLICE DEPARTMENT  1995-04-30T00:00:00    78026.00
# 49990               POLICE DEPARTMENT  1991-04-30T00:00:00    88151.00
# 49991               POLICE DEPARTMENT  2011-07-06T00:00:00    57747.00
# 49992               POLICE DEPARTMENT  2014-07-09T00:00:00    44521.00
# 49993               POLICE DEPARTMENT  1991-04-30T00:00:00    77253.00
# 49994               POLICE DEPARTMENT  2004-01-20T00:00:00   108748.00
# 49995               POLICE DEPARTMENT  1980-12-31T00:00:00    38319.00
# 49996               POLICE DEPARTMENT  1993-08-30T00:00:00    78026.00
# 49997               POLICE DEPARTMENT  1992-06-30T00:00:00    99053.00
# 49998               POLICE DEPARTMENT  2005-07-25T00:00:00    37821.00
# 49999               POLICE DEPARTMENT  2006-07-10T00:00:00    78026.00
#
#        first_name fiscal_year        last_name leave_status_as_of_july_31  \
# 0       RAHASHEEM        2016        ABA'AHMID                     ACTIVE
# 1        MARGARET        2016          ABENSUR                     ACTIVE
# 2          ANDREA        2016        ABOUNAOUM                   ON LEAVE
# 3        JONATHAN        2016          ABRAHAM                     ACTIVE
# 4          JOSEPH        2016           ABRAMS                     CEASED
# 5        JENNIFER        2016            ABREU                     ACTIVE
# 6            JUAN        2016            ABREU                     ACTIVE
# 7        JENNIFER        2016          ACEVEDO                     ACTIVE
# 8         MATTHEW        2016         ACOCELLA                     CEASED
# 9            RITA        2016           ACOSTA                     ACTIVE
# 10      KATHERINE        2016            ADAMS                     CEASED
# 11       NEERESHA        2016            ADAMS                     ACTIVE
# 12     OYINDAMOLA        2016         ADEGBORO                     ACTIVE
# 13       SANCHITA        2016         AGGARWAL                     ACTIVE
# 14         YAMIRA        2016          AGUILAR                     ACTIVE
# 15         JORDAN        2016          AGUIRRE                     CEASED
# 16        ARTEMIS        2016          AHMETAJ                     ACTIVE
# 17          HELEN        2016              AHN                     ACTIVE
# 18         SANDRA        2016          ALCAIDE                     CEASED
# 19         DANIEL        2016        ALCANTARA                     ACTIVE
# 20           ERIN        2016        ALEXANDER                     ACTIVE
# 21           PAUL        2016           ALFLEN                     ACTIVE
# 22      SHEHARYAR        2016              ALI                     ACTIVE
# 23          SYEED        2016              ALI                     ACTIVE
# 24        JEFFREY        2016     AL-KAABAH II                     ACTIVE
# 25          ABEER        2016       ALKHAFAJEE                     CEASED
# 26        SHAIMAA        2016       ALKHAFAJEE                     ACTIVE
# 27        BENNETT        2016            ALLEN                     ACTIVE
# 28         ROBERT        2016            ALLEN                     ACTIVE
# 29        MARISOL        2016  ALMONTE-ALMANZA                     ACTIVE
# ...           ...         ...              ...                        ...
# 49970      SELENA        2016           PALMER                     ACTIVE
# 49971   SHANIELLE        2016           PALMER                     ACTIVE
# 49972     VINCENT        2016           PALMER                     ACTIVE
# 49973     WILLIAM        2016           PALMER                     CEASED
# 49974     WILLIAM        2016           PALMER                     ACTIVE
# 49975      THOMAS        2016        PALMER JR                   ON LEAVE
# 49976       CHRIS        2016          PALMERI                     ACTIVE
# 49977      JOSEPH        2016          PALMERI                     ACTIVE
# 49978     MATTHEW        2016        PALMERINI                     ACTIVE
# 49979        JOHN        2016          PALMESE                     CEASED
# 49980      JOSEPH        2016          PALMESE                     ACTIVE
# 49981     MICHAEL        2016          PALMESE                     ACTIVE
# 49982       SCOTT        2016          PALMESE                     ACTIVE
# 49983       COSMO        2016         PALMIERI                     CEASED
# 49984    CRISTINA        2016         PALMIERI                     ACTIVE
# 49985        DAWN        2016         PALMIERI                     CEASED
# 49986     DOROTHY        2016         PALMIERI                     CEASED
# 49987        JOHN        2016         PALMIERI                     CEASED
# 49988     MATTHEW        2016         PALMIERI                     ACTIVE
# 49989      REGINA        2016         PALMIERI                     CEASED
# 49990      DENISE        2016       PALMINTERI                     CEASED
# 49991        PAUL        2016       PALMINTERI                     ACTIVE
# 49992        RYAN        2016       PALMINTERI                     ACTIVE
# 49993      PIERRE        2016        PALMIOTTI                     CEASED
# 49994      JOSEPH        2016        PALMIOTTO                     ACTIVE
# 49995    GENEVIEV        2016          PALOMBA                     ACTIVE
# 49996     MICHAEL        2016          PALOMBO                     ACTIVE
# 49997        PAUL        2016          PALOMBO                     CEASED
# 49998       RALPH        2016          PALOMBO                     ACTIVE
# 49999       OSCAR        2016         PALOMINO                     ACTIVE
#
#       mid_init ot_hours   pay_basis regular_gross_paid regular_hours  \
# 0            E     2.25   per Annum           47166.03       1830.00
# 1          NaN     0.00   per Annum          119042.50       1831.00
# 2            L     1.00   per Annum           27452.62       1181.68
# 3            J     0.00   per Annum          115104.57       1831.00
# 4          NaN     0.00    per Hour            3500.00          0.00
# 5          NaN     0.00   per Annum           71967.34       1831.00
# 6            D     0.00   per Annum           87614.01       1831.00
# 7          NaN     0.00    per Hour             500.00          0.00
# 8            J     0.00   per Annum            9507.15        349.00
# 9            E     0.00   per Annum           64357.12       1830.00
# 10           J     0.00   per Annum            6073.13        200.70
# 11         NaN     0.00   per Annum           39895.79       1830.00
# 12           F     0.00   per Annum           65909.63       1830.00
# 13           J     0.00   per Annum          111806.82       1831.00
# 14         NaN   716.25   per Annum           51890.77       1830.00
# 15         NaN     0.00    per Hour            3500.00          0.00
# 16         NaN    51.75   per Annum           40052.01       1830.00
# 17           H     0.00   per Annum           59023.02       1076.00
# 18         NaN     0.00    per Hour            3500.00          0.00
# 19         NaN     0.00   per Annum           39866.21       1830.00
# 20           L     0.00   per Annum           64498.36       1509.00
# 21           R   408.75     per Day          139072.14       1830.00
# 22         NaN     0.00    per Hour            1000.00          0.00
# 23           A   173.75     per Day           56602.00       1830.00
# 24           I   276.50   per Annum           46271.84       1829.75
# 25           K     1.00   per Annum            4661.03         38.10
# 26         NaN     0.00   per Annum           35765.73       1830.00
# 27           L     0.00   per Annum           64895.59       1830.00
# 28           K     0.00   per Annum           55411.18       1830.00
# 29         NaN     0.75   per Annum           26422.22       1383.00
# ...        ...      ...         ...                ...           ...
# 49970        M    44.25   per Annum           46174.73       2091.42
# 49971        A   593.00   per Annum           41886.35       2091.42
# 49972        M   261.28   per Annum           84324.25       2091.42
# 49973        E     0.00   per Annum              14.37          0.00
# 49974        G   356.00   per Annum           84251.63       2091.42
# 49975        J     0.00   per Annum          100022.63       2091.42
# 49976      NaN   313.85   per Annum           84324.25       2091.42
# 49977        I   136.00   per Annum           59201.58       2091.42
# 49978        L   289.92   per Annum           83933.75       2091.42
# 49979        T    67.53   per Annum           38607.43       1862.87
# 49980        J   110.15   per Annum           43336.90       2091.42
# 49981        A   145.00   per Annum           84324.25       2091.42
# 49982        T     0.00   per Annum           18484.76        988.57
# 49983        J    68.33   per Annum          103076.98       1742.85
# 49984      NaN   179.17   per Annum           53969.46       2091.42
# 49985        M     0.00   per Annum           18475.75        493.32
# 49986        B   194.40   per Annum           95400.41       1394.28
# 49987        L     0.00   per Annum               0.00          0.00
# 49988        C   466.62   per Annum           70403.18       2091.42
# 49989      NaN     0.00   per Annum            1515.30          0.00
# 49990        E     0.00   per Annum               0.00          0.00
# 49991        G   473.53   per Annum           59085.02       2091.42
# 49992        M   162.00   per Annum           44097.46       2091.42
# 49993        A     0.00   per Annum             572.44          0.00
# 49994        A   399.33   per Annum          106479.51       2091.42
# 49995        T     0.00   per Annum           37903.14       1830.00
# 49996        L   117.67   per Annum           84324.25       2091.42
# 49997      NaN     0.00   per Annum               0.00          0.00
# 49998      NaN     0.00   per Annum           37414.88       1830.00
# 49999      NaN   244.37   per Annum           83933.75       2091.42
#
#                                        title_description total_ot_paid  \
# 0      COMMUNITY ASSOCIATE                           ...         57.28
# 1      ADMINISTRATIVE ACCOUNTANT                     ...          0.00
# 2      COMMUNITY ASSOCIATE                           ...         21.34
# 3      COMPUTER SYSTEMS MANAGER                      ...          0.00
# 4      COLLEGE AIDE                                  ...          0.00
# 5      ASSISTANT DISTRICT ATTORNEY                   ...          0.00
# 6      ASSISTANT DISTRICT ATTORNEY                   ...          0.00
# 7      COLLEGE AIDE                                  ...          0.00
# 8      COMMUNITY ASSOCIATE                           ...          0.00
# 9                 PRINCIPAL ADMINISTRATIVE ASSOCIATE              0.00
# 10     COMMUNITY ASSOCIATE                           ...          0.00
# 11     COMMUNITY ASSOCIATE                           ...          0.00
# 12     COMMUNITY COORDINATOR                         ...          0.00
# 13     PRINCIPAL ACCOUNTANT INVESTIGATOR             ...          0.00
# 14     COMMUNITY ASSOCIATE                           ...      25943.55
# 15     COLLEGE AIDE                                  ...          0.00
# 16     COMMUNITY ASSISTANT                           ...       1413.40
# 17     ASSISTANT DISTRICT ATTORNEY                   ...          0.00
# 18     COLLEGE AIDE                                  ...          0.00
# 19     COMMUNITY ASSOCIATE                           ...          0.00
# 20     ASSISTANT DISTRICT ATTORNEY                   ...          0.00
# 21     CARPENTER                                     ...      50546.28
# 22     COLLEGE AIDE                                  ...          0.00
# 23     ELECTRICIAN'S HELPER                          ...       8991.82
# 24     COMMUNITY ASSOCIATE                           ...       7757.06
# 25     COMMUNITY ASSOCIATE                           ...        169.90
# 26     COMMUNITY ASSISTANT                           ...          0.00
# 27     COMMUNITY COORDINATOR                         ...          0.00
# 28          CLERICAL ASSOCIATE                                    0.00
# 29     COMMUNITY ASSOCIATE                           ...         15.41
# ...                                                  ...           ...
# 49970                                SCHOOL SAFETY AGENT       1143.36
# 49971                          TRAFFIC ENFORCEMENT AGENT      18481.54
# 49972                                     POLICE OFFICER      16567.29
# 49973                                     POLICE OFFICER          0.00
# 49974                                     POLICE OFFICER      25358.29
# 49975                                         LIEUTENANT         55.27
# 49976                                     POLICE OFFICER      21233.14
# 49977                                     POLICE OFFICER       5092.19
# 49978                                     POLICE OFFICER      23203.18
# 49979                                     POLICE OFFICER       2249.98
# 49980                                     POLICE OFFICER       3496.86
# 49981                                     POLICE OFFICER      11675.40
# 49982                                     POLICE OFFICER          0.00
# 49983                                         LIEUTENANT       7185.07
# 49984                                     POLICE OFFICER       7024.45
# 49985                                SCHOOL SAFETY AGENT        802.50
# 49986                POLICE OFFICER D/A DETECTIVE 2ND GR      18236.79
# 49987                                         LIEUTENANT          0.00
# 49988                                     POLICE OFFICER      26717.51
# 49989                                     POLICE OFFICER         89.71
# 49990                                    P.O. DA DET GR3          0.00
# 49991                                     POLICE OFFICER      20094.90
# 49992                                     POLICE OFFICER       4626.96
# 49993                                     POLICE OFFICER        216.93
# 49994                                         LIEUTENANT      32645.02
# 49995                         POLICE ADMINISTRATIVE AIDE          0.00
# 49996                                     POLICE OFFICER       9874.96
# 49997                POLICE OFFICER D/A DETECTIVE 2ND GR          0.00
# 49998                         POLICE ADMINISTRATIVE AIDE          0.00
# 49999                                     POLICE OFFICER      22913.54
#
#       total_other_pay work_location_borough
# 0                0.00         MANHATTAN
# 1                0.00         MANHATTAN
# 2               33.00         MANHATTAN
# 3                0.00         MANHATTAN
# 4                0.00         MANHATTAN
# 5                0.00         MANHATTAN
# 6              750.00         MANHATTAN
# 7                0.00         MANHATTAN
# 8                0.00         MANHATTAN
# 9             3824.72         MANHATTAN
# 10               8.25         MANHATTAN
# 11              74.25         MANHATTAN
# 12              33.00         MANHATTAN
# 13             500.00         MANHATTAN
# 14             747.93         MANHATTAN
# 15               0.00         MANHATTAN
# 16             526.11         MANHATTAN
# 17               0.00         MANHATTAN
# 18               0.00         MANHATTAN
# 19               0.00         MANHATTAN
# 20            1750.00         MANHATTAN
# 21            5060.37         MANHATTAN
# 22               0.00         MANHATTAN
# 23            7424.72         MANHATTAN
# 24             755.84         MANHATTAN
# 25              94.40         MANHATTAN
# 26               0.00         MANHATTAN
# 27              99.50         MANHATTAN
# 28            4424.50         MANHATTAN
# 29              24.75         MANHATTAN
# ...               ...                   ...
# 49970         1001.78             MANHATTAN
# 49971         3072.52             MANHATTAN
# 49972        13125.99              RICHMOND
# 49973            0.00             MANHATTAN
# 49974        17016.10              RICHMOND
# 49975        15291.80             MANHATTAN
# 49976        19202.84             MANHATTAN
# 49977         5284.23             MANHATTAN
# 49978        15761.20                 BRONX
# 49979         3629.91             MANHATTAN
# 49980         5934.76                QUEENS
# 49981        18823.03             MANHATTAN
# 49982            0.00             MANHATTAN
# 49983         3580.87             MANHATTAN
# 49984         4695.04                QUEENS
# 49985         1486.50             MANHATTAN
# 49986        12655.63             MANHATTAN
# 49987          128.60             MANHATTAN
# 49988        13351.94              BROOKLYN
# 49989          297.85             MANHATTAN
# 49990           40.50             MANHATTAN
# 49991         6313.97              BROOKLYN
# 49992         7506.25              BROOKLYN
# 49993          124.54             MANHATTAN
# 49994        15653.39              RICHMOND
# 49995         4424.50             MANHATTAN
# 49996        21765.80             MANHATTAN
# 49997           65.80             MANHATTAN
# 49998         2817.13             MANHATTAN
# 49999        17963.32              BROOKLYN
#
# [50000 rows x 16 columns]

# %%
df.keys()
# Out:
# Index([], dtype='object')

# %%
results = client.get(identified, limit=50000, offset=50000*1)

# %%
pd.read_json(results)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-55-1a088540ad15> in <module>()
# ----> 1 pd.read_json(results)
#
# /usr/lib/python3/dist-packages/pandas/io/json/json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, lines, chunksize, compression)
#     350     compression = _infer_compression(path_or_buf, compression)
#     351     filepath_or_buffer, _, compression = get_filepath_or_buffer(
# --> 352         path_or_buf, encoding=encoding, compression=compression,
#     353     )
#     354
#
# /usr/lib/python3/dist-packages/pandas/io/common.py in get_filepath_or_buffer(filepath_or_buffer, encoding, compression)
#     209     if not is_file_like(filepath_or_buffer):
#     210         msg = "Invalid file path or buffer object type: {_type}"
# --> 211         raise ValueError(msg.format(_type=type(filepath_or_buffer)))
#     212
#     213     return filepath_or_buffer, None, compression
#
# ValueError: Invalid file path or buffer object type: <class 'list'>

# %%
results
# Out:
# [{'agency_name': 'POLICE DEPARTMENT',
#   'pay_basis': 'per Annum',
#   'agency_start_date': '2001-07-02T00:00:00',
#   'title_description': 'POLICE OFFICER',
#   'last_name': 'PALOMO',
#   'regular_hours': '2091.42',
#   'ot_hours': '350.90',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '84324.25',
#   'work_location_borough': 'QUEENS',
#   'base_salary': '78026.00',
#   'total_other_pay': '12822.47',
#   'fiscal_year': '2016',
#   'total_ot_paid': '23932.75',
#   'mid_init': 'C',
#   'first_name': 'DANA'},
#  {'agency_name': 'POLICE DEPARTMENT',
#   'pay_basis': 'per Annum',
#   'agency_start_date': '2014-07-09T00:00:00',
#   'title_description': 'POLICE OFFICER',
#   'last_name': 'PALTOO',
#   'regular_hours': '2091.42',
#   'ot_hours': '227.17',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '45267.84',
#   'work_location_borough': 'BROOKLYN',
#   'base_salary': '44521.00',
#   'total_other_pay': '4334.07',
#   'fiscal_year': '2016',
#   'total_ot_paid': '8754.46',
#   'first_name': 'ASHMEED'},
#  {'agency_name': 'POLICE DEPARTMENT',
#   'pay_basis': 'per Annum',
#   'agency_start_date': '1995-04-02T00:00:00',
#   'title_description': 'P.O. DA DET GR3',
#   'last_name': 'PALTOO',
#   'regular_hours': '1742.85',
#   'ot_hours': '391.77',
#   'leave_status_as_of_july_31': 'CEASED',
#   'regular_gross_paid': '79497.44',
#   'work_location_borough': 'MANHATTAN',
#   'base_salary': '90822.00',
#   'total_other_pay': '-37054.09',
#   'fiscal_year': '2016',
#   'total_ot_paid': '29192.92',
#   'first_name': 'RAYMOND'},
#  {'agency_name': 'POLICE DEPARTMENT',
#   'pay_basis': 'per Annum',
#   'agency_start_date': '2015-07-08T00:00:00',
#   'title_description': 'POLICE OFFICER',
#   'last_name': 'PALUCH',
#   'regular_hours': '2028.57',
#   'ot_hours': '19.33',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '39777.33',
#   'work_location_borough': 'BRONX',
#   'base_salary': '42819.00',
#   'total_other_pay': '3062.97',
#   'fiscal_year': '2016',
#   'total_ot_paid': '472.90',
#   'first_name': 'MICHAEL'},
#  {'agency_name': 'POLICE DEPARTMENT',
#   'pay_basis': 'per Annum',
#   'agency_start_date': '2007-07-09T00:00:00',
#   'title_description': 'POLICE OFFICER',
#   'last_name': 'PALUCHOWSKI',
#   'regular_hours': '2091.42',
#   'ot_hours': '342.50',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '83466.58',
#   'work_location_borough': 'MANHATTAN',
#   'base_salary': '78026.00',
#   'total_other_pay': '11322.23',
#   'fiscal_year': '2016',
#   'total_ot_paid': '24189.00',
#   'first_name': 'MARCIN'},
#  {'agency_name': 'POLICE DEPARTMENT',
#   'pay_basis': 'per Annum',
#   'agency_start_date': '2011-07-06T00:00:00',
#   'title_description': 'POLICE OFFICER',
#   'last_name': 'PALUMBO',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'CEASED',
#   'regular_gross_paid': '15.50',
#   'work_location_borough': 'MANHATTAN',
#   'base_salary': '42395.00',
#   'total_other_pay': '0.71',
#   'fiscal_year': '2016',
#   'total_ot_paid': '0.00',
#   'first_name': 'ANTONIO'},
#  {'agency_name': 'POLICE DEPARTMENT',
#   'pay_basis': 'per Annum',
#   'agency_start_date': '2000-03-01T00:00:00',
#   'title_description': 'POLICE OFFICER',
#   'last_name': 'PALUMBO',
#   'regular_hours': '2091.42',
#   'ot_hours': '17.78',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '84324.25',
#   'work_location_borough': 'MANHATTAN',
#   'base_salary': '78026.00',
#   'total_other_pay': '15131.99',
#   'fiscal_year': '2016',
#   'total_ot_paid': '1483.63',
#   'mid_init': 'J',
#   'first_name': 'DANIEL'},
#  {'agency_name': 'POLICE DEPARTMENT',
#   'pay_basis': 'per Annum',
#   'agency_start_date': '1998-12-20T00:00:00',
#   'title_description': 'SCHOOL SAFETY AGENT',
#   'last_name': 'PALUMBO',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'CEASED',
#   'regular_gross_paid': '2287.00',
#   'work_location_borough': 'MANHATTAN',
#   'base_salary': '36033.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2016',
#   'total_ot_paid': '0.00',
#   'mid_init': 'D',
#   'first_name': 'FELISHA'},
#  {'agency_name': 'POLICE DEPARTMENT',
#   'pay_basis': 'per Annum',
#   'agency_start_date': '1999-07-07T00:00:00',
#   'title_description': 'SERGEANT',
#   'last_name': 'PALUMBO',
#   'regular_hours': '2091.42',
#   'ot_hours': '79.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '88096.64',
#   'work_location_borough': 'BRONX',
#   'base_salary': '103585.00',
#   'total_other_pay': '16075.67',
#   'fiscal_year': '2016',
#   'total_ot_paid': '6285.45',
#   'mid_init': 'J',
#   'first_name': 'FRANK'},
#  {'agency_name': 'POLICE DEPARTMENT',
#   'pay_basis': 'per Annum',
#   'agency_start_date': '2002-10-28T00:00:00',
#   'title_description': 'CRIMINALIST',
#   'last_name': 'PALUMBO',
#   'regular_hours': '1830.00',
#   'ot_hours': '11.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '96956.19',
#   'work_location_borough': 'QUEENS',
#   'base_salary': '98025.00',
#   'total_other_pay': '5360.45',
#   'fiscal_year': '2016',
#   'total_ot_paid': '616.42',
#   'first_name': 'HEATHER'},
#  {'agency_name': 'POLICE DEPARTMENT',
#   'pay_basis': 'per Annum',
#   'agency_start_date': '2000-09-29T00:00:00',
#   'title_description': 'CAPTAIN D/A DEPUTY INSPECTOR',
#   'last_name': 'PALUMBO',
#   'regular_hours': '2091.42',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '151269.90',
#   'work_location_borough': 'BROOKLYN',
#   'base_salary': '160565.00',
#   'total_other_pay': '21043.68',
#   'fiscal_year': '2016',
#   'total_ot_paid': '0.00',
#   'mid_init': 'R',
#   'first_name': 'JAMES'},
#  {'agency_name': 'POLICE DEPARTMENT',
#   'pay_basis': 'per Annum',
#   'agency_start_date': '1990-07-10T00:00:00',
#   'title_description': 'POLICE OFFICER',
#   'last_name': 'PALUMBO',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'CEASED',
#   'regular_gross_paid': '700.17',
#   'work_location_borough': 'MANHATTAN',
#   'base_salary': '77253.00',
#   'total_other_pay': '146.47',
#   'fiscal_year': '2016',
#   'total_ot_paid': '75.80',
#   'first_name': 'LINETTE'},
#  {'agency_name': 'POLICE DEPARTMENT',
#   'pay_basis': 'per Annum',
#   'agency_start_date': '2007-05-29T00:00:00',
#   'title_description': 'SCHOOL SAFETY AGENT',
#   'last_name': 'PALUMBO',
#   'regular_hours': '2091.42',
#   'ot_hours': '10.50',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '46068.19',
#   'work_location_borough': 'BRONX',
#   'base_salary': '39868.00',
#   'total_other_pay': '1000.00',
#   'fiscal_year': '2016',
#   'total_ot_paid': '54.43',
#   'mid_init': 'A',
#   'first_name': 'LOUISE'},
#  {'agency_name': 'POLICE DEPARTMENT',
#   'pay_basis': 'per Annum',
#   'agency_start_date': '1995-04-02T00:00:00',
#   'title_description': 'POLICE OFFICER',
#   'last_name': 'PALUMBO',
#   'regular_hours': '2091.42',
#   'ot_hours': '497.52',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '84324.25',
#   'work_location_borough': 'MANHATTAN',
#   'base_salary': '78026.00',
#   'total_other_pay': '21318.24',
#   'fiscal_year': '2016',
#   'total_ot_paid': '32966.43',
#   'first_name': 'PETER'},
#  {'agency_name': 'POLICE DEPARTMENT',
#   'pay_basis': 'per Annum',
#   'agency_start_date': '2014-01-08T00:00:00',
#   'title_description': 'POLICE OFFICER',
#   'last_name': 'PALUMBO',
#   'regular_hours': '2091.42',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '45378.52',
#   'work_location_borough': 'BROOKLYN',
#   'base_salary': '44521.00',
#   'total_other_pay': '6358.98',
#   'fiscal_year': '2016',
#   'total_ot_paid': '10.70',
#   'mid_init': 'C',
#   'first_name': 'VINCENT'},
#  {'agency_name': 'POLICE DEPARTMENT',
#   'pay_basis': 'per Annum',
#   'agency_start_date': '1995-06-30T00:00:00',
#   'title_description': 'CAPTAIN',
#   'last_name': 'PALUMMO',
#   'regular_hours': '2091.42',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '151269.90',
#   'work_location_borough': 'MANHATTAN',
#   'base_salary': '152534.00',
#   'total_other_pay': '20340.59',
#   'fiscal_year': '2016',
#   'total_ot_paid': '0.00',
#   'mid_init': 'C',
#   'first_name': 'CARMINE'},
#  {'agency_name': 'POLICE DEPARTMENT',
#   'pay_basis': 'per Annum',
#   'agency_start_date': '1995-04-30T00:00:00',
#   'title_description': 'SERGEANT',
#   'last_name': 'PALUSKO',
#   'regular_hours': '2091.42',
#   'ot_hours': '102.75',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '102689.21',
#   'work_location_borough': 'QUEENS',
#   'base_salary': '103585.00',
#   'total_other_pay': '17094.57',
#   'fiscal_year': '2016',
#   'total_ot_paid': '10383.74',
#   'first_name': 'ERIC'},
#  {'agency_name': 'POLICE DEPARTMENT',
#   'pay_basis': 'per Annum',
#   'agency_start_date': '1995-04-30T00:00:00',
#   'title_description': 'POLICE OFFICER',
#   'last_name': 'PALUSKO',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'CEASED',
#   'regular_gross_paid': '3967.47',
#   'work_location_borough': 'MANHATTAN',
#   'base_salary': '78026.00',
#   'total_other_pay': '692.60',
#   'fiscal_year': '2016',
#   'total_ot_paid': '374.93',
#   'first_name': 'VANESSA'},
#  {'agency_name': 'POLICE DEPARTMENT',
#   'pay_basis': 'per Annum',
#   'agency_start_date': '2002-07-22T00:00:00',
#   'title_description': 'POLICE OFFICER',
#   'last_name': 'PALUSZKIEWICZ',
#   'regular_hours': '2091.42',
#   'ot_hours': '458.50',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '84324.25',
#   'work_location_borough': 'QUEENS',
#   'base_salary': '78026.00',
#   'total_other_pay': '12472.55',
#   'fiscal_year': '2016',
#   'total_ot_paid': '29260.69',
#   'mid_init': 'J',
#   'first_name': 'RICHARD'},
#  {'agency_name': 'POLICE DEPARTMENT',
#   'pay_basis': 'per Annum',
#   'agency_start_date': '1997-04-15T00:00:00',
#   'title_description': 'LIEUTENANT D/A SPECIAL ASSIGNMENT',
#   'last_name': 'PAMPAFIKOS',
#   'regular_hours': '2091.42',
#   'ot_hours': '436.67',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '118016.28',
#   'work_location_borough': 'MANHATTAN',
#   'base_salary': '121179.00',
#   'total_other_pay': '14903.29',
#   'fiscal_year': '2016',
#   'total_ot_paid': '40180.33',
#   'first_name': 'HELEN'},
#  {'agency_name': 'POLICE DEPARTMENT',
#   'pay_basis': 'per Annum',
#   'agency_start_date': '2007-07-09T00:00:00',
#   'title_description': 'P.O. DA DET GR3',
#   'last_name': 'PAMPENA',
#   'regular_hours': '1922.85',
#   'ot_hours': '253.72',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '85347.84',
#   'work_location_borough': 'QUEENS',
#   'base_salary': '87204.00',
#   'total_other_pay': '12072.82',
#   'fiscal_year': '2016',
#   'total_ot_paid': '17748.62',
#   'mid_init': 'J',
#   'first_name': 'ANGELO'},
#  {'agency_name': 'POLICE DEPARTMENT',
#   'pay_basis': 'per Annum',
#   'agency_start_date': '2006-01-09T00:00:00',
#   'title_description': 'POLICE OFFICER',
#   'last_name': 'PAMPHILE',
#   'regular_hours': '2091.42',
#   'ot_hours': '117.72',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '84137.87',
#   'work_location_borough': 'BRONX',
#   'base_salary': '78026.00',
#   'total_other_pay': '13383.27',
#   'fiscal_year': '2016',
#   'total_ot_paid': '9062.59',
#   'first_name': 'DAPHNEY'},
#  {'agency_name': 'POLICE DEPARTMENT',
#   'pay_basis': 'per Annum',
#   'agency_start_date': '2013-01-09T00:00:00',
#   'title_description': 'POLICE OFFICER',
#   'last_name': 'PAMPHILE',
#   'regular_hours': '2091.42',
#   'ot_hours': '194.67',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '51215.11',
#   'work_location_borough': 'BRONX',
#   'base_salary': '49760.00',
#   'total_other_pay': '7886.14',
#   'fiscal_year': '2016',
#   'total_ot_paid': '7239.93',
#   'first_name': 'KEVIN'},
#  {'agency_name': 'POLICE DEPARTMENT',
#   'pay_basis': 'per Annum',
#   'agency_start_date': '2005-01-10T00:00:00',
#   'title_description': 'SERGEANT',
#   'last_name': 'PAN',
#   'regular_hours': '2091.42',
#   'ot_hours': '36.67',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '102802.38',
#   'work_location_borough': 'MANHATTAN',
#   'base_salary': '103585.00',
#   'total_other_pay': '14166.31',
#   'fiscal_year': '2016',
#   'total_ot_paid': '3226.48',
#   'mid_init': 'T',
#   'first_name': 'JESSIE'},
#  {'agency_name': 'POLICE DEPARTMENT',
#   'pay_basis': 'per Annum',
#   'agency_start_date': '2006-07-10T00:00:00',
#   'title_description': 'POLICE OFFICER',
#   'last_name': 'PAN',
#   'regular_hours': '2091.42',
#   'ot_hours': '146.40',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '83933.75',
#   'work_location_borough': 'QUEENS',
#   'base_salary': '78026.00',
#   'total_other_pay': '12969.49',
#   'fiscal_year': '2016',
#   'total_ot_paid': '9792.52',
#   'first_name': 'JOHN'},
#  {'agency_name': 'POLICE DEPARTMENT',
#   'pay_basis': 'per Annum',
#   'agency_start_date': '1995-06-30T00:00:00',
#   'title_description': 'P.O. DA DET GR3',
#   'last_name': 'PAN',
#   'regular_hours': '1051.42',
#   'ot_hours': '252.67',
#   'leave_status_as_of_july_31': 'CEASED',
#   'regular_gross_paid': '66397.57',
#   'work_location_borough': 'MANHATTAN',
#   'base_salary': '90822.00',
#   'total_other_pay': '10892.09',
#   'fiscal_year': '2016',
#   'total_ot_paid': '18682.96',
#   'mid_init': 'V',
#   'first_name': 'KAREN'},
#  {'agency_name': 'POLICE DEPARTMENT',
#   'pay_basis': 'per Annum',
#   'agency_start_date': '2013-07-09T00:00:00',
#   'title_description': 'POLICE OFFICER',
#   'last_name': 'PAN',
#   'regular_hours': '2091.42',
#   'ot_hours': '262.33',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '48146.21',
#   'work_location_borough': 'MANHATTAN',
#   'base_salary': '49760.00',
#   'total_other_pay': '7349.95',
#   'fiscal_year': '2016',
#   'total_ot_paid': '10125.50',
#   'first_name': 'MEI'},
#  {'agency_name': 'POLICE DEPARTMENT',
#   'pay_basis': 'per Annum',
#   'agency_start_date': '2006-01-09T00:00:00',
#   'title_description': 'POLICE OFFICER',
#   'last_name': 'PAN',
#   'regular_hours': '2091.42',
#   'ot_hours': '428.87',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '84137.87',
#   'work_location_borough': 'MANHATTAN',
#   'base_salary': '78026.00',
#   'total_other_pay': '12050.65',
#   'fiscal_year': '2016',
#   'total_ot_paid': '30975.11',
#   'first_name': 'MIN QIN'},
#  {'agency_name': 'POLICE DEPARTMENT',
#   'pay_basis': 'per Annum',
#   'agency_start_date': '2010-06-14T00:00:00',
#   'title_description': 'MANAGEMENT AUDITOR',
#   'last_name': 'PAN',
#   'regular_hours': '1830.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '63358.25',
#   'work_location_borough': 'MANHATTAN',
#   'base_salary': '67409.00',
#   'total_other_pay': '5784.91',
#   'fiscal_year': '2016',
#   'total_ot_paid': '0.00',
#   'first_name': 'YE'},
#  {'agency_name': 'POLICE DEPARTMENT',
#   'pay_basis': 'per Annum',
#   'agency_start_date': '1995-04-30T00:00:00',
#   'title_description': 'SERGEANT',
#   'last_name': 'PANACOPOULOS',
#   'regular_hours': '348.57',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'CEASED',
#   'regular_gross_paid': '23293.14',
#   'work_location_borough': 'MANHATTAN',
#   'base_salary': '102054.00',
#   'total_other_pay': '5143.84',
#   'fiscal_year': '2016',
#   'total_ot_paid': '0.00',
#   'first_name': 'SPIROS'},
#  {'agency_name': 'POLICE DEPARTMENT',
#   'pay_basis': 'per Annum',
#   'agency_start_date': '2016-04-06T00:00:00',
#   'title_description': 'POLICE OFFICER',
#   'last_name': 'PANAGIOTOPOULOS',
#   'regular_hours': '491.42',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '7838.47',
#   'work_location_borough': 'MANHATTAN',
#   'base_salary': '42819.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2016',
#   'total_ot_paid': '0.00',
#   'mid_init': 'G',
#   'first_name': 'KONSTANTINOS'},
#  {'agency_name': 'POLICE DEPARTMENT',
#   'pay_basis': 'per Hour',
#   'agency_start_date': '2016-01-11T00:00:00',
#   'title_description': 'POLICE CADET',
#   'last_name': 'PANAGIOTOU',
#   'regular_hours': '748.83',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '9460.94',
#   'work_location_borough': 'QUEENS',
#   'base_salary': '15.18',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2016',
#   'total_ot_paid': '0.00',
#   'first_name': 'ANDREAS'},
#  {'agency_name': 'POLICE DEPARTMENT',
#   'pay_basis': 'per Annum',
#   'agency_start_date': '1995-06-30T00:00:00',
#   'title_description': 'P.O. DA DET GR3',
#   'last_name': 'PANAGOPOULOS',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'CEASED',
#   'regular_gross_paid': '23895.19',
#   'work_location_borough': 'MANHATTAN',
#   'base_salary': '89923.00',
#   'total_other_pay': '3192.08',
#   'fiscal_year': '2016',
#   'total_ot_paid': '0.00',
#   'mid_init': 'E',
#   'first_name': 'STILIANOS'},
#  {'agency_name': 'POLICE DEPARTMENT',
#   'pay_basis': 'per Annum',
#   'agency_start_date': '1992-06-30T00:00:00',
#   'title_description': 'POLICE OFFICER',
#   'last_name': 'PANARESE',
#   'regular_hours': '2091.42',
#   'ot_hours': '17.17',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '84324.25',
#   'work_location_borough': 'QUEENS',
#   'base_salary': '78026.00',
#   'total_other_pay': '21077.15',
#   'fiscal_year': '2016',
#   'total_ot_paid': '1920.19',
#   'mid_init': 'A',
#   'first_name': 'GLENN'},
#  {'agency_name': 'POLICE DEPARTMENT',
#   'pay_basis': 'per Annum',
#   'agency_start_date': '1990-10-15T00:00:00',
#   'title_description': 'POLICE OFFICER',
#   'last_name': 'PANARESE',
#   'regular_hours': '2091.42',
#   'ot_hours': '16.78',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '84324.25',
#   'work_location_borough': 'QUEENS',
#   'base_salary': '78026.00',
#   'total_other_pay': '21128.34',
#   'fiscal_year': '2016',
#   'total_ot_paid': '1381.21',
#   'mid_init': 'G',
#   'first_name': 'STEPHEN'},
#  {'agency_name': 'POLICE DEPARTMENT',
#   'pay_basis': 'per Annum',
#   'agency_start_date': '2014-07-09T00:00:00',
#   'title_description': 'POLICE OFFICER',
#   'last_name': 'PANARIELLO',
#   'regular_hours': '2091.42',
#   'ot_hours': '158.42',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '44097.46',
#   'work_location_borough': 'BROOKLYN',
#   'base_salary': '44521.00',
#   'total_other_pay': '6034.01',
#   'fiscal_year': '2016',
#   'total_ot_paid': '5797.98',
#   'mid_init': 'E',
#   'first_name': 'ANTHONY'},
#  {'agency_name': 'POLICE DEPARTMENT',
#   'pay_basis': 'per Annum',
#   'agency_start_date': '1990-10-15T00:00:00',
#   'title_description': 'POLICE OFFICER',
#   'last_name': 'PANARIELLO',
#   'regular_hours': '1920.00',
#   'ot_hours': '317.62',
#   'leave_status_as_of_july_31': 'CEASED',
#   'regular_gross_paid': '81979.24',
#   'work_location_borough': 'MANHATTAN',
#   'base_salary': '78026.00',
#   'total_other_pay': '20174.77',
#   'fiscal_year': '2016',
#   'total_ot_paid': '25197.87',
#   'mid_init': 'J',
#   'first_name': 'MATTHEW'},
#  {'agency_name': 'POLICE DEPARTMENT',
#   'pay_basis': 'per Annum',
#   'agency_start_date': '2015-01-07T00:00:00',
#   'title_description': 'POLICE OFFICER',
#   'last_name': 'PANAROTTO',
#   'regular_hours': '2091.42',
#   'ot_hours': '175.17',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '42955.90',
#   'work_location_borough': 'BRONX',
#   'base_salary': '42819.00',
#   'total_other_pay': '4338.80',
#   'fiscal_year': '2016',
#   'total_ot_paid': '5437.42',
#   'mid_init': 'P',
#   'first_name': 'RYAN'},
#  {'agency_name': 'POLICE DEPARTMENT',
#   'pay_basis': 'per Annum',
#   'agency_start_date': '2006-07-20T00:00:00',
#   'title_description': 'P.O. DA DET GR3',
#   'last_name': 'PANAS',
#   'regular_hours': '2091.42',
#   'ot_hours': '392.37',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '91756.19',
#   'work_location_borough': 'QUEENS',
#   'base_salary': '87791.00',
#   'total_other_pay': '14245.97',
#   'fiscal_year': '2016',
#   'total_ot_paid': '27177.13',
#   'mid_init': 'J',
#   'first_name': 'BENJAMIN'},
#  {'agency_name': 'POLICE DEPARTMENT',
#   'pay_basis': 'per Annum',
#   'agency_start_date': '2003-07-01T00:00:00',
#   'title_description': 'POLICE OFFICER',
#   'last_name': 'PANASUK',
#   'regular_hours': '2091.42',
#   'ot_hours': '228.42',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '84324.25',
#   'work_location_borough': 'BRONX',
#   'base_salary': '78026.00',
#   'total_other_pay': '16401.37',
#   'fiscal_year': '2016',
#   'total_ot_paid': '17072.18',
#   'mid_init': 'P',
#   'first_name': 'ADAM'},
#  {'agency_name': 'POLICE DEPARTMENT',
#   'pay_basis': 'per Annum',
#   'agency_start_date': '2011-07-06T00:00:00',
#   'title_description': 'POLICE OFFICER',
#   'last_name': 'PANAYIOTOU',
#   'regular_hours': '2091.42',
#   'ot_hours': '219.07',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '59085.02',
#   'work_location_borough': 'RICHMOND',
#   'base_salary': '57747.00',
#   'total_other_pay': '3856.47',
#   'fiscal_year': '2016',
#   'total_ot_paid': '9557.95',
#   'first_name': 'ANDREW'},
#  {'agency_name': 'POLICE DEPARTMENT',
#   'pay_basis': 'per Annum',
#   'agency_start_date': '2004-09-21T00:00:00',
#   'title_description': 'SCHOOL SAFETY AGENT',
#   'last_name': 'PANAYOTY',
#   'regular_hours': '2091.42',
#   'ot_hours': '17.50',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '46068.19',
#   'work_location_borough': 'QUEENS',
#   'base_salary': '39868.00',
#   'total_other_pay': '1125.41',
#   'fiscal_year': '2016',
#   'total_ot_paid': '1048.58',
#   'first_name': 'WILKINSON'},
#  {'agency_name': 'POLICE DEPARTMENT',
#   'pay_basis': 'per Annum',
#   'agency_start_date': '2012-09-27T00:00:00',
#   'title_description': 'TRAFFIC ENFORCEMENT AGENT',
#   'last_name': 'PANCHADCHARAM',
#   'regular_hours': '2091.42',
#   'ot_hours': '1075.75',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '40382.85',
#   'work_location_borough': 'QUEENS',
#   'base_salary': '39164.00',
#   'total_other_pay': '3773.38',
#   'fiscal_year': '2016',
#   'total_ot_paid': '27889.26',
#   'first_name': 'ARULRANGAN'},
#  {'agency_name': 'POLICE DEPARTMENT',
#   'pay_basis': 'per Annum',
#   'agency_start_date': '1991-04-17T00:00:00',
#   'title_description': 'CRIMINALIST',
#   'last_name': 'PANCHAL',
#   'regular_hours': '1830.00',
#   'ot_hours': '367.75',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '73911.36',
#   'work_location_borough': 'QUEENS',
#   'base_salary': '74743.00',
#   'total_other_pay': '8153.04',
#   'fiscal_year': '2016',
#   'total_ot_paid': '19162.39',
#   'mid_init': 'R',
#   'first_name': 'RAMILABEN'},
#  {'agency_name': 'POLICE DEPARTMENT',
#   'pay_basis': 'per Annum',
#   'agency_start_date': '2008-07-08T00:00:00',
#   'title_description': 'P.O. DA DET GR3',
#   'last_name': 'PANCHYN',
#   'regular_hours': '2091.42',
#   'ot_hours': '507.75',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '90829.18',
#   'work_location_borough': 'BROOKLYN',
#   'base_salary': '87791.00',
#   'total_other_pay': '15139.46',
#   'fiscal_year': '2016',
#   'total_ot_paid': '38532.45',
#   'first_name': 'DANIEL'},
#  {'agency_name': 'POLICE DEPARTMENT',
#   'pay_basis': 'per Annum',
#   'agency_start_date': '2005-04-25T00:00:00',
#   'title_description': 'TRAFFIC ENFORCEMENT AGENT',
#   'last_name': 'PANDEYA',
#   'regular_hours': '2091.42',
#   'ot_hours': '758.50',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '41913.30',
#   'work_location_borough': 'QUEENS',
#   'base_salary': '39164.00',
#   'total_other_pay': '4219.58',
#   'fiscal_year': '2016',
#   'total_ot_paid': '25687.53',
#   'mid_init': 'P',
#   'first_name': 'DURGA'},
#  {'agency_name': 'POLICE DEPARTMENT',
#   'pay_basis': 'per Annum',
#   'agency_start_date': '2013-01-09T00:00:00',
#   'title_description': 'POLICE OFFICER',
#   'last_name': 'PANDHI',
#   'regular_hours': '2091.42',
#   'ot_hours': '153.25',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '52469.59',
#   'work_location_borough': 'BROOKLYN',
#   'base_salary': '49760.00',
#   'total_other_pay': '5729.31',
#   'fiscal_year': '2016',
#   'total_ot_paid': '5825.27',
#   'mid_init': 'J',
#   'first_name': 'KRUNAL'},
#  {'agency_name': 'POLICE DEPARTMENT',
#   'pay_basis': 'per Annum',
#   'agency_start_date': '2012-01-09T00:00:00',
#   'title_description': 'POLICE OFFICER',
#   'last_name': 'PANDO',
#   'regular_hours': '2091.42',
#   'ot_hours': '355.58',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '56774.52',
#   'work_location_borough': 'BRONX',
#   'base_salary': '54341.00',
#   'total_other_pay': '4817.47',
#   'fiscal_year': '2016',
#   'total_ot_paid': '14807.58',
#   'mid_init': 'J',
#   'first_name': 'MICHAEL'},
#  {'agency_name': 'POLICE DEPARTMENT',
#   'pay_basis': 'per Annum',
#   'agency_start_date': '1994-02-28T00:00:00',
#   'title_description': 'POLICE OFFICER',
#   'last_name': 'PANDOLFI',
#   'regular_hours': '2091.42',
#   'ot_hours': '529.17',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '84324.25',
#   'work_location_borough': 'RICHMOND',
#   'base_salary': '78026.00',
#   'total_other_pay': '16795.71',
#   'fiscal_year': '2016',
#   'total_ot_paid': '38315.71',
#   'mid_init': 'A',
#   'first_name': 'ROBERT'},
#  {'agency_name': 'POLICE DEPARTMENT',
#   'pay_basis': 'per Hour',
#   'agency_start_date': '2000-04-27T00:00:00',
#   'title_description': 'SCHOOL CROSSING GUARD',
#   'last_name': 'PANDOLFINI',
#   'regular_hours': '947.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '14540.27',
#   'work_location_borough': 'QUEENS',
#   'base_salary': '13.83',
#   'total_other_pay': '659.42',
#   'fiscal_year': '2016',
#   'total_ot_paid': '0.00',
#   'mid_init': 'A',
#   'first_name': 'MARGARET'},
#  {'agency_name': 'POLICE DEPARTMENT',
#   'pay_basis': 'per Annum',
#   'agency_start_date': '1987-01-20T00:00:00',
#   'title_description': 'POLICE OFFICER',
#   'last_name': 'PANDOLFO',
#   'regular_hours': '2091.42',
#   'ot_hours': '152.03',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '84324.25',
#   'work_location_borough': 'QUEENS',
#   'base_salary': '78026.00',
#   'total_other_pay': '17126.49',
#   'fiscal_year': '2016',
#   'total_ot_paid': '15266.12',
#   'mid_init': 'C',
#   'first_name': 'RICHARD'},
#  {'agency_name': 'POLICE DEPARTMENT',
#   'pay_basis': 'per Annum',
#   'agency_start_date': '2007-07-09T00:00:00',
#   'title_description': 'POLICE OFFICER',
#   'last_name': 'PANDOS',
#   'regular_hours': '2091.42',
#   'ot_hours': '260.50',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '83466.58',
#   'work_location_borough': 'MANHATTAN',
#   'base_salary': '78026.00',
#   'total_other_pay': '11157.77',
#   'fiscal_year': '2016',
#   'total_ot_paid': '17528.43',
#   'mid_init': 'M',
#   'first_name': 'THOMAS'},
#  {'agency_name': 'POLICE DEPARTMENT',
#   'pay_basis': 'per Annum',
#   'agency_start_date': '1997-04-15T00:00:00',
#   'title_description': 'SERGEANT',
#   'last_name': 'PANDULLO',
#   'regular_hours': '2091.42',
#   'ot_hours': '448.62',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '102689.21',
#   'work_location_borough': 'BROOKLYN',
#   'base_salary': '103585.00',
#   'total_other_pay': '21833.26',
#   'fiscal_year': '2016',
#   'total_ot_paid': '41526.08',
#   'first_name': 'FRANK'},
#  {'agency_name': 'POLICE DEPARTMENT',
#   'pay_basis': 'per Annum',
#   'agency_start_date': '2010-01-11T00:00:00',
#   'title_description': 'POLICE OFFICER',
#   'last_name': 'PANE',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'CEASED',
#   'regular_gross_paid': '1499.40',
#   'work_location_borough': 'MANHATTAN',
#   'base_salary': '54341.00',
#   'total_other_pay': '541.12',
#   'fiscal_year': '2016',
#   'total_ot_paid': '289.06',
#   'mid_init': 'M',
#   'first_name': 'CHRISTINA'},
#  {'agency_name': 'POLICE DEPARTMENT',
#   'pay_basis': 'per Annum',
#   'agency_start_date': '2013-01-09T00:00:00',
#   'title_description': 'POLICE OFFICER',
#   'last_name': 'PANE',
#   'regular_hours': '1894.30',
#   'ot_hours': '206.63',
#   'leave_status_as_of_july_31': 'CEASED',
#   'regular_gross_paid': '49107.67',
#   'work_location_borough': 'MANHATTAN',
#   'base_salary': '49760.00',
#   'total_other_pay': '5175.90',
#   'fiscal_year': '2016',
#   'total_ot_paid': '9391.31',
#   'mid_init': 'P',
#   'first_name': 'MARK'},
#  {'agency_name': 'POLICE DEPARTMENT',
#   'pay_basis': 'per Annum',
#   'agency_start_date': '2011-07-06T00:00:00',
#   'title_description': 'POLICE OFFICER',
#   'last_name': 'PANEK',
#   'regular_hours': '2091.42',
#   'ot_hours': '344.17',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '59085.02',
#   'work_location_borough': 'BROOKLYN',
#   'base_salary': '57747.00',
#   'total_other_pay': '6089.69',
#   'fiscal_year': '2016',
#   'total_ot_paid': '15340.23',
#   'mid_init': 'S',
#   'first_name': 'JOSEPH'},
#  {'agency_name': 'POLICE DEPARTMENT',
#   'pay_basis': 'per Annum',
#   'agency_start_date': '2001-07-02T00:00:00',
#   'title_description': 'POLICE OFFICER',
#   'last_name': 'PANEPINTO',
#   'regular_hours': '2091.42',
#   'ot_hours': '340.15',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '84324.25',
#   'work_location_borough': 'BROOKLYN',
#   'base_salary': '78026.00',
#   'total_other_pay': '15587.59',
#   'fiscal_year': '2016',
#   'total_ot_paid': '21596.42',
#   'mid_init': 'P',
#   'first_name': 'MICHAEL'},
#  {'agency_name': 'POLICE DEPARTMENT',
#   'pay_basis': 'per Annum',
#   'agency_start_date': '2014-06-24T00:00:00',
#   'title_description': 'SCHOOL SAFETY AGENT',
#   'last_name': 'PANEPINTO',
#   'regular_hours': '2091.42',
#   'ot_hours': '485.75',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '35692.69',
#   'work_location_borough': 'RICHMOND',
#   'base_salary': '38828.00',
#   'total_other_pay': '2160.65',
#   'fiscal_year': '2016',
#   'total_ot_paid': '12111.95',
#   'first_name': 'SNEZANA'},
#  {'agency_name': 'POLICE DEPARTMENT',
#   'pay_basis': 'per Annum',
#   'agency_start_date': '2005-01-10T00:00:00',
#   'title_description': 'SERGEANT',
#   'last_name': 'PANETTA',
#   'regular_hours': '2091.42',
#   'ot_hours': '380.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '101122.97',
#   'work_location_borough': 'BROOKLYN',
#   'base_salary': '103585.00',
#   'total_other_pay': '18869.53',
#   'fiscal_year': '2016',
#   'total_ot_paid': '30370.03',
#   'mid_init': 'L',
#   'first_name': 'ANTHONY'},
#  {'agency_name': 'POLICE DEPARTMENT',
#   'pay_basis': 'per Annum',
#   'agency_start_date': '2000-03-01T00:00:00',
#   'title_description': 'POLICE OFFICER D/A DETECTIVE 2ND GR',
#   'last_name': 'PANETTA',
#   'regular_hours': '2091.42',
#   'ot_hours': '106.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '95351.40',
#   'work_location_borough': 'MANHATTAN',
#   'base_salary': '102054.00',
#   'total_other_pay': '15831.51',
#   'fiscal_year': '2016',
#   'total_ot_paid': '8287.59',
#   'mid_init': 'J',
#   'first_name': 'CHRISTOPHER'},
#  {'agency_name': 'POLICE DEPARTMENT',
#   'pay_basis': 'per Annum',
#   'agency_start_date': '2014-07-09T00:00:00',
#   'title_description': 'POLICE OFFICER',
#   'last_name': 'PANETTA',
#   'regular_hours': '2091.42',
#   'ot_hours': '238.32',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '44097.46',
#   'work_location_borough': 'BROOKLYN',
#   'base_salary': '44521.00',
#   'total_other_pay': '5954.41',
#   'fiscal_year': '2016',
#   'total_ot_paid': '7177.19',
#   'mid_init': 'R',
#   'first_name': 'MICHAEL'},
#  {'agency_name': 'POLICE DEPARTMENT',
#   'pay_basis': 'per Annum',
#   'agency_start_date': '1995-04-30T00:00:00',
#   'title_description': 'LIEUTENANT D/A COMMANDER OF DETECTIVE SQUAD',
#   'last_name': 'PANETTA',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'CEASED',
#   'regular_gross_paid': '2555.79',
#   'work_location_borough': 'MANHATTAN',
#   'base_salary': '127588.00',
#   'total_other_pay': '315.53',
#   'fiscal_year': '2016',
#   'total_ot_paid': '0.00',
#   'first_name': 'THOMAS'},
#  {'agency_name': 'POLICE DEPARTMENT',
#   'pay_basis': 'per Annum',
#   'agency_start_date': '2016-01-06T00:00:00',
#   'title_description': 'POLICE OFFICER',
#   'last_name': 'PANETTIERE',
#   'regular_hours': '988.57',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '18484.76',
#   'work_location_borough': 'MANHATTAN',
#   'base_salary': '42819.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2016',
#   'total_ot_paid': '0.00',
#   'mid_init': 'M',
#   'first_name': 'GINA'},
#  {'agency_name': 'POLICE DEPARTMENT',
#   'pay_basis': 'per Annum',
#   'agency_start_date': '2013-01-09T00:00:00',
#   'title_description': 'POLICE OFFICER',
#   'last_name': 'PANG',
#   'regular_hours': '2091.42',
#   'ot_hours': '191.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '51215.11',
#   'work_location_borough': 'BROOKLYN',
#   'base_salary': '49760.00',
#   'total_other_pay': '1683.37',
#   'fiscal_year': '2016',
#   'total_ot_paid': '7120.28',
#   'mid_init': 'J',
#   'first_name': 'CHANTHOU'},
#  {'agency_name': 'POLICE DEPARTMENT',
#   'pay_basis': 'per Annum',
#   'agency_start_date': '2005-07-11T00:00:00',
#   'title_description': 'P.O. DET SPEC',
#   'last_name': 'PANG',
#   'regular_hours': '2091.42',
#   'ot_hours': '436.32',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '85352.39',
#   'work_location_borough': 'BROOKLYN',
#   'base_salary': '87204.00',
#   'total_other_pay': '13878.01',
#   'fiscal_year': '2016',
#   'total_ot_paid': '30661.16',
#   'mid_init': 'Y',
#   'first_name': 'LOK'},
#  {'agency_name': 'POLICE DEPARTMENT',
#   'pay_basis': 'per Annum',
#   'agency_start_date': '2003-07-01T00:00:00',
#   'title_description': 'POLICE OFFICER',
#   'last_name': 'PANGALLO',
#   'regular_hours': '2091.42',
#   'ot_hours': '445.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '84324.25',
#   'work_location_borough': 'BROOKLYN',
#   'base_salary': '78026.00',
#   'total_other_pay': '15908.07',
#   'fiscal_year': '2016',
#   'total_ot_paid': '31228.22',
#   'mid_init': 'S',
#   'first_name': 'MICHAEL'},
#  {'agency_name': 'POLICE DEPARTMENT',
#   'pay_basis': 'per Annum',
#   'agency_start_date': '2007-01-10T00:00:00',
#   'title_description': 'POLICE OFFICER',
#   'last_name': 'PANIAGUA',
#   'regular_hours': '2091.42',
#   'ot_hours': '170.90',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '83718.54',
#   'work_location_borough': 'MANHATTAN',
#   'base_salary': '78026.00',
#   'total_other_pay': '11667.02',
#   'fiscal_year': '2016',
#   'total_ot_paid': '11851.02',
#   'first_name': 'IVAN'},
#  {'agency_name': 'POLICE DEPARTMENT',
#   'pay_basis': 'per Annum',
#   'agency_start_date': '2005-04-25T00:00:00',
#   'title_description': 'TRAFFIC ENFORC AGENT',
#   'last_name': 'PANIAGUA',
#   'regular_hours': '2091.42',
#   'ot_hours': '701.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '48235.25',
#   'work_location_borough': 'MANHATTAN',
#   'base_salary': '44714.00',
#   'total_other_pay': '6839.79',
#   'fiscal_year': '2016',
#   'total_ot_paid': '25781.25',
#   'first_name': 'RAFAEL'},
#  {'agency_name': 'POLICE DEPARTMENT',
#   'pay_basis': 'per Annum',
#   'agency_start_date': '1992-06-30T00:00:00',
#   'title_description': 'POLICE OFFICER D/A DETECTIVE 2ND GR',
#   'last_name': 'PANICHI',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'CEASED',
#   'regular_gross_paid': '0.00',
#   'work_location_borough': 'MANHATTAN',
#   'base_salary': '99053.00',
#   'total_other_pay': '28.34',
#   'fiscal_year': '2016',
#   'total_ot_paid': '0.00',
#   'mid_init': 'F',
#   'first_name': 'MICHAEL'},
#  {'agency_name': 'POLICE DEPARTMENT',
#   'pay_basis': 'per Annum',
#   'agency_start_date': '2000-05-30T00:00:00',
#   'title_description': 'ASSOC SPVR OF SCHOOL SECURITY',
#   'last_name': 'PANICKER',
#   'regular_hours': '1960.72',
#   'ot_hours': '5.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '72574.66',
#   'work_location_borough': 'RICHMOND',
#   'base_salary': '71021.00',
#   'total_other_pay': '6254.06',
#   'fiscal_year': '2016',
#   'total_ot_paid': '250.23',
#   'mid_init': 'K',
#   'first_name': 'SANTHOSH'},
#  {'agency_name': 'POLICE DEPARTMENT',
#   'pay_basis': 'per Annum',
#   'agency_start_date': '2003-07-01T00:00:00',
#   'title_description': 'SERGEANT',
#   'last_name': 'PANICO',
#   'regular_hours': '2091.42',
#   'ot_hours': '372.20',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '102689.21',
#   'work_location_borough': 'MANHATTAN',
#   'base_salary': '103585.00',
#   'total_other_pay': '16068.72',
#   'fiscal_year': '2016',
#   'total_ot_paid': '28249.44',
#   'mid_init': 'F',
#   'first_name': 'JOSEPH'},
#  {'agency_name': 'POLICE DEPARTMENT',
#   'pay_basis': 'per Annum',
#   'agency_start_date': '2008-07-08T00:00:00',
#   'title_description': 'POLICE OFFICER',
#   'last_name': 'PANICO',
#   'regular_hours': '2091.42',
#   'ot_hours': '349.83',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '82913.51',
#   'work_location_borough': 'BROOKLYN',
#   'base_salary': '78026.00',
#   'total_other_pay': '11382.15',
#   'fiscal_year': '2016',
#   'total_ot_paid': '22578.73',
#   'mid_init': 'J',
#   'first_name': 'JOSEPH'},
#  {'agency_name': 'POLICE DEPARTMENT',
#   'pay_basis': 'per Annum',
#   'agency_start_date': '1998-07-01T00:00:00',
#   'title_description': 'POLICE OFFICER',
#   'last_name': 'PANICO',
#   'regular_hours': '2091.42',
#   'ot_hours': '207.40',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '84324.25',
#   'work_location_borough': 'MANHATTAN',
#   'base_salary': '78026.00',
#   'total_other_pay': '13709.02',
#   'fiscal_year': '2016',
#   'total_ot_paid': '15087.74',
#   'mid_init': 'M',
#   'first_name': 'SUSAN'},
#  {'agency_name': 'POLICE DEPARTMENT',
#   'pay_basis': 'per Annum',
#   'agency_start_date': '2013-07-09T00:00:00',
#   'title_description': 'POLICE OFFICER',
#   'last_name': 'PANIK',
#   'regular_hours': '2091.42',
#   'ot_hours': '244.25',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '48146.21',
#   'work_location_borough': 'RICHMOND',
#   'base_salary': '49760.00',
#   'total_other_pay': '7082.99',
#   'fiscal_year': '2016',
#   'total_ot_paid': '9778.13',
#   'mid_init': 'P',
#   'first_name': 'JOHN'},
#  {'agency_name': 'POLICE DEPARTMENT',
#   'pay_basis': 'per Annum',
#   'agency_start_date': '2016-01-06T00:00:00',
#   'title_description': 'POLICE OFFICER',
#   'last_name': 'PANIK',
#   'regular_hours': '988.57',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '18484.76',
#   'work_location_borough': 'MANHATTAN',
#   'base_salary': '42819.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2016',
#   'total_ot_paid': '0.00',
#   'mid_init': 'J',
#   'first_name': 'MATTHEW'},
#  {'agency_name': 'POLICE DEPARTMENT',
#   'pay_basis': 'per Annum',
#   'agency_start_date': '1995-06-30T00:00:00',
#   'title_description': 'POLICE OFFICER',
#   'last_name': 'PANISS',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'CEASED',
#   'regular_gross_paid': '10612.76',
#   'work_location_borough': 'MANHATTAN',
#   'base_salary': '78026.00',
#   'total_other_pay': '3737.11',
#   'fiscal_year': '2016',
#   'total_ot_paid': '2466.29',
#   'mid_init': 'T',
#   'first_name': 'WILLIAM'},
#  {'agency_name': 'POLICE DEPARTMENT',
#   'pay_basis': 'per Annum',
#   'agency_start_date': '1993-08-30T00:00:00',
#   'title_description': 'SERGEANT',
#   'last_name': 'PANISSIDI',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'CEASED',
#   'regular_gross_paid': '744.92',
#   'work_location_borough': 'MANHATTAN',
#   'base_salary': '101044.00',
#   'total_other_pay': '633.73',
#   'fiscal_year': '2016',
#   'total_ot_paid': '0.00',
#   'first_name': 'DANIEL'},
#  {'agency_name': 'POLICE DEPARTMENT',
#   'pay_basis': 'per Annum',
#   'agency_start_date': '1994-02-28T00:00:00',
#   'title_description': 'P.O. DA DET GR3',
#   'last_name': 'PANISSIDI',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'CEASED',
#   'regular_gross_paid': '0.00',
#   'work_location_borough': 'MANHATTAN',
#   'base_salary': '89033.00',
#   'total_other_pay': '167.41',
#   'fiscal_year': '2016',
#   'total_ot_paid': '0.00',
#   'first_name': 'LON'},
#  {'agency_name': 'POLICE DEPARTMENT',
#   'pay_basis': 'per Hour',
#   'agency_start_date': '2014-08-22T00:00:00',
#   'title_description': 'SCHOOL CROSSING GUARD',
#   'last_name': 'PANKOWSKI',
#   'regular_hours': '1118.83',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '14359.10',
#   'work_location_borough': 'BROOKLYN',
#   'base_salary': '11.79',
#   'total_other_pay': '207.00',
#   'fiscal_year': '2016',
#   'total_ot_paid': '0.00',
#   'mid_init': 'L',
#   'first_name': 'JENNIFER'},
#  {'agency_name': 'POLICE DEPARTMENT',
#   'pay_basis': 'per Annum',
#   'agency_start_date': '2002-07-01T00:00:00',
#   'title_description': 'SERGEANT',
#   'last_name': 'PANNI',
#   'regular_hours': '2091.42',
#   'ot_hours': '103.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '87992.30',
#   'work_location_borough': 'QUEENS',
#   'base_salary': '103585.00',
#   'total_other_pay': '11850.25',
#   'fiscal_year': '2016',
#   'total_ot_paid': '6946.67',
#   'first_name': 'ERIC'},
#  {'agency_name': 'POLICE DEPARTMENT',
#   'pay_basis': 'per Annum',
#   'agency_start_date': '1994-02-28T00:00:00',
#   'title_description': 'POLICE OFFICER',
#   'last_name': 'PANNIZZO',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'CEASED',
#   'regular_gross_paid': '3485.00',
#   'work_location_borough': 'MANHATTAN',
#   'base_salary': '78026.00',
#   'total_other_pay': '421.56',
#   'fiscal_year': '2016',
#   'total_ot_paid': '165.82',
#   'mid_init': 'J',
#   'first_name': 'DAVID'},
#  {'agency_name': 'POLICE DEPARTMENT',
#   'pay_basis': 'per Annum',
#   'agency_start_date': '2006-07-10T00:00:00',
#   'title_description': 'POLICE OFFICER',
#   'last_name': 'PANNONE',
#   'regular_hours': '2091.42',
#   'ot_hours': '68.27',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '83933.75',
#   'work_location_borough': 'MANHATTAN',
#   'base_salary': '78026.00',
#   'total_other_pay': '11848.08',
#   'fiscal_year': '2016',
#   'total_ot_paid': '5200.15',
#   'first_name': 'BARTHOLOMEW'},
#  {'agency_name': 'POLICE DEPARTMENT',
#   'pay_basis': 'per Annum',
#   'agency_start_date': '1996-07-18T00:00:00',
#   'title_description': 'SERGEANT',
#   'last_name': 'PANNONE',
#   'regular_hours': '2091.42',
#   'ot_hours': '555.73',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '102689.21',
#   'work_location_borough': 'QUEENS',
#   'base_salary': '103585.00',
#   'total_other_pay': '16049.50',
#   'fiscal_year': '2016',
#   'total_ot_paid': '44048.98',
#   'mid_init': 'A',
#   'first_name': 'DALLAS'},
#  {'agency_name': 'POLICE DEPARTMENT',
#   'pay_basis': 'per Annum',
#   'agency_start_date': '2012-12-03T00:00:00',
#   'title_description': 'POLICE ADMINISTRATIVE AIDE',
#   'last_name': 'PANNONE',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'CEASED',
#   'regular_gross_paid': '-117.68',
#   'work_location_borough': 'MANHATTAN',
#   'base_salary': '36899.00',
#   'total_other_pay': '333.23',
#   'fiscal_year': '2016',
#   'total_ot_paid': '0.00',
#   'first_name': 'JOSEPHINE'},
#  {'agency_name': 'POLICE DEPARTMENT',
#   'pay_basis': 'per Annum',
#   'agency_start_date': '1995-04-30T00:00:00',
#   'title_description': 'POLICE OFFICER',
#   'last_name': 'PANNONE',
#   'regular_hours': '2091.42',
#   'ot_hours': '194.83',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '84324.25',
#   'work_location_borough': 'MANHATTAN',
#   'base_salary': '78026.00',
#   'total_other_pay': '20215.44',
#   'fiscal_year': '2016',
#   'total_ot_paid': '14109.72',
#   'first_name': 'LOUIS'},
#  {'agency_name': 'POLICE DEPARTMENT',
#   'pay_basis': 'per Annum',
#   'agency_start_date': '1992-06-30T00:00:00',
#   'title_description': 'POLICE OFFICER',
#   'last_name': 'PANNOZZO',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'CEASED',
#   'regular_gross_paid': '2956.15',
#   'work_location_borough': 'MANHATTAN',
#   'base_salary': '78026.00',
#   'total_other_pay': '571.02',
#   'fiscal_year': '2016',
#   'total_ot_paid': '859.28',
#   'mid_init': 'B',
#   'first_name': 'JOHN'},
#  {'agency_name': 'POLICE DEPARTMENT',
#   'pay_basis': 'per Annum',
#   'agency_start_date': '2013-07-09T00:00:00',
#   'title_description': 'POLICE OFFICER',
#   'last_name': 'PANNULLA',
#   'regular_hours': '2091.42',
#   'ot_hours': '158.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '48146.21',
#   'work_location_borough': 'BROOKLYN',
#   'base_salary': '49760.00',
#   'total_other_pay': '5653.88',
#   'fiscal_year': '2016',
#   'total_ot_paid': '6277.37',
#   'mid_init': 'M',
#   'first_name': 'NICHOLAS'},
#  {'agency_name': 'POLICE DEPARTMENT',
#   'pay_basis': 'per Annum',
#   'agency_start_date': '1994-02-28T00:00:00',
#   'title_description': 'SERGEANT',
#   'last_name': 'PANOPOULOS',
#   'regular_hours': '1228.57',
#   'ot_hours': '83.58',
#   'leave_status_as_of_july_31': 'CEASED',
#   'regular_gross_paid': '84410.34',
#   'work_location_borough': 'MANHATTAN',
#   'base_salary': '102054.00',
#   'total_other_pay': '13285.68',
#   'fiscal_year': '2016',
#   'total_ot_paid': '8164.44',
#   'mid_init': 'G',
#   'first_name': 'ALKIVIADIS'},
#  {'agency_name': 'POLICE DEPARTMENT',
#   'pay_basis': 'per Annum',
#   'agency_start_date': '2000-09-29T00:00:00',
#   'title_description': 'P.O. DA DET GR3',
#   'last_name': 'PANOPOULOS',
#   'regular_hours': '2091.42',
#   'ot_hours': '307.03',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '91814.79',
#   'work_location_borough': 'MANHATTAN',
#   'base_salary': '90822.00',
#   'total_other_pay': '16672.81',
#   'fiscal_year': '2016',
#   'total_ot_paid': '23127.68',
#   'mid_init': 'G',
#   'first_name': 'KONSTANTINOS'},
#  {'agency_name': 'POLICE DEPARTMENT',
#   'pay_basis': 'per Annum',
#   'agency_start_date': '2004-02-23T00:00:00',
#   'title_description': 'SCHOOL SAFETY AGENT',
#   'last_name': 'PANORA',
#   'regular_hours': '2091.42',
#   'ot_hours': '572.75',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '46068.19',
#   'work_location_borough': 'BRONX',
#   'base_salary': '39868.00',
#   'total_other_pay': '2006.17',
#   'fiscal_year': '2016',
#   'total_ot_paid': '16035.24',
#   'mid_init': 'A',
#   'first_name': 'LUIS'},
#  {'agency_name': 'POLICE DEPARTMENT',
#   'pay_basis': 'per Annum',
#   'agency_start_date': '1990-10-15T00:00:00',
#   'title_description': 'POLICE OFFICER',
#   'last_name': 'PANOS',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'CEASED',
#   'regular_gross_paid': '162.70',
#   'work_location_borough': 'MANHATTAN',
#   'base_salary': '77253.00',
#   'total_other_pay': '27.69',
#   'fiscal_year': '2016',
#   'total_ot_paid': '0.00',
#   'first_name': 'ANTHONY'},
#  {'agency_name': 'POLICE DEPARTMENT',
#   'pay_basis': 'per Annum',
#   'agency_start_date': '2006-07-20T00:00:00',
#   'title_description': 'POLICE OFFICER',
#   'last_name': 'PANTALEO',
#   'regular_hours': '2091.42',
#   'ot_hours': '359.02',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '83921.92',
#   'work_location_borough': 'RICHMOND',
#   'base_salary': '78026.00',
#   'total_other_pay': '12853.79',
#   'fiscal_year': '2016',
#   'total_ot_paid': '23220.58',
#   'mid_init': 'J',
#   'first_name': 'DANIEL'},
#  {'agency_name': 'POLICE DEPARTMENT',
#   'pay_basis': 'per Annum',
#   'agency_start_date': '2008-02-25T00:00:00',
#   'title_description': 'SCHOOL SAFETY AGENT',
#   'last_name': 'PANTALEON',
#   'regular_hours': '2091.42',
#   'ot_hours': '865.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '46068.19',
#   'work_location_borough': 'MANHATTAN',
#   'base_salary': '39868.00',
#   'total_other_pay': '1294.25',
#   'fiscal_year': '2016',
#   'total_ot_paid': '24326.68',
#   'mid_init': 'R',
#   'first_name': 'JOSE'},
#  {'agency_name': 'POLICE DEPARTMENT',
#   'pay_basis': 'per Annum',
#   'agency_start_date': '2005-01-10T00:00:00',
#   'title_description': 'POLICE OFFICER',
#   'last_name': 'PANTALEON',
#   'regular_hours': '2091.42',
#   'ot_hours': '208.12',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '84665.14',
#   'work_location_borough': 'BROOKLYN',
#   'base_salary': '78026.00',
#   'total_other_pay': '15259.45',
#   'fiscal_year': '2016',
#   'total_ot_paid': '12892.75',
#   'mid_init': 'N',
#   'first_name': 'KIRSSI'},
#  {'agency_name': 'POLICE DEPARTMENT',
#   'pay_basis': 'per Annum',
#   'agency_start_date': '2014-08-25T00:00:00',
#   'title_description': 'CUSTODIAL ASSISTANT',
#   'last_name': 'PANTANO',
#   'regular_hours': '2091.42',
#   'ot_hours': '29.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '28699.38',
#   'work_location_borough': 'MANHATTAN',
#   'base_salary': '29011.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2016',
#   'total_ot_paid': '354.28',
#   'mid_init': 'F',
# ...
#   'base_salary': '54341.00',
#   'total_other_pay': '5690.52',
#   'fiscal_year': '2016',
#   'total_ot_paid': '6993.50',
#   'first_name': 'RANDOLPH'},
#  {'agency_name': 'POLICE DEPARTMENT',
#   'pay_basis': 'per Annum',
#   'agency_start_date': '2005-01-10T00:00:00',
#   'title_description': 'POLICE OFFICER',
#   'last_name': 'PENARANDA',
#   'regular_hours': '2091.42',
#   'ot_hours': '168.33',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '84324.25',
#   'work_location_borough': 'BROOKLYN',
#   'base_salary': '78026.00',
#   'total_other_pay': '12534.07',
#   'fiscal_year': '2016',
#   'total_ot_paid': '11253.73',
#   'mid_init': 'A',
#   'first_name': 'STEPHEN'},
#  {'agency_name': 'POLICE DEPARTMENT',
#   'pay_basis': 'per Annum',
#   'agency_start_date': '2006-01-09T00:00:00',
#   'title_description': 'POLICE OFFICER',
#   'last_name': 'PENA-RODRIGUEZ',
#   'regular_hours': '2091.42',
#   'ot_hours': '162.33',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '84137.87',
#   'work_location_borough': 'BROOKLYN',
#   'base_salary': '78026.00',
#   'total_other_pay': '13827.51',
#   'fiscal_year': '2016',
#   'total_ot_paid': '13462.23',
#   'mid_init': 'T',
#   'first_name': 'FRANCISCA'},
#  {'agency_name': 'POLICE DEPARTMENT',
#   'pay_basis': 'per Annum',
#   'agency_start_date': '2007-01-10T00:00:00',
#   'title_description': 'POLICE OFFICER',
#   'last_name': 'PENATE',
#   'regular_hours': '1917.12',
#   'ot_hours': '80.33',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '77215.51',
#   'work_location_borough': 'BRONX',
#   'base_salary': '78026.00',
#   'total_other_pay': '14602.51',
#   'fiscal_year': '2016',
#   'total_ot_paid': '6295.11',
#   'first_name': 'ALEXIS'},
#  {'agency_name': 'POLICE DEPARTMENT',
#   'pay_basis': 'per Annum',
#   'agency_start_date': '1992-11-30T00:00:00',
#   'title_description': 'POLICE OFFICER',
#   'last_name': 'PENCHENSKI',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'CEASED',
#   'regular_gross_paid': '161.75',
#   'work_location_borough': 'MANHATTAN',
#   'base_salary': '77253.00',
#   'total_other_pay': '40.21',
#   'fiscal_year': '2016',
#   'total_ot_paid': '0.00',
#   'mid_init': 'J',
#   'first_name': 'MARK'},
#  {'agency_name': 'POLICE DEPARTMENT',
#   'pay_basis': 'per Annum',
#   'agency_start_date': '1991-07-31T00:00:00',
#   'title_description': 'POLICE COMMUNICATIONS TECHNICIAN',
#   'last_name': 'PENDARVIS',
#   'regular_hours': '1830.00',
#   'ot_hours': '107.50',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '47697.78',
#   'work_location_borough': 'BROOKLYN',
#   'base_salary': '48220.00',
#   'total_other_pay': '9898.06',
#   'fiscal_year': '2016',
#   'total_ot_paid': '3202.97',
#   'mid_init': 'D',
#   'first_name': 'CAMELIA'},
#  {'agency_name': 'POLICE DEPARTMENT',
#   'pay_basis': 'per Annum',
#   'agency_start_date': '1987-06-10T00:00:00',
#   'title_description': 'POLICE ADMINISTRATIVE AIDE',
#   'last_name': 'PENDARVIS',
#   'regular_hours': '1830.00',
#   'ot_hours': '416.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '37414.88',
#   'work_location_borough': 'BROOKLYN',
#   'base_salary': '37821.00',
#   'total_other_pay': '4087.76',
#   'fiscal_year': '2016',
#   'total_ot_paid': '11190.86',
#   'mid_init': 'L',
#   'first_name': 'SANDRA'},
#  {'agency_name': 'POLICE DEPARTMENT',
#   'pay_basis': 'per Annum',
#   'agency_start_date': '1986-01-09T00:00:00',
#   'title_description': 'POLICE OFFICER D/A DETECTIVE 2ND GR',
#   'last_name': 'PENDER',
#   'regular_hours': '2091.42',
#   'ot_hours': '502.57',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '101039.99',
#   'work_location_borough': 'MANHATTAN',
#   'base_salary': '102054.00',
#   'total_other_pay': '17754.65',
#   'fiscal_year': '2016',
#   'total_ot_paid': '38075.97',
#   'mid_init': 'E',
#   'first_name': 'LAURA'},
#  {'agency_name': 'POLICE DEPARTMENT',
#   'pay_basis': 'per Annum',
#   'agency_start_date': '2002-07-01T00:00:00',
#   'title_description': 'SERGEANT',
#   'last_name': 'PENDLETON',
#   'regular_hours': '2091.42',
#   'ot_hours': '217.30',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '97903.73',
#   'work_location_borough': 'BROOKLYN',
#   'base_salary': '103585.00',
#   'total_other_pay': '13907.60',
#   'fiscal_year': '2016',
#   'total_ot_paid': '16851.72',
#   'first_name': 'LAEL'},
#  {'agency_name': 'POLICE DEPARTMENT',
#   'pay_basis': 'per Hour',
#   'agency_start_date': '2004-01-21T00:00:00',
#   'title_description': 'SCHOOL CROSSING GUARD',
#   'last_name': 'PENDLEY-JAMES',
#   'regular_hours': '1040.03',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '16022.59',
#   'work_location_borough': 'QUEENS',
#   'base_salary': '13.83',
#   'total_other_pay': '207.00',
#   'fiscal_year': '2016',
#   'total_ot_paid': '0.00',
#   'mid_init': 'A',
#   'first_name': 'NICOLA'},
#  {'agency_name': 'POLICE DEPARTMENT',
#   'pay_basis': 'per Annum',
#   'agency_start_date': '1997-12-08T00:00:00',
#   'title_description': 'P.O. DET SPEC',
#   'last_name': 'PENEDO',
#   'regular_hours': '2091.42',
#   'ot_hours': '377.32',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '89919.65',
#   'work_location_borough': 'MANHATTAN',
#   'base_salary': '90822.00',
#   'total_other_pay': '6992.14',
#   'fiscal_year': '2016',
#   'total_ot_paid': '27659.49',
#   'mid_init': 'A',
#   'first_name': 'MARCOS'},
#  {'agency_name': 'POLICE DEPARTMENT',
#   'pay_basis': 'per Annum',
#   'agency_start_date': '2010-07-06T00:00:00',
#   'title_description': 'POLICE OFFICER',
#   'last_name': 'PENG',
#   'regular_hours': '2091.42',
#   'ot_hours': '192.02',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '70403.18',
#   'work_location_borough': 'BROOKLYN',
#   'base_salary': '78026.00',
#   'total_other_pay': '13497.06',
#   'fiscal_year': '2016',
#   'total_ot_paid': '10959.24',
#   'first_name': 'HONGMING'},
#  {'agency_name': 'POLICE DEPARTMENT',
#   'pay_basis': 'per Annum',
#   'agency_start_date': '2012-05-14T00:00:00',
#   'title_description': 'MANAGEMENT AUDITOR',
#   'last_name': 'PENG',
#   'regular_hours': '1830.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '57669.71',
#   'work_location_borough': 'MANHATTAN',
#   'base_salary': '58308.00',
#   'total_other_pay': '5490.59',
#   'fiscal_year': '2016',
#   'total_ot_paid': '0.00',
#   'first_name': 'SHULUN'},
#  {'agency_name': 'POLICE DEPARTMENT',
#   'pay_basis': 'per Annum',
#   'agency_start_date': '2003-07-01T00:00:00',
#   'title_description': 'P.O. DA DET GR3',
#   'last_name': 'PENGEL',
#   'regular_hours': '2091.42',
#   'ot_hours': '370.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '92160.35',
#   'work_location_borough': 'MANHATTAN',
#   'base_salary': '90822.00',
#   'total_other_pay': '18954.57',
#   'fiscal_year': '2016',
#   'total_ot_paid': '28016.96',
#   'mid_init': 'A',
#   'first_name': 'RICHARD'},
#  {'agency_name': 'POLICE DEPARTMENT',
#   'pay_basis': 'per Annum',
#   'agency_start_date': '2014-01-08T00:00:00',
#   'title_description': 'POLICE OFFICER',
#   'last_name': 'PENKAL',
#   'regular_hours': '2091.42',
#   'ot_hours': '66.73',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '45378.52',
#   'work_location_borough': 'BROOKLYN',
#   'base_salary': '44521.00',
#   'total_other_pay': '4690.67',
#   'fiscal_year': '2016',
#   'total_ot_paid': '2720.42',
#   'mid_init': 'T',
#   'first_name': 'WILLIAM'},
#  {'agency_name': 'POLICE DEPARTMENT',
#   'pay_basis': 'per Annum',
#   'agency_start_date': '2005-07-11T00:00:00',
#   'title_description': 'POLICE OFFICER',
#   'last_name': 'PENKOVSKY II',
#   'regular_hours': '2091.42',
#   'ot_hours': '385.58',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '84324.25',
#   'work_location_borough': 'QUEENS',
#   'base_salary': '78026.00',
#   'total_other_pay': '12613.44',
#   'fiscal_year': '2016',
#   'total_ot_paid': '25560.50',
#   'mid_init': 'N',
#   'first_name': 'LEO'},
#  {'agency_name': 'POLICE DEPARTMENT',
#   'pay_basis': 'per Annum',
#   'agency_start_date': '1990-10-15T00:00:00',
#   'title_description': 'P.O. DET SPEC',
#   'last_name': 'PENN',
#   'regular_hours': '2091.42',
#   'ot_hours': '441.90',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '93027.97',
#   'work_location_borough': 'MANHATTAN',
#   'base_salary': '90822.00',
#   'total_other_pay': '19902.39',
#   'fiscal_year': '2016',
#   'total_ot_paid': '33970.62',
#   'mid_init': 'B',
#   'first_name': 'KELVIN'},
#  {'agency_name': 'POLICE DEPARTMENT',
#   'pay_basis': 'per Annum',
#   'agency_start_date': '2001-03-02T00:00:00',
#   'title_description': 'SCHOOL SAFETY AGENT',
#   'last_name': 'PENN',
#   'regular_hours': '2091.42',
#   'ot_hours': '243.50',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '46068.19',
#   'work_location_borough': 'RICHMOND',
#   'base_salary': '39868.00',
#   'total_other_pay': '1072.57',
#   'fiscal_year': '2016',
#   'total_ot_paid': '6788.39',
#   'mid_init': 'M',
#   'first_name': 'SHANNDA'},
#  {'agency_name': 'POLICE DEPARTMENT',
#   'pay_basis': 'per Annum',
#   'agency_start_date': '2009-01-14T00:00:00',
#   'title_description': 'POLICE OFFICER',
#   'last_name': 'PENNACCHIA',
#   'regular_hours': '2091.42',
#   'ot_hours': '151.17',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '82601.46',
#   'work_location_borough': 'MANHATTAN',
#   'base_salary': '78026.00',
#   'total_other_pay': '9892.21',
#   'fiscal_year': '2016',
#   'total_ot_paid': '11072.34',
#   'first_name': 'JOHNPAUL'},
#  {'agency_name': 'POLICE DEPARTMENT',
#   'pay_basis': 'per Annum',
#   'agency_start_date': '2000-03-01T00:00:00',
#   'title_description': 'POLICE OFFICER',
#   'last_name': 'PENNACCHIO',
#   'regular_hours': '2091.42',
#   'ot_hours': '280.17',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '84324.25',
#   'work_location_borough': 'BROOKLYN',
#   'base_salary': '78026.00',
#   'total_other_pay': '18822.82',
#   'fiscal_year': '2016',
#   'total_ot_paid': '24248.34',
#   'mid_init': 'R',
#   'first_name': 'MICHAEL'},
#  {'agency_name': 'POLICE DEPARTMENT',
#   'pay_basis': 'per Annum',
#   'agency_start_date': '2011-07-06T00:00:00',
#   'title_description': 'POLICE OFFICER',
#   'last_name': 'PENNANT',
#   'regular_hours': '2091.42',
#   'ot_hours': '244.17',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '59085.01',
#   'work_location_borough': 'BRONX',
#   'base_salary': '57747.00',
#   'total_other_pay': '5317.81',
#   'fiscal_year': '2016',
#   'total_ot_paid': '12518.05',
#   'first_name': 'MAURICE'},
#  {'agency_name': 'POLICE DEPARTMENT',
#   'pay_basis': 'per Annum',
#   'agency_start_date': '2012-01-09T00:00:00',
#   'title_description': 'POLICE OFFICER',
#   'last_name': 'PENNECKE JR.',
#   'regular_hours': '2091.42',
#   'ot_hours': '67.20',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '56806.89',
#   'work_location_borough': 'QUEENS',
#   'base_salary': '54341.00',
#   'total_other_pay': '-12636.05',
#   'fiscal_year': '2016',
#   'total_ot_paid': '2574.78',
#   'mid_init': 'K',
#   'first_name': 'RICHARD'},
#  {'agency_name': 'POLICE DEPARTMENT',
#   'pay_basis': 'per Annum',
#   'agency_start_date': '2013-07-09T00:00:00',
#   'title_description': 'POLICE OFFICER',
#   'last_name': 'PENNER',
#   'regular_hours': '2091.42',
#   'ot_hours': '118.92',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '48146.21',
#   'work_location_borough': 'BROOKLYN',
#   'base_salary': '49760.00',
#   'total_other_pay': '7495.15',
#   'fiscal_year': '2016',
#   'total_ot_paid': '3453.59',
#   'mid_init': 'A',
#   'first_name': 'BRIDGET'},
#  {'agency_name': 'POLICE DEPARTMENT',
#   'pay_basis': 'per Annum',
#   'agency_start_date': '2016-01-06T00:00:00',
#   'title_description': 'POLICE OFFICER',
#   'last_name': 'PENNETTI',
#   'regular_hours': '988.57',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '18484.76',
#   'work_location_borough': 'MANHATTAN',
#   'base_salary': '42819.00',
#   'total_other_pay': '0.00',
#   'fiscal_year': '2016',
#   'total_ot_paid': '0.00',
#   'mid_init': 'R',
#   'first_name': 'MARC'},
#  {'agency_name': 'POLICE DEPARTMENT',
#   'pay_basis': 'per Annum',
#   'agency_start_date': '2011-07-06T00:00:00',
#   'title_description': 'POLICE OFFICER',
#   'last_name': 'PENNETTI',
#   'regular_hours': '0.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'CEASED',
#   'regular_gross_paid': '4601.85',
#   'work_location_borough': 'MANHATTAN',
#   'base_salary': '54341.00',
#   'total_other_pay': '388.12',
#   'fiscal_year': '2016',
#   'total_ot_paid': '464.84',
#   'first_name': 'RUDY'},
#  {'agency_name': 'POLICE DEPARTMENT',
#   'pay_basis': 'per Annum',
#   'agency_start_date': '2001-07-02T00:00:00',
#   'title_description': 'POLICE OFFICER',
#   'last_name': 'PENNEY',
#   'regular_hours': '2091.42',
#   'ot_hours': '330.40',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '84324.25',
#   'work_location_borough': 'QUEENS',
#   'base_salary': '78026.00',
#   'total_other_pay': '19964.49',
#   'fiscal_year': '2016',
#   'total_ot_paid': '25441.93',
#   'mid_init': 'M',
#   'first_name': 'KEITH'},
#  {'agency_name': 'POLICE DEPARTMENT',
#   'pay_basis': 'per Annum',
#   'agency_start_date': '2004-01-20T00:00:00',
#   'title_description': 'POLICE OFFICER',
#   'last_name': 'PENNINGTON',
#   'regular_hours': '2091.42',
#   'ot_hours': '161.75',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '84324.25',
#   'work_location_borough': 'MANHATTAN',
#   'base_salary': '78026.00',
#   'total_other_pay': '13061.50',
#   'fiscal_year': '2016',
#   'total_ot_paid': '11229.44',
#   'mid_init': 'K',
#   'first_name': 'RAYMOND'},
#  {'agency_name': 'POLICE DEPARTMENT',
#   'pay_basis': 'per Annum',
#   'agency_start_date': '2011-07-06T00:00:00',
#   'title_description': 'POLICE OFFICER',
#   'last_name': 'PENNISI',
#   'regular_hours': '2091.42',
#   'ot_hours': '178.08',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '59085.02',
#   'work_location_borough': 'BROOKLYN',
#   'base_salary': '57747.00',
#   'total_other_pay': '3802.20',
#   'fiscal_year': '2016',
#   'total_ot_paid': '9065.41',
#   'mid_init': 'P',
#   'first_name': 'FRANCESCO'},
#  {'agency_name': 'POLICE DEPARTMENT',
#   'pay_basis': 'per Annum',
#   'agency_start_date': '2010-07-06T00:00:00',
#   'title_description': 'POLICE OFFICER',
#   'last_name': 'PENNISI',
#   'regular_hours': '2091.42',
#   'ot_hours': '37.92',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '70403.18',
#   'work_location_borough': 'QUEENS',
#   'base_salary': '78026.00',
#   'total_other_pay': '14702.81',
#   'fiscal_year': '2016',
#   'total_ot_paid': '3822.68',
#   'mid_init': 'J',
#   'first_name': 'JOSEPH'},
#  {'agency_name': 'POLICE DEPARTMENT',
#   'pay_basis': 'per Annum',
#   'agency_start_date': '2002-08-21T00:00:00',
#   'title_description': 'SCHOOL SAFETY AGENT',
#   'last_name': 'PENNISTON',
#   'regular_hours': '1600.10',
#   'ot_hours': '142.25',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '34693.79',
#   'work_location_borough': 'MANHATTAN',
#   'base_salary': '39868.00',
#   'total_other_pay': '1013.52',
#   'fiscal_year': '2016',
#   'total_ot_paid': '3902.20',
#   'mid_init': 'L',
#   'first_name': 'NADINE'},
#  {'agency_name': 'POLICE DEPARTMENT',
#   'pay_basis': 'per Annum',
#   'agency_start_date': '2004-07-01T00:00:00',
#   'title_description': 'SERGEANT',
#   'last_name': 'PENNISTON',
#   'regular_hours': '2091.42',
#   'ot_hours': '151.50',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '103257.15',
#   'work_location_borough': 'MANHATTAN',
#   'base_salary': '103585.00',
#   'total_other_pay': '14165.70',
#   'fiscal_year': '2016',
#   'total_ot_paid': '11194.05',
#   'mid_init': 'M',
#   'first_name': 'ODO'},
#  {'agency_name': 'POLICE DEPARTMENT',
#   'pay_basis': 'per Hour',
#   'agency_start_date': '1981-05-04T00:00:00',
#   'title_description': 'SCHOOL CROSSING GUARD',
#   'last_name': 'PENNIX',
#   'regular_hours': '641.00',
#   'ot_hours': '0.00',
#   'leave_status_as_of_july_31': 'ACTIVE',
#   'regular_gross_paid': '10623.48',
#   'work_location_borough': 'MANHATTAN',
#   'base_salary': '14.54',
#   'total_other_pay': '504.19',
#   'fiscal_year': '2016',
#   'total_ot_paid': '0.00',
#   'mid_init': 'M',
#   'first_name': 'BRENDA'},
#  ...]

# %%
pd.DataFrame(results)
# Out:
#                           agency_name    agency_start_date base_salary  \
# 0                   POLICE DEPARTMENT  2001-07-02T00:00:00    78026.00
# 1                   POLICE DEPARTMENT  2014-07-09T00:00:00    44521.00
# 2                   POLICE DEPARTMENT  1995-04-02T00:00:00    90822.00
# 3                   POLICE DEPARTMENT  2015-07-08T00:00:00    42819.00
# 4                   POLICE DEPARTMENT  2007-07-09T00:00:00    78026.00
# 5                   POLICE DEPARTMENT  2011-07-06T00:00:00    42395.00
# 6                   POLICE DEPARTMENT  2000-03-01T00:00:00    78026.00
# 7                   POLICE DEPARTMENT  1998-12-20T00:00:00    36033.00
# 8                   POLICE DEPARTMENT  1999-07-07T00:00:00   103585.00
# 9                   POLICE DEPARTMENT  2002-10-28T00:00:00    98025.00
# 10                  POLICE DEPARTMENT  2000-09-29T00:00:00   160565.00
# 11                  POLICE DEPARTMENT  1990-07-10T00:00:00    77253.00
# 12                  POLICE DEPARTMENT  2007-05-29T00:00:00    39868.00
# 13                  POLICE DEPARTMENT  1995-04-02T00:00:00    78026.00
# 14                  POLICE DEPARTMENT  2014-01-08T00:00:00    44521.00
# 15                  POLICE DEPARTMENT  1995-06-30T00:00:00   152534.00
# 16                  POLICE DEPARTMENT  1995-04-30T00:00:00   103585.00
# 17                  POLICE DEPARTMENT  1995-04-30T00:00:00    78026.00
# 18                  POLICE DEPARTMENT  2002-07-22T00:00:00    78026.00
# 19                  POLICE DEPARTMENT  1997-04-15T00:00:00   121179.00
# 20                  POLICE DEPARTMENT  2007-07-09T00:00:00    87204.00
# 21                  POLICE DEPARTMENT  2006-01-09T00:00:00    78026.00
# 22                  POLICE DEPARTMENT  2013-01-09T00:00:00    49760.00
# 23                  POLICE DEPARTMENT  2005-01-10T00:00:00   103585.00
# 24                  POLICE DEPARTMENT  2006-07-10T00:00:00    78026.00
# 25                  POLICE DEPARTMENT  1995-06-30T00:00:00    90822.00
# 26                  POLICE DEPARTMENT  2013-07-09T00:00:00    49760.00
# 27                  POLICE DEPARTMENT  2006-01-09T00:00:00    78026.00
# 28                  POLICE DEPARTMENT  2010-06-14T00:00:00    67409.00
# 29                  POLICE DEPARTMENT  1995-04-30T00:00:00   102054.00
# ...                               ...                  ...         ...
# 49970  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49971  BOARD OF ELECTION POLL WORKERS  2016-01-01T00:00:00        1.00
# 49972  BOARD OF ELECTION POLL WORKERS  2016-01-01T00:00:00        1.00
# 49973  BOARD OF ELECTION POLL WORKERS  2013-01-01T00:00:00        1.00
# 49974  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49975  BOARD OF ELECTION POLL WORKERS  2012-01-02T00:00:00        1.00
# 49976  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49977  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49978  BOARD OF ELECTION POLL WORKERS  2014-01-01T00:00:00        1.00
# 49979  BOARD OF ELECTION POLL WORKERS  2013-01-01T00:00:00        1.00
# 49980  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49981  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49982  BOARD OF ELECTION POLL WORKERS  2012-01-02T00:00:00        1.00
# 49983  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49984  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49985  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49986  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49987  BOARD OF ELECTION POLL WORKERS  2011-01-01T00:00:00        1.00
# 49988  BOARD OF ELECTION POLL WORKERS  2014-01-01T00:00:00        1.00
# 49989  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49990  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49991  BOARD OF ELECTION POLL WORKERS  2012-01-02T00:00:00        1.00
# 49992  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49993  BOARD OF ELECTION POLL WORKERS  2013-01-01T00:00:00        1.00
# 49994  BOARD OF ELECTION POLL WORKERS  2015-01-01T00:00:00        1.00
# 49995  BOARD OF ELECTION POLL WORKERS  2011-01-01T00:00:00        1.00
# 49996  BOARD OF ELECTION POLL WORKERS  2014-01-01T00:00:00        1.00
# 49997  BOARD OF ELECTION POLL WORKERS  2012-01-02T00:00:00        1.00
# 49998  BOARD OF ELECTION POLL WORKERS  2015-01-01T00:00:00        1.00
# 49999  BOARD OF ELECTION POLL WORKERS  2012-01-02T00:00:00        1.00
#
#         first_name fiscal_year       last_name leave_status_as_of_july_31  \
# 0             DANA        2016          PALOMO                     ACTIVE
# 1          ASHMEED        2016          PALTOO                     ACTIVE
# 2          RAYMOND        2016          PALTOO                     CEASED
# 3          MICHAEL        2016          PALUCH                     ACTIVE
# 4           MARCIN        2016     PALUCHOWSKI                     ACTIVE
# 5          ANTONIO        2016         PALUMBO                     CEASED
# 6           DANIEL        2016         PALUMBO                     ACTIVE
# 7          FELISHA        2016         PALUMBO                     CEASED
# 8            FRANK        2016         PALUMBO                     ACTIVE
# 9          HEATHER        2016         PALUMBO                     ACTIVE
# 10           JAMES        2016         PALUMBO                     ACTIVE
# 11         LINETTE        2016         PALUMBO                     CEASED
# 12          LOUISE        2016         PALUMBO                     ACTIVE
# 13           PETER        2016         PALUMBO                     ACTIVE
# 14         VINCENT        2016         PALUMBO                     ACTIVE
# 15         CARMINE        2016         PALUMMO                     ACTIVE
# 16            ERIC        2016         PALUSKO                     ACTIVE
# 17         VANESSA        2016         PALUSKO                     CEASED
# 18         RICHARD        2016   PALUSZKIEWICZ                     ACTIVE
# 19           HELEN        2016      PAMPAFIKOS                     ACTIVE
# 20          ANGELO        2016         PAMPENA                     ACTIVE
# 21         DAPHNEY        2016        PAMPHILE                     ACTIVE
# 22           KEVIN        2016        PAMPHILE                     ACTIVE
# 23          JESSIE        2016             PAN                     ACTIVE
# 24            JOHN        2016             PAN                     ACTIVE
# 25           KAREN        2016             PAN                     CEASED
# 26             MEI        2016             PAN                     ACTIVE
# 27         MIN QIN        2016             PAN                     ACTIVE
# 28              YE        2016             PAN                     ACTIVE
# 29          SPIROS        2016    PANACOPOULOS                     CEASED
# ...            ...         ...             ...                        ...
# 49970    ZULLY ANN        2016           PEREZ                     ACTIVE
# 49971       SANDRA        2016   PEREZ FRAGOSO                     ACTIVE
# 49972       JOSEPH        2016        PEREZ JR                     ACTIVE
# 49973     IDELISSE        2016      PEREZ LUNA                     ACTIVE
# 49974    SHARLEENE        2016  PEREZ-ANDERSON                     ACTIVE
# 49975        DIANA        2016    PEREZ-OCASIO                     ACTIVE
# 49976      MARITZA        2016      PEREZ-SOTO                     ACTIVE
# 49977        MARIA        2016         PERILLI                     ACTIVE
# 49978   JACQUELINE        2016          PERINE                     ACTIVE
# 49979        JASON        2016          PERINE                     ACTIVE
# 49980        KWESI        2016          PERINE                     ACTIVE
# 49981        LINDA        2016          PERINE                     ACTIVE
# 49982      SYLVIAN        2016           PERIS                     ACTIVE
# 49983         JOHN        2016          PERITO                     ACTIVE
# 49984  RAVISHANKAR        2016     PERIYAPATNA                     ACTIVE
# 49985        BETTY        2016         PERKINS                     ACTIVE
# 49986       DWAYNE        2016         PERKINS                     ACTIVE
# 49987        ESMIE        2016         PERKINS                     ACTIVE
# 49988      GENNELL        2016         PERKINS                     ACTIVE
# 49989         JOHN        2016         PERKINS                     ACTIVE
# 49990      LORETTA        2016         PERKINS                     ACTIVE
# 49991        MONEE        2016         PERKINS                     ACTIVE
# 49992        NAOMI        2016         PERKINS                     ACTIVE
# 49993   NICKOLETTE        2016         PERKINS                     ACTIVE
# 49994     PRECIOUS        2016         PERKINS                     ACTIVE
# 49995        JOYCE        2016  PERKINS CUFFEE                     ACTIVE
# 49996     JOYCELIN        2016           PERKS                     ACTIVE
# 49997   CHRYSANTHY        2016        PERLEGIS                     ACTIVE
# 49998     PATRICIA        2016      PERLMUTTER                     ACTIVE
# 49999      TRISTAN        2016         PERMELL                     ACTIVE
#
#       mid_init ot_hours  pay_basis regular_gross_paid regular_hours  \
# 0            C   350.90  per Annum           84324.25       2091.42
# 1          NaN   227.17  per Annum           45267.84       2091.42
# 2          NaN   391.77  per Annum           79497.44       1742.85
# 3          NaN    19.33  per Annum           39777.33       2028.57
# 4          NaN   342.50  per Annum           83466.58       2091.42
# 5          NaN     0.00  per Annum              15.50          0.00
# 6            J    17.78  per Annum           84324.25       2091.42
# 7            D     0.00  per Annum            2287.00          0.00
# 8            J    79.00  per Annum           88096.64       2091.42
# 9          NaN    11.00  per Annum           96956.19       1830.00
# 10           R     0.00  per Annum          151269.90       2091.42
# 11         NaN     0.00  per Annum             700.17          0.00
# 12           A    10.50  per Annum           46068.19       2091.42
# 13         NaN   497.52  per Annum           84324.25       2091.42
# 14           C     0.00  per Annum           45378.52       2091.42
# 15           C     0.00  per Annum          151269.90       2091.42
# 16         NaN   102.75  per Annum          102689.21       2091.42
# 17         NaN     0.00  per Annum            3967.47          0.00
# 18           J   458.50  per Annum           84324.25       2091.42
# 19         NaN   436.67  per Annum          118016.28       2091.42
# 20           J   253.72  per Annum           85347.84       1922.85
# 21         NaN   117.72  per Annum           84137.87       2091.42
# 22         NaN   194.67  per Annum           51215.11       2091.42
# 23           T    36.67  per Annum          102802.38       2091.42
# 24         NaN   146.40  per Annum           83933.75       2091.42
# 25           V   252.67  per Annum           66397.57       1051.42
# 26         NaN   262.33  per Annum           48146.21       2091.42
# 27         NaN   428.87  per Annum           84137.87       2091.42
# 28         NaN     0.00  per Annum           63358.25       1830.00
# 29         NaN     0.00  per Annum           23293.14        348.57
# ...        ...      ...        ...                ...           ...
# 49970      NaN     0.00   per Hour             586.00          0.00
# 49971      NaN     0.00   per Hour             200.00          0.00
# 49972        T     0.00   per Hour             200.00          0.00
# 49973      NaN     0.00   per Hour             460.00          0.00
# 49974        N     0.00   per Hour             575.00          0.00
# 49975      NaN     0.00   per Hour             575.00          0.00
# 49976        A     0.00   per Hour             578.00          0.00
# 49977      NaN     0.00   per Hour             575.00          0.00
# 49978      NaN     0.00   per Hour             631.00          0.00
# 49979        A     0.00   per Hour             300.00          0.00
# 49980        S     0.00   per Hour            1041.63          0.00
# 49981        J     0.00   per Hour            1025.00          0.00
# 49982        J     0.00   per Hour             305.00          0.00
# 49983      NaN     0.00   per Hour             480.00          0.00
# 49984        N     0.00   per Hour             775.00          0.00
# 49985        A     0.00   per Hour             450.00          0.00
# 49986      NaN     0.00   per Hour             775.00          0.00
# 49987      NaN     0.00   per Hour             580.00          0.00
# 49988      NaN     0.00   per Hour             578.00          0.00
# 49989      NaN     0.00   per Hour             580.00          0.00
# 49990      NaN     0.00   per Hour             575.00          0.00
# 49991        M     0.00   per Hour             775.00          0.00
# 49992        N     0.00   per Hour             400.00          0.00
# 49993      NaN     0.00   per Hour             303.00          0.00
# 49994      NaN     0.00   per Hour             575.00          0.00
# 49995      NaN     0.00   per Hour             583.00          0.00
# 49996      NaN     0.00   per Hour             575.00          0.00
# 49997      NaN     0.00   per Hour             300.00          0.00
# 49998      NaN     0.00   per Hour             575.00          0.00
# 49999        K     0.00   per Hour             688.31          0.00
#
#                                        title_description total_ot_paid  \
# 0                                         POLICE OFFICER      23932.75
# 1                                         POLICE OFFICER       8754.46
# 2                                        P.O. DA DET GR3      29192.92
# 3                                         POLICE OFFICER        472.90
# 4                                         POLICE OFFICER      24189.00
# 5                                         POLICE OFFICER          0.00
# 6                                         POLICE OFFICER       1483.63
# 7                                    SCHOOL SAFETY AGENT          0.00
# 8                                               SERGEANT       6285.45
# 9                                            CRIMINALIST        616.42
# 10                          CAPTAIN D/A DEPUTY INSPECTOR          0.00
# 11                                        POLICE OFFICER         75.80
# 12                                   SCHOOL SAFETY AGENT         54.43
# 13                                        POLICE OFFICER      32966.43
# 14                                        POLICE OFFICER         10.70
# 15                                               CAPTAIN          0.00
# 16                                              SERGEANT      10383.74
# 17                                        POLICE OFFICER        374.93
# 18                                        POLICE OFFICER      29260.69
# 19                     LIEUTENANT D/A SPECIAL ASSIGNMENT      40180.33
# 20                                       P.O. DA DET GR3      17748.62
# 21                                        POLICE OFFICER       9062.59
# 22                                        POLICE OFFICER       7239.93
# 23                                              SERGEANT       3226.48
# 24                                        POLICE OFFICER       9792.52
# 25                                       P.O. DA DET GR3      18682.96
# 26                                        POLICE OFFICER      10125.50
# 27                                        POLICE OFFICER      30975.11
# 28                                    MANAGEMENT AUDITOR          0.00
# 29                                              SERGEANT          0.00
# ...                                                  ...           ...
# 49970  ELECTION WORKER                               ...          0.00
# 49971  ELECTION WORKER                               ...          0.00
# 49972  ELECTION WORKER                               ...          0.00
# 49973  ELECTION WORKER                               ...          0.00
# 49974  ELECTION WORKER                               ...          0.00
# 49975  ELECTION WORKER                               ...          0.00
# 49976  ELECTION WORKER                               ...          0.00
# 49977  ELECTION WORKER                               ...          0.00
# 49978  ELECTION WORKER                               ...          0.00
# 49979  ELECTION WORKER                               ...          0.00
# 49980  ELECTION WORKER                               ...          0.00
# 49981  ELECTION WORKER                               ...          0.00
# 49982  ELECTION WORKER                               ...          0.00
# 49983  ELECTION WORKER                               ...          0.00
# 49984  ELECTION WORKER                               ...          0.00
# 49985  ELECTION WORKER                               ...          0.00
# 49986  ELECTION WORKER                               ...          0.00
# 49987  ELECTION WORKER                               ...          0.00
# 49988  ELECTION WORKER                               ...          0.00
# 49989  ELECTION WORKER                               ...          0.00
# 49990  ELECTION WORKER                               ...          0.00
# 49991  ELECTION WORKER                               ...          0.00
# 49992  ELECTION WORKER                               ...          0.00
# 49993  ELECTION WORKER                               ...          0.00
# 49994  ELECTION WORKER                               ...          0.00
# 49995  ELECTION WORKER                               ...          0.00
# 49996  ELECTION WORKER                               ...          0.00
# 49997  ELECTION WORKER                               ...          0.00
# 49998  ELECTION WORKER                               ...          0.00
# 49999  ELECTION WORKER                               ...          0.00
#
#       total_other_pay work_location_borough
# 0            12822.47                QUEENS
# 1             4334.07              BROOKLYN
# 2           -37054.09             MANHATTAN
# 3             3062.97                 BRONX
# 4            11322.23             MANHATTAN
# 5                0.71             MANHATTAN
# 6            15131.99             MANHATTAN
# 7                0.00             MANHATTAN
# 8            16075.67                 BRONX
# 9             5360.45                QUEENS
# 10           21043.68              BROOKLYN
# 11             146.47             MANHATTAN
# 12            1000.00                 BRONX
# 13           21318.24             MANHATTAN
# 14            6358.98              BROOKLYN
# 15           20340.59             MANHATTAN
# 16           17094.57                QUEENS
# 17             692.60             MANHATTAN
# 18           12472.55                QUEENS
# 19           14903.29             MANHATTAN
# 20           12072.82                QUEENS
# 21           13383.27                 BRONX
# 22            7886.14                 BRONX
# 23           14166.31             MANHATTAN
# 24           12969.49                QUEENS
# 25           10892.09             MANHATTAN
# 26            7349.95             MANHATTAN
# 27           12050.65             MANHATTAN
# 28            5784.91             MANHATTAN
# 29            5143.84             MANHATTAN
# ...               ...                   ...
# 49970            0.00         MANHATTAN
# 49971            0.00         MANHATTAN
# 49972            0.00         MANHATTAN
# 49973            0.00         MANHATTAN
# 49974            0.00         MANHATTAN
# 49975            0.00         MANHATTAN
# 49976            0.00         MANHATTAN
# 49977            0.00         MANHATTAN
# 49978            0.00         MANHATTAN
# 49979            0.00         MANHATTAN
# 49980            0.00         MANHATTAN
# 49981            0.00         MANHATTAN
# 49982            0.00         MANHATTAN
# 49983            0.00         MANHATTAN
# 49984            0.00         MANHATTAN
# 49985            0.00         MANHATTAN
# 49986            0.00         MANHATTAN
# 49987            0.00         MANHATTAN
# 49988            0.00         MANHATTAN
# 49989            0.00         MANHATTAN
# 49990            0.00         MANHATTAN
# 49991            0.00         MANHATTAN
# 49992            0.00         MANHATTAN
# 49993            0.00         MANHATTAN
# 49994            0.00         MANHATTAN
# 49995            0.00         MANHATTAN
# 49996            0.00         MANHATTAN
# 49997            0.00         MANHATTAN
# 49998            0.00         MANHATTAN
# 49999            0.00         MANHATTAN
#
# [50000 rows x 16 columns]

# %%
df.append(pd.DataFrame(results))
# Out:
#                           agency_name    agency_start_date base_salary  \
# 0                   POLICE DEPARTMENT  2001-07-02T00:00:00    78026.00
# 1                   POLICE DEPARTMENT  2014-07-09T00:00:00    44521.00
# 2                   POLICE DEPARTMENT  1995-04-02T00:00:00    90822.00
# 3                   POLICE DEPARTMENT  2015-07-08T00:00:00    42819.00
# 4                   POLICE DEPARTMENT  2007-07-09T00:00:00    78026.00
# 5                   POLICE DEPARTMENT  2011-07-06T00:00:00    42395.00
# 6                   POLICE DEPARTMENT  2000-03-01T00:00:00    78026.00
# 7                   POLICE DEPARTMENT  1998-12-20T00:00:00    36033.00
# 8                   POLICE DEPARTMENT  1999-07-07T00:00:00   103585.00
# 9                   POLICE DEPARTMENT  2002-10-28T00:00:00    98025.00
# 10                  POLICE DEPARTMENT  2000-09-29T00:00:00   160565.00
# 11                  POLICE DEPARTMENT  1990-07-10T00:00:00    77253.00
# 12                  POLICE DEPARTMENT  2007-05-29T00:00:00    39868.00
# 13                  POLICE DEPARTMENT  1995-04-02T00:00:00    78026.00
# 14                  POLICE DEPARTMENT  2014-01-08T00:00:00    44521.00
# 15                  POLICE DEPARTMENT  1995-06-30T00:00:00   152534.00
# 16                  POLICE DEPARTMENT  1995-04-30T00:00:00   103585.00
# 17                  POLICE DEPARTMENT  1995-04-30T00:00:00    78026.00
# 18                  POLICE DEPARTMENT  2002-07-22T00:00:00    78026.00
# 19                  POLICE DEPARTMENT  1997-04-15T00:00:00   121179.00
# 20                  POLICE DEPARTMENT  2007-07-09T00:00:00    87204.00
# 21                  POLICE DEPARTMENT  2006-01-09T00:00:00    78026.00
# 22                  POLICE DEPARTMENT  2013-01-09T00:00:00    49760.00
# 23                  POLICE DEPARTMENT  2005-01-10T00:00:00   103585.00
# 24                  POLICE DEPARTMENT  2006-07-10T00:00:00    78026.00
# 25                  POLICE DEPARTMENT  1995-06-30T00:00:00    90822.00
# 26                  POLICE DEPARTMENT  2013-07-09T00:00:00    49760.00
# 27                  POLICE DEPARTMENT  2006-01-09T00:00:00    78026.00
# 28                  POLICE DEPARTMENT  2010-06-14T00:00:00    67409.00
# 29                  POLICE DEPARTMENT  1995-04-30T00:00:00   102054.00
# ...                               ...                  ...         ...
# 49970  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49971  BOARD OF ELECTION POLL WORKERS  2016-01-01T00:00:00        1.00
# 49972  BOARD OF ELECTION POLL WORKERS  2016-01-01T00:00:00        1.00
# 49973  BOARD OF ELECTION POLL WORKERS  2013-01-01T00:00:00        1.00
# 49974  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49975  BOARD OF ELECTION POLL WORKERS  2012-01-02T00:00:00        1.00
# 49976  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49977  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49978  BOARD OF ELECTION POLL WORKERS  2014-01-01T00:00:00        1.00
# 49979  BOARD OF ELECTION POLL WORKERS  2013-01-01T00:00:00        1.00
# 49980  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49981  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49982  BOARD OF ELECTION POLL WORKERS  2012-01-02T00:00:00        1.00
# 49983  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49984  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49985  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49986  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49987  BOARD OF ELECTION POLL WORKERS  2011-01-01T00:00:00        1.00
# 49988  BOARD OF ELECTION POLL WORKERS  2014-01-01T00:00:00        1.00
# 49989  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49990  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49991  BOARD OF ELECTION POLL WORKERS  2012-01-02T00:00:00        1.00
# 49992  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49993  BOARD OF ELECTION POLL WORKERS  2013-01-01T00:00:00        1.00
# 49994  BOARD OF ELECTION POLL WORKERS  2015-01-01T00:00:00        1.00
# 49995  BOARD OF ELECTION POLL WORKERS  2011-01-01T00:00:00        1.00
# 49996  BOARD OF ELECTION POLL WORKERS  2014-01-01T00:00:00        1.00
# 49997  BOARD OF ELECTION POLL WORKERS  2012-01-02T00:00:00        1.00
# 49998  BOARD OF ELECTION POLL WORKERS  2015-01-01T00:00:00        1.00
# 49999  BOARD OF ELECTION POLL WORKERS  2012-01-02T00:00:00        1.00
#
#         first_name fiscal_year       last_name leave_status_as_of_july_31  \
# 0             DANA        2016          PALOMO                     ACTIVE
# 1          ASHMEED        2016          PALTOO                     ACTIVE
# 2          RAYMOND        2016          PALTOO                     CEASED
# 3          MICHAEL        2016          PALUCH                     ACTIVE
# 4           MARCIN        2016     PALUCHOWSKI                     ACTIVE
# 5          ANTONIO        2016         PALUMBO                     CEASED
# 6           DANIEL        2016         PALUMBO                     ACTIVE
# 7          FELISHA        2016         PALUMBO                     CEASED
# 8            FRANK        2016         PALUMBO                     ACTIVE
# 9          HEATHER        2016         PALUMBO                     ACTIVE
# 10           JAMES        2016         PALUMBO                     ACTIVE
# 11         LINETTE        2016         PALUMBO                     CEASED
# 12          LOUISE        2016         PALUMBO                     ACTIVE
# 13           PETER        2016         PALUMBO                     ACTIVE
# 14         VINCENT        2016         PALUMBO                     ACTIVE
# 15         CARMINE        2016         PALUMMO                     ACTIVE
# 16            ERIC        2016         PALUSKO                     ACTIVE
# 17         VANESSA        2016         PALUSKO                     CEASED
# 18         RICHARD        2016   PALUSZKIEWICZ                     ACTIVE
# 19           HELEN        2016      PAMPAFIKOS                     ACTIVE
# 20          ANGELO        2016         PAMPENA                     ACTIVE
# 21         DAPHNEY        2016        PAMPHILE                     ACTIVE
# 22           KEVIN        2016        PAMPHILE                     ACTIVE
# 23          JESSIE        2016             PAN                     ACTIVE
# 24            JOHN        2016             PAN                     ACTIVE
# 25           KAREN        2016             PAN                     CEASED
# 26             MEI        2016             PAN                     ACTIVE
# 27         MIN QIN        2016             PAN                     ACTIVE
# 28              YE        2016             PAN                     ACTIVE
# 29          SPIROS        2016    PANACOPOULOS                     CEASED
# ...            ...         ...             ...                        ...
# 49970    ZULLY ANN        2016           PEREZ                     ACTIVE
# 49971       SANDRA        2016   PEREZ FRAGOSO                     ACTIVE
# 49972       JOSEPH        2016        PEREZ JR                     ACTIVE
# 49973     IDELISSE        2016      PEREZ LUNA                     ACTIVE
# 49974    SHARLEENE        2016  PEREZ-ANDERSON                     ACTIVE
# 49975        DIANA        2016    PEREZ-OCASIO                     ACTIVE
# 49976      MARITZA        2016      PEREZ-SOTO                     ACTIVE
# 49977        MARIA        2016         PERILLI                     ACTIVE
# 49978   JACQUELINE        2016          PERINE                     ACTIVE
# 49979        JASON        2016          PERINE                     ACTIVE
# 49980        KWESI        2016          PERINE                     ACTIVE
# 49981        LINDA        2016          PERINE                     ACTIVE
# 49982      SYLVIAN        2016           PERIS                     ACTIVE
# 49983         JOHN        2016          PERITO                     ACTIVE
# 49984  RAVISHANKAR        2016     PERIYAPATNA                     ACTIVE
# 49985        BETTY        2016         PERKINS                     ACTIVE
# 49986       DWAYNE        2016         PERKINS                     ACTIVE
# 49987        ESMIE        2016         PERKINS                     ACTIVE
# 49988      GENNELL        2016         PERKINS                     ACTIVE
# 49989         JOHN        2016         PERKINS                     ACTIVE
# 49990      LORETTA        2016         PERKINS                     ACTIVE
# 49991        MONEE        2016         PERKINS                     ACTIVE
# 49992        NAOMI        2016         PERKINS                     ACTIVE
# 49993   NICKOLETTE        2016         PERKINS                     ACTIVE
# 49994     PRECIOUS        2016         PERKINS                     ACTIVE
# 49995        JOYCE        2016  PERKINS CUFFEE                     ACTIVE
# 49996     JOYCELIN        2016           PERKS                     ACTIVE
# 49997   CHRYSANTHY        2016        PERLEGIS                     ACTIVE
# 49998     PATRICIA        2016      PERLMUTTER                     ACTIVE
# 49999      TRISTAN        2016         PERMELL                     ACTIVE
#
#       mid_init ot_hours  pay_basis regular_gross_paid regular_hours  \
# 0            C   350.90  per Annum           84324.25       2091.42
# 1          NaN   227.17  per Annum           45267.84       2091.42
# 2          NaN   391.77  per Annum           79497.44       1742.85
# 3          NaN    19.33  per Annum           39777.33       2028.57
# 4          NaN   342.50  per Annum           83466.58       2091.42
# 5          NaN     0.00  per Annum              15.50          0.00
# 6            J    17.78  per Annum           84324.25       2091.42
# 7            D     0.00  per Annum            2287.00          0.00
# 8            J    79.00  per Annum           88096.64       2091.42
# 9          NaN    11.00  per Annum           96956.19       1830.00
# 10           R     0.00  per Annum          151269.90       2091.42
# 11         NaN     0.00  per Annum             700.17          0.00
# 12           A    10.50  per Annum           46068.19       2091.42
# 13         NaN   497.52  per Annum           84324.25       2091.42
# 14           C     0.00  per Annum           45378.52       2091.42
# 15           C     0.00  per Annum          151269.90       2091.42
# 16         NaN   102.75  per Annum          102689.21       2091.42
# 17         NaN     0.00  per Annum            3967.47          0.00
# 18           J   458.50  per Annum           84324.25       2091.42
# 19         NaN   436.67  per Annum          118016.28       2091.42
# 20           J   253.72  per Annum           85347.84       1922.85
# 21         NaN   117.72  per Annum           84137.87       2091.42
# 22         NaN   194.67  per Annum           51215.11       2091.42
# 23           T    36.67  per Annum          102802.38       2091.42
# 24         NaN   146.40  per Annum           83933.75       2091.42
# 25           V   252.67  per Annum           66397.57       1051.42
# 26         NaN   262.33  per Annum           48146.21       2091.42
# 27         NaN   428.87  per Annum           84137.87       2091.42
# 28         NaN     0.00  per Annum           63358.25       1830.00
# 29         NaN     0.00  per Annum           23293.14        348.57
# ...        ...      ...        ...                ...           ...
# 49970      NaN     0.00   per Hour             586.00          0.00
# 49971      NaN     0.00   per Hour             200.00          0.00
# 49972        T     0.00   per Hour             200.00          0.00
# 49973      NaN     0.00   per Hour             460.00          0.00
# 49974        N     0.00   per Hour             575.00          0.00
# 49975      NaN     0.00   per Hour             575.00          0.00
# 49976        A     0.00   per Hour             578.00          0.00
# 49977      NaN     0.00   per Hour             575.00          0.00
# 49978      NaN     0.00   per Hour             631.00          0.00
# 49979        A     0.00   per Hour             300.00          0.00
# 49980        S     0.00   per Hour            1041.63          0.00
# 49981        J     0.00   per Hour            1025.00          0.00
# 49982        J     0.00   per Hour             305.00          0.00
# 49983      NaN     0.00   per Hour             480.00          0.00
# 49984        N     0.00   per Hour             775.00          0.00
# 49985        A     0.00   per Hour             450.00          0.00
# 49986      NaN     0.00   per Hour             775.00          0.00
# 49987      NaN     0.00   per Hour             580.00          0.00
# 49988      NaN     0.00   per Hour             578.00          0.00
# 49989      NaN     0.00   per Hour             580.00          0.00
# 49990      NaN     0.00   per Hour             575.00          0.00
# 49991        M     0.00   per Hour             775.00          0.00
# 49992        N     0.00   per Hour             400.00          0.00
# 49993      NaN     0.00   per Hour             303.00          0.00
# 49994      NaN     0.00   per Hour             575.00          0.00
# 49995      NaN     0.00   per Hour             583.00          0.00
# 49996      NaN     0.00   per Hour             575.00          0.00
# 49997      NaN     0.00   per Hour             300.00          0.00
# 49998      NaN     0.00   per Hour             575.00          0.00
# 49999        K     0.00   per Hour             688.31          0.00
#
#                                        title_description total_ot_paid  \
# 0                                         POLICE OFFICER      23932.75
# 1                                         POLICE OFFICER       8754.46
# 2                                        P.O. DA DET GR3      29192.92
# 3                                         POLICE OFFICER        472.90
# 4                                         POLICE OFFICER      24189.00
# 5                                         POLICE OFFICER          0.00
# 6                                         POLICE OFFICER       1483.63
# 7                                    SCHOOL SAFETY AGENT          0.00
# 8                                               SERGEANT       6285.45
# 9                                            CRIMINALIST        616.42
# 10                          CAPTAIN D/A DEPUTY INSPECTOR          0.00
# 11                                        POLICE OFFICER         75.80
# 12                                   SCHOOL SAFETY AGENT         54.43
# 13                                        POLICE OFFICER      32966.43
# 14                                        POLICE OFFICER         10.70
# 15                                               CAPTAIN          0.00
# 16                                              SERGEANT      10383.74
# 17                                        POLICE OFFICER        374.93
# 18                                        POLICE OFFICER      29260.69
# 19                     LIEUTENANT D/A SPECIAL ASSIGNMENT      40180.33
# 20                                       P.O. DA DET GR3      17748.62
# 21                                        POLICE OFFICER       9062.59
# 22                                        POLICE OFFICER       7239.93
# 23                                              SERGEANT       3226.48
# 24                                        POLICE OFFICER       9792.52
# 25                                       P.O. DA DET GR3      18682.96
# 26                                        POLICE OFFICER      10125.50
# 27                                        POLICE OFFICER      30975.11
# 28                                    MANAGEMENT AUDITOR          0.00
# 29                                              SERGEANT          0.00
# ...                                                  ...           ...
# 49970  ELECTION WORKER                               ...          0.00
# 49971  ELECTION WORKER                               ...          0.00
# 49972  ELECTION WORKER                               ...          0.00
# 49973  ELECTION WORKER                               ...          0.00
# 49974  ELECTION WORKER                               ...          0.00
# 49975  ELECTION WORKER                               ...          0.00
# 49976  ELECTION WORKER                               ...          0.00
# 49977  ELECTION WORKER                               ...          0.00
# 49978  ELECTION WORKER                               ...          0.00
# 49979  ELECTION WORKER                               ...          0.00
# 49980  ELECTION WORKER                               ...          0.00
# 49981  ELECTION WORKER                               ...          0.00
# 49982  ELECTION WORKER                               ...          0.00
# 49983  ELECTION WORKER                               ...          0.00
# 49984  ELECTION WORKER                               ...          0.00
# 49985  ELECTION WORKER                               ...          0.00
# 49986  ELECTION WORKER                               ...          0.00
# 49987  ELECTION WORKER                               ...          0.00
# 49988  ELECTION WORKER                               ...          0.00
# 49989  ELECTION WORKER                               ...          0.00
# 49990  ELECTION WORKER                               ...          0.00
# 49991  ELECTION WORKER                               ...          0.00
# 49992  ELECTION WORKER                               ...          0.00
# 49993  ELECTION WORKER                               ...          0.00
# 49994  ELECTION WORKER                               ...          0.00
# 49995  ELECTION WORKER                               ...          0.00
# 49996  ELECTION WORKER                               ...          0.00
# 49997  ELECTION WORKER                               ...          0.00
# 49998  ELECTION WORKER                               ...          0.00
# 49999  ELECTION WORKER                               ...          0.00
#
#       total_other_pay work_location_borough
# 0            12822.47                QUEENS
# 1             4334.07              BROOKLYN
# 2           -37054.09             MANHATTAN
# 3             3062.97                 BRONX
# 4            11322.23             MANHATTAN
# 5                0.71             MANHATTAN
# 6            15131.99             MANHATTAN
# 7                0.00             MANHATTAN
# 8            16075.67                 BRONX
# 9             5360.45                QUEENS
# 10           21043.68              BROOKLYN
# 11             146.47             MANHATTAN
# 12            1000.00                 BRONX
# 13           21318.24             MANHATTAN
# 14            6358.98              BROOKLYN
# 15           20340.59             MANHATTAN
# 16           17094.57                QUEENS
# 17             692.60             MANHATTAN
# 18           12472.55                QUEENS
# 19           14903.29             MANHATTAN
# 20           12072.82                QUEENS
# 21           13383.27                 BRONX
# 22            7886.14                 BRONX
# 23           14166.31             MANHATTAN
# 24           12969.49                QUEENS
# 25           10892.09             MANHATTAN
# 26            7349.95             MANHATTAN
# 27           12050.65             MANHATTAN
# 28            5784.91             MANHATTAN
# 29            5143.84             MANHATTAN
# ...               ...                   ...
# 49970            0.00         MANHATTAN
# 49971            0.00         MANHATTAN
# 49972            0.00         MANHATTAN
# 49973            0.00         MANHATTAN
# 49974            0.00         MANHATTAN
# 49975            0.00         MANHATTAN
# 49976            0.00         MANHATTAN
# 49977            0.00         MANHATTAN
# 49978            0.00         MANHATTAN
# 49979            0.00         MANHATTAN
# 49980            0.00         MANHATTAN
# 49981            0.00         MANHATTAN
# 49982            0.00         MANHATTAN
# 49983            0.00         MANHATTAN
# 49984            0.00         MANHATTAN
# 49985            0.00         MANHATTAN
# 49986            0.00         MANHATTAN
# 49987            0.00         MANHATTAN
# 49988            0.00         MANHATTAN
# 49989            0.00         MANHATTAN
# 49990            0.00         MANHATTAN
# 49991            0.00         MANHATTAN
# 49992            0.00         MANHATTAN
# 49993            0.00         MANHATTAN
# 49994            0.00         MANHATTAN
# 49995            0.00         MANHATTAN
# 49996            0.00         MANHATTAN
# 49997            0.00         MANHATTAN
# 49998            0.00         MANHATTAN
# 49999            0.00         MANHATTAN
#
# [50000 rows x 16 columns]

# %%
df = pd.DataFrame()

# %%
results = client.get(identified, limit=50000, offset=50000*0)
results2 = results = client.get(identified, limit=50000, offset=50000*1)

# %%
results[0]
# Out:
# {'agency_name': 'POLICE DEPARTMENT',
#  'pay_basis': 'per Annum',
#  'agency_start_date': '2001-07-02T00:00:00',
#  'title_description': 'POLICE OFFICER',
#  'last_name': 'PALOMO',
#  'regular_hours': '2091.42',
#  'ot_hours': '350.90',
#  'leave_status_as_of_july_31': 'ACTIVE',
#  'regular_gross_paid': '84324.25',
#  'work_location_borough': 'QUEENS',
#  'base_salary': '78026.00',
#  'total_other_pay': '12822.47',
#  'fiscal_year': '2016',
#  'total_ot_paid': '23932.75',
#  'mid_init': 'C',
#  'first_name': 'DANA'}

# %%
results2[0]
# Out:
# {'agency_name': 'POLICE DEPARTMENT',
#  'pay_basis': 'per Annum',
#  'agency_start_date': '2001-07-02T00:00:00',
#  'title_description': 'POLICE OFFICER',
#  'last_name': 'PALOMO',
#  'regular_hours': '2091.42',
#  'ot_hours': '350.90',
#  'leave_status_as_of_july_31': 'ACTIVE',
#  'regular_gross_paid': '84324.25',
#  'work_location_borough': 'QUEENS',
#  'base_salary': '78026.00',
#  'total_other_pay': '12822.47',
#  'fiscal_year': '2016',
#  'total_ot_paid': '23932.75',
#  'mid_init': 'C',
#  'first_name': 'DANA'}

# %%
results = client.get(identified, limit=50000, offset=50000*0)
results2 = client.get(identified, limit=50000, offset=50000*1)

# %%
results[0]
# Out:
# {'agency_name': 'DISTRICT ATTORNEY-MANHATTAN   ',
#  'pay_basis': ' per Annum',
#  'agency_start_date': '2003-07-14T00:00:00',
#  'title_description': 'COMMUNITY ASSOCIATE                                         ',
#  'last_name': "ABA'AHMID",
#  'regular_hours': '1830.00',
#  'ot_hours': '2.25',
#  'leave_status_as_of_july_31': 'ACTIVE',
#  'regular_gross_paid': '47166.03',
#  'work_location_borough': 'MANHATTAN    ',
#  'base_salary': '47678.00',
#  'total_other_pay': '0.00',
#  'fiscal_year': '2016',
#  'total_ot_paid': '57.28',
#  'mid_init': 'E',
#  'first_name': 'RAHASHEEM'}

# %%
results2[0]
# Out:
# {'agency_name': 'POLICE DEPARTMENT',
#  'pay_basis': 'per Annum',
#  'agency_start_date': '2001-07-02T00:00:00',
#  'title_description': 'POLICE OFFICER',
#  'last_name': 'PALOMO',
#  'regular_hours': '2091.42',
#  'ot_hours': '350.90',
#  'leave_status_as_of_july_31': 'ACTIVE',
#  'regular_gross_paid': '84324.25',
#  'work_location_borough': 'QUEENS',
#  'base_salary': '78026.00',
#  'total_other_pay': '12822.47',
#  'fiscal_year': '2016',
#  'total_ot_paid': '23932.75',
#  'mid_init': 'C',
#  'first_name': 'DANA'}

# %%
1 = pd.DataFrame(results)
# Out:
#   File "<ipython-input-66-569dca1dce61>", line 1
#     1 = pd.DataFrame(results)
#                              ^
# SyntaxError: can't assign to literal

# %%
a = pd.DataFrame(results)

# %%
b = pd.DataFrame(results2)

# %%
data = [a,b]

# %%
resulting = pd.concat(data)

# %%
resulting
# Out:
#                           agency_name    agency_start_date base_salary  \
# 0      DISTRICT ATTORNEY-MANHATTAN     2003-07-14T00:00:00    47678.00
# 1      DISTRICT ATTORNEY-MANHATTAN     1995-06-12T00:00:00   119959.00
# 2      DISTRICT ATTORNEY-MANHATTAN     2011-10-11T00:00:00    39966.00
# 3      DISTRICT ATTORNEY-MANHATTAN     2014-12-01T00:00:00   116000.00
# 4      DISTRICT ATTORNEY-MANHATTAN     2015-05-21T00:00:00        1.00
# 5      DISTRICT ATTORNEY-MANHATTAN     2012-09-04T00:00:00    71500.00
# 6      DISTRICT ATTORNEY-MANHATTAN     2007-09-04T00:00:00    88000.00
# 7      DISTRICT ATTORNEY-MANHATTAN     2016-06-06T00:00:00        1.00
# 8      DISTRICT ATTORNEY-MANHATTAN     2014-09-02T00:00:00    41000.00
# 9      DISTRICT ATTORNEY-MANHATTAN     1978-05-31T00:00:00    66035.00
# 10     DISTRICT ATTORNEY-MANHATTAN     2013-04-22T00:00:00    38869.00
# 11     DISTRICT ATTORNEY-MANHATTAN     2014-08-25T00:00:00    42075.00
# 12     DISTRICT ATTORNEY-MANHATTAN     2014-01-13T00:00:00    66625.00
# 13     DISTRICT ATTORNEY-MANHATTAN     2005-03-28T00:00:00   112592.00
# 14     DISTRICT ATTORNEY-MANHATTAN     2009-11-09T00:00:00    52548.00
# 15     DISTRICT ATTORNEY-MANHATTAN     2015-05-21T00:00:00        1.00
# 16     DISTRICT ATTORNEY-MANHATTAN     2014-04-28T00:00:00    43299.00
# 17     DISTRICT ATTORNEY-MANHATTAN     2004-09-07T00:00:00   102500.00
# 18     DISTRICT ATTORNEY-MANHATTAN     2015-05-21T00:00:00        1.00
# 19     DISTRICT ATTORNEY-MANHATTAN     2007-01-19T00:00:00    40299.00
# 20     DISTRICT ATTORNEY-MANHATTAN     2014-09-02T00:00:00    78000.00
# 21     DISTRICT ATTORNEY-MANHATTAN     2008-09-21T00:00:00      370.16
# 22     DISTRICT ATTORNEY-MANHATTAN     2016-06-06T00:00:00        1.00
# 23     DISTRICT ATTORNEY-MANHATTAN     2009-03-02T00:00:00      217.70
# 24     DISTRICT ATTORNEY-MANHATTAN     2015-06-08T00:00:00    53366.00
# 25     DISTRICT ATTORNEY-MANHATTAN     2010-08-16T00:00:00    45985.00
# 26     DISTRICT ATTORNEY-MANHATTAN     2008-01-14T00:00:00    36154.00
# 27     DISTRICT ATTORNEY-MANHATTAN     2014-10-20T00:00:00    65600.00
# 28     DISTRICT ATTORNEY-MANHATTAN     1980-01-21T00:00:00    56017.00
# 29     DISTRICT ATTORNEY-MANHATTAN     2015-09-28T00:00:00    37541.00
# ...                               ...                  ...         ...
# 49970  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49971  BOARD OF ELECTION POLL WORKERS  2016-01-01T00:00:00        1.00
# 49972  BOARD OF ELECTION POLL WORKERS  2016-01-01T00:00:00        1.00
# 49973  BOARD OF ELECTION POLL WORKERS  2013-01-01T00:00:00        1.00
# 49974  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49975  BOARD OF ELECTION POLL WORKERS  2012-01-02T00:00:00        1.00
# 49976  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49977  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49978  BOARD OF ELECTION POLL WORKERS  2014-01-01T00:00:00        1.00
# 49979  BOARD OF ELECTION POLL WORKERS  2013-01-01T00:00:00        1.00
# 49980  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49981  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49982  BOARD OF ELECTION POLL WORKERS  2012-01-02T00:00:00        1.00
# 49983  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49984  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49985  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49986  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49987  BOARD OF ELECTION POLL WORKERS  2011-01-01T00:00:00        1.00
# 49988  BOARD OF ELECTION POLL WORKERS  2014-01-01T00:00:00        1.00
# 49989  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49990  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49991  BOARD OF ELECTION POLL WORKERS  2012-01-02T00:00:00        1.00
# 49992  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49993  BOARD OF ELECTION POLL WORKERS  2013-01-01T00:00:00        1.00
# 49994  BOARD OF ELECTION POLL WORKERS  2015-01-01T00:00:00        1.00
# 49995  BOARD OF ELECTION POLL WORKERS  2011-01-01T00:00:00        1.00
# 49996  BOARD OF ELECTION POLL WORKERS  2014-01-01T00:00:00        1.00
# 49997  BOARD OF ELECTION POLL WORKERS  2012-01-02T00:00:00        1.00
# 49998  BOARD OF ELECTION POLL WORKERS  2015-01-01T00:00:00        1.00
# 49999  BOARD OF ELECTION POLL WORKERS  2012-01-02T00:00:00        1.00
#
#         first_name fiscal_year        last_name leave_status_as_of_july_31  \
# 0        RAHASHEEM        2016        ABA'AHMID                     ACTIVE
# 1         MARGARET        2016          ABENSUR                     ACTIVE
# 2           ANDREA        2016        ABOUNAOUM                   ON LEAVE
# 3         JONATHAN        2016          ABRAHAM                     ACTIVE
# 4           JOSEPH        2016           ABRAMS                     CEASED
# 5         JENNIFER        2016            ABREU                     ACTIVE
# 6             JUAN        2016            ABREU                     ACTIVE
# 7         JENNIFER        2016          ACEVEDO                     ACTIVE
# 8          MATTHEW        2016         ACOCELLA                     CEASED
# 9             RITA        2016           ACOSTA                     ACTIVE
# 10       KATHERINE        2016            ADAMS                     CEASED
# 11        NEERESHA        2016            ADAMS                     ACTIVE
# 12      OYINDAMOLA        2016         ADEGBORO                     ACTIVE
# 13        SANCHITA        2016         AGGARWAL                     ACTIVE
# 14          YAMIRA        2016          AGUILAR                     ACTIVE
# 15          JORDAN        2016          AGUIRRE                     CEASED
# 16         ARTEMIS        2016          AHMETAJ                     ACTIVE
# 17           HELEN        2016              AHN                     ACTIVE
# 18          SANDRA        2016          ALCAIDE                     CEASED
# 19          DANIEL        2016        ALCANTARA                     ACTIVE
# 20            ERIN        2016        ALEXANDER                     ACTIVE
# 21            PAUL        2016           ALFLEN                     ACTIVE
# 22       SHEHARYAR        2016              ALI                     ACTIVE
# 23           SYEED        2016              ALI                     ACTIVE
# 24         JEFFREY        2016     AL-KAABAH II                     ACTIVE
# 25           ABEER        2016       ALKHAFAJEE                     CEASED
# 26         SHAIMAA        2016       ALKHAFAJEE                     ACTIVE
# 27         BENNETT        2016            ALLEN                     ACTIVE
# 28          ROBERT        2016            ALLEN                     ACTIVE
# 29         MARISOL        2016  ALMONTE-ALMANZA                     ACTIVE
# ...            ...         ...              ...                        ...
# 49970    ZULLY ANN        2016            PEREZ                     ACTIVE
# 49971       SANDRA        2016    PEREZ FRAGOSO                     ACTIVE
# 49972       JOSEPH        2016         PEREZ JR                     ACTIVE
# 49973     IDELISSE        2016       PEREZ LUNA                     ACTIVE
# 49974    SHARLEENE        2016   PEREZ-ANDERSON                     ACTIVE
# 49975        DIANA        2016     PEREZ-OCASIO                     ACTIVE
# 49976      MARITZA        2016       PEREZ-SOTO                     ACTIVE
# 49977        MARIA        2016          PERILLI                     ACTIVE
# 49978   JACQUELINE        2016           PERINE                     ACTIVE
# 49979        JASON        2016           PERINE                     ACTIVE
# 49980        KWESI        2016           PERINE                     ACTIVE
# 49981        LINDA        2016           PERINE                     ACTIVE
# 49982      SYLVIAN        2016            PERIS                     ACTIVE
# 49983         JOHN        2016           PERITO                     ACTIVE
# 49984  RAVISHANKAR        2016      PERIYAPATNA                     ACTIVE
# 49985        BETTY        2016          PERKINS                     ACTIVE
# 49986       DWAYNE        2016          PERKINS                     ACTIVE
# 49987        ESMIE        2016          PERKINS                     ACTIVE
# 49988      GENNELL        2016          PERKINS                     ACTIVE
# 49989         JOHN        2016          PERKINS                     ACTIVE
# 49990      LORETTA        2016          PERKINS                     ACTIVE
# 49991        MONEE        2016          PERKINS                     ACTIVE
# 49992        NAOMI        2016          PERKINS                     ACTIVE
# 49993   NICKOLETTE        2016          PERKINS                     ACTIVE
# 49994     PRECIOUS        2016          PERKINS                     ACTIVE
# 49995        JOYCE        2016   PERKINS CUFFEE                     ACTIVE
# 49996     JOYCELIN        2016            PERKS                     ACTIVE
# 49997   CHRYSANTHY        2016         PERLEGIS                     ACTIVE
# 49998     PATRICIA        2016       PERLMUTTER                     ACTIVE
# 49999      TRISTAN        2016          PERMELL                     ACTIVE
#
#       mid_init ot_hours   pay_basis regular_gross_paid regular_hours  \
# 0            E     2.25   per Annum           47166.03       1830.00
# 1          NaN     0.00   per Annum          119042.50       1831.00
# 2            L     1.00   per Annum           27452.62       1181.68
# 3            J     0.00   per Annum          115104.57       1831.00
# 4          NaN     0.00    per Hour            3500.00          0.00
# 5          NaN     0.00   per Annum           71967.34       1831.00
# 6            D     0.00   per Annum           87614.01       1831.00
# 7          NaN     0.00    per Hour             500.00          0.00
# 8            J     0.00   per Annum            9507.15        349.00
# 9            E     0.00   per Annum           64357.12       1830.00
# 10           J     0.00   per Annum            6073.13        200.70
# 11         NaN     0.00   per Annum           39895.79       1830.00
# 12           F     0.00   per Annum           65909.63       1830.00
# 13           J     0.00   per Annum          111806.82       1831.00
# 14         NaN   716.25   per Annum           51890.77       1830.00
# 15         NaN     0.00    per Hour            3500.00          0.00
# 16         NaN    51.75   per Annum           40052.01       1830.00
# 17           H     0.00   per Annum           59023.02       1076.00
# 18         NaN     0.00    per Hour            3500.00          0.00
# 19         NaN     0.00   per Annum           39866.21       1830.00
# 20           L     0.00   per Annum           64498.36       1509.00
# 21           R   408.75     per Day          139072.14       1830.00
# 22         NaN     0.00    per Hour            1000.00          0.00
# 23           A   173.75     per Day           56602.00       1830.00
# 24           I   276.50   per Annum           46271.84       1829.75
# 25           K     1.00   per Annum            4661.03         38.10
# 26         NaN     0.00   per Annum           35765.73       1830.00
# 27           L     0.00   per Annum           64895.59       1830.00
# 28           K     0.00   per Annum           55411.18       1830.00
# 29         NaN     0.75   per Annum           26422.22       1383.00
# ...        ...      ...         ...                ...           ...
# 49970      NaN     0.00    per Hour             586.00          0.00
# 49971      NaN     0.00    per Hour             200.00          0.00
# 49972        T     0.00    per Hour             200.00          0.00
# 49973      NaN     0.00    per Hour             460.00          0.00
# 49974        N     0.00    per Hour             575.00          0.00
# 49975      NaN     0.00    per Hour             575.00          0.00
# 49976        A     0.00    per Hour             578.00          0.00
# 49977      NaN     0.00    per Hour             575.00          0.00
# 49978      NaN     0.00    per Hour             631.00          0.00
# 49979        A     0.00    per Hour             300.00          0.00
# 49980        S     0.00    per Hour            1041.63          0.00
# 49981        J     0.00    per Hour            1025.00          0.00
# 49982        J     0.00    per Hour             305.00          0.00
# 49983      NaN     0.00    per Hour             480.00          0.00
# 49984        N     0.00    per Hour             775.00          0.00
# 49985        A     0.00    per Hour             450.00          0.00
# 49986      NaN     0.00    per Hour             775.00          0.00
# 49987      NaN     0.00    per Hour             580.00          0.00
# 49988      NaN     0.00    per Hour             578.00          0.00
# 49989      NaN     0.00    per Hour             580.00          0.00
# 49990      NaN     0.00    per Hour             575.00          0.00
# 49991        M     0.00    per Hour             775.00          0.00
# 49992        N     0.00    per Hour             400.00          0.00
# 49993      NaN     0.00    per Hour             303.00          0.00
# 49994      NaN     0.00    per Hour             575.00          0.00
# 49995      NaN     0.00    per Hour             583.00          0.00
# 49996      NaN     0.00    per Hour             575.00          0.00
# 49997      NaN     0.00    per Hour             300.00          0.00
# 49998      NaN     0.00    per Hour             575.00          0.00
# 49999        K     0.00    per Hour             688.31          0.00
#
#                                        title_description total_ot_paid  \
# 0      COMMUNITY ASSOCIATE                           ...         57.28
# 1      ADMINISTRATIVE ACCOUNTANT                     ...          0.00
# 2      COMMUNITY ASSOCIATE                           ...         21.34
# 3      COMPUTER SYSTEMS MANAGER                      ...          0.00
# 4      COLLEGE AIDE                                  ...          0.00
# 5      ASSISTANT DISTRICT ATTORNEY                   ...          0.00
# 6      ASSISTANT DISTRICT ATTORNEY                   ...          0.00
# 7      COLLEGE AIDE                                  ...          0.00
# 8      COMMUNITY ASSOCIATE                           ...          0.00
# 9                 PRINCIPAL ADMINISTRATIVE ASSOCIATE              0.00
# 10     COMMUNITY ASSOCIATE                           ...          0.00
# 11     COMMUNITY ASSOCIATE                           ...          0.00
# 12     COMMUNITY COORDINATOR                         ...          0.00
# 13     PRINCIPAL ACCOUNTANT INVESTIGATOR             ...          0.00
# 14     COMMUNITY ASSOCIATE                           ...      25943.55
# 15     COLLEGE AIDE                                  ...          0.00
# 16     COMMUNITY ASSISTANT                           ...       1413.40
# 17     ASSISTANT DISTRICT ATTORNEY                   ...          0.00
# 18     COLLEGE AIDE                                  ...          0.00
# 19     COMMUNITY ASSOCIATE                           ...          0.00
# 20     ASSISTANT DISTRICT ATTORNEY                   ...          0.00
# 21     CARPENTER                                     ...      50546.28
# 22     COLLEGE AIDE                                  ...          0.00
# 23     ELECTRICIAN'S HELPER                          ...       8991.82
# 24     COMMUNITY ASSOCIATE                           ...       7757.06
# 25     COMMUNITY ASSOCIATE                           ...        169.90
# 26     COMMUNITY ASSISTANT                           ...          0.00
# 27     COMMUNITY COORDINATOR                         ...          0.00
# 28          CLERICAL ASSOCIATE                                    0.00
# 29     COMMUNITY ASSOCIATE                           ...         15.41
# ...                                                  ...           ...
# 49970  ELECTION WORKER                               ...          0.00
# 49971  ELECTION WORKER                               ...          0.00
# 49972  ELECTION WORKER                               ...          0.00
# 49973  ELECTION WORKER                               ...          0.00
# 49974  ELECTION WORKER                               ...          0.00
# 49975  ELECTION WORKER                               ...          0.00
# 49976  ELECTION WORKER                               ...          0.00
# 49977  ELECTION WORKER                               ...          0.00
# 49978  ELECTION WORKER                               ...          0.00
# 49979  ELECTION WORKER                               ...          0.00
# 49980  ELECTION WORKER                               ...          0.00
# 49981  ELECTION WORKER                               ...          0.00
# 49982  ELECTION WORKER                               ...          0.00
# 49983  ELECTION WORKER                               ...          0.00
# 49984  ELECTION WORKER                               ...          0.00
# 49985  ELECTION WORKER                               ...          0.00
# 49986  ELECTION WORKER                               ...          0.00
# 49987  ELECTION WORKER                               ...          0.00
# 49988  ELECTION WORKER                               ...          0.00
# 49989  ELECTION WORKER                               ...          0.00
# 49990  ELECTION WORKER                               ...          0.00
# 49991  ELECTION WORKER                               ...          0.00
# 49992  ELECTION WORKER                               ...          0.00
# 49993  ELECTION WORKER                               ...          0.00
# 49994  ELECTION WORKER                               ...          0.00
# 49995  ELECTION WORKER                               ...          0.00
# 49996  ELECTION WORKER                               ...          0.00
# 49997  ELECTION WORKER                               ...          0.00
# 49998  ELECTION WORKER                               ...          0.00
# 49999  ELECTION WORKER                               ...          0.00
#
#       total_other_pay work_location_borough
# 0                0.00         MANHATTAN
# 1                0.00         MANHATTAN
# 2               33.00         MANHATTAN
# 3                0.00         MANHATTAN
# 4                0.00         MANHATTAN
# 5                0.00         MANHATTAN
# 6              750.00         MANHATTAN
# 7                0.00         MANHATTAN
# 8                0.00         MANHATTAN
# 9             3824.72         MANHATTAN
# 10               8.25         MANHATTAN
# 11              74.25         MANHATTAN
# 12              33.00         MANHATTAN
# 13             500.00         MANHATTAN
# 14             747.93         MANHATTAN
# 15               0.00         MANHATTAN
# 16             526.11         MANHATTAN
# 17               0.00         MANHATTAN
# 18               0.00         MANHATTAN
# 19               0.00         MANHATTAN
# 20            1750.00         MANHATTAN
# 21            5060.37         MANHATTAN
# 22               0.00         MANHATTAN
# 23            7424.72         MANHATTAN
# 24             755.84         MANHATTAN
# 25              94.40         MANHATTAN
# 26               0.00         MANHATTAN
# 27              99.50         MANHATTAN
# 28            4424.50         MANHATTAN
# 29              24.75         MANHATTAN
# ...               ...                   ...
# 49970            0.00         MANHATTAN
# 49971            0.00         MANHATTAN
# 49972            0.00         MANHATTAN
# 49973            0.00         MANHATTAN
# 49974            0.00         MANHATTAN
# 49975            0.00         MANHATTAN
# 49976            0.00         MANHATTAN
# 49977            0.00         MANHATTAN
# 49978            0.00         MANHATTAN
# 49979            0.00         MANHATTAN
# 49980            0.00         MANHATTAN
# 49981            0.00         MANHATTAN
# 49982            0.00         MANHATTAN
# 49983            0.00         MANHATTAN
# 49984            0.00         MANHATTAN
# 49985            0.00         MANHATTAN
# 49986            0.00         MANHATTAN
# 49987            0.00         MANHATTAN
# 49988            0.00         MANHATTAN
# 49989            0.00         MANHATTAN
# 49990            0.00         MANHATTAN
# 49991            0.00         MANHATTAN
# 49992            0.00         MANHATTAN
# 49993            0.00         MANHATTAN
# 49994            0.00         MANHATTAN
# 49995            0.00         MANHATTAN
# 49996            0.00         MANHATTAN
# 49997            0.00         MANHATTAN
# 49998            0.00         MANHATTAN
# 49999            0.00         MANHATTAN
#
# [100000 rows x 16 columns]

# %%
final_results = []
loops = 24 
records = 50000
values = 'abcdefghi'
#for i in range(loops):
    #results = client.get(identified, limit=records, offset=records*i)
    #df.append(results)

# %%
values
# Out:
# 'abcdefghi'

# %%
values[0]
# Out:
# 'a'

# %%
final_results.append(values[0])

# %%
final_results
# Out:
# ['a']

# %%
final_results = []

# %%
final_results = []
loops = 24 
records = 50000
values = 'abcdefghijklmnopqrstuvwxyz'
for i in range(loops):
    results = client.get(identified, limit=records, offset=records*i)
    final_results.append(pd.DataFrame(results))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-78-bb23bdeb67a9> in <module>()
#       5 for i in range(loops):
#       6     results = client.get(identified, limit=records, offset=records*i)
# ----> 7     values[i] = pd.DataFrame(results)
#       8     final_results.append(values[i])
#       9
#
# TypeError: 'str' object does not support item assignment

# %%
final_results = []
loops = 24 
records = 50000
values = 'abcdefghijklmnopqrstuvwxyz'
for i in range(loops):
    results = client.get(identified, limit=records, offset=records*i)
    final_results.append(pd.DataFrame(results))

# %%
final_results
# Out:
# [                          agency_name    agency_start_date base_salary  \
#  0      DISTRICT ATTORNEY-MANHATTAN     2003-07-14T00:00:00    47678.00
#  1      DISTRICT ATTORNEY-MANHATTAN     1995-06-12T00:00:00   119959.00
#  2      DISTRICT ATTORNEY-MANHATTAN     2011-10-11T00:00:00    39966.00
#  3      DISTRICT ATTORNEY-MANHATTAN     2014-12-01T00:00:00   116000.00
#  4      DISTRICT ATTORNEY-MANHATTAN     2015-05-21T00:00:00        1.00
#  5      DISTRICT ATTORNEY-MANHATTAN     2012-09-04T00:00:00    71500.00
#  6      DISTRICT ATTORNEY-MANHATTAN     2007-09-04T00:00:00    88000.00
#  7      DISTRICT ATTORNEY-MANHATTAN     2016-06-06T00:00:00        1.00
#  8      DISTRICT ATTORNEY-MANHATTAN     2014-09-02T00:00:00    41000.00
#  9      DISTRICT ATTORNEY-MANHATTAN     1978-05-31T00:00:00    66035.00
#  10     DISTRICT ATTORNEY-MANHATTAN     2013-04-22T00:00:00    38869.00
#  11     DISTRICT ATTORNEY-MANHATTAN     2014-08-25T00:00:00    42075.00
#  12     DISTRICT ATTORNEY-MANHATTAN     2014-01-13T00:00:00    66625.00
#  13     DISTRICT ATTORNEY-MANHATTAN     2005-03-28T00:00:00   112592.00
#  14     DISTRICT ATTORNEY-MANHATTAN     2009-11-09T00:00:00    52548.00
#  15     DISTRICT ATTORNEY-MANHATTAN     2015-05-21T00:00:00        1.00
#  16     DISTRICT ATTORNEY-MANHATTAN     2014-04-28T00:00:00    43299.00
#  17     DISTRICT ATTORNEY-MANHATTAN     2004-09-07T00:00:00   102500.00
#  18     DISTRICT ATTORNEY-MANHATTAN     2015-05-21T00:00:00        1.00
#  19     DISTRICT ATTORNEY-MANHATTAN     2007-01-19T00:00:00    40299.00
#  20     DISTRICT ATTORNEY-MANHATTAN     2014-09-02T00:00:00    78000.00
#  21     DISTRICT ATTORNEY-MANHATTAN     2008-09-21T00:00:00      370.16
#  22     DISTRICT ATTORNEY-MANHATTAN     2016-06-06T00:00:00        1.00
#  23     DISTRICT ATTORNEY-MANHATTAN     2009-03-02T00:00:00      217.70
#  24     DISTRICT ATTORNEY-MANHATTAN     2015-06-08T00:00:00    53366.00
#  25     DISTRICT ATTORNEY-MANHATTAN     2010-08-16T00:00:00    45985.00
#  26     DISTRICT ATTORNEY-MANHATTAN     2008-01-14T00:00:00    36154.00
#  27     DISTRICT ATTORNEY-MANHATTAN     2014-10-20T00:00:00    65600.00
#  28     DISTRICT ATTORNEY-MANHATTAN     1980-01-21T00:00:00    56017.00
#  29     DISTRICT ATTORNEY-MANHATTAN     2015-09-28T00:00:00    37541.00
#  ...                               ...                  ...         ...
#  49970               POLICE DEPARTMENT  2005-09-26T00:00:00    39868.00
#  49971               POLICE DEPARTMENT  2009-02-02T00:00:00    39164.00
#  49972               POLICE DEPARTMENT  2005-07-20T00:00:00    78026.00
#  49973               POLICE DEPARTMENT  2010-07-06T00:00:00    42395.00
#  49974               POLICE DEPARTMENT  2005-01-10T00:00:00    78026.00
#  49975               POLICE DEPARTMENT  1996-07-26T00:00:00   118902.00
#  49976               POLICE DEPARTMENT  1998-08-31T00:00:00    78026.00
#  49977               POLICE DEPARTMENT  2011-07-06T00:00:00    57747.00
#  49978               POLICE DEPARTMENT  2006-07-10T00:00:00    78026.00
#  49979               POLICE DEPARTMENT  2015-07-08T00:00:00    42819.00
#  49980               POLICE DEPARTMENT  2015-01-07T00:00:00    42819.00
#  49981               POLICE DEPARTMENT  2001-07-02T00:00:00    78026.00
#  49982               POLICE DEPARTMENT  2016-01-06T00:00:00    42819.00
#  49983               POLICE DEPARTMENT  1994-02-28T00:00:00   117145.00
#  49984               POLICE DEPARTMENT  2012-07-11T00:00:00    54341.00
#  49985               POLICE DEPARTMENT  1998-12-20T00:00:00    38044.00
#  49986               POLICE DEPARTMENT  1990-10-15T00:00:00   102054.00
#  49987               POLICE DEPARTMENT  1989-07-05T00:00:00   103517.00
#  49988               POLICE DEPARTMENT  2010-07-06T00:00:00    78026.00
#  49989               POLICE DEPARTMENT  1995-04-30T00:00:00    78026.00
#  49990               POLICE DEPARTMENT  1991-04-30T00:00:00    88151.00
#  49991               POLICE DEPARTMENT  2011-07-06T00:00:00    57747.00
#  49992               POLICE DEPARTMENT  2014-07-09T00:00:00    44521.00
#  49993               POLICE DEPARTMENT  1991-04-30T00:00:00    77253.00
#  49994               POLICE DEPARTMENT  2004-01-20T00:00:00   108748.00
#  49995               POLICE DEPARTMENT  1980-12-31T00:00:00    38319.00
#  49996               POLICE DEPARTMENT  1993-08-30T00:00:00    78026.00
#  49997               POLICE DEPARTMENT  1992-06-30T00:00:00    99053.00
#  49998               POLICE DEPARTMENT  2005-07-25T00:00:00    37821.00
#  49999               POLICE DEPARTMENT  2006-07-10T00:00:00    78026.00
#
#         first_name fiscal_year        last_name leave_status_as_of_july_31  \
#  0       RAHASHEEM        2016        ABA'AHMID                     ACTIVE
#  1        MARGARET        2016          ABENSUR                     ACTIVE
#  2          ANDREA        2016        ABOUNAOUM                   ON LEAVE
#  3        JONATHAN        2016          ABRAHAM                     ACTIVE
#  4          JOSEPH        2016           ABRAMS                     CEASED
#  5        JENNIFER        2016            ABREU                     ACTIVE
#  6            JUAN        2016            ABREU                     ACTIVE
#  7        JENNIFER        2016          ACEVEDO                     ACTIVE
#  8         MATTHEW        2016         ACOCELLA                     CEASED
#  9            RITA        2016           ACOSTA                     ACTIVE
#  10      KATHERINE        2016            ADAMS                     CEASED
#  11       NEERESHA        2016            ADAMS                     ACTIVE
#  12     OYINDAMOLA        2016         ADEGBORO                     ACTIVE
#  13       SANCHITA        2016         AGGARWAL                     ACTIVE
#  14         YAMIRA        2016          AGUILAR                     ACTIVE
#  15         JORDAN        2016          AGUIRRE                     CEASED
#  16        ARTEMIS        2016          AHMETAJ                     ACTIVE
#  17          HELEN        2016              AHN                     ACTIVE
#  18         SANDRA        2016          ALCAIDE                     CEASED
#  19         DANIEL        2016        ALCANTARA                     ACTIVE
#  20           ERIN        2016        ALEXANDER                     ACTIVE
#  21           PAUL        2016           ALFLEN                     ACTIVE
#  22      SHEHARYAR        2016              ALI                     ACTIVE
#  23          SYEED        2016              ALI                     ACTIVE
#  24        JEFFREY        2016     AL-KAABAH II                     ACTIVE
#  25          ABEER        2016       ALKHAFAJEE                     CEASED
#  26        SHAIMAA        2016       ALKHAFAJEE                     ACTIVE
#  27        BENNETT        2016            ALLEN                     ACTIVE
#  28         ROBERT        2016            ALLEN                     ACTIVE
#  29        MARISOL        2016  ALMONTE-ALMANZA                     ACTIVE
#  ...           ...         ...              ...                        ...
#  49970      SELENA        2016           PALMER                     ACTIVE
#  49971   SHANIELLE        2016           PALMER                     ACTIVE
#  49972     VINCENT        2016           PALMER                     ACTIVE
#  49973     WILLIAM        2016           PALMER                     CEASED
#  49974     WILLIAM        2016           PALMER                     ACTIVE
#  49975      THOMAS        2016        PALMER JR                   ON LEAVE
#  49976       CHRIS        2016          PALMERI                     ACTIVE
#  49977      JOSEPH        2016          PALMERI                     ACTIVE
#  49978     MATTHEW        2016        PALMERINI                     ACTIVE
#  49979        JOHN        2016          PALMESE                     CEASED
#  49980      JOSEPH        2016          PALMESE                     ACTIVE
#  49981     MICHAEL        2016          PALMESE                     ACTIVE
#  49982       SCOTT        2016          PALMESE                     ACTIVE
#  49983       COSMO        2016         PALMIERI                     CEASED
#  49984    CRISTINA        2016         PALMIERI                     ACTIVE
#  49985        DAWN        2016         PALMIERI                     CEASED
#  49986     DOROTHY        2016         PALMIERI                     CEASED
#  49987        JOHN        2016         PALMIERI                     CEASED
#  49988     MATTHEW        2016         PALMIERI                     ACTIVE
#  49989      REGINA        2016         PALMIERI                     CEASED
#  49990      DENISE        2016       PALMINTERI                     CEASED
#  49991        PAUL        2016       PALMINTERI                     ACTIVE
#  49992        RYAN        2016       PALMINTERI                     ACTIVE
#  49993      PIERRE        2016        PALMIOTTI                     CEASED
#  49994      JOSEPH        2016        PALMIOTTO                     ACTIVE
#  49995    GENEVIEV        2016          PALOMBA                     ACTIVE
#  49996     MICHAEL        2016          PALOMBO                     ACTIVE
#  49997        PAUL        2016          PALOMBO                     CEASED
#  49998       RALPH        2016          PALOMBO                     ACTIVE
#  49999       OSCAR        2016         PALOMINO                     ACTIVE
#
#        mid_init ot_hours   pay_basis regular_gross_paid regular_hours  \
#  0            E     2.25   per Annum           47166.03       1830.00
#  1          NaN     0.00   per Annum          119042.50       1831.00
#  2            L     1.00   per Annum           27452.62       1181.68
#  3            J     0.00   per Annum          115104.57       1831.00
#  4          NaN     0.00    per Hour            3500.00          0.00
#  5          NaN     0.00   per Annum           71967.34       1831.00
#  6            D     0.00   per Annum           87614.01       1831.00
#  7          NaN     0.00    per Hour             500.00          0.00
#  8            J     0.00   per Annum            9507.15        349.00
#  9            E     0.00   per Annum           64357.12       1830.00
#  10           J     0.00   per Annum            6073.13        200.70
#  11         NaN     0.00   per Annum           39895.79       1830.00
#  12           F     0.00   per Annum           65909.63       1830.00
#  13           J     0.00   per Annum          111806.82       1831.00
#  14         NaN   716.25   per Annum           51890.77       1830.00
#  15         NaN     0.00    per Hour            3500.00          0.00
#  16         NaN    51.75   per Annum           40052.01       1830.00
#  17           H     0.00   per Annum           59023.02       1076.00
#  18         NaN     0.00    per Hour            3500.00          0.00
#  19         NaN     0.00   per Annum           39866.21       1830.00
#  20           L     0.00   per Annum           64498.36       1509.00
#  21           R   408.75     per Day          139072.14       1830.00
#  22         NaN     0.00    per Hour            1000.00          0.00
#  23           A   173.75     per Day           56602.00       1830.00
#  24           I   276.50   per Annum           46271.84       1829.75
#  25           K     1.00   per Annum            4661.03         38.10
#  26         NaN     0.00   per Annum           35765.73       1830.00
#  27           L     0.00   per Annum           64895.59       1830.00
#  28           K     0.00   per Annum           55411.18       1830.00
#  29         NaN     0.75   per Annum           26422.22       1383.00
#  ...        ...      ...         ...                ...           ...
#  49970        M    44.25   per Annum           46174.73       2091.42
#  49971        A   593.00   per Annum           41886.35       2091.42
#  49972        M   261.28   per Annum           84324.25       2091.42
#  49973        E     0.00   per Annum              14.37          0.00
#  49974        G   356.00   per Annum           84251.63       2091.42
#  49975        J     0.00   per Annum          100022.63       2091.42
#  49976      NaN   313.85   per Annum           84324.25       2091.42
#  49977        I   136.00   per Annum           59201.58       2091.42
#  49978        L   289.92   per Annum           83933.75       2091.42
#  49979        T    67.53   per Annum           38607.43       1862.87
#  49980        J   110.15   per Annum           43336.90       2091.42
#  49981        A   145.00   per Annum           84324.25       2091.42
#  49982        T     0.00   per Annum           18484.76        988.57
#  49983        J    68.33   per Annum          103076.98       1742.85
#  49984      NaN   179.17   per Annum           53969.46       2091.42
#  49985        M     0.00   per Annum           18475.75        493.32
#  49986        B   194.40   per Annum           95400.41       1394.28
#  49987        L     0.00   per Annum               0.00          0.00
#  49988        C   466.62   per Annum           70403.18       2091.42
#  49989      NaN     0.00   per Annum            1515.30          0.00
#  49990        E     0.00   per Annum               0.00          0.00
#  49991        G   473.53   per Annum           59085.02       2091.42
#  49992        M   162.00   per Annum           44097.46       2091.42
#  49993        A     0.00   per Annum             572.44          0.00
#  49994        A   399.33   per Annum          106479.51       2091.42
#  49995        T     0.00   per Annum           37903.14       1830.00
#  49996        L   117.67   per Annum           84324.25       2091.42
#  49997      NaN     0.00   per Annum               0.00          0.00
#  49998      NaN     0.00   per Annum           37414.88       1830.00
#  49999      NaN   244.37   per Annum           83933.75       2091.42
#
#                                         title_description total_ot_paid  \
#  0      COMMUNITY ASSOCIATE                           ...         57.28
#  1      ADMINISTRATIVE ACCOUNTANT                     ...          0.00
#  2      COMMUNITY ASSOCIATE                           ...         21.34
#  3      COMPUTER SYSTEMS MANAGER                      ...          0.00
#  4      COLLEGE AIDE                                  ...          0.00
#  5      ASSISTANT DISTRICT ATTORNEY                   ...          0.00
#  6      ASSISTANT DISTRICT ATTORNEY                   ...          0.00
#  7      COLLEGE AIDE                                  ...          0.00
#  8      COMMUNITY ASSOCIATE                           ...          0.00
#  9                 PRINCIPAL ADMINISTRATIVE ASSOCIATE              0.00
#  10     COMMUNITY ASSOCIATE                           ...          0.00
#  11     COMMUNITY ASSOCIATE                           ...          0.00
#  12     COMMUNITY COORDINATOR                         ...          0.00
#  13     PRINCIPAL ACCOUNTANT INVESTIGATOR             ...          0.00
#  14     COMMUNITY ASSOCIATE                           ...      25943.55
#  15     COLLEGE AIDE                                  ...          0.00
#  16     COMMUNITY ASSISTANT                           ...       1413.40
#  17     ASSISTANT DISTRICT ATTORNEY                   ...          0.00
#  18     COLLEGE AIDE                                  ...          0.00
#  19     COMMUNITY ASSOCIATE                           ...          0.00
#  20     ASSISTANT DISTRICT ATTORNEY                   ...          0.00
#  21     CARPENTER                                     ...      50546.28
#  22     COLLEGE AIDE                                  ...          0.00
#  23     ELECTRICIAN'S HELPER                          ...       8991.82
#  24     COMMUNITY ASSOCIATE                           ...       7757.06
#  25     COMMUNITY ASSOCIATE                           ...        169.90
#  26     COMMUNITY ASSISTANT                           ...          0.00
#  27     COMMUNITY COORDINATOR                         ...          0.00
#  28          CLERICAL ASSOCIATE                                    0.00
#  29     COMMUNITY ASSOCIATE                           ...         15.41
#  ...                                                  ...           ...
#  49970                                SCHOOL SAFETY AGENT       1143.36
#  49971                          TRAFFIC ENFORCEMENT AGENT      18481.54
#  49972                                     POLICE OFFICER      16567.29
#  49973                                     POLICE OFFICER          0.00
#  49974                                     POLICE OFFICER      25358.29
#  49975                                         LIEUTENANT         55.27
#  49976                                     POLICE OFFICER      21233.14
#  49977                                     POLICE OFFICER       5092.19
#  49978                                     POLICE OFFICER      23203.18
#  49979                                     POLICE OFFICER       2249.98
#  49980                                     POLICE OFFICER       3496.86
#  49981                                     POLICE OFFICER      11675.40
#  49982                                     POLICE OFFICER          0.00
#  49983                                         LIEUTENANT       7185.07
#  49984                                     POLICE OFFICER       7024.45
#  49985                                SCHOOL SAFETY AGENT        802.50
#  49986                POLICE OFFICER D/A DETECTIVE 2ND GR      18236.79
#  49987                                         LIEUTENANT          0.00
#  49988                                     POLICE OFFICER      26717.51
#  49989                                     POLICE OFFICER         89.71
#  49990                                    P.O. DA DET GR3          0.00
#  49991                                     POLICE OFFICER      20094.90
#  49992                                     POLICE OFFICER       4626.96
#  49993                                     POLICE OFFICER        216.93
#  49994                                         LIEUTENANT      32645.02
#  49995                         POLICE ADMINISTRATIVE AIDE          0.00
#  49996                                     POLICE OFFICER       9874.96
#  49997                POLICE OFFICER D/A DETECTIVE 2ND GR          0.00
#  49998                         POLICE ADMINISTRATIVE AIDE          0.00
#  49999                                     POLICE OFFICER      22913.54
#
#        total_other_pay work_location_borough
#  0                0.00         MANHATTAN
#  1                0.00         MANHATTAN
#  2               33.00         MANHATTAN
#  3                0.00         MANHATTAN
#  4                0.00         MANHATTAN
#  5                0.00         MANHATTAN
#  6              750.00         MANHATTAN
#  7                0.00         MANHATTAN
#  8                0.00         MANHATTAN
#  9             3824.72         MANHATTAN
#  10               8.25         MANHATTAN
#  11              74.25         MANHATTAN
#  12              33.00         MANHATTAN
#  13             500.00         MANHATTAN
#  14             747.93         MANHATTAN
#  15               0.00         MANHATTAN
#  16             526.11         MANHATTAN
#  17               0.00         MANHATTAN
#  18               0.00         MANHATTAN
#  19               0.00         MANHATTAN
#  20            1750.00         MANHATTAN
#  21            5060.37         MANHATTAN
#  22               0.00         MANHATTAN
#  23            7424.72         MANHATTAN
#  24             755.84         MANHATTAN
#  25              94.40         MANHATTAN
#  26               0.00         MANHATTAN
#  27              99.50         MANHATTAN
#  28            4424.50         MANHATTAN
#  29              24.75         MANHATTAN
#  ...               ...                   ...
#  49970         1001.78             MANHATTAN
#  49971         3072.52             MANHATTAN
#  49972        13125.99              RICHMOND
#  49973            0.00             MANHATTAN
#  49974        17016.10              RICHMOND
#  49975        15291.80             MANHATTAN
#  49976        19202.84             MANHATTAN
#  49977         5284.23             MANHATTAN
#  49978        15761.20                 BRONX
#  49979         3629.91             MANHATTAN
#  49980         5934.76                QUEENS
#  49981        18823.03             MANHATTAN
#  49982            0.00             MANHATTAN
#  49983         3580.87             MANHATTAN
#  49984         4695.04                QUEENS
#  49985         1486.50             MANHATTAN
#  49986        12655.63             MANHATTAN
#  49987          128.60             MANHATTAN
#  49988        13351.94              BROOKLYN
#  49989          297.85             MANHATTAN
#  49990           40.50             MANHATTAN
#  49991         6313.97              BROOKLYN
#  49992         7506.25              BROOKLYN
#  49993          124.54             MANHATTAN
#  49994        15653.39              RICHMOND
#  49995         4424.50             MANHATTAN
#  49996        21765.80             MANHATTAN
#  49997           65.80             MANHATTAN
#  49998         2817.13             MANHATTAN
#  49999        17963.32              BROOKLYN
#
#  [50000 rows x 16 columns],
#                            agency_name    agency_start_date base_salary  \
#  0                   POLICE DEPARTMENT  2001-07-02T00:00:00    78026.00
#  1                   POLICE DEPARTMENT  2014-07-09T00:00:00    44521.00
#  2                   POLICE DEPARTMENT  1995-04-02T00:00:00    90822.00
#  3                   POLICE DEPARTMENT  2015-07-08T00:00:00    42819.00
#  4                   POLICE DEPARTMENT  2007-07-09T00:00:00    78026.00
#  5                   POLICE DEPARTMENT  2011-07-06T00:00:00    42395.00
#  6                   POLICE DEPARTMENT  2000-03-01T00:00:00    78026.00
#  7                   POLICE DEPARTMENT  1998-12-20T00:00:00    36033.00
#  8                   POLICE DEPARTMENT  1999-07-07T00:00:00   103585.00
#  9                   POLICE DEPARTMENT  2002-10-28T00:00:00    98025.00
#  10                  POLICE DEPARTMENT  2000-09-29T00:00:00   160565.00
#  11                  POLICE DEPARTMENT  1990-07-10T00:00:00    77253.00
#  12                  POLICE DEPARTMENT  2007-05-29T00:00:00    39868.00
#  13                  POLICE DEPARTMENT  1995-04-02T00:00:00    78026.00
#  14                  POLICE DEPARTMENT  2014-01-08T00:00:00    44521.00
#  15                  POLICE DEPARTMENT  1995-06-30T00:00:00   152534.00
#  16                  POLICE DEPARTMENT  1995-04-30T00:00:00   103585.00
#  17                  POLICE DEPARTMENT  1995-04-30T00:00:00    78026.00
#  18                  POLICE DEPARTMENT  2002-07-22T00:00:00    78026.00
#  19                  POLICE DEPARTMENT  1997-04-15T00:00:00   121179.00
#  20                  POLICE DEPARTMENT  2007-07-09T00:00:00    87204.00
#  21                  POLICE DEPARTMENT  2006-01-09T00:00:00    78026.00
#  22                  POLICE DEPARTMENT  2013-01-09T00:00:00    49760.00
#  23                  POLICE DEPARTMENT  2005-01-10T00:00:00   103585.00
#  24                  POLICE DEPARTMENT  2006-07-10T00:00:00    78026.00
#  25                  POLICE DEPARTMENT  1995-06-30T00:00:00    90822.00
#  26                  POLICE DEPARTMENT  2013-07-09T00:00:00    49760.00
#  27                  POLICE DEPARTMENT  2006-01-09T00:00:00    78026.00
#  28                  POLICE DEPARTMENT  2010-06-14T00:00:00    67409.00
#  29                  POLICE DEPARTMENT  1995-04-30T00:00:00   102054.00
#  ...                               ...                  ...         ...
#  49970  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
#  49971  BOARD OF ELECTION POLL WORKERS  2016-01-01T00:00:00        1.00
#  49972  BOARD OF ELECTION POLL WORKERS  2016-01-01T00:00:00        1.00
#  49973  BOARD OF ELECTION POLL WORKERS  2013-01-01T00:00:00        1.00
#  49974  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
#  49975  BOARD OF ELECTION POLL WORKERS  2012-01-02T00:00:00        1.00
#  49976  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
#  49977  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
#  49978  BOARD OF ELECTION POLL WORKERS  2014-01-01T00:00:00        1.00
#  49979  BOARD OF ELECTION POLL WORKERS  2013-01-01T00:00:00        1.00
#  49980  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
#  49981  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
#  49982  BOARD OF ELECTION POLL WORKERS  2012-01-02T00:00:00        1.00
#  49983  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
#  49984  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
#  49985  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
#  49986  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
#  49987  BOARD OF ELECTION POLL WORKERS  2011-01-01T00:00:00        1.00
#  49988  BOARD OF ELECTION POLL WORKERS  2014-01-01T00:00:00        1.00
#  49989  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
#  49990  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
#  49991  BOARD OF ELECTION POLL WORKERS  2012-01-02T00:00:00        1.00
#  49992  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
#  49993  BOARD OF ELECTION POLL WORKERS  2013-01-01T00:00:00        1.00
#  49994  BOARD OF ELECTION POLL WORKERS  2015-01-01T00:00:00        1.00
#  49995  BOARD OF ELECTION POLL WORKERS  2011-01-01T00:00:00        1.00
#  49996  BOARD OF ELECTION POLL WORKERS  2014-01-01T00:00:00        1.00
#  49997  BOARD OF ELECTION POLL WORKERS  2012-01-02T00:00:00        1.00
#  49998  BOARD OF ELECTION POLL WORKERS  2015-01-01T00:00:00        1.00
#  49999  BOARD OF ELECTION POLL WORKERS  2012-01-02T00:00:00        1.00
#
#          first_name fiscal_year       last_name leave_status_as_of_july_31  \
#  0             DANA        2016          PALOMO                     ACTIVE
#  1          ASHMEED        2016          PALTOO                     ACTIVE
#  2          RAYMOND        2016          PALTOO                     CEASED
#  3          MICHAEL        2016          PALUCH                     ACTIVE
#  4           MARCIN        2016     PALUCHOWSKI                     ACTIVE
#  5          ANTONIO        2016         PALUMBO                     CEASED
#  6           DANIEL        2016         PALUMBO                     ACTIVE
#  7          FELISHA        2016         PALUMBO                     CEASED
#  8            FRANK        2016         PALUMBO                     ACTIVE
#  9          HEATHER        2016         PALUMBO                     ACTIVE
#  10           JAMES        2016         PALUMBO                     ACTIVE
#  11         LINETTE        2016         PALUMBO                     CEASED
#  12          LOUISE        2016         PALUMBO                     ACTIVE
#  13           PETER        2016         PALUMBO                     ACTIVE
#  14         VINCENT        2016         PALUMBO                     ACTIVE
#  15         CARMINE        2016         PALUMMO                     ACTIVE
#  16            ERIC        2016         PALUSKO                     ACTIVE
#  17         VANESSA        2016         PALUSKO                     CEASED
#  18         RICHARD        2016   PALUSZKIEWICZ                     ACTIVE
#  19           HELEN        2016      PAMPAFIKOS                     ACTIVE
#  20          ANGELO        2016         PAMPENA                     ACTIVE
#  21         DAPHNEY        2016        PAMPHILE                     ACTIVE
#  22           KEVIN        2016        PAMPHILE                     ACTIVE
#  23          JESSIE        2016             PAN                     ACTIVE
#  24            JOHN        2016             PAN                     ACTIVE
#  25           KAREN        2016             PAN                     CEASED
#  26             MEI        2016             PAN                     ACTIVE
#  27         MIN QIN        2016             PAN                     ACTIVE
#  28              YE        2016             PAN                     ACTIVE
#  29          SPIROS        2016    PANACOPOULOS                     CEASED
#  ...            ...         ...             ...                        ...
#  49970    ZULLY ANN        2016           PEREZ                     ACTIVE
#  49971       SANDRA        2016   PEREZ FRAGOSO                     ACTIVE
#  49972       JOSEPH        2016        PEREZ JR                     ACTIVE
#  49973     IDELISSE        2016      PEREZ LUNA                     ACTIVE
#  49974    SHARLEENE        2016  PEREZ-ANDERSON                     ACTIVE
#  49975        DIANA        2016    PEREZ-OCASIO                     ACTIVE
#  49976      MARITZA        2016      PEREZ-SOTO                     ACTIVE
#  49977        MARIA        2016         PERILLI                     ACTIVE
#  49978   JACQUELINE        2016          PERINE                     ACTIVE
#  49979        JASON        2016          PERINE                     ACTIVE
#  49980        KWESI        2016          PERINE                     ACTIVE
#  49981        LINDA        2016          PERINE                     ACTIVE
#  49982      SYLVIAN        2016           PERIS                     ACTIVE
#  49983         JOHN        2016          PERITO                     ACTIVE
#  49984  RAVISHANKAR        2016     PERIYAPATNA                     ACTIVE
#  49985        BETTY        2016         PERKINS                     ACTIVE
#  49986       DWAYNE        2016         PERKINS                     ACTIVE
#  49987        ESMIE        2016         PERKINS                     ACTIVE
#  49988      GENNELL        2016         PERKINS                     ACTIVE
#  49989         JOHN        2016         PERKINS                     ACTIVE
#  49990      LORETTA        2016         PERKINS                     ACTIVE
#  49991        MONEE        2016         PERKINS                     ACTIVE
#  49992        NAOMI        2016         PERKINS                     ACTIVE
#  49993   NICKOLETTE        2016         PERKINS                     ACTIVE
#  49994     PRECIOUS        2016         PERKINS                     ACTIVE
#  49995        JOYCE        2016  PERKINS CUFFEE                     ACTIVE
#  49996     JOYCELIN        2016           PERKS                     ACTIVE
#  49997   CHRYSANTHY        2016        PERLEGIS                     ACTIVE
#  49998     PATRICIA        2016      PERLMUTTER                     ACTIVE
#  49999      TRISTAN        2016         PERMELL                     ACTIVE
#
#        mid_init ot_hours  pay_basis regular_gross_paid regular_hours  \
#  0            C   350.90  per Annum           84324.25       2091.42
#  1          NaN   227.17  per Annum           45267.84       2091.42
#  2          NaN   391.77  per Annum           79497.44       1742.85
#  3          NaN    19.33  per Annum           39777.33       2028.57
#  4          NaN   342.50  per Annum           83466.58       2091.42
#  5          NaN     0.00  per Annum              15.50          0.00
#  6            J    17.78  per Annum           84324.25       2091.42
#  7            D     0.00  per Annum            2287.00          0.00
#  8            J    79.00  per Annum           88096.64       2091.42
#  9          NaN    11.00  per Annum           96956.19       1830.00
#  10           R     0.00  per Annum          151269.90       2091.42
#  11         NaN     0.00  per Annum             700.17          0.00
#  12           A    10.50  per Annum           46068.19       2091.42
#  13         NaN   497.52  per Annum           84324.25       2091.42
#  14           C     0.00  per Annum           45378.52       2091.42
#  15           C     0.00  per Annum          151269.90       2091.42
#  16         NaN   102.75  per Annum          102689.21       2091.42
#  17         NaN     0.00  per Annum            3967.47          0.00
#  18           J   458.50  per Annum           84324.25       2091.42
#  19         NaN   436.67  per Annum          118016.28       2091.42
#  20           J   253.72  per Annum           85347.84       1922.85
#  21         NaN   117.72  per Annum           84137.87       2091.42
#  22         NaN   194.67  per Annum           51215.11       2091.42
#  23           T    36.67  per Annum          102802.38       2091.42
#  24         NaN   146.40  per Annum           83933.75       2091.42
#  25           V   252.67  per Annum           66397.57       1051.42
#  26         NaN   262.33  per Annum           48146.21       2091.42
#  27         NaN   428.87  per Annum           84137.87       2091.42
#  28         NaN     0.00  per Annum           63358.25       1830.00
#  29         NaN     0.00  per Annum           23293.14        348.57
#  ...        ...      ...        ...                ...           ...
#  49970      NaN     0.00   per Hour             586.00          0.00
#  49971      NaN     0.00   per Hour             200.00          0.00
#  49972        T     0.00   per Hour             200.00          0.00
#  49973      NaN     0.00   per Hour             460.00          0.00
#  49974        N     0.00   per Hour             575.00          0.00
#  49975      NaN     0.00   per Hour             575.00          0.00
#  49976        A     0.00   per Hour             578.00          0.00
#  49977      NaN     0.00   per Hour             575.00          0.00
#  49978      NaN     0.00   per Hour             631.00          0.00
#  49979        A     0.00   per Hour             300.00          0.00
#  49980        S     0.00   per Hour            1041.63          0.00
#  49981        J     0.00   per Hour            1025.00          0.00
#  49982        J     0.00   per Hour             305.00          0.00
#  49983      NaN     0.00   per Hour             480.00          0.00
#  49984        N     0.00   per Hour             775.00          0.00
#  49985        A     0.00   per Hour             450.00          0.00
#  49986      NaN     0.00   per Hour             775.00          0.00
#  49987      NaN     0.00   per Hour             580.00          0.00
#  49988      NaN     0.00   per Hour             578.00          0.00
#  49989      NaN     0.00   per Hour             580.00          0.00
#  49990      NaN     0.00   per Hour             575.00          0.00
#  49991        M     0.00   per Hour             775.00          0.00
#  49992        N     0.00   per Hour             400.00          0.00
#  49993      NaN     0.00   per Hour             303.00          0.00
#  49994      NaN     0.00   per Hour             575.00          0.00
#  49995      NaN     0.00   per Hour             583.00          0.00
#  49996      NaN     0.00   per Hour             575.00          0.00
#  49997      NaN     0.00   per Hour             300.00          0.00
#  49998      NaN     0.00   per Hour             575.00          0.00
#  49999        K     0.00   per Hour             688.31          0.00
#
#                                         title_description total_ot_paid  \
#  0                                         POLICE OFFICER      23932.75
#  1                                         POLICE OFFICER       8754.46
#  2                                        P.O. DA DET GR3      29192.92
#  3                                         POLICE OFFICER        472.90
#  4                                         POLICE OFFICER      24189.00
#  5                                         POLICE OFFICER          0.00
#  6                                         POLICE OFFICER       1483.63
#  7                                    SCHOOL SAFETY AGENT          0.00
#  8                                               SERGEANT       6285.45
#  9                                            CRIMINALIST        616.42
#  10                          CAPTAIN D/A DEPUTY INSPECTOR          0.00
#  11                                        POLICE OFFICER         75.80
#  12                                   SCHOOL SAFETY AGENT         54.43
#  13                                        POLICE OFFICER      32966.43
#  14                                        POLICE OFFICER         10.70
#  15                                               CAPTAIN          0.00
#  16                                              SERGEANT      10383.74
#  17                                        POLICE OFFICER        374.93
#  18                                        POLICE OFFICER      29260.69
#  19                     LIEUTENANT D/A SPECIAL ASSIGNMENT      40180.33
#  20                                       P.O. DA DET GR3      17748.62
#  21                                        POLICE OFFICER       9062.59
#  22                                        POLICE OFFICER       7239.93
#  23                                              SERGEANT       3226.48
#  24                                        POLICE OFFICER       9792.52
#  25                                       P.O. DA DET GR3      18682.96
#  26                                        POLICE OFFICER      10125.50
#  27                                        POLICE OFFICER      30975.11
#  28                                    MANAGEMENT AUDITOR          0.00
#  29                                              SERGEANT          0.00
#  ...                                                  ...           ...
#  49970  ELECTION WORKER                               ...          0.00
#  49971  ELECTION WORKER                               ...          0.00
#  49972  ELECTION WORKER                               ...          0.00
#  49973  ELECTION WORKER                               ...          0.00
#  49974  ELECTION WORKER                               ...          0.00
#  49975  ELECTION WORKER                               ...          0.00
#  49976  ELECTION WORKER                               ...          0.00
#  49977  ELECTION WORKER                               ...          0.00
#  49978  ELECTION WORKER                               ...          0.00
#  49979  ELECTION WORKER                               ...          0.00
#  49980  ELECTION WORKER                               ...          0.00
#  49981  ELECTION WORKER                               ...          0.00
#  49982  ELECTION WORKER                               ...          0.00
#  49983  ELECTION WORKER                               ...          0.00
#  49984  ELECTION WORKER                               ...          0.00
#  49985  ELECTION WORKER                               ...          0.00
#  49986  ELECTION WORKER                               ...          0.00
#  49987  ELECTION WORKER                               ...          0.00
#  49988  ELECTION WORKER                               ...          0.00
#  49989  ELECTION WORKER                               ...          0.00
#  49990  ELECTION WORKER                               ...          0.00
#  49991  ELECTION WORKER                               ...          0.00
#  49992  ELECTION WORKER                               ...          0.00
#  49993  ELECTION WORKER                               ...          0.00
#  49994  ELECTION WORKER                               ...          0.00
#  49995  ELECTION WORKER                               ...          0.00
#  49996  ELECTION WORKER                               ...          0.00
#  49997  ELECTION WORKER                               ...          0.00
#  49998  ELECTION WORKER                               ...          0.00
#  49999  ELECTION WORKER                               ...          0.00
#
#        total_other_pay work_location_borough
#  0            12822.47                QUEENS
#  1             4334.07              BROOKLYN
#  2           -37054.09             MANHATTAN
#  3             3062.97                 BRONX
#  4            11322.23             MANHATTAN
#  5                0.71             MANHATTAN
#  6            15131.99             MANHATTAN
#  7                0.00             MANHATTAN
#  8            16075.67                 BRONX
#  9             5360.45                QUEENS
#  10           21043.68              BROOKLYN
#  11             146.47             MANHATTAN
#  12            1000.00                 BRONX
#  13           21318.24             MANHATTAN
#  14            6358.98              BROOKLYN
#  15           20340.59             MANHATTAN
#  16           17094.57                QUEENS
#  17             692.60             MANHATTAN
#  18           12472.55                QUEENS
#  19           14903.29             MANHATTAN
#  20           12072.82                QUEENS
#  21           13383.27                 BRONX
#  22            7886.14                 BRONX
#  23           14166.31             MANHATTAN
#  24           12969.49                QUEENS
#  25           10892.09             MANHATTAN
#  26            7349.95             MANHATTAN
#  27           12050.65             MANHATTAN
#  28            5784.91             MANHATTAN
#  29            5143.84             MANHATTAN
#  ...               ...                   ...
#  49970            0.00         MANHATTAN
#  49971            0.00         MANHATTAN
#  49972            0.00         MANHATTAN
#  49973            0.00         MANHATTAN
#  49974            0.00         MANHATTAN
#  49975            0.00         MANHATTAN
#  49976            0.00         MANHATTAN
#  49977            0.00         MANHATTAN
#  49978            0.00         MANHATTAN
#  49979            0.00         MANHATTAN
#  49980            0.00         MANHATTAN
#  49981            0.00         MANHATTAN
#  49982            0.00         MANHATTAN
#  49983            0.00         MANHATTAN
#  49984            0.00         MANHATTAN
#  49985            0.00         MANHATTAN
#  49986            0.00         MANHATTAN
#  49987            0.00         MANHATTAN
#  49988            0.00         MANHATTAN
#  49989            0.00         MANHATTAN
#  49990            0.00         MANHATTAN
#  49991            0.00         MANHATTAN
#  49992            0.00         MANHATTAN
#  49993            0.00         MANHATTAN
#  49994            0.00         MANHATTAN
#  49995            0.00         MANHATTAN
#  49996            0.00         MANHATTAN
#  49997            0.00         MANHATTAN
#  49998            0.00         MANHATTAN
#  49999            0.00         MANHATTAN
#
#  [50000 rows x 16 columns],
#                            agency_name    agency_start_date base_salary  \
#  0      BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
#  1      BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
#  2      BOARD OF ELECTION POLL WORKERS  2015-01-01T00:00:00        1.00
#  3      BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
#  4      BOARD OF ELECTION POLL WORKERS  2014-01-01T00:00:00        1.00
#  5      BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
#  6      BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
#  7      BOARD OF ELECTION POLL WORKERS  2012-01-02T00:00:00        1.00
#  8      BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
#  9      BOARD OF ELECTION POLL WORKERS  2014-01-01T00:00:00        1.00
#  10     BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
#  11     BOARD OF ELECTION POLL WORKERS  2012-01-02T00:00:00        1.00
#  12     BOARD OF ELECTION POLL WORKERS  2011-01-01T00:00:00        1.00
#  13     BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
#  14     BOARD OF ELECTION POLL WORKERS  2014-01-01T00:00:00        1.00
#  15     BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
#  16     BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
#  17     BOARD OF ELECTION POLL WORKERS  2013-01-01T00:00:00        1.00
#  18     BOARD OF ELECTION POLL WORKERS  2012-01-02T00:00:00        1.00
#  19     BOARD OF ELECTION POLL WORKERS  2012-01-02T00:00:00        1.00
#  20     BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
#  21     BOARD OF ELECTION POLL WORKERS  2014-01-01T00:00:00        1.00
#  22     BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
#  23     BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
#  24     BOARD OF ELECTION POLL WORKERS  2014-01-01T00:00:00        1.00
#  25     BOARD OF ELECTION POLL WORKERS  2015-01-01T00:00:00        1.00
#  26     BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
#  27     BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
#  28     BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
#  29     BOARD OF ELECTION POLL WORKERS  2014-01-01T00:00:00        1.00
#  ...                               ...                  ...         ...
#  49970  DEPARTMENT OF CORRECTION        2001-10-11T00:00:00    80788.00
#  49971  DEPARTMENT OF CORRECTION        2007-08-30T00:00:00    80788.00
#  49972  DEPARTMENT OF CORRECTION        1982-06-22T00:00:00    59139.00
#  49973  DEPARTMENT OF CORRECTION        2012-04-26T00:00:00    54546.00
#  49974  DEPARTMENT OF CORRECTION        1987-04-02T00:00:00   114837.00
#  49975  DEPARTMENT OF CORRECTION        2016-01-14T00:00:00    41992.00
#  49976  DEPARTMENT OF CORRECTION        1995-09-14T00:00:00    79594.00
#  49977  DEPARTMENT OF CORRECTION        2008-01-17T00:00:00    80788.00
#  49978  DEPARTMENT OF CORRECTION        1989-02-16T00:00:00    80788.00
#  49979  DEPARTMENT OF CORRECTION        2016-01-14T00:00:00    41992.00
#  49980  DEPARTMENT OF CORRECTION        2004-02-12T00:00:00    80788.00
#  49981  DEPARTMENT OF CORRECTION        2007-11-01T00:00:00    80788.00
#  49982  DEPARTMENT OF CORRECTION        2005-06-02T00:00:00    80788.00
#  49983  DEPARTMENT OF CORRECTION        2012-09-06T00:00:00    44693.00
#  49984  DEPARTMENT OF CORRECTION        1995-09-14T00:00:00    80788.00
#  49985  DEPARTMENT OF CORRECTION        2006-06-29T00:00:00    80788.00
#  49986  DEPARTMENT OF CORRECTION        2008-09-22T00:00:00      467.12
#  49987  DEPARTMENT OF CORRECTION        2008-06-09T00:00:00      396.72
#  49988  DEPARTMENT OF CORRECTION        2008-11-20T00:00:00    80788.00
#  49989  DEPARTMENT OF CORRECTION        2009-08-27T00:00:00    80788.00
#  49990  DEPARTMENT OF CORRECTION        2004-12-16T00:00:00    80788.00
#  49991  DEPARTMENT OF CORRECTION        2012-09-06T00:00:00    54546.00
#  49992  DEPARTMENT OF CORRECTION        2010-12-16T00:00:00    80788.00
#  49993  DEPARTMENT OF CORRECTION        2002-06-06T00:00:00    80788.00
#  49994  DEPARTMENT OF CORRECTION        1989-11-09T00:00:00    80788.00
#  49995  DEPARTMENT OF CORRECTION        2006-12-07T00:00:00    80788.00
#  49996  DEPARTMENT OF CORRECTION        2004-02-12T00:00:00    80788.00
#  49997  DEPARTMENT OF CORRECTION        1989-09-14T00:00:00    79594.00
#  49998  DEPARTMENT OF CORRECTION        1996-11-14T00:00:00    80788.00
#  49999  DEPARTMENT OF CORRECTION        2013-09-26T00:00:00    49415.00
#
#          first_name fiscal_year        last_name leave_status_as_of_july_31  \
#  0           ELAINE        2016            PERNA                     ACTIVE
# ...
#  49990  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
#  49991  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
#  49992  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
#  49993  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
#  49994  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
#  49995  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
#  49996  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
#  49997  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
#  49998  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
#  49999  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
#
#         first_name fiscal_year  last_name leave_status_as_of_july_31 mid_init  \
#  0          GLYNIS        2014     LADSON                     ACTIVE        M
#  1         GISELLE        2014      LALLA                     ACTIVE        N
#  2         BERNICE        2014    LATORRE                     ACTIVE      NaN
#  3          PAMELA        2014    MORSELL                     ACTIVE      NaN
#  4         LILLIAN        2014       REID                     ACTIVE      NaN
#  5            LISA        2014   RICHARDS                     ACTIVE      NaN
#  6          SOPHIA        2014    VENTURA                     ACTIVE        A
#  7         DEBORAH        2014       WEBB                     ACTIVE      NaN
#  8            REMY        2014      YIGAN                     ACTIVE        K
#  9         BEVERLY        2014       TODD                     CEASED      NaN
#  10         TAWANA        2014      GIBBS                   ON LEAVE        K
#  11        BARBARA        2014      HENRY        ON SEPARATION LEAVE        A
#  12      ELIZABETH        2014      REITH                     CEASED        M
#  13         TAISHA        2014    FRAZIER                     ACTIVE      NaN
#  14          TRACY        2014    PRINGLE                     ACTIVE      NaN
#  15       ROCHELLE        2014    RAYFORD                     ACTIVE      NaN
#  16         ILEANE        2014    SALOMON                     ACTIVE      NaN
#  17        DARLENE        2014      SCOTT                     ACTIVE        M
#  18         FARINA        2014    SHARIFF                     ACTIVE        A
#  19        MELISSA        2014     WATSON                     ACTIVE      NaN
#  20        MARITZA        2014    BADILLO                     ACTIVE      NaN
#  21      THEODOCIA        2014      HALEY                     ACTIVE      NaN
#  22          KESHA        2014     JOYNER                     CEASED        S
#  23        DELORES        2014     SAXTON                     ACTIVE      NaN
#  24        DANESSA        2014   WILLIAMS                     ACTIVE      NaN
#  25          EDDEL        2014  KERNISANT        ON SEPARATION LEAVE        R
#  26          DAVID        2014     REZNIK                     ACTIVE      NaN
#  27          DAISY        2014       CAMA                     ACTIVE        A
#  28      CASSANDRA        2014      STONE                     ACTIVE        D
#  29       ZELLETTE        2014   CHEATHAM                     ACTIVE        R
#  ...           ...         ...        ...                        ...      ...
#  49970      LARISA        2014  PARDILOVA                     ACTIVE      NaN
#  49971     ANTHONY        2014    PAREDES                     ACTIVE        A
#  49972      GEORGE        2014    PAREDES                     ACTIVE        I
#  49973        JOHN        2014    PAREDES                     ACTIVE        P
#  49974     MARYANN        2014    PAREDES                     ACTIVE      NaN
#  49975    PATRICIA        2014    PAREDES                     ACTIVE      NaN
#  49976        INDU        2014     PAREKH                     ACTIVE        K
#  49977   JOSEPHINE        2014    PARENTE                     ACTIVE        A
#  49978  ANTOINETTE        2014     PARHAM                     ACTIVE      NaN
#  49979       ANITA        2014     PARHAS                     ACTIVE        M
#  49980      ANJANA        2014     PARIKH                     ACTIVE        N
#  49981      NAUTAM        2014     PARIKH                     ACTIVE        N
#  49982      ROHINI        2014     PARIKH                     ACTIVE        V
#  49983     SHIRISH        2014     PARIKH                     ACTIVE        P
#  49984         RAY        2014     PARISH                     ACTIVE        A
#  49985      JOSEPH        2014       PARK                     ACTIVE      NaN
#  49986       KYUNG        2014       PARK                     ACTIVE        Y
#  49987          OM        2014    PARKASH                     ACTIVE      NaN
#  49988       ADELE        2014     PARKER                     ACTIVE      NaN
#  49989       AVRIL        2014     PARKER                     ACTIVE        A
#  49990       BETTY        2014     PARKER                     ACTIVE        E
#  49991     CLASSIE        2014     PARKER                     ACTIVE      NaN
#  49992   HENRIETTA        2014     PARKER                     ACTIVE      NaN
#  49993        INEZ        2014     PARKER                     ACTIVE      NaN
#  49994        JOHN        2014     PARKER                     ACTIVE      NaN
#  49995         KIM        2014     PARKER                     ACTIVE        A
#  49996       LYMON        2014     PARKER                     ACTIVE      NaN
#  49997     MARLENA        2014     PARKER                     ACTIVE      NaN
#  49998     MONIQUE        2014     PARKER                     ACTIVE        L
#  49999       PATTI        2014     PARKER                     ACTIVE        L
#
#        ot_hours   pay_basis regular_gross_paid regular_hours  \
#  0         0.00   per Annum           45852.04       1819.00
#  1         0.00   per Annum           45606.41       1809.75
#  2         0.00   per Annum           45852.04       1825.00
#  3         0.00   per Annum           43381.04       1705.92
#  4         0.00   per Annum           45852.04       1825.00
#  5         0.00   per Annum           45852.04       1825.00
#  6         0.00   per Annum           45852.04       1825.00
#  7         3.75   per Annum           36316.01       1825.00
#  8         0.00   per Annum           45675.69       1818.00
#  9         0.00   per Annum           14461.00        499.00
#  10        0.00   per Annum           33129.36       1236.00
#  11        0.00   per Annum           39079.29       1825.00
#  12      108.75   per Annum           25083.57        919.00
#  13        0.00   per Annum           51303.99       1825.00
#  14        0.00   per Annum           51303.99       1825.00
#  15        0.00   per Annum           51303.99       1825.00
#  16        0.00   per Annum           51303.99       1825.00
#  17        0.00   per Annum           51303.99       1825.00
#  18        0.00   per Annum           37043.50       1438.00
#  19        0.00   per Annum           49906.78       1775.43
#  20        0.00   per Annum           56755.14       1825.00
#  21        0.00   per Annum           43927.26       1825.00
#  22      103.75   per Annum           50112.14       1290.00
#  23        4.50   per Annum           31764.72       1825.00
#  24        0.00   per Annum           31764.72       1825.00
#  25        0.00   per Annum           31764.72       1822.00
#  26        0.00   per Annum           89288.78       1811.00
#  27      143.75   per Annum           49425.22       1825.00
#  28        0.00   per Annum           30176.51       1720.00
#  29       20.50   per Annum           35188.40       1825.00
#  ...        ...         ...                ...           ...
#  49970     0.00    per Hour             606.00          0.00
#  49971     0.00    per Hour             781.00          0.00
#  49972     0.00    per Hour             778.00          0.00
#  49973     0.00    per Hour             225.00          0.00
#  49974     0.00    per Hour             660.00          0.00
#  49975     0.00    per Hour             503.00          0.00
#  49976     0.00    per Hour             778.00          0.00
#  49977     0.00    per Hour             775.00          0.00
#  49978     0.00    per Hour             775.00          0.00
#  49979     0.00    per Hour             500.00          0.00
#  49980     0.00    per Hour             775.00          0.00
#  49981     0.00    per Hour             781.00          0.00
#  49982     0.00    per Hour             500.00          0.00
#  49983     0.00    per Hour             775.00          0.00
#  49984     0.00    per Hour             660.00          0.00
#  49985     0.00    per Hour             660.00          0.00
#  49986     0.00    per Hour             660.00          0.00
#  49987     0.00    per Hour             775.00          0.00
#  49988     0.00    per Hour             684.64          0.00
#  49989     0.00    per Hour             300.00          0.00
#  49990     0.00    per Hour             775.00          0.00
#  49991     0.00    per Hour            1375.00          0.00
#  49992     0.00    per Hour             775.00          0.00
#  49993     0.00    per Hour             778.00          0.00
#  49994     0.00    per Hour             775.00          0.00
#  49995     0.00    per Hour            1075.00          0.00
#  49996     0.00    per Hour             775.00          0.00
#  49997     0.00    per Hour             425.00          0.00
#  49998     0.00    per Hour             781.00          0.00
#  49999     0.00    per Hour             300.00          0.00
#
#                                         title_description total_ot_paid  \
#  0      PRINCIPAL ADMINISTRATIVE ASSOCIATE - LEV 1 & 2...          0.00
#  1      PRINCIPAL ADMINISTRATIVE ASSOCIATE - LEV 1 & 2...          0.00
#  2      PRINCIPAL ADMINISTRATIVE ASSOCIATE - LEV 1 & 2...          0.00
#  3      PRINCIPAL ADMINISTRATIVE ASSOCIATE - LEV 1 & 2...          0.00
#  4      PRINCIPAL ADMINISTRATIVE ASSOCIATE - LEV 1 & 2...          0.00
#  5      PRINCIPAL ADMINISTRATIVE ASSOCIATE - LEV 1 & 2...          0.00
#  6      PRINCIPAL ADMINISTRATIVE ASSOCIATE - LEV 1 & 2...          0.00
#  7      PRINCIPAL ADMINISTRATIVE ASSOCIATE - LEV 1 & 2...         95.70
#  8      PRINCIPAL ADMINISTRATIVE ASSOCIATE - LEV 1 & 2...          0.00
#  9      PRINCIPAL ADMINISTRATIVE ASSOCIATE - LEV 1 & 2...          0.00
#  10     PRINCIPAL ADMINISTRATIVE ASSOCIATE - LEV 1 & 2...          0.00
#  11     PRINCIPAL ADMINISTRATIVE ASSOCIATE - LEV 1 & 2...          0.00
#  12     PRINCIPAL ADMINISTRATIVE ASSOCIATE - LEV 1 & 2...       3949.15
#  13     PRINCIPAL ADMINISTRATIVE ASSOCIATE - LEV 1 & 2...          0.00
#  14     PRINCIPAL ADMINISTRATIVE ASSOCIATE - LEV 1 & 2...          0.00
#  15     PRINCIPAL ADMINISTRATIVE ASSOCIATE - LEV 1 & 2...          0.00
#  16     PRINCIPAL ADMINISTRATIVE ASSOCIATE - LEV 1 & 2...          0.00
#  17     PRINCIPAL ADMINISTRATIVE ASSOCIATE - LEV 1 & 2...          0.00
#  18     PRINCIPAL ADMINISTRATIVE ASSOCIATE - LEV 1 & 2...          0.00
#  19     PRINCIPAL ADMINISTRATIVE ASSOCIATE - LEV 1 & 2...          0.00
#  20     PRINCIPAL ADMINISTRATIVE ASSOCIATE - LEV 1 & 2...          0.00
#  21     RESEARCH ASSISTANT                            ...          0.00
#  22     SECRETARY OF COMM                             ...       4385.79
#  23     CLERICAL ASSOCIATE MOST MAYORAL AG            ...         83.84
#  24     CLERICAL ASSOCIATE MOST MAYORAL AG            ...          0.00
#  25     CLERICAL ASSOCIATE MOST MAYORAL AG            ...          0.00
#  26     DIRECTOR OF FIELD OPERATIONS                  ...          0.00
#  27     CHILD PROTECTIVE SPECIALIST                   ...       4329.68
#  28     CLERICAL ASSOCIATE MOST MAYORAL AG            ...          0.00
#  29     CLERICAL ASSOCIATE MOST MAYORAL AG            ...        353.81
#  ...                                                  ...           ...
#  49970  ELECTION WORKER                               ...          0.00
#  49971  ELECTION WORKER                               ...          0.00
#  49972  ELECTION WORKER                               ...          0.00
#  49973  ELECTION WORKER                               ...          0.00
#  49974  ELECTION WORKER                               ...          0.00
#  49975  ELECTION WORKER                               ...          0.00
#  49976  ELECTION WORKER                               ...          0.00
#  49977  ELECTION WORKER                               ...          0.00
#  49978  ELECTION WORKER                               ...          0.00
#  49979  ELECTION WORKER                               ...          0.00
#  49980  ELECTION WORKER                               ...          0.00
#  49981  ELECTION WORKER                               ...          0.00
#  49982  ELECTION WORKER                               ...          0.00
#  49983  ELECTION WORKER                               ...          0.00
#  49984  ELECTION WORKER                               ...          0.00
#  49985  ELECTION WORKER                               ...          0.00
#  49986  ELECTION WORKER                               ...          0.00
#  49987  ELECTION WORKER                               ...          0.00
#  49988  ELECTION WORKER                               ...          0.00
#  49989  ELECTION WORKER                               ...          0.00
#  49990  ELECTION WORKER                               ...          0.00
#  49991  ELECTION WORKER                               ...          0.00
#  49992  ELECTION WORKER                               ...          0.00
#  49993  ELECTION WORKER                               ...          0.00
#  49994  ELECTION WORKER                               ...          0.00
#  49995  ELECTION WORKER                               ...          0.00
#  49996  ELECTION WORKER                               ...          0.00
#  49997  ELECTION WORKER                               ...          0.00
#  49998  ELECTION WORKER                               ...          0.00
#  49999  ELECTION WORKER                               ...          0.00
#
#        total_other_pay
#  0             2771.35
#  1             2756.50
#  2             2771.35
#  3             2621.98
#  4             2771.35
#  5             2771.35
#  6             2771.35
#  7             2528.16
#  8              644.66
#  9             1164.99
#  10            2002.38
#  11            1977.65
#  12            2025.66
#  13            2796.10
#  14            2771.35
#  15            5728.37
#  16            2771.35
#  17            2771.35
#  18             938.94
#  19            1526.87
#  20            1569.63
#  21              74.25
#  22               9.16
#  23            2182.97
#  24            3414.59
#  25            3414.59
#  26               0.00
#  27            1838.01
#  28            3243.77
#  29            2191.28
#  ...               ...
#  49970            0.00
#  49971            0.00
#  49972            0.00
#  49973            0.00
#  49974            0.00
#  49975            0.00
#  49976            0.00
#  49977            0.00
#  49978            0.00
#  49979            0.00
#  49980            0.00
#  49981            0.00
#  49982            0.00
#  49983            0.00
#  49984            0.00
#  49985            0.00
#  49986            0.00
#  49987            0.00
#  49988            0.00
#  49989            0.00
#  49990            0.00
#  49991            0.00
#  49992            0.00
#  49993            0.00
#  49994            0.00
#  49995            0.00
#  49996            0.00
#  49997            0.00
#  49998            0.00
#  49999            0.00
#
#  [50000 rows x 15 columns]]

# %%
result = pd.concat(final_results)

# %%
result
# Out:
#                           agency_name    agency_start_date base_salary  \
# 0      DISTRICT ATTORNEY-MANHATTAN     2003-07-14T00:00:00    47678.00
# 1      DISTRICT ATTORNEY-MANHATTAN     1995-06-12T00:00:00   119959.00
# 2      DISTRICT ATTORNEY-MANHATTAN     2011-10-11T00:00:00    39966.00
# 3      DISTRICT ATTORNEY-MANHATTAN     2014-12-01T00:00:00   116000.00
# 4      DISTRICT ATTORNEY-MANHATTAN     2015-05-21T00:00:00        1.00
# 5      DISTRICT ATTORNEY-MANHATTAN     2012-09-04T00:00:00    71500.00
# 6      DISTRICT ATTORNEY-MANHATTAN     2007-09-04T00:00:00    88000.00
# 7      DISTRICT ATTORNEY-MANHATTAN     2016-06-06T00:00:00        1.00
# 8      DISTRICT ATTORNEY-MANHATTAN     2014-09-02T00:00:00    41000.00
# 9      DISTRICT ATTORNEY-MANHATTAN     1978-05-31T00:00:00    66035.00
# 10     DISTRICT ATTORNEY-MANHATTAN     2013-04-22T00:00:00    38869.00
# 11     DISTRICT ATTORNEY-MANHATTAN     2014-08-25T00:00:00    42075.00
# 12     DISTRICT ATTORNEY-MANHATTAN     2014-01-13T00:00:00    66625.00
# 13     DISTRICT ATTORNEY-MANHATTAN     2005-03-28T00:00:00   112592.00
# 14     DISTRICT ATTORNEY-MANHATTAN     2009-11-09T00:00:00    52548.00
# 15     DISTRICT ATTORNEY-MANHATTAN     2015-05-21T00:00:00        1.00
# 16     DISTRICT ATTORNEY-MANHATTAN     2014-04-28T00:00:00    43299.00
# 17     DISTRICT ATTORNEY-MANHATTAN     2004-09-07T00:00:00   102500.00
# 18     DISTRICT ATTORNEY-MANHATTAN     2015-05-21T00:00:00        1.00
# 19     DISTRICT ATTORNEY-MANHATTAN     2007-01-19T00:00:00    40299.00
# 20     DISTRICT ATTORNEY-MANHATTAN     2014-09-02T00:00:00    78000.00
# 21     DISTRICT ATTORNEY-MANHATTAN     2008-09-21T00:00:00      370.16
# 22     DISTRICT ATTORNEY-MANHATTAN     2016-06-06T00:00:00        1.00
# 23     DISTRICT ATTORNEY-MANHATTAN     2009-03-02T00:00:00      217.70
# 24     DISTRICT ATTORNEY-MANHATTAN     2015-06-08T00:00:00    53366.00
# 25     DISTRICT ATTORNEY-MANHATTAN     2010-08-16T00:00:00    45985.00
# 26     DISTRICT ATTORNEY-MANHATTAN     2008-01-14T00:00:00    36154.00
# 27     DISTRICT ATTORNEY-MANHATTAN     2014-10-20T00:00:00    65600.00
# 28     DISTRICT ATTORNEY-MANHATTAN     1980-01-21T00:00:00    56017.00
# 29     DISTRICT ATTORNEY-MANHATTAN     2015-09-28T00:00:00    37541.00
# ...                               ...                  ...         ...
# 49970  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49971  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49972  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49973  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49974  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49975  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49976  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49977  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49978  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49979  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49980  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49981  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49982  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49983  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49984  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49985  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49986  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49987  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49988  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49989  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49990  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49991  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49992  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49993  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49994  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49995  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49996  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49997  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49998  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49999  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
#
#        first_name fiscal_year        last_name leave_status_as_of_july_31  \
# 0       RAHASHEEM        2016        ABA'AHMID                     ACTIVE
# 1        MARGARET        2016          ABENSUR                     ACTIVE
# 2          ANDREA        2016        ABOUNAOUM                   ON LEAVE
# 3        JONATHAN        2016          ABRAHAM                     ACTIVE
# 4          JOSEPH        2016           ABRAMS                     CEASED
# 5        JENNIFER        2016            ABREU                     ACTIVE
# 6            JUAN        2016            ABREU                     ACTIVE
# 7        JENNIFER        2016          ACEVEDO                     ACTIVE
# 8         MATTHEW        2016         ACOCELLA                     CEASED
# 9            RITA        2016           ACOSTA                     ACTIVE
# 10      KATHERINE        2016            ADAMS                     CEASED
# 11       NEERESHA        2016            ADAMS                     ACTIVE
# 12     OYINDAMOLA        2016         ADEGBORO                     ACTIVE
# 13       SANCHITA        2016         AGGARWAL                     ACTIVE
# 14         YAMIRA        2016          AGUILAR                     ACTIVE
# 15         JORDAN        2016          AGUIRRE                     CEASED
# 16        ARTEMIS        2016          AHMETAJ                     ACTIVE
# 17          HELEN        2016              AHN                     ACTIVE
# 18         SANDRA        2016          ALCAIDE                     CEASED
# 19         DANIEL        2016        ALCANTARA                     ACTIVE
# 20           ERIN        2016        ALEXANDER                     ACTIVE
# 21           PAUL        2016           ALFLEN                     ACTIVE
# 22      SHEHARYAR        2016              ALI                     ACTIVE
# 23          SYEED        2016              ALI                     ACTIVE
# 24        JEFFREY        2016     AL-KAABAH II                     ACTIVE
# 25          ABEER        2016       ALKHAFAJEE                     CEASED
# 26        SHAIMAA        2016       ALKHAFAJEE                     ACTIVE
# 27        BENNETT        2016            ALLEN                     ACTIVE
# 28         ROBERT        2016            ALLEN                     ACTIVE
# 29        MARISOL        2016  ALMONTE-ALMANZA                     ACTIVE
# ...           ...         ...              ...                        ...
# 49970      LARISA        2014        PARDILOVA                     ACTIVE
# 49971     ANTHONY        2014          PAREDES                     ACTIVE
# 49972      GEORGE        2014          PAREDES                     ACTIVE
# 49973        JOHN        2014          PAREDES                     ACTIVE
# 49974     MARYANN        2014          PAREDES                     ACTIVE
# 49975    PATRICIA        2014          PAREDES                     ACTIVE
# 49976        INDU        2014           PAREKH                     ACTIVE
# 49977   JOSEPHINE        2014          PARENTE                     ACTIVE
# 49978  ANTOINETTE        2014           PARHAM                     ACTIVE
# 49979       ANITA        2014           PARHAS                     ACTIVE
# 49980      ANJANA        2014           PARIKH                     ACTIVE
# 49981      NAUTAM        2014           PARIKH                     ACTIVE
# 49982      ROHINI        2014           PARIKH                     ACTIVE
# 49983     SHIRISH        2014           PARIKH                     ACTIVE
# 49984         RAY        2014           PARISH                     ACTIVE
# 49985      JOSEPH        2014             PARK                     ACTIVE
# 49986       KYUNG        2014             PARK                     ACTIVE
# 49987          OM        2014          PARKASH                     ACTIVE
# 49988       ADELE        2014           PARKER                     ACTIVE
# 49989       AVRIL        2014           PARKER                     ACTIVE
# 49990       BETTY        2014           PARKER                     ACTIVE
# 49991     CLASSIE        2014           PARKER                     ACTIVE
# 49992   HENRIETTA        2014           PARKER                     ACTIVE
# 49993        INEZ        2014           PARKER                     ACTIVE
# 49994        JOHN        2014           PARKER                     ACTIVE
# 49995         KIM        2014           PARKER                     ACTIVE
# 49996       LYMON        2014           PARKER                     ACTIVE
# 49997     MARLENA        2014           PARKER                     ACTIVE
# 49998     MONIQUE        2014           PARKER                     ACTIVE
# 49999       PATTI        2014           PARKER                     ACTIVE
#
#       mid_init ot_hours   pay_basis regular_gross_paid regular_hours  \
# 0            E     2.25   per Annum           47166.03       1830.00
# 1          NaN     0.00   per Annum          119042.50       1831.00
# 2            L     1.00   per Annum           27452.62       1181.68
# 3            J     0.00   per Annum          115104.57       1831.00
# 4          NaN     0.00    per Hour            3500.00          0.00
# 5          NaN     0.00   per Annum           71967.34       1831.00
# 6            D     0.00   per Annum           87614.01       1831.00
# 7          NaN     0.00    per Hour             500.00          0.00
# 8            J     0.00   per Annum            9507.15        349.00
# 9            E     0.00   per Annum           64357.12       1830.00
# 10           J     0.00   per Annum            6073.13        200.70
# 11         NaN     0.00   per Annum           39895.79       1830.00
# 12           F     0.00   per Annum           65909.63       1830.00
# 13           J     0.00   per Annum          111806.82       1831.00
# 14         NaN   716.25   per Annum           51890.77       1830.00
# 15         NaN     0.00    per Hour            3500.00          0.00
# 16         NaN    51.75   per Annum           40052.01       1830.00
# 17           H     0.00   per Annum           59023.02       1076.00
# 18         NaN     0.00    per Hour            3500.00          0.00
# 19         NaN     0.00   per Annum           39866.21       1830.00
# 20           L     0.00   per Annum           64498.36       1509.00
# 21           R   408.75     per Day          139072.14       1830.00
# 22         NaN     0.00    per Hour            1000.00          0.00
# 23           A   173.75     per Day           56602.00       1830.00
# 24           I   276.50   per Annum           46271.84       1829.75
# 25           K     1.00   per Annum            4661.03         38.10
# 26         NaN     0.00   per Annum           35765.73       1830.00
# 27           L     0.00   per Annum           64895.59       1830.00
# 28           K     0.00   per Annum           55411.18       1830.00
# 29         NaN     0.75   per Annum           26422.22       1383.00
# ...        ...      ...         ...                ...           ...
# 49970      NaN     0.00    per Hour             606.00          0.00
# 49971        A     0.00    per Hour             781.00          0.00
# 49972        I     0.00    per Hour             778.00          0.00
# 49973        P     0.00    per Hour             225.00          0.00
# 49974      NaN     0.00    per Hour             660.00          0.00
# 49975      NaN     0.00    per Hour             503.00          0.00
# 49976        K     0.00    per Hour             778.00          0.00
# 49977        A     0.00    per Hour             775.00          0.00
# 49978      NaN     0.00    per Hour             775.00          0.00
# 49979        M     0.00    per Hour             500.00          0.00
# 49980        N     0.00    per Hour             775.00          0.00
# 49981        N     0.00    per Hour             781.00          0.00
# 49982        V     0.00    per Hour             500.00          0.00
# 49983        P     0.00    per Hour             775.00          0.00
# 49984        A     0.00    per Hour             660.00          0.00
# 49985      NaN     0.00    per Hour             660.00          0.00
# 49986        Y     0.00    per Hour             660.00          0.00
# 49987      NaN     0.00    per Hour             775.00          0.00
# 49988      NaN     0.00    per Hour             684.64          0.00
# 49989        A     0.00    per Hour             300.00          0.00
# 49990        E     0.00    per Hour             775.00          0.00
# 49991      NaN     0.00    per Hour            1375.00          0.00
# 49992      NaN     0.00    per Hour             775.00          0.00
# 49993      NaN     0.00    per Hour             778.00          0.00
# 49994      NaN     0.00    per Hour             775.00          0.00
# 49995        A     0.00    per Hour            1075.00          0.00
# 49996      NaN     0.00    per Hour             775.00          0.00
# 49997      NaN     0.00    per Hour             425.00          0.00
# 49998        L     0.00    per Hour             781.00          0.00
# 49999        L     0.00    per Hour             300.00          0.00
#
#                                        title_description total_ot_paid  \
# 0      COMMUNITY ASSOCIATE                           ...         57.28
# 1      ADMINISTRATIVE ACCOUNTANT                     ...          0.00
# 2      COMMUNITY ASSOCIATE                           ...         21.34
# 3      COMPUTER SYSTEMS MANAGER                      ...          0.00
# 4      COLLEGE AIDE                                  ...          0.00
# 5      ASSISTANT DISTRICT ATTORNEY                   ...          0.00
# 6      ASSISTANT DISTRICT ATTORNEY                   ...          0.00
# 7      COLLEGE AIDE                                  ...          0.00
# 8      COMMUNITY ASSOCIATE                           ...          0.00
# 9                 PRINCIPAL ADMINISTRATIVE ASSOCIATE              0.00
# 10     COMMUNITY ASSOCIATE                           ...          0.00
# 11     COMMUNITY ASSOCIATE                           ...          0.00
# 12     COMMUNITY COORDINATOR                         ...          0.00
# 13     PRINCIPAL ACCOUNTANT INVESTIGATOR             ...          0.00
# 14     COMMUNITY ASSOCIATE                           ...      25943.55
# 15     COLLEGE AIDE                                  ...          0.00
# 16     COMMUNITY ASSISTANT                           ...       1413.40
# 17     ASSISTANT DISTRICT ATTORNEY                   ...          0.00
# 18     COLLEGE AIDE                                  ...          0.00
# 19     COMMUNITY ASSOCIATE                           ...          0.00
# 20     ASSISTANT DISTRICT ATTORNEY                   ...          0.00
# 21     CARPENTER                                     ...      50546.28
# 22     COLLEGE AIDE                                  ...          0.00
# 23     ELECTRICIAN'S HELPER                          ...       8991.82
# 24     COMMUNITY ASSOCIATE                           ...       7757.06
# 25     COMMUNITY ASSOCIATE                           ...        169.90
# 26     COMMUNITY ASSISTANT                           ...          0.00
# 27     COMMUNITY COORDINATOR                         ...          0.00
# 28          CLERICAL ASSOCIATE                                    0.00
# 29     COMMUNITY ASSOCIATE                           ...         15.41
# ...                                                  ...           ...
# 49970  ELECTION WORKER                               ...          0.00
# 49971  ELECTION WORKER                               ...          0.00
# 49972  ELECTION WORKER                               ...          0.00
# 49973  ELECTION WORKER                               ...          0.00
# 49974  ELECTION WORKER                               ...          0.00
# 49975  ELECTION WORKER                               ...          0.00
# 49976  ELECTION WORKER                               ...          0.00
# 49977  ELECTION WORKER                               ...          0.00
# 49978  ELECTION WORKER                               ...          0.00
# 49979  ELECTION WORKER                               ...          0.00
# 49980  ELECTION WORKER                               ...          0.00
# 49981  ELECTION WORKER                               ...          0.00
# 49982  ELECTION WORKER                               ...          0.00
# 49983  ELECTION WORKER                               ...          0.00
# 49984  ELECTION WORKER                               ...          0.00
# 49985  ELECTION WORKER                               ...          0.00
# 49986  ELECTION WORKER                               ...          0.00
# 49987  ELECTION WORKER                               ...          0.00
# 49988  ELECTION WORKER                               ...          0.00
# 49989  ELECTION WORKER                               ...          0.00
# 49990  ELECTION WORKER                               ...          0.00
# 49991  ELECTION WORKER                               ...          0.00
# 49992  ELECTION WORKER                               ...          0.00
# 49993  ELECTION WORKER                               ...          0.00
# 49994  ELECTION WORKER                               ...          0.00
# 49995  ELECTION WORKER                               ...          0.00
# 49996  ELECTION WORKER                               ...          0.00
# 49997  ELECTION WORKER                               ...          0.00
# 49998  ELECTION WORKER                               ...          0.00
# 49999  ELECTION WORKER                               ...          0.00
#
#       total_other_pay work_location_borough
# 0                0.00         MANHATTAN
# 1                0.00         MANHATTAN
# 2               33.00         MANHATTAN
# 3                0.00         MANHATTAN
# 4                0.00         MANHATTAN
# 5                0.00         MANHATTAN
# 6              750.00         MANHATTAN
# 7                0.00         MANHATTAN
# 8                0.00         MANHATTAN
# 9             3824.72         MANHATTAN
# 10               8.25         MANHATTAN
# 11              74.25         MANHATTAN
# 12              33.00         MANHATTAN
# 13             500.00         MANHATTAN
# 14             747.93         MANHATTAN
# 15               0.00         MANHATTAN
# 16             526.11         MANHATTAN
# 17               0.00         MANHATTAN
# 18               0.00         MANHATTAN
# 19               0.00         MANHATTAN
# 20            1750.00         MANHATTAN
# 21            5060.37         MANHATTAN
# 22               0.00         MANHATTAN
# 23            7424.72         MANHATTAN
# 24             755.84         MANHATTAN
# 25              94.40         MANHATTAN
# 26               0.00         MANHATTAN
# 27              99.50         MANHATTAN
# 28            4424.50         MANHATTAN
# 29              24.75         MANHATTAN
# ...               ...                   ...
# 49970            0.00                   NaN
# 49971            0.00                   NaN
# 49972            0.00                   NaN
# 49973            0.00                   NaN
# 49974            0.00                   NaN
# 49975            0.00                   NaN
# 49976            0.00                   NaN
# 49977            0.00                   NaN
# 49978            0.00                   NaN
# 49979            0.00                   NaN
# 49980            0.00                   NaN
# 49981            0.00                   NaN
# 49982            0.00                   NaN
# 49983            0.00                   NaN
# 49984            0.00                   NaN
# 49985            0.00                   NaN
# 49986            0.00                   NaN
# 49987            0.00                   NaN
# 49988            0.00                   NaN
# 49989            0.00                   NaN
# 49990            0.00                   NaN
# 49991            0.00                   NaN
# 49992            0.00                   NaN
# 49993            0.00                   NaN
# 49994            0.00                   NaN
# 49995            0.00                   NaN
# 49996            0.00                   NaN
# 49997            0.00                   NaN
# 49998            0.00                   NaN
# 49999            0.00                   NaN
#
# [1200000 rows x 16 columns]

# %%
result.tail
# Out:
# <bound method NDFrame.tail of                           agency_name    agency_start_date base_salary  \
# 0      DISTRICT ATTORNEY-MANHATTAN     2003-07-14T00:00:00    47678.00
# 1      DISTRICT ATTORNEY-MANHATTAN     1995-06-12T00:00:00   119959.00
# 2      DISTRICT ATTORNEY-MANHATTAN     2011-10-11T00:00:00    39966.00
# 3      DISTRICT ATTORNEY-MANHATTAN     2014-12-01T00:00:00   116000.00
# 4      DISTRICT ATTORNEY-MANHATTAN     2015-05-21T00:00:00        1.00
# 5      DISTRICT ATTORNEY-MANHATTAN     2012-09-04T00:00:00    71500.00
# 6      DISTRICT ATTORNEY-MANHATTAN     2007-09-04T00:00:00    88000.00
# 7      DISTRICT ATTORNEY-MANHATTAN     2016-06-06T00:00:00        1.00
# 8      DISTRICT ATTORNEY-MANHATTAN     2014-09-02T00:00:00    41000.00
# 9      DISTRICT ATTORNEY-MANHATTAN     1978-05-31T00:00:00    66035.00
# 10     DISTRICT ATTORNEY-MANHATTAN     2013-04-22T00:00:00    38869.00
# 11     DISTRICT ATTORNEY-MANHATTAN     2014-08-25T00:00:00    42075.00
# 12     DISTRICT ATTORNEY-MANHATTAN     2014-01-13T00:00:00    66625.00
# 13     DISTRICT ATTORNEY-MANHATTAN     2005-03-28T00:00:00   112592.00
# 14     DISTRICT ATTORNEY-MANHATTAN     2009-11-09T00:00:00    52548.00
# 15     DISTRICT ATTORNEY-MANHATTAN     2015-05-21T00:00:00        1.00
# 16     DISTRICT ATTORNEY-MANHATTAN     2014-04-28T00:00:00    43299.00
# 17     DISTRICT ATTORNEY-MANHATTAN     2004-09-07T00:00:00   102500.00
# 18     DISTRICT ATTORNEY-MANHATTAN     2015-05-21T00:00:00        1.00
# 19     DISTRICT ATTORNEY-MANHATTAN     2007-01-19T00:00:00    40299.00
# 20     DISTRICT ATTORNEY-MANHATTAN     2014-09-02T00:00:00    78000.00
# 21     DISTRICT ATTORNEY-MANHATTAN     2008-09-21T00:00:00      370.16
# 22     DISTRICT ATTORNEY-MANHATTAN     2016-06-06T00:00:00        1.00
# 23     DISTRICT ATTORNEY-MANHATTAN     2009-03-02T00:00:00      217.70
# 24     DISTRICT ATTORNEY-MANHATTAN     2015-06-08T00:00:00    53366.00
# 25     DISTRICT ATTORNEY-MANHATTAN     2010-08-16T00:00:00    45985.00
# 26     DISTRICT ATTORNEY-MANHATTAN     2008-01-14T00:00:00    36154.00
# 27     DISTRICT ATTORNEY-MANHATTAN     2014-10-20T00:00:00    65600.00
# 28     DISTRICT ATTORNEY-MANHATTAN     1980-01-21T00:00:00    56017.00
# 29     DISTRICT ATTORNEY-MANHATTAN     2015-09-28T00:00:00    37541.00
# ...                               ...                  ...         ...
# 49970  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49971  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49972  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49973  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49974  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49975  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49976  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49977  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49978  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49979  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49980  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49981  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49982  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49983  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49984  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49985  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49986  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49987  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49988  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49989  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49990  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49991  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49992  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49993  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49994  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49995  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49996  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49997  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49998  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49999  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
#
#        first_name fiscal_year        last_name leave_status_as_of_july_31  \
# 0       RAHASHEEM        2016        ABA'AHMID                     ACTIVE
# 1        MARGARET        2016          ABENSUR                     ACTIVE
# 2          ANDREA        2016        ABOUNAOUM                   ON LEAVE
# 3        JONATHAN        2016          ABRAHAM                     ACTIVE
# 4          JOSEPH        2016           ABRAMS                     CEASED
# 5        JENNIFER        2016            ABREU                     ACTIVE
# 6            JUAN        2016            ABREU                     ACTIVE
# 7        JENNIFER        2016          ACEVEDO                     ACTIVE
# 8         MATTHEW        2016         ACOCELLA                     CEASED
# 9            RITA        2016           ACOSTA                     ACTIVE
# 10      KATHERINE        2016            ADAMS                     CEASED
# 11       NEERESHA        2016            ADAMS                     ACTIVE
# 12     OYINDAMOLA        2016         ADEGBORO                     ACTIVE
# 13       SANCHITA        2016         AGGARWAL                     ACTIVE
# 14         YAMIRA        2016          AGUILAR                     ACTIVE
# 15         JORDAN        2016          AGUIRRE                     CEASED
# 16        ARTEMIS        2016          AHMETAJ                     ACTIVE
# 17          HELEN        2016              AHN                     ACTIVE
# 18         SANDRA        2016          ALCAIDE                     CEASED
# 19         DANIEL        2016        ALCANTARA                     ACTIVE
# 20           ERIN        2016        ALEXANDER                     ACTIVE
# 21           PAUL        2016           ALFLEN                     ACTIVE
# 22      SHEHARYAR        2016              ALI                     ACTIVE
# 23          SYEED        2016              ALI                     ACTIVE
# 24        JEFFREY        2016     AL-KAABAH II                     ACTIVE
# 25          ABEER        2016       ALKHAFAJEE                     CEASED
# 26        SHAIMAA        2016       ALKHAFAJEE                     ACTIVE
# 27        BENNETT        2016            ALLEN                     ACTIVE
# 28         ROBERT        2016            ALLEN                     ACTIVE
# 29        MARISOL        2016  ALMONTE-ALMANZA                     ACTIVE
# ...           ...         ...              ...                        ...
# 49970      LARISA        2014        PARDILOVA                     ACTIVE
# 49971     ANTHONY        2014          PAREDES                     ACTIVE
# 49972      GEORGE        2014          PAREDES                     ACTIVE
# 49973        JOHN        2014          PAREDES                     ACTIVE
# 49974     MARYANN        2014          PAREDES                     ACTIVE
# 49975    PATRICIA        2014          PAREDES                     ACTIVE
# 49976        INDU        2014           PAREKH                     ACTIVE
# 49977   JOSEPHINE        2014          PARENTE                     ACTIVE
# 49978  ANTOINETTE        2014           PARHAM                     ACTIVE
# 49979       ANITA        2014           PARHAS                     ACTIVE
# 49980      ANJANA        2014           PARIKH                     ACTIVE
# 49981      NAUTAM        2014           PARIKH                     ACTIVE
# 49982      ROHINI        2014           PARIKH                     ACTIVE
# 49983     SHIRISH        2014           PARIKH                     ACTIVE
# 49984         RAY        2014           PARISH                     ACTIVE
# 49985      JOSEPH        2014             PARK                     ACTIVE
# 49986       KYUNG        2014             PARK                     ACTIVE
# 49987          OM        2014          PARKASH                     ACTIVE
# 49988       ADELE        2014           PARKER                     ACTIVE
# 49989       AVRIL        2014           PARKER                     ACTIVE
# 49990       BETTY        2014           PARKER                     ACTIVE
# 49991     CLASSIE        2014           PARKER                     ACTIVE
# 49992   HENRIETTA        2014           PARKER                     ACTIVE
# 49993        INEZ        2014           PARKER                     ACTIVE
# 49994        JOHN        2014           PARKER                     ACTIVE
# 49995         KIM        2014           PARKER                     ACTIVE
# 49996       LYMON        2014           PARKER                     ACTIVE
# 49997     MARLENA        2014           PARKER                     ACTIVE
# 49998     MONIQUE        2014           PARKER                     ACTIVE
# 49999       PATTI        2014           PARKER                     ACTIVE
#
#       mid_init ot_hours   pay_basis regular_gross_paid regular_hours  \
# 0            E     2.25   per Annum           47166.03       1830.00
# 1          NaN     0.00   per Annum          119042.50       1831.00
# 2            L     1.00   per Annum           27452.62       1181.68
# 3            J     0.00   per Annum          115104.57       1831.00
# 4          NaN     0.00    per Hour            3500.00          0.00
# 5          NaN     0.00   per Annum           71967.34       1831.00
# 6            D     0.00   per Annum           87614.01       1831.00
# 7          NaN     0.00    per Hour             500.00          0.00
# 8            J     0.00   per Annum            9507.15        349.00
# 9            E     0.00   per Annum           64357.12       1830.00
# 10           J     0.00   per Annum            6073.13        200.70
# 11         NaN     0.00   per Annum           39895.79       1830.00
# 12           F     0.00   per Annum           65909.63       1830.00
# 13           J     0.00   per Annum          111806.82       1831.00
# 14         NaN   716.25   per Annum           51890.77       1830.00
# 15         NaN     0.00    per Hour            3500.00          0.00
# 16         NaN    51.75   per Annum           40052.01       1830.00
# 17           H     0.00   per Annum           59023.02       1076.00
# 18         NaN     0.00    per Hour            3500.00          0.00
# 19         NaN     0.00   per Annum           39866.21       1830.00
# 20           L     0.00   per Annum           64498.36       1509.00
# 21           R   408.75     per Day          139072.14       1830.00
# 22         NaN     0.00    per Hour            1000.00          0.00
# 23           A   173.75     per Day           56602.00       1830.00
# 24           I   276.50   per Annum           46271.84       1829.75
# 25           K     1.00   per Annum            4661.03         38.10
# 26         NaN     0.00   per Annum           35765.73       1830.00
# 27           L     0.00   per Annum           64895.59       1830.00
# 28           K     0.00   per Annum           55411.18       1830.00
# 29         NaN     0.75   per Annum           26422.22       1383.00
# ...        ...      ...         ...                ...           ...
# 49970      NaN     0.00    per Hour             606.00          0.00
# 49971        A     0.00    per Hour             781.00          0.00
# 49972        I     0.00    per Hour             778.00          0.00
# 49973        P     0.00    per Hour             225.00          0.00
# 49974      NaN     0.00    per Hour             660.00          0.00
# 49975      NaN     0.00    per Hour             503.00          0.00
# 49976        K     0.00    per Hour             778.00          0.00
# 49977        A     0.00    per Hour             775.00          0.00
# 49978      NaN     0.00    per Hour             775.00          0.00
# 49979        M     0.00    per Hour             500.00          0.00
# 49980        N     0.00    per Hour             775.00          0.00
# 49981        N     0.00    per Hour             781.00          0.00
# 49982        V     0.00    per Hour             500.00          0.00
# 49983        P     0.00    per Hour             775.00          0.00
# 49984        A     0.00    per Hour             660.00          0.00
# 49985      NaN     0.00    per Hour             660.00          0.00
# 49986        Y     0.00    per Hour             660.00          0.00
# 49987      NaN     0.00    per Hour             775.00          0.00
# 49988      NaN     0.00    per Hour             684.64          0.00
# 49989        A     0.00    per Hour             300.00          0.00
# 49990        E     0.00    per Hour             775.00          0.00
# 49991      NaN     0.00    per Hour            1375.00          0.00
# 49992      NaN     0.00    per Hour             775.00          0.00
# 49993      NaN     0.00    per Hour             778.00          0.00
# 49994      NaN     0.00    per Hour             775.00          0.00
# 49995        A     0.00    per Hour            1075.00          0.00
# 49996      NaN     0.00    per Hour             775.00          0.00
# 49997      NaN     0.00    per Hour             425.00          0.00
# 49998        L     0.00    per Hour             781.00          0.00
# 49999        L     0.00    per Hour             300.00          0.00
#
#                                        title_description total_ot_paid  \
# 0      COMMUNITY ASSOCIATE                           ...         57.28
# 1      ADMINISTRATIVE ACCOUNTANT                     ...          0.00
# 2      COMMUNITY ASSOCIATE                           ...         21.34
# 3      COMPUTER SYSTEMS MANAGER                      ...          0.00
# 4      COLLEGE AIDE                                  ...          0.00
# 5      ASSISTANT DISTRICT ATTORNEY                   ...          0.00
# 6      ASSISTANT DISTRICT ATTORNEY                   ...          0.00
# 7      COLLEGE AIDE                                  ...          0.00
# 8      COMMUNITY ASSOCIATE                           ...          0.00
# 9                 PRINCIPAL ADMINISTRATIVE ASSOCIATE              0.00
# 10     COMMUNITY ASSOCIATE                           ...          0.00
# 11     COMMUNITY ASSOCIATE                           ...          0.00
# 12     COMMUNITY COORDINATOR                         ...          0.00
# 13     PRINCIPAL ACCOUNTANT INVESTIGATOR             ...          0.00
# 14     COMMUNITY ASSOCIATE                           ...      25943.55
# 15     COLLEGE AIDE                                  ...          0.00
# 16     COMMUNITY ASSISTANT                           ...       1413.40
# 17     ASSISTANT DISTRICT ATTORNEY                   ...          0.00
# 18     COLLEGE AIDE                                  ...          0.00
# 19     COMMUNITY ASSOCIATE                           ...          0.00
# 20     ASSISTANT DISTRICT ATTORNEY                   ...          0.00
# 21     CARPENTER                                     ...      50546.28
# 22     COLLEGE AIDE                                  ...          0.00
# 23     ELECTRICIAN'S HELPER                          ...       8991.82
# 24     COMMUNITY ASSOCIATE                           ...       7757.06
# 25     COMMUNITY ASSOCIATE                           ...        169.90
# 26     COMMUNITY ASSISTANT                           ...          0.00
# 27     COMMUNITY COORDINATOR                         ...          0.00
# 28          CLERICAL ASSOCIATE                                    0.00
# 29     COMMUNITY ASSOCIATE                           ...         15.41
# ...                                                  ...           ...
# 49970  ELECTION WORKER                               ...          0.00
# 49971  ELECTION WORKER                               ...          0.00
# 49972  ELECTION WORKER                               ...          0.00
# 49973  ELECTION WORKER                               ...          0.00
# 49974  ELECTION WORKER                               ...          0.00
# 49975  ELECTION WORKER                               ...          0.00
# 49976  ELECTION WORKER                               ...          0.00
# 49977  ELECTION WORKER                               ...          0.00
# 49978  ELECTION WORKER                               ...          0.00
# 49979  ELECTION WORKER                               ...          0.00
# 49980  ELECTION WORKER                               ...          0.00
# 49981  ELECTION WORKER                               ...          0.00
# 49982  ELECTION WORKER                               ...          0.00
# 49983  ELECTION WORKER                               ...          0.00
# 49984  ELECTION WORKER                               ...          0.00
# 49985  ELECTION WORKER                               ...          0.00
# 49986  ELECTION WORKER                               ...          0.00
# 49987  ELECTION WORKER                               ...          0.00
# 49988  ELECTION WORKER                               ...          0.00
# 49989  ELECTION WORKER                               ...          0.00
# 49990  ELECTION WORKER                               ...          0.00
# 49991  ELECTION WORKER                               ...          0.00
# 49992  ELECTION WORKER                               ...          0.00
# 49993  ELECTION WORKER                               ...          0.00
# 49994  ELECTION WORKER                               ...          0.00
# 49995  ELECTION WORKER                               ...          0.00
# 49996  ELECTION WORKER                               ...          0.00
# 49997  ELECTION WORKER                               ...          0.00
# 49998  ELECTION WORKER                               ...          0.00
# 49999  ELECTION WORKER                               ...          0.00
#
#       total_other_pay work_location_borough
# 0                0.00         MANHATTAN
# 1                0.00         MANHATTAN
# 2               33.00         MANHATTAN
# 3                0.00         MANHATTAN
# 4                0.00         MANHATTAN
# 5                0.00         MANHATTAN
# 6              750.00         MANHATTAN
# 7                0.00         MANHATTAN
# 8                0.00         MANHATTAN
# 9             3824.72         MANHATTAN
# 10               8.25         MANHATTAN
# 11              74.25         MANHATTAN
# 12              33.00         MANHATTAN
# 13             500.00         MANHATTAN
# 14             747.93         MANHATTAN
# 15               0.00         MANHATTAN
# 16             526.11         MANHATTAN
# 17               0.00         MANHATTAN
# 18               0.00         MANHATTAN
# 19               0.00         MANHATTAN
# 20            1750.00         MANHATTAN
# 21            5060.37         MANHATTAN
# 22               0.00         MANHATTAN
# 23            7424.72         MANHATTAN
# 24             755.84         MANHATTAN
# 25              94.40         MANHATTAN
# 26               0.00         MANHATTAN
# 27              99.50         MANHATTAN
# 28            4424.50         MANHATTAN
# 29              24.75         MANHATTAN
# ...               ...                   ...
# 49970            0.00                   NaN
# 49971            0.00                   NaN
# 49972            0.00                   NaN
# 49973            0.00                   NaN
# 49974            0.00                   NaN
# 49975            0.00                   NaN
# 49976            0.00                   NaN
# 49977            0.00                   NaN
# 49978            0.00                   NaN
# 49979            0.00                   NaN
# 49980            0.00                   NaN
# 49981            0.00                   NaN
# 49982            0.00                   NaN
# 49983            0.00                   NaN
# 49984            0.00                   NaN
# 49985            0.00                   NaN
# 49986            0.00                   NaN
# 49987            0.00                   NaN
# 49988            0.00                   NaN
# 49989            0.00                   NaN
# 49990            0.00                   NaN
# 49991            0.00                   NaN
# 49992            0.00                   NaN
# 49993            0.00                   NaN
# 49994            0.00                   NaN
# 49995            0.00                   NaN
# 49996            0.00                   NaN
# 49997            0.00                   NaN
# 49998            0.00                   NaN
# 49999            0.00                   NaN
#
# [1200000 rows x 16 columns]>

# %%
result.tail()
# Out:
#                           agency_name    agency_start_date base_salary  \
# 49995  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49996  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49997  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49998  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49999  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
#
#       first_name fiscal_year last_name leave_status_as_of_july_31 mid_init  \
# 49995        KIM        2014    PARKER                     ACTIVE        A
# 49996      LYMON        2014    PARKER                     ACTIVE      NaN
# 49997    MARLENA        2014    PARKER                     ACTIVE      NaN
# 49998    MONIQUE        2014    PARKER                     ACTIVE        L
# 49999      PATTI        2014    PARKER                     ACTIVE        L
#
#       ot_hours  pay_basis regular_gross_paid regular_hours  \
# 49995     0.00   per Hour            1075.00          0.00
# 49996     0.00   per Hour             775.00          0.00
# 49997     0.00   per Hour             425.00          0.00
# 49998     0.00   per Hour             781.00          0.00
# 49999     0.00   per Hour             300.00          0.00
#
#                                        title_description total_ot_paid  \
# 49995  ELECTION WORKER                               ...          0.00
# 49996  ELECTION WORKER                               ...          0.00
# 49997  ELECTION WORKER                               ...          0.00
# 49998  ELECTION WORKER                               ...          0.00
# 49999  ELECTION WORKER                               ...          0.00
#
#       total_other_pay work_location_borough
# 49995            0.00                   NaN
# 49996            0.00                   NaN
# 49997            0.00                   NaN
# 49998            0.00                   NaN
# 49999            0.00                   NaN

# %%
result.head()
# Out:
#                       agency_name    agency_start_date base_salary first_name  \
# 0  DISTRICT ATTORNEY-MANHATTAN     2003-07-14T00:00:00    47678.00  RAHASHEEM
# 1  DISTRICT ATTORNEY-MANHATTAN     1995-06-12T00:00:00   119959.00   MARGARET
# 2  DISTRICT ATTORNEY-MANHATTAN     2011-10-11T00:00:00    39966.00     ANDREA
# 3  DISTRICT ATTORNEY-MANHATTAN     2014-12-01T00:00:00   116000.00   JONATHAN
# 4  DISTRICT ATTORNEY-MANHATTAN     2015-05-21T00:00:00        1.00     JOSEPH
#
#   fiscal_year  last_name leave_status_as_of_july_31 mid_init ot_hours  \
# 0        2016  ABA'AHMID                     ACTIVE        E     2.25
# 1        2016    ABENSUR                     ACTIVE      NaN     0.00
# 2        2016  ABOUNAOUM                   ON LEAVE        L     1.00
# 3        2016    ABRAHAM                     ACTIVE        J     0.00
# 4        2016     ABRAMS                     CEASED      NaN     0.00
#
#     pay_basis regular_gross_paid regular_hours  \
# 0   per Annum           47166.03       1830.00
# 1   per Annum          119042.50       1831.00
# 2   per Annum           27452.62       1181.68
# 3   per Annum          115104.57       1831.00
# 4    per Hour            3500.00          0.00
#
#                                    title_description total_ot_paid  \
# 0  COMMUNITY ASSOCIATE                           ...         57.28
# 1  ADMINISTRATIVE ACCOUNTANT                     ...          0.00
# 2  COMMUNITY ASSOCIATE                           ...         21.34
# 3  COMPUTER SYSTEMS MANAGER                      ...          0.00
# 4  COLLEGE AIDE                                  ...          0.00
#
#   total_other_pay work_location_borough
# 0            0.00         MANHATTAN
# 1            0.00         MANHATTAN
# 2           33.00         MANHATTAN
# 3            0.00         MANHATTAN
# 4            0.00         MANHATTAN

# %% [raw]
# result

# %%
result
# Out:
#                           agency_name    agency_start_date base_salary  \
# 0      DISTRICT ATTORNEY-MANHATTAN     2003-07-14T00:00:00    47678.00
# 1      DISTRICT ATTORNEY-MANHATTAN     1995-06-12T00:00:00   119959.00
# 2      DISTRICT ATTORNEY-MANHATTAN     2011-10-11T00:00:00    39966.00
# 3      DISTRICT ATTORNEY-MANHATTAN     2014-12-01T00:00:00   116000.00
# 4      DISTRICT ATTORNEY-MANHATTAN     2015-05-21T00:00:00        1.00
# 5      DISTRICT ATTORNEY-MANHATTAN     2012-09-04T00:00:00    71500.00
# 6      DISTRICT ATTORNEY-MANHATTAN     2007-09-04T00:00:00    88000.00
# 7      DISTRICT ATTORNEY-MANHATTAN     2016-06-06T00:00:00        1.00
# 8      DISTRICT ATTORNEY-MANHATTAN     2014-09-02T00:00:00    41000.00
# 9      DISTRICT ATTORNEY-MANHATTAN     1978-05-31T00:00:00    66035.00
# 10     DISTRICT ATTORNEY-MANHATTAN     2013-04-22T00:00:00    38869.00
# 11     DISTRICT ATTORNEY-MANHATTAN     2014-08-25T00:00:00    42075.00
# 12     DISTRICT ATTORNEY-MANHATTAN     2014-01-13T00:00:00    66625.00
# 13     DISTRICT ATTORNEY-MANHATTAN     2005-03-28T00:00:00   112592.00
# 14     DISTRICT ATTORNEY-MANHATTAN     2009-11-09T00:00:00    52548.00
# 15     DISTRICT ATTORNEY-MANHATTAN     2015-05-21T00:00:00        1.00
# 16     DISTRICT ATTORNEY-MANHATTAN     2014-04-28T00:00:00    43299.00
# 17     DISTRICT ATTORNEY-MANHATTAN     2004-09-07T00:00:00   102500.00
# 18     DISTRICT ATTORNEY-MANHATTAN     2015-05-21T00:00:00        1.00
# 19     DISTRICT ATTORNEY-MANHATTAN     2007-01-19T00:00:00    40299.00
# 20     DISTRICT ATTORNEY-MANHATTAN     2014-09-02T00:00:00    78000.00
# 21     DISTRICT ATTORNEY-MANHATTAN     2008-09-21T00:00:00      370.16
# 22     DISTRICT ATTORNEY-MANHATTAN     2016-06-06T00:00:00        1.00
# 23     DISTRICT ATTORNEY-MANHATTAN     2009-03-02T00:00:00      217.70
# 24     DISTRICT ATTORNEY-MANHATTAN     2015-06-08T00:00:00    53366.00
# 25     DISTRICT ATTORNEY-MANHATTAN     2010-08-16T00:00:00    45985.00
# 26     DISTRICT ATTORNEY-MANHATTAN     2008-01-14T00:00:00    36154.00
# 27     DISTRICT ATTORNEY-MANHATTAN     2014-10-20T00:00:00    65600.00
# 28     DISTRICT ATTORNEY-MANHATTAN     1980-01-21T00:00:00    56017.00
# 29     DISTRICT ATTORNEY-MANHATTAN     2015-09-28T00:00:00    37541.00
# ...                               ...                  ...         ...
# 49970  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49971  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49972  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49973  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49974  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49975  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49976  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49977  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49978  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49979  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49980  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49981  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49982  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49983  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49984  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49985  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49986  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49987  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49988  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49989  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49990  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49991  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49992  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49993  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49994  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49995  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49996  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49997  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49998  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49999  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
#
#        first_name fiscal_year        last_name leave_status_as_of_july_31  \
# 0       RAHASHEEM        2016        ABA'AHMID                     ACTIVE
# 1        MARGARET        2016          ABENSUR                     ACTIVE
# 2          ANDREA        2016        ABOUNAOUM                   ON LEAVE
# 3        JONATHAN        2016          ABRAHAM                     ACTIVE
# 4          JOSEPH        2016           ABRAMS                     CEASED
# 5        JENNIFER        2016            ABREU                     ACTIVE
# 6            JUAN        2016            ABREU                     ACTIVE
# 7        JENNIFER        2016          ACEVEDO                     ACTIVE
# 8         MATTHEW        2016         ACOCELLA                     CEASED
# 9            RITA        2016           ACOSTA                     ACTIVE
# 10      KATHERINE        2016            ADAMS                     CEASED
# 11       NEERESHA        2016            ADAMS                     ACTIVE
# 12     OYINDAMOLA        2016         ADEGBORO                     ACTIVE
# 13       SANCHITA        2016         AGGARWAL                     ACTIVE
# 14         YAMIRA        2016          AGUILAR                     ACTIVE
# 15         JORDAN        2016          AGUIRRE                     CEASED
# 16        ARTEMIS        2016          AHMETAJ                     ACTIVE
# 17          HELEN        2016              AHN                     ACTIVE
# 18         SANDRA        2016          ALCAIDE                     CEASED
# 19         DANIEL        2016        ALCANTARA                     ACTIVE
# 20           ERIN        2016        ALEXANDER                     ACTIVE
# 21           PAUL        2016           ALFLEN                     ACTIVE
# 22      SHEHARYAR        2016              ALI                     ACTIVE
# 23          SYEED        2016              ALI                     ACTIVE
# 24        JEFFREY        2016     AL-KAABAH II                     ACTIVE
# 25          ABEER        2016       ALKHAFAJEE                     CEASED
# 26        SHAIMAA        2016       ALKHAFAJEE                     ACTIVE
# 27        BENNETT        2016            ALLEN                     ACTIVE
# 28         ROBERT        2016            ALLEN                     ACTIVE
# 29        MARISOL        2016  ALMONTE-ALMANZA                     ACTIVE
# ...           ...         ...              ...                        ...
# 49970      LARISA        2014        PARDILOVA                     ACTIVE
# 49971     ANTHONY        2014          PAREDES                     ACTIVE
# 49972      GEORGE        2014          PAREDES                     ACTIVE
# 49973        JOHN        2014          PAREDES                     ACTIVE
# 49974     MARYANN        2014          PAREDES                     ACTIVE
# 49975    PATRICIA        2014          PAREDES                     ACTIVE
# 49976        INDU        2014           PAREKH                     ACTIVE
# 49977   JOSEPHINE        2014          PARENTE                     ACTIVE
# 49978  ANTOINETTE        2014           PARHAM                     ACTIVE
# 49979       ANITA        2014           PARHAS                     ACTIVE
# 49980      ANJANA        2014           PARIKH                     ACTIVE
# 49981      NAUTAM        2014           PARIKH                     ACTIVE
# 49982      ROHINI        2014           PARIKH                     ACTIVE
# 49983     SHIRISH        2014           PARIKH                     ACTIVE
# 49984         RAY        2014           PARISH                     ACTIVE
# 49985      JOSEPH        2014             PARK                     ACTIVE
# 49986       KYUNG        2014             PARK                     ACTIVE
# 49987          OM        2014          PARKASH                     ACTIVE
# 49988       ADELE        2014           PARKER                     ACTIVE
# 49989       AVRIL        2014           PARKER                     ACTIVE
# 49990       BETTY        2014           PARKER                     ACTIVE
# 49991     CLASSIE        2014           PARKER                     ACTIVE
# 49992   HENRIETTA        2014           PARKER                     ACTIVE
# 49993        INEZ        2014           PARKER                     ACTIVE
# 49994        JOHN        2014           PARKER                     ACTIVE
# 49995         KIM        2014           PARKER                     ACTIVE
# 49996       LYMON        2014           PARKER                     ACTIVE
# 49997     MARLENA        2014           PARKER                     ACTIVE
# 49998     MONIQUE        2014           PARKER                     ACTIVE
# 49999       PATTI        2014           PARKER                     ACTIVE
#
#       mid_init ot_hours   pay_basis regular_gross_paid regular_hours  \
# 0            E     2.25   per Annum           47166.03       1830.00
# 1          NaN     0.00   per Annum          119042.50       1831.00
# 2            L     1.00   per Annum           27452.62       1181.68
# 3            J     0.00   per Annum          115104.57       1831.00
# 4          NaN     0.00    per Hour            3500.00          0.00
# 5          NaN     0.00   per Annum           71967.34       1831.00
# 6            D     0.00   per Annum           87614.01       1831.00
# 7          NaN     0.00    per Hour             500.00          0.00
# 8            J     0.00   per Annum            9507.15        349.00
# 9            E     0.00   per Annum           64357.12       1830.00
# 10           J     0.00   per Annum            6073.13        200.70
# 11         NaN     0.00   per Annum           39895.79       1830.00
# 12           F     0.00   per Annum           65909.63       1830.00
# 13           J     0.00   per Annum          111806.82       1831.00
# 14         NaN   716.25   per Annum           51890.77       1830.00
# 15         NaN     0.00    per Hour            3500.00          0.00
# 16         NaN    51.75   per Annum           40052.01       1830.00
# 17           H     0.00   per Annum           59023.02       1076.00
# 18         NaN     0.00    per Hour            3500.00          0.00
# 19         NaN     0.00   per Annum           39866.21       1830.00
# 20           L     0.00   per Annum           64498.36       1509.00
# 21           R   408.75     per Day          139072.14       1830.00
# 22         NaN     0.00    per Hour            1000.00          0.00
# 23           A   173.75     per Day           56602.00       1830.00
# 24           I   276.50   per Annum           46271.84       1829.75
# 25           K     1.00   per Annum            4661.03         38.10
# 26         NaN     0.00   per Annum           35765.73       1830.00
# 27           L     0.00   per Annum           64895.59       1830.00
# 28           K     0.00   per Annum           55411.18       1830.00
# 29         NaN     0.75   per Annum           26422.22       1383.00
# ...        ...      ...         ...                ...           ...
# 49970      NaN     0.00    per Hour             606.00          0.00
# 49971        A     0.00    per Hour             781.00          0.00
# 49972        I     0.00    per Hour             778.00          0.00
# 49973        P     0.00    per Hour             225.00          0.00
# 49974      NaN     0.00    per Hour             660.00          0.00
# 49975      NaN     0.00    per Hour             503.00          0.00
# 49976        K     0.00    per Hour             778.00          0.00
# 49977        A     0.00    per Hour             775.00          0.00
# 49978      NaN     0.00    per Hour             775.00          0.00
# 49979        M     0.00    per Hour             500.00          0.00
# 49980        N     0.00    per Hour             775.00          0.00
# 49981        N     0.00    per Hour             781.00          0.00
# 49982        V     0.00    per Hour             500.00          0.00
# 49983        P     0.00    per Hour             775.00          0.00
# 49984        A     0.00    per Hour             660.00          0.00
# 49985      NaN     0.00    per Hour             660.00          0.00
# 49986        Y     0.00    per Hour             660.00          0.00
# 49987      NaN     0.00    per Hour             775.00          0.00
# 49988      NaN     0.00    per Hour             684.64          0.00
# 49989        A     0.00    per Hour             300.00          0.00
# 49990        E     0.00    per Hour             775.00          0.00
# 49991      NaN     0.00    per Hour            1375.00          0.00
# 49992      NaN     0.00    per Hour             775.00          0.00
# 49993      NaN     0.00    per Hour             778.00          0.00
# 49994      NaN     0.00    per Hour             775.00          0.00
# 49995        A     0.00    per Hour            1075.00          0.00
# 49996      NaN     0.00    per Hour             775.00          0.00
# 49997      NaN     0.00    per Hour             425.00          0.00
# 49998        L     0.00    per Hour             781.00          0.00
# 49999        L     0.00    per Hour             300.00          0.00
#
#                                        title_description total_ot_paid  \
# 0      COMMUNITY ASSOCIATE                           ...         57.28
# 1      ADMINISTRATIVE ACCOUNTANT                     ...          0.00
# 2      COMMUNITY ASSOCIATE                           ...         21.34
# 3      COMPUTER SYSTEMS MANAGER                      ...          0.00
# 4      COLLEGE AIDE                                  ...          0.00
# 5      ASSISTANT DISTRICT ATTORNEY                   ...          0.00
# 6      ASSISTANT DISTRICT ATTORNEY                   ...          0.00
# 7      COLLEGE AIDE                                  ...          0.00
# 8      COMMUNITY ASSOCIATE                           ...          0.00
# 9                 PRINCIPAL ADMINISTRATIVE ASSOCIATE              0.00
# 10     COMMUNITY ASSOCIATE                           ...          0.00
# 11     COMMUNITY ASSOCIATE                           ...          0.00
# 12     COMMUNITY COORDINATOR                         ...          0.00
# 13     PRINCIPAL ACCOUNTANT INVESTIGATOR             ...          0.00
# 14     COMMUNITY ASSOCIATE                           ...      25943.55
# 15     COLLEGE AIDE                                  ...          0.00
# 16     COMMUNITY ASSISTANT                           ...       1413.40
# 17     ASSISTANT DISTRICT ATTORNEY                   ...          0.00
# 18     COLLEGE AIDE                                  ...          0.00
# 19     COMMUNITY ASSOCIATE                           ...          0.00
# 20     ASSISTANT DISTRICT ATTORNEY                   ...          0.00
# 21     CARPENTER                                     ...      50546.28
# 22     COLLEGE AIDE                                  ...          0.00
# 23     ELECTRICIAN'S HELPER                          ...       8991.82
# 24     COMMUNITY ASSOCIATE                           ...       7757.06
# 25     COMMUNITY ASSOCIATE                           ...        169.90
# 26     COMMUNITY ASSISTANT                           ...          0.00
# 27     COMMUNITY COORDINATOR                         ...          0.00
# 28          CLERICAL ASSOCIATE                                    0.00
# 29     COMMUNITY ASSOCIATE                           ...         15.41
# ...                                                  ...           ...
# 49970  ELECTION WORKER                               ...          0.00
# 49971  ELECTION WORKER                               ...          0.00
# 49972  ELECTION WORKER                               ...          0.00
# 49973  ELECTION WORKER                               ...          0.00
# 49974  ELECTION WORKER                               ...          0.00
# 49975  ELECTION WORKER                               ...          0.00
# 49976  ELECTION WORKER                               ...          0.00
# 49977  ELECTION WORKER                               ...          0.00
# 49978  ELECTION WORKER                               ...          0.00
# 49979  ELECTION WORKER                               ...          0.00
# 49980  ELECTION WORKER                               ...          0.00
# 49981  ELECTION WORKER                               ...          0.00
# 49982  ELECTION WORKER                               ...          0.00
# 49983  ELECTION WORKER                               ...          0.00
# 49984  ELECTION WORKER                               ...          0.00
# 49985  ELECTION WORKER                               ...          0.00
# 49986  ELECTION WORKER                               ...          0.00
# 49987  ELECTION WORKER                               ...          0.00
# 49988  ELECTION WORKER                               ...          0.00
# 49989  ELECTION WORKER                               ...          0.00
# 49990  ELECTION WORKER                               ...          0.00
# 49991  ELECTION WORKER                               ...          0.00
# 49992  ELECTION WORKER                               ...          0.00
# 49993  ELECTION WORKER                               ...          0.00
# 49994  ELECTION WORKER                               ...          0.00
# 49995  ELECTION WORKER                               ...          0.00
# 49996  ELECTION WORKER                               ...          0.00
# 49997  ELECTION WORKER                               ...          0.00
# 49998  ELECTION WORKER                               ...          0.00
# 49999  ELECTION WORKER                               ...          0.00
#
#       total_other_pay work_location_borough
# 0                0.00         MANHATTAN
# 1                0.00         MANHATTAN
# 2               33.00         MANHATTAN
# 3                0.00         MANHATTAN
# 4                0.00         MANHATTAN
# 5                0.00         MANHATTAN
# 6              750.00         MANHATTAN
# 7                0.00         MANHATTAN
# 8                0.00         MANHATTAN
# 9             3824.72         MANHATTAN
# 10               8.25         MANHATTAN
# 11              74.25         MANHATTAN
# 12              33.00         MANHATTAN
# 13             500.00         MANHATTAN
# 14             747.93         MANHATTAN
# 15               0.00         MANHATTAN
# 16             526.11         MANHATTAN
# 17               0.00         MANHATTAN
# 18               0.00         MANHATTAN
# 19               0.00         MANHATTAN
# 20            1750.00         MANHATTAN
# 21            5060.37         MANHATTAN
# 22               0.00         MANHATTAN
# 23            7424.72         MANHATTAN
# 24             755.84         MANHATTAN
# 25              94.40         MANHATTAN
# 26               0.00         MANHATTAN
# 27              99.50         MANHATTAN
# 28            4424.50         MANHATTAN
# 29              24.75         MANHATTAN
# ...               ...                   ...
# 49970            0.00                   NaN
# 49971            0.00                   NaN
# 49972            0.00                   NaN
# 49973            0.00                   NaN
# 49974            0.00                   NaN
# 49975            0.00                   NaN
# 49976            0.00                   NaN
# 49977            0.00                   NaN
# 49978            0.00                   NaN
# 49979            0.00                   NaN
# 49980            0.00                   NaN
# 49981            0.00                   NaN
# 49982            0.00                   NaN
# 49983            0.00                   NaN
# 49984            0.00                   NaN
# 49985            0.00                   NaN
# 49986            0.00                   NaN
# 49987            0.00                   NaN
# 49988            0.00                   NaN
# 49989            0.00                   NaN
# 49990            0.00                   NaN
# 49991            0.00                   NaN
# 49992            0.00                   NaN
# 49993            0.00                   NaN
# 49994            0.00                   NaN
# 49995            0.00                   NaN
# 49996            0.00                   NaN
# 49997            0.00                   NaN
# 49998            0.00                   NaN
# 49999            0.00                   NaN
#
# [1200000 rows x 16 columns]

# %%
result[60000]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/lib/python3/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 60000
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-87-d038c70f9849> in <module>()
# ----> 1 result[60000]
#
# /usr/lib/python3/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    2137             return self._getitem_multilevel(key)
#    2138         else:
# -> 2139             return self._getitem_column(key)
#    2140
#    2141     def _getitem_column(self, key):
#
# /usr/lib/python3/dist-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2144         # get column
#    2145         if self.columns.is_unique:
# -> 2146             return self._get_item_cache(key)
#    2147
#    2148         # duplicate columns & possible reduce dimensionality
#
# /usr/lib/python3/dist-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    1840         res = cache.get(item)
#    1841         if res is None:
# -> 1842             values = self._data.get(item)
#    1843             res = self._box_item_values(item, values)
#    1844             cache[item] = res
#
# /usr/lib/python3/dist-packages/pandas/core/internals.py in get(self, item, fastpath)
#    3841
#    3842             if not isna(item):
# -> 3843                 loc = self.items.get_loc(item)
#    3844             else:
#    3845                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# /usr/lib/python3/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
# -> 2527                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2528
#    2529         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 60000

# %%
result.iloc[60000]
# Out:
# agency_name                     POLICE DEPARTMENT
# agency_start_date             2008-07-08T00:00:00
# base_salary                              78026.00
# first_name                                  GLENN
# fiscal_year                                  2016
# last_name                                 SEMIOLI
# leave_status_as_of_july_31                 ACTIVE
# mid_init                                        A
# ot_hours                                    83.67
# pay_basis                               per Annum
# regular_gross_paid                       82913.51
# regular_hours                             2091.42
# title_description                  POLICE OFFICER
# total_ot_paid                             7830.92
# total_other_pay                          17132.29
# work_location_borough                    RICHMOND
# Name: 10000, dtype: object

# %%
result.iloc[-1]
# Out:
# agency_name                                      BOARD OF ELECTION POLL WORKERS
# agency_start_date                                           2010-01-01T00:00:00
# base_salary                                                                1.00
# first_name                                                                PATTI
# fiscal_year                                                                2014
# last_name                                                                PARKER
# leave_status_as_of_july_31                                               ACTIVE
# mid_init                                                                      L
# ot_hours                                                                   0.00
# pay_basis                                                              per Hour
# regular_gross_paid                                                       300.00
# regular_hours                                                              0.00
# title_description             ELECTION WORKER                               ...
# total_ot_paid                                                              0.00
# total_other_pay                                                            0.00
# work_location_borough                                                       NaN
# Name: 49999, dtype: object

# %%
result.iloc[10000]
# Out:
# agency_name                     POLICE DEPARTMENT
# agency_start_date             2007-07-09T00:00:00
# base_salary                              87204.00
# first_name                                MICHAEL
# fiscal_year                                  2016
# last_name                                     BIA
# leave_status_as_of_july_31                 ACTIVE
# mid_init                                        E
# ot_hours                                   370.10
# pay_basis                               per Annum
# regular_gross_paid                       88626.76
# regular_hours                             2091.42
# title_description                 P.O. DA DET GR3
# total_ot_paid                            24488.80
# total_other_pay                          14262.94
# work_location_borough                   MANHATTAN
# Name: 10000, dtype: object

# %%
result.reset_index()
# Out:
#          index                     agency_name    agency_start_date  \
# 0            0  DISTRICT ATTORNEY-MANHATTAN     2003-07-14T00:00:00
# 1            1  DISTRICT ATTORNEY-MANHATTAN     1995-06-12T00:00:00
# 2            2  DISTRICT ATTORNEY-MANHATTAN     2011-10-11T00:00:00
# 3            3  DISTRICT ATTORNEY-MANHATTAN     2014-12-01T00:00:00
# 4            4  DISTRICT ATTORNEY-MANHATTAN     2015-05-21T00:00:00
# 5            5  DISTRICT ATTORNEY-MANHATTAN     2012-09-04T00:00:00
# 6            6  DISTRICT ATTORNEY-MANHATTAN     2007-09-04T00:00:00
# 7            7  DISTRICT ATTORNEY-MANHATTAN     2016-06-06T00:00:00
# 8            8  DISTRICT ATTORNEY-MANHATTAN     2014-09-02T00:00:00
# 9            9  DISTRICT ATTORNEY-MANHATTAN     1978-05-31T00:00:00
# 10          10  DISTRICT ATTORNEY-MANHATTAN     2013-04-22T00:00:00
# 11          11  DISTRICT ATTORNEY-MANHATTAN     2014-08-25T00:00:00
# 12          12  DISTRICT ATTORNEY-MANHATTAN     2014-01-13T00:00:00
# 13          13  DISTRICT ATTORNEY-MANHATTAN     2005-03-28T00:00:00
# 14          14  DISTRICT ATTORNEY-MANHATTAN     2009-11-09T00:00:00
# 15          15  DISTRICT ATTORNEY-MANHATTAN     2015-05-21T00:00:00
# 16          16  DISTRICT ATTORNEY-MANHATTAN     2014-04-28T00:00:00
# 17          17  DISTRICT ATTORNEY-MANHATTAN     2004-09-07T00:00:00
# 18          18  DISTRICT ATTORNEY-MANHATTAN     2015-05-21T00:00:00
# 19          19  DISTRICT ATTORNEY-MANHATTAN     2007-01-19T00:00:00
# 20          20  DISTRICT ATTORNEY-MANHATTAN     2014-09-02T00:00:00
# 21          21  DISTRICT ATTORNEY-MANHATTAN     2008-09-21T00:00:00
# 22          22  DISTRICT ATTORNEY-MANHATTAN     2016-06-06T00:00:00
# 23          23  DISTRICT ATTORNEY-MANHATTAN     2009-03-02T00:00:00
# 24          24  DISTRICT ATTORNEY-MANHATTAN     2015-06-08T00:00:00
# 25          25  DISTRICT ATTORNEY-MANHATTAN     2010-08-16T00:00:00
# 26          26  DISTRICT ATTORNEY-MANHATTAN     2008-01-14T00:00:00
# 27          27  DISTRICT ATTORNEY-MANHATTAN     2014-10-20T00:00:00
# 28          28  DISTRICT ATTORNEY-MANHATTAN     1980-01-21T00:00:00
# 29          29  DISTRICT ATTORNEY-MANHATTAN     2015-09-28T00:00:00
# ...        ...                             ...                  ...
# 1199970  49970  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00
# 1199971  49971  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00
# 1199972  49972  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00
# 1199973  49973  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00
# 1199974  49974  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00
# 1199975  49975  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00
# 1199976  49976  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00
# 1199977  49977  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00
# 1199978  49978  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00
# 1199979  49979  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00
# 1199980  49980  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00
# 1199981  49981  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00
# 1199982  49982  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00
# 1199983  49983  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00
# 1199984  49984  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00
# 1199985  49985  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00
# 1199986  49986  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00
# 1199987  49987  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00
# 1199988  49988  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00
# 1199989  49989  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00
# 1199990  49990  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00
# 1199991  49991  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00
# 1199992  49992  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00
# 1199993  49993  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00
# 1199994  49994  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00
# 1199995  49995  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00
# 1199996  49996  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00
# 1199997  49997  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00
# 1199998  49998  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00
# 1199999  49999  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00
#
#         base_salary  first_name fiscal_year        last_name  \
# 0          47678.00   RAHASHEEM        2016        ABA'AHMID
# 1         119959.00    MARGARET        2016          ABENSUR
# 2          39966.00      ANDREA        2016        ABOUNAOUM
# 3         116000.00    JONATHAN        2016          ABRAHAM
# 4              1.00      JOSEPH        2016           ABRAMS
# 5          71500.00    JENNIFER        2016            ABREU
# 6          88000.00        JUAN        2016            ABREU
# 7              1.00    JENNIFER        2016          ACEVEDO
# 8          41000.00     MATTHEW        2016         ACOCELLA
# 9          66035.00        RITA        2016           ACOSTA
# 10         38869.00   KATHERINE        2016            ADAMS
# 11         42075.00    NEERESHA        2016            ADAMS
# 12         66625.00  OYINDAMOLA        2016         ADEGBORO
# 13        112592.00    SANCHITA        2016         AGGARWAL
# 14         52548.00      YAMIRA        2016          AGUILAR
# 15             1.00      JORDAN        2016          AGUIRRE
# 16         43299.00     ARTEMIS        2016          AHMETAJ
# 17        102500.00       HELEN        2016              AHN
# 18             1.00      SANDRA        2016          ALCAIDE
# 19         40299.00      DANIEL        2016        ALCANTARA
# 20         78000.00        ERIN        2016        ALEXANDER
# 21           370.16        PAUL        2016           ALFLEN
# 22             1.00   SHEHARYAR        2016              ALI
# 23           217.70       SYEED        2016              ALI
# 24         53366.00     JEFFREY        2016     AL-KAABAH II
# 25         45985.00       ABEER        2016       ALKHAFAJEE
# 26         36154.00     SHAIMAA        2016       ALKHAFAJEE
# 27         65600.00     BENNETT        2016            ALLEN
# 28         56017.00      ROBERT        2016            ALLEN
# 29         37541.00     MARISOL        2016  ALMONTE-ALMANZA
# ...             ...         ...         ...              ...
# 1199970        1.00      LARISA        2014        PARDILOVA
# 1199971        1.00     ANTHONY        2014          PAREDES
# 1199972        1.00      GEORGE        2014          PAREDES
# 1199973        1.00        JOHN        2014          PAREDES
# 1199974        1.00     MARYANN        2014          PAREDES
# 1199975        1.00    PATRICIA        2014          PAREDES
# 1199976        1.00        INDU        2014           PAREKH
# 1199977        1.00   JOSEPHINE        2014          PARENTE
# 1199978        1.00  ANTOINETTE        2014           PARHAM
# 1199979        1.00       ANITA        2014           PARHAS
# 1199980        1.00      ANJANA        2014           PARIKH
# 1199981        1.00      NAUTAM        2014           PARIKH
# 1199982        1.00      ROHINI        2014           PARIKH
# 1199983        1.00     SHIRISH        2014           PARIKH
# 1199984        1.00         RAY        2014           PARISH
# 1199985        1.00      JOSEPH        2014             PARK
# 1199986        1.00       KYUNG        2014             PARK
# 1199987        1.00          OM        2014          PARKASH
# 1199988        1.00       ADELE        2014           PARKER
# 1199989        1.00       AVRIL        2014           PARKER
# 1199990        1.00       BETTY        2014           PARKER
# 1199991        1.00     CLASSIE        2014           PARKER
# 1199992        1.00   HENRIETTA        2014           PARKER
# 1199993        1.00        INEZ        2014           PARKER
# 1199994        1.00        JOHN        2014           PARKER
# 1199995        1.00         KIM        2014           PARKER
# 1199996        1.00       LYMON        2014           PARKER
# 1199997        1.00     MARLENA        2014           PARKER
# 1199998        1.00     MONIQUE        2014           PARKER
# 1199999        1.00       PATTI        2014           PARKER
#
#         leave_status_as_of_july_31 mid_init ot_hours   pay_basis  \
# 0                           ACTIVE        E     2.25   per Annum
# 1                           ACTIVE      NaN     0.00   per Annum
# 2                         ON LEAVE        L     1.00   per Annum
# 3                           ACTIVE        J     0.00   per Annum
# 4                           CEASED      NaN     0.00    per Hour
# 5                           ACTIVE      NaN     0.00   per Annum
# 6                           ACTIVE        D     0.00   per Annum
# 7                           ACTIVE      NaN     0.00    per Hour
# 8                           CEASED        J     0.00   per Annum
# 9                           ACTIVE        E     0.00   per Annum
# 10                          CEASED        J     0.00   per Annum
# 11                          ACTIVE      NaN     0.00   per Annum
# 12                          ACTIVE        F     0.00   per Annum
# 13                          ACTIVE        J     0.00   per Annum
# 14                          ACTIVE      NaN   716.25   per Annum
# 15                          CEASED      NaN     0.00    per Hour
# 16                          ACTIVE      NaN    51.75   per Annum
# 17                          ACTIVE        H     0.00   per Annum
# 18                          CEASED      NaN     0.00    per Hour
# 19                          ACTIVE      NaN     0.00   per Annum
# 20                          ACTIVE        L     0.00   per Annum
# 21                          ACTIVE        R   408.75     per Day
# 22                          ACTIVE      NaN     0.00    per Hour
# 23                          ACTIVE        A   173.75     per Day
# 24                          ACTIVE        I   276.50   per Annum
# 25                          CEASED        K     1.00   per Annum
# 26                          ACTIVE      NaN     0.00   per Annum
# 27                          ACTIVE        L     0.00   per Annum
# 28                          ACTIVE        K     0.00   per Annum
# 29                          ACTIVE      NaN     0.75   per Annum
# ...                            ...      ...      ...         ...
# 1199970                     ACTIVE      NaN     0.00    per Hour
# 1199971                     ACTIVE        A     0.00    per Hour
# 1199972                     ACTIVE        I     0.00    per Hour
# 1199973                     ACTIVE        P     0.00    per Hour
# 1199974                     ACTIVE      NaN     0.00    per Hour
# 1199975                     ACTIVE      NaN     0.00    per Hour
# 1199976                     ACTIVE        K     0.00    per Hour
# 1199977                     ACTIVE        A     0.00    per Hour
# 1199978                     ACTIVE      NaN     0.00    per Hour
# 1199979                     ACTIVE        M     0.00    per Hour
# 1199980                     ACTIVE        N     0.00    per Hour
# 1199981                     ACTIVE        N     0.00    per Hour
# 1199982                     ACTIVE        V     0.00    per Hour
# 1199983                     ACTIVE        P     0.00    per Hour
# 1199984                     ACTIVE        A     0.00    per Hour
# 1199985                     ACTIVE      NaN     0.00    per Hour
# 1199986                     ACTIVE        Y     0.00    per Hour
# 1199987                     ACTIVE      NaN     0.00    per Hour
# 1199988                     ACTIVE      NaN     0.00    per Hour
# 1199989                     ACTIVE        A     0.00    per Hour
# 1199990                     ACTIVE        E     0.00    per Hour
# 1199991                     ACTIVE      NaN     0.00    per Hour
# 1199992                     ACTIVE      NaN     0.00    per Hour
# 1199993                     ACTIVE      NaN     0.00    per Hour
# 1199994                     ACTIVE      NaN     0.00    per Hour
# 1199995                     ACTIVE        A     0.00    per Hour
# 1199996                     ACTIVE      NaN     0.00    per Hour
# 1199997                     ACTIVE      NaN     0.00    per Hour
# 1199998                     ACTIVE        L     0.00    per Hour
# 1199999                     ACTIVE        L     0.00    per Hour
#
#         regular_gross_paid regular_hours  \
# 0                 47166.03       1830.00
# 1                119042.50       1831.00
# 2                 27452.62       1181.68
# 3                115104.57       1831.00
# 4                  3500.00          0.00
# 5                 71967.34       1831.00
# 6                 87614.01       1831.00
# 7                   500.00          0.00
# 8                  9507.15        349.00
# 9                 64357.12       1830.00
# 10                 6073.13        200.70
# 11                39895.79       1830.00
# 12                65909.63       1830.00
# 13               111806.82       1831.00
# 14                51890.77       1830.00
# 15                 3500.00          0.00
# 16                40052.01       1830.00
# 17                59023.02       1076.00
# 18                 3500.00          0.00
# 19                39866.21       1830.00
# 20                64498.36       1509.00
# 21               139072.14       1830.00
# 22                 1000.00          0.00
# 23                56602.00       1830.00
# 24                46271.84       1829.75
# 25                 4661.03         38.10
# 26                35765.73       1830.00
# 27                64895.59       1830.00
# 28                55411.18       1830.00
# 29                26422.22       1383.00
# ...                    ...           ...
# 1199970             606.00          0.00
# 1199971             781.00          0.00
# 1199972             778.00          0.00
# 1199973             225.00          0.00
# 1199974             660.00          0.00
# 1199975             503.00          0.00
# 1199976             778.00          0.00
# 1199977             775.00          0.00
# 1199978             775.00          0.00
# 1199979             500.00          0.00
# 1199980             775.00          0.00
# 1199981             781.00          0.00
# 1199982             500.00          0.00
# 1199983             775.00          0.00
# 1199984             660.00          0.00
# 1199985             660.00          0.00
# 1199986             660.00          0.00
# 1199987             775.00          0.00
# 1199988             684.64          0.00
# 1199989             300.00          0.00
# 1199990             775.00          0.00
# 1199991            1375.00          0.00
# 1199992             775.00          0.00
# 1199993             778.00          0.00
# 1199994             775.00          0.00
# 1199995            1075.00          0.00
# 1199996             775.00          0.00
# 1199997             425.00          0.00
# 1199998             781.00          0.00
# 1199999             300.00          0.00
#
#                                          title_description total_ot_paid  \
# 0        COMMUNITY ASSOCIATE                           ...         57.28
# 1        ADMINISTRATIVE ACCOUNTANT                     ...          0.00
# 2        COMMUNITY ASSOCIATE                           ...         21.34
# 3        COMPUTER SYSTEMS MANAGER                      ...          0.00
# 4        COLLEGE AIDE                                  ...          0.00
# 5        ASSISTANT DISTRICT ATTORNEY                   ...          0.00
# 6        ASSISTANT DISTRICT ATTORNEY                   ...          0.00
# 7        COLLEGE AIDE                                  ...          0.00
# 8        COMMUNITY ASSOCIATE                           ...          0.00
# 9                   PRINCIPAL ADMINISTRATIVE ASSOCIATE              0.00
# 10       COMMUNITY ASSOCIATE                           ...          0.00
# 11       COMMUNITY ASSOCIATE                           ...          0.00
# 12       COMMUNITY COORDINATOR                         ...          0.00
# 13       PRINCIPAL ACCOUNTANT INVESTIGATOR             ...          0.00
# 14       COMMUNITY ASSOCIATE                           ...      25943.55
# 15       COLLEGE AIDE                                  ...          0.00
# 16       COMMUNITY ASSISTANT                           ...       1413.40
# 17       ASSISTANT DISTRICT ATTORNEY                   ...          0.00
# 18       COLLEGE AIDE                                  ...          0.00
# 19       COMMUNITY ASSOCIATE                           ...          0.00
# 20       ASSISTANT DISTRICT ATTORNEY                   ...          0.00
# 21       CARPENTER                                     ...      50546.28
# 22       COLLEGE AIDE                                  ...          0.00
# 23       ELECTRICIAN'S HELPER                          ...       8991.82
# 24       COMMUNITY ASSOCIATE                           ...       7757.06
# 25       COMMUNITY ASSOCIATE                           ...        169.90
# 26       COMMUNITY ASSISTANT                           ...          0.00
# 27       COMMUNITY COORDINATOR                         ...          0.00
# 28            CLERICAL ASSOCIATE                                    0.00
# 29       COMMUNITY ASSOCIATE                           ...         15.41
# ...                                                    ...           ...
# 1199970  ELECTION WORKER                               ...          0.00
# 1199971  ELECTION WORKER                               ...          0.00
# 1199972  ELECTION WORKER                               ...          0.00
# 1199973  ELECTION WORKER                               ...          0.00
# 1199974  ELECTION WORKER                               ...          0.00
# 1199975  ELECTION WORKER                               ...          0.00
# 1199976  ELECTION WORKER                               ...          0.00
# 1199977  ELECTION WORKER                               ...          0.00
# 1199978  ELECTION WORKER                               ...          0.00
# 1199979  ELECTION WORKER                               ...          0.00
# 1199980  ELECTION WORKER                               ...          0.00
# 1199981  ELECTION WORKER                               ...          0.00
# 1199982  ELECTION WORKER                               ...          0.00
# 1199983  ELECTION WORKER                               ...          0.00
# 1199984  ELECTION WORKER                               ...          0.00
# 1199985  ELECTION WORKER                               ...          0.00
# 1199986  ELECTION WORKER                               ...          0.00
# 1199987  ELECTION WORKER                               ...          0.00
# 1199988  ELECTION WORKER                               ...          0.00
# 1199989  ELECTION WORKER                               ...          0.00
# 1199990  ELECTION WORKER                               ...          0.00
# 1199991  ELECTION WORKER                               ...          0.00
# 1199992  ELECTION WORKER                               ...          0.00
# 1199993  ELECTION WORKER                               ...          0.00
# 1199994  ELECTION WORKER                               ...          0.00
# 1199995  ELECTION WORKER                               ...          0.00
# 1199996  ELECTION WORKER                               ...          0.00
# 1199997  ELECTION WORKER                               ...          0.00
# 1199998  ELECTION WORKER                               ...          0.00
# 1199999  ELECTION WORKER                               ...          0.00
#
#         total_other_pay work_location_borough
# 0                  0.00         MANHATTAN
# 1                  0.00         MANHATTAN
# 2                 33.00         MANHATTAN
# 3                  0.00         MANHATTAN
# 4                  0.00         MANHATTAN
# 5                  0.00         MANHATTAN
# 6                750.00         MANHATTAN
# 7                  0.00         MANHATTAN
# 8                  0.00         MANHATTAN
# 9               3824.72         MANHATTAN
# 10                 8.25         MANHATTAN
# 11                74.25         MANHATTAN
# 12                33.00         MANHATTAN
# 13               500.00         MANHATTAN
# 14               747.93         MANHATTAN
# 15                 0.00         MANHATTAN
# 16               526.11         MANHATTAN
# 17                 0.00         MANHATTAN
# 18                 0.00         MANHATTAN
# 19                 0.00         MANHATTAN
# 20              1750.00         MANHATTAN
# 21              5060.37         MANHATTAN
# 22                 0.00         MANHATTAN
# 23              7424.72         MANHATTAN
# 24               755.84         MANHATTAN
# 25                94.40         MANHATTAN
# 26                 0.00         MANHATTAN
# 27                99.50         MANHATTAN
# 28              4424.50         MANHATTAN
# 29                24.75         MANHATTAN
# ...                 ...                   ...
# 1199970            0.00                   NaN
# 1199971            0.00                   NaN
# 1199972            0.00                   NaN
# 1199973            0.00                   NaN
# 1199974            0.00                   NaN
# 1199975            0.00                   NaN
# 1199976            0.00                   NaN
# 1199977            0.00                   NaN
# 1199978            0.00                   NaN
# 1199979            0.00                   NaN
# 1199980            0.00                   NaN
# 1199981            0.00                   NaN
# 1199982            0.00                   NaN
# 1199983            0.00                   NaN
# 1199984            0.00                   NaN
# 1199985            0.00                   NaN
# 1199986            0.00                   NaN
# 1199987            0.00                   NaN
# 1199988            0.00                   NaN
# 1199989            0.00                   NaN
# 1199990            0.00                   NaN
# 1199991            0.00                   NaN
# 1199992            0.00                   NaN
# 1199993            0.00                   NaN
# 1199994            0.00                   NaN
# 1199995            0.00                   NaN
# 1199996            0.00                   NaN
# 1199997            0.00                   NaN
# 1199998            0.00                   NaN
# 1199999            0.00                   NaN
#
# [1200000 rows x 17 columns]

# %%
result
# Out:
#                           agency_name    agency_start_date base_salary  \
# 0      DISTRICT ATTORNEY-MANHATTAN     2003-07-14T00:00:00    47678.00
# 1      DISTRICT ATTORNEY-MANHATTAN     1995-06-12T00:00:00   119959.00
# 2      DISTRICT ATTORNEY-MANHATTAN     2011-10-11T00:00:00    39966.00
# 3      DISTRICT ATTORNEY-MANHATTAN     2014-12-01T00:00:00   116000.00
# 4      DISTRICT ATTORNEY-MANHATTAN     2015-05-21T00:00:00        1.00
# 5      DISTRICT ATTORNEY-MANHATTAN     2012-09-04T00:00:00    71500.00
# 6      DISTRICT ATTORNEY-MANHATTAN     2007-09-04T00:00:00    88000.00
# 7      DISTRICT ATTORNEY-MANHATTAN     2016-06-06T00:00:00        1.00
# 8      DISTRICT ATTORNEY-MANHATTAN     2014-09-02T00:00:00    41000.00
# 9      DISTRICT ATTORNEY-MANHATTAN     1978-05-31T00:00:00    66035.00
# 10     DISTRICT ATTORNEY-MANHATTAN     2013-04-22T00:00:00    38869.00
# 11     DISTRICT ATTORNEY-MANHATTAN     2014-08-25T00:00:00    42075.00
# 12     DISTRICT ATTORNEY-MANHATTAN     2014-01-13T00:00:00    66625.00
# 13     DISTRICT ATTORNEY-MANHATTAN     2005-03-28T00:00:00   112592.00
# 14     DISTRICT ATTORNEY-MANHATTAN     2009-11-09T00:00:00    52548.00
# 15     DISTRICT ATTORNEY-MANHATTAN     2015-05-21T00:00:00        1.00
# 16     DISTRICT ATTORNEY-MANHATTAN     2014-04-28T00:00:00    43299.00
# 17     DISTRICT ATTORNEY-MANHATTAN     2004-09-07T00:00:00   102500.00
# 18     DISTRICT ATTORNEY-MANHATTAN     2015-05-21T00:00:00        1.00
# 19     DISTRICT ATTORNEY-MANHATTAN     2007-01-19T00:00:00    40299.00
# 20     DISTRICT ATTORNEY-MANHATTAN     2014-09-02T00:00:00    78000.00
# 21     DISTRICT ATTORNEY-MANHATTAN     2008-09-21T00:00:00      370.16
# 22     DISTRICT ATTORNEY-MANHATTAN     2016-06-06T00:00:00        1.00
# 23     DISTRICT ATTORNEY-MANHATTAN     2009-03-02T00:00:00      217.70
# 24     DISTRICT ATTORNEY-MANHATTAN     2015-06-08T00:00:00    53366.00
# 25     DISTRICT ATTORNEY-MANHATTAN     2010-08-16T00:00:00    45985.00
# 26     DISTRICT ATTORNEY-MANHATTAN     2008-01-14T00:00:00    36154.00
# 27     DISTRICT ATTORNEY-MANHATTAN     2014-10-20T00:00:00    65600.00
# 28     DISTRICT ATTORNEY-MANHATTAN     1980-01-21T00:00:00    56017.00
# 29     DISTRICT ATTORNEY-MANHATTAN     2015-09-28T00:00:00    37541.00
# ...                               ...                  ...         ...
# 49970  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49971  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49972  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49973  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49974  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49975  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49976  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49977  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49978  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49979  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49980  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49981  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49982  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49983  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49984  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49985  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49986  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49987  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49988  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49989  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49990  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49991  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49992  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49993  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49994  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49995  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49996  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49997  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49998  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 49999  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
#
#        first_name fiscal_year        last_name leave_status_as_of_july_31  \
# 0       RAHASHEEM        2016        ABA'AHMID                     ACTIVE
# 1        MARGARET        2016          ABENSUR                     ACTIVE
# 2          ANDREA        2016        ABOUNAOUM                   ON LEAVE
# 3        JONATHAN        2016          ABRAHAM                     ACTIVE
# 4          JOSEPH        2016           ABRAMS                     CEASED
# 5        JENNIFER        2016            ABREU                     ACTIVE
# 6            JUAN        2016            ABREU                     ACTIVE
# 7        JENNIFER        2016          ACEVEDO                     ACTIVE
# 8         MATTHEW        2016         ACOCELLA                     CEASED
# 9            RITA        2016           ACOSTA                     ACTIVE
# 10      KATHERINE        2016            ADAMS                     CEASED
# 11       NEERESHA        2016            ADAMS                     ACTIVE
# 12     OYINDAMOLA        2016         ADEGBORO                     ACTIVE
# 13       SANCHITA        2016         AGGARWAL                     ACTIVE
# 14         YAMIRA        2016          AGUILAR                     ACTIVE
# 15         JORDAN        2016          AGUIRRE                     CEASED
# 16        ARTEMIS        2016          AHMETAJ                     ACTIVE
# 17          HELEN        2016              AHN                     ACTIVE
# 18         SANDRA        2016          ALCAIDE                     CEASED
# 19         DANIEL        2016        ALCANTARA                     ACTIVE
# 20           ERIN        2016        ALEXANDER                     ACTIVE
# 21           PAUL        2016           ALFLEN                     ACTIVE
# 22      SHEHARYAR        2016              ALI                     ACTIVE
# 23          SYEED        2016              ALI                     ACTIVE
# 24        JEFFREY        2016     AL-KAABAH II                     ACTIVE
# 25          ABEER        2016       ALKHAFAJEE                     CEASED
# 26        SHAIMAA        2016       ALKHAFAJEE                     ACTIVE
# 27        BENNETT        2016            ALLEN                     ACTIVE
# 28         ROBERT        2016            ALLEN                     ACTIVE
# 29        MARISOL        2016  ALMONTE-ALMANZA                     ACTIVE
# ...           ...         ...              ...                        ...
# 49970      LARISA        2014        PARDILOVA                     ACTIVE
# 49971     ANTHONY        2014          PAREDES                     ACTIVE
# 49972      GEORGE        2014          PAREDES                     ACTIVE
# 49973        JOHN        2014          PAREDES                     ACTIVE
# 49974     MARYANN        2014          PAREDES                     ACTIVE
# 49975    PATRICIA        2014          PAREDES                     ACTIVE
# 49976        INDU        2014           PAREKH                     ACTIVE
# 49977   JOSEPHINE        2014          PARENTE                     ACTIVE
# 49978  ANTOINETTE        2014           PARHAM                     ACTIVE
# 49979       ANITA        2014           PARHAS                     ACTIVE
# 49980      ANJANA        2014           PARIKH                     ACTIVE
# 49981      NAUTAM        2014           PARIKH                     ACTIVE
# 49982      ROHINI        2014           PARIKH                     ACTIVE
# 49983     SHIRISH        2014           PARIKH                     ACTIVE
# 49984         RAY        2014           PARISH                     ACTIVE
# 49985      JOSEPH        2014             PARK                     ACTIVE
# 49986       KYUNG        2014             PARK                     ACTIVE
# 49987          OM        2014          PARKASH                     ACTIVE
# 49988       ADELE        2014           PARKER                     ACTIVE
# 49989       AVRIL        2014           PARKER                     ACTIVE
# 49990       BETTY        2014           PARKER                     ACTIVE
# 49991     CLASSIE        2014           PARKER                     ACTIVE
# 49992   HENRIETTA        2014           PARKER                     ACTIVE
# 49993        INEZ        2014           PARKER                     ACTIVE
# 49994        JOHN        2014           PARKER                     ACTIVE
# 49995         KIM        2014           PARKER                     ACTIVE
# 49996       LYMON        2014           PARKER                     ACTIVE
# 49997     MARLENA        2014           PARKER                     ACTIVE
# 49998     MONIQUE        2014           PARKER                     ACTIVE
# 49999       PATTI        2014           PARKER                     ACTIVE
#
#       mid_init ot_hours   pay_basis regular_gross_paid regular_hours  \
# 0            E     2.25   per Annum           47166.03       1830.00
# 1          NaN     0.00   per Annum          119042.50       1831.00
# 2            L     1.00   per Annum           27452.62       1181.68
# 3            J     0.00   per Annum          115104.57       1831.00
# 4          NaN     0.00    per Hour            3500.00          0.00
# 5          NaN     0.00   per Annum           71967.34       1831.00
# 6            D     0.00   per Annum           87614.01       1831.00
# 7          NaN     0.00    per Hour             500.00          0.00
# 8            J     0.00   per Annum            9507.15        349.00
# 9            E     0.00   per Annum           64357.12       1830.00
# 10           J     0.00   per Annum            6073.13        200.70
# 11         NaN     0.00   per Annum           39895.79       1830.00
# 12           F     0.00   per Annum           65909.63       1830.00
# 13           J     0.00   per Annum          111806.82       1831.00
# 14         NaN   716.25   per Annum           51890.77       1830.00
# 15         NaN     0.00    per Hour            3500.00          0.00
# 16         NaN    51.75   per Annum           40052.01       1830.00
# 17           H     0.00   per Annum           59023.02       1076.00
# 18         NaN     0.00    per Hour            3500.00          0.00
# 19         NaN     0.00   per Annum           39866.21       1830.00
# 20           L     0.00   per Annum           64498.36       1509.00
# 21           R   408.75     per Day          139072.14       1830.00
# 22         NaN     0.00    per Hour            1000.00          0.00
# 23           A   173.75     per Day           56602.00       1830.00
# 24           I   276.50   per Annum           46271.84       1829.75
# 25           K     1.00   per Annum            4661.03         38.10
# 26         NaN     0.00   per Annum           35765.73       1830.00
# 27           L     0.00   per Annum           64895.59       1830.00
# 28           K     0.00   per Annum           55411.18       1830.00
# 29         NaN     0.75   per Annum           26422.22       1383.00
# ...        ...      ...         ...                ...           ...
# 49970      NaN     0.00    per Hour             606.00          0.00
# 49971        A     0.00    per Hour             781.00          0.00
# 49972        I     0.00    per Hour             778.00          0.00
# 49973        P     0.00    per Hour             225.00          0.00
# 49974      NaN     0.00    per Hour             660.00          0.00
# 49975      NaN     0.00    per Hour             503.00          0.00
# 49976        K     0.00    per Hour             778.00          0.00
# 49977        A     0.00    per Hour             775.00          0.00
# 49978      NaN     0.00    per Hour             775.00          0.00
# 49979        M     0.00    per Hour             500.00          0.00
# 49980        N     0.00    per Hour             775.00          0.00
# 49981        N     0.00    per Hour             781.00          0.00
# 49982        V     0.00    per Hour             500.00          0.00
# 49983        P     0.00    per Hour             775.00          0.00
# 49984        A     0.00    per Hour             660.00          0.00
# 49985      NaN     0.00    per Hour             660.00          0.00
# 49986        Y     0.00    per Hour             660.00          0.00
# 49987      NaN     0.00    per Hour             775.00          0.00
# 49988      NaN     0.00    per Hour             684.64          0.00
# 49989        A     0.00    per Hour             300.00          0.00
# 49990        E     0.00    per Hour             775.00          0.00
# 49991      NaN     0.00    per Hour            1375.00          0.00
# 49992      NaN     0.00    per Hour             775.00          0.00
# 49993      NaN     0.00    per Hour             778.00          0.00
# 49994      NaN     0.00    per Hour             775.00          0.00
# 49995        A     0.00    per Hour            1075.00          0.00
# 49996      NaN     0.00    per Hour             775.00          0.00
# 49997      NaN     0.00    per Hour             425.00          0.00
# 49998        L     0.00    per Hour             781.00          0.00
# 49999        L     0.00    per Hour             300.00          0.00
#
#                                        title_description total_ot_paid  \
# 0      COMMUNITY ASSOCIATE                           ...         57.28
# 1      ADMINISTRATIVE ACCOUNTANT                     ...          0.00
# 2      COMMUNITY ASSOCIATE                           ...         21.34
# 3      COMPUTER SYSTEMS MANAGER                      ...          0.00
# 4      COLLEGE AIDE                                  ...          0.00
# 5      ASSISTANT DISTRICT ATTORNEY                   ...          0.00
# 6      ASSISTANT DISTRICT ATTORNEY                   ...          0.00
# 7      COLLEGE AIDE                                  ...          0.00
# 8      COMMUNITY ASSOCIATE                           ...          0.00
# 9                 PRINCIPAL ADMINISTRATIVE ASSOCIATE              0.00
# 10     COMMUNITY ASSOCIATE                           ...          0.00
# 11     COMMUNITY ASSOCIATE                           ...          0.00
# 12     COMMUNITY COORDINATOR                         ...          0.00
# 13     PRINCIPAL ACCOUNTANT INVESTIGATOR             ...          0.00
# 14     COMMUNITY ASSOCIATE                           ...      25943.55
# 15     COLLEGE AIDE                                  ...          0.00
# 16     COMMUNITY ASSISTANT                           ...       1413.40
# 17     ASSISTANT DISTRICT ATTORNEY                   ...          0.00
# 18     COLLEGE AIDE                                  ...          0.00
# 19     COMMUNITY ASSOCIATE                           ...          0.00
# 20     ASSISTANT DISTRICT ATTORNEY                   ...          0.00
# 21     CARPENTER                                     ...      50546.28
# 22     COLLEGE AIDE                                  ...          0.00
# 23     ELECTRICIAN'S HELPER                          ...       8991.82
# 24     COMMUNITY ASSOCIATE                           ...       7757.06
# 25     COMMUNITY ASSOCIATE                           ...        169.90
# 26     COMMUNITY ASSISTANT                           ...          0.00
# 27     COMMUNITY COORDINATOR                         ...          0.00
# 28          CLERICAL ASSOCIATE                                    0.00
# 29     COMMUNITY ASSOCIATE                           ...         15.41
# ...                                                  ...           ...
# 49970  ELECTION WORKER                               ...          0.00
# 49971  ELECTION WORKER                               ...          0.00
# 49972  ELECTION WORKER                               ...          0.00
# 49973  ELECTION WORKER                               ...          0.00
# 49974  ELECTION WORKER                               ...          0.00
# 49975  ELECTION WORKER                               ...          0.00
# 49976  ELECTION WORKER                               ...          0.00
# 49977  ELECTION WORKER                               ...          0.00
# 49978  ELECTION WORKER                               ...          0.00
# 49979  ELECTION WORKER                               ...          0.00
# 49980  ELECTION WORKER                               ...          0.00
# 49981  ELECTION WORKER                               ...          0.00
# 49982  ELECTION WORKER                               ...          0.00
# 49983  ELECTION WORKER                               ...          0.00
# 49984  ELECTION WORKER                               ...          0.00
# 49985  ELECTION WORKER                               ...          0.00
# 49986  ELECTION WORKER                               ...          0.00
# 49987  ELECTION WORKER                               ...          0.00
# 49988  ELECTION WORKER                               ...          0.00
# 49989  ELECTION WORKER                               ...          0.00
# 49990  ELECTION WORKER                               ...          0.00
# 49991  ELECTION WORKER                               ...          0.00
# 49992  ELECTION WORKER                               ...          0.00
# 49993  ELECTION WORKER                               ...          0.00
# 49994  ELECTION WORKER                               ...          0.00
# 49995  ELECTION WORKER                               ...          0.00
# 49996  ELECTION WORKER                               ...          0.00
# 49997  ELECTION WORKER                               ...          0.00
# 49998  ELECTION WORKER                               ...          0.00
# 49999  ELECTION WORKER                               ...          0.00
#
#       total_other_pay work_location_borough
# 0                0.00         MANHATTAN
# 1                0.00         MANHATTAN
# 2               33.00         MANHATTAN
# 3                0.00         MANHATTAN
# 4                0.00         MANHATTAN
# 5                0.00         MANHATTAN
# 6              750.00         MANHATTAN
# 7                0.00         MANHATTAN
# 8                0.00         MANHATTAN
# 9             3824.72         MANHATTAN
# 10               8.25         MANHATTAN
# 11              74.25         MANHATTAN
# 12              33.00         MANHATTAN
# 13             500.00         MANHATTAN
# 14             747.93         MANHATTAN
# 15               0.00         MANHATTAN
# 16             526.11         MANHATTAN
# 17               0.00         MANHATTAN
# 18               0.00         MANHATTAN
# 19               0.00         MANHATTAN
# 20            1750.00         MANHATTAN
# 21            5060.37         MANHATTAN
# 22               0.00         MANHATTAN
# 23            7424.72         MANHATTAN
# 24             755.84         MANHATTAN
# 25              94.40         MANHATTAN
# 26               0.00         MANHATTAN
# 27              99.50         MANHATTAN
# 28            4424.50         MANHATTAN
# 29              24.75         MANHATTAN
# ...               ...                   ...
# 49970            0.00                   NaN
# 49971            0.00                   NaN
# 49972            0.00                   NaN
# 49973            0.00                   NaN
# 49974            0.00                   NaN
# 49975            0.00                   NaN
# 49976            0.00                   NaN
# 49977            0.00                   NaN
# 49978            0.00                   NaN
# 49979            0.00                   NaN
# 49980            0.00                   NaN
# 49981            0.00                   NaN
# 49982            0.00                   NaN
# 49983            0.00                   NaN
# 49984            0.00                   NaN
# 49985            0.00                   NaN
# 49986            0.00                   NaN
# 49987            0.00                   NaN
# 49988            0.00                   NaN
# 49989            0.00                   NaN
# 49990            0.00                   NaN
# 49991            0.00                   NaN
# 49992            0.00                   NaN
# 49993            0.00                   NaN
# 49994            0.00                   NaN
# 49995            0.00                   NaN
# 49996            0.00                   NaN
# 49997            0.00                   NaN
# 49998            0.00                   NaN
# 49999            0.00                   NaN
#
# [1200000 rows x 16 columns]

# %%
result = result.reset_index()

# %%
result
# Out:
#          index                     agency_name    agency_start_date  \
# 0            0  DISTRICT ATTORNEY-MANHATTAN     2003-07-14T00:00:00
# 1            1  DISTRICT ATTORNEY-MANHATTAN     1995-06-12T00:00:00
# 2            2  DISTRICT ATTORNEY-MANHATTAN     2011-10-11T00:00:00
# 3            3  DISTRICT ATTORNEY-MANHATTAN     2014-12-01T00:00:00
# 4            4  DISTRICT ATTORNEY-MANHATTAN     2015-05-21T00:00:00
# 5            5  DISTRICT ATTORNEY-MANHATTAN     2012-09-04T00:00:00
# 6            6  DISTRICT ATTORNEY-MANHATTAN     2007-09-04T00:00:00
# 7            7  DISTRICT ATTORNEY-MANHATTAN     2016-06-06T00:00:00
# 8            8  DISTRICT ATTORNEY-MANHATTAN     2014-09-02T00:00:00
# 9            9  DISTRICT ATTORNEY-MANHATTAN     1978-05-31T00:00:00
# 10          10  DISTRICT ATTORNEY-MANHATTAN     2013-04-22T00:00:00
# 11          11  DISTRICT ATTORNEY-MANHATTAN     2014-08-25T00:00:00
# 12          12  DISTRICT ATTORNEY-MANHATTAN     2014-01-13T00:00:00
# 13          13  DISTRICT ATTORNEY-MANHATTAN     2005-03-28T00:00:00
# 14          14  DISTRICT ATTORNEY-MANHATTAN     2009-11-09T00:00:00
# 15          15  DISTRICT ATTORNEY-MANHATTAN     2015-05-21T00:00:00
# 16          16  DISTRICT ATTORNEY-MANHATTAN     2014-04-28T00:00:00
# 17          17  DISTRICT ATTORNEY-MANHATTAN     2004-09-07T00:00:00
# 18          18  DISTRICT ATTORNEY-MANHATTAN     2015-05-21T00:00:00
# 19          19  DISTRICT ATTORNEY-MANHATTAN     2007-01-19T00:00:00
# 20          20  DISTRICT ATTORNEY-MANHATTAN     2014-09-02T00:00:00
# 21          21  DISTRICT ATTORNEY-MANHATTAN     2008-09-21T00:00:00
# 22          22  DISTRICT ATTORNEY-MANHATTAN     2016-06-06T00:00:00
# 23          23  DISTRICT ATTORNEY-MANHATTAN     2009-03-02T00:00:00
# 24          24  DISTRICT ATTORNEY-MANHATTAN     2015-06-08T00:00:00
# 25          25  DISTRICT ATTORNEY-MANHATTAN     2010-08-16T00:00:00
# 26          26  DISTRICT ATTORNEY-MANHATTAN     2008-01-14T00:00:00
# 27          27  DISTRICT ATTORNEY-MANHATTAN     2014-10-20T00:00:00
# 28          28  DISTRICT ATTORNEY-MANHATTAN     1980-01-21T00:00:00
# 29          29  DISTRICT ATTORNEY-MANHATTAN     2015-09-28T00:00:00
# ...        ...                             ...                  ...
# 1199970  49970  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00
# 1199971  49971  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00
# 1199972  49972  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00
# 1199973  49973  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00
# 1199974  49974  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00
# 1199975  49975  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00
# 1199976  49976  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00
# 1199977  49977  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00
# 1199978  49978  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00
# 1199979  49979  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00
# 1199980  49980  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00
# 1199981  49981  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00
# 1199982  49982  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00
# 1199983  49983  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00
# 1199984  49984  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00
# 1199985  49985  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00
# 1199986  49986  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00
# 1199987  49987  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00
# 1199988  49988  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00
# 1199989  49989  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00
# 1199990  49990  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00
# 1199991  49991  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00
# 1199992  49992  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00
# 1199993  49993  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00
# 1199994  49994  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00
# 1199995  49995  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00
# 1199996  49996  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00
# 1199997  49997  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00
# 1199998  49998  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00
# 1199999  49999  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00
#
#         base_salary  first_name fiscal_year        last_name  \
# 0          47678.00   RAHASHEEM        2016        ABA'AHMID
# 1         119959.00    MARGARET        2016          ABENSUR
# 2          39966.00      ANDREA        2016        ABOUNAOUM
# 3         116000.00    JONATHAN        2016          ABRAHAM
# 4              1.00      JOSEPH        2016           ABRAMS
# 5          71500.00    JENNIFER        2016            ABREU
# 6          88000.00        JUAN        2016            ABREU
# 7              1.00    JENNIFER        2016          ACEVEDO
# 8          41000.00     MATTHEW        2016         ACOCELLA
# 9          66035.00        RITA        2016           ACOSTA
# 10         38869.00   KATHERINE        2016            ADAMS
# 11         42075.00    NEERESHA        2016            ADAMS
# 12         66625.00  OYINDAMOLA        2016         ADEGBORO
# 13        112592.00    SANCHITA        2016         AGGARWAL
# 14         52548.00      YAMIRA        2016          AGUILAR
# 15             1.00      JORDAN        2016          AGUIRRE
# 16         43299.00     ARTEMIS        2016          AHMETAJ
# 17        102500.00       HELEN        2016              AHN
# 18             1.00      SANDRA        2016          ALCAIDE
# 19         40299.00      DANIEL        2016        ALCANTARA
# 20         78000.00        ERIN        2016        ALEXANDER
# 21           370.16        PAUL        2016           ALFLEN
# 22             1.00   SHEHARYAR        2016              ALI
# 23           217.70       SYEED        2016              ALI
# 24         53366.00     JEFFREY        2016     AL-KAABAH II
# 25         45985.00       ABEER        2016       ALKHAFAJEE
# 26         36154.00     SHAIMAA        2016       ALKHAFAJEE
# 27         65600.00     BENNETT        2016            ALLEN
# 28         56017.00      ROBERT        2016            ALLEN
# 29         37541.00     MARISOL        2016  ALMONTE-ALMANZA
# ...             ...         ...         ...              ...
# 1199970        1.00      LARISA        2014        PARDILOVA
# 1199971        1.00     ANTHONY        2014          PAREDES
# 1199972        1.00      GEORGE        2014          PAREDES
# 1199973        1.00        JOHN        2014          PAREDES
# 1199974        1.00     MARYANN        2014          PAREDES
# 1199975        1.00    PATRICIA        2014          PAREDES
# 1199976        1.00        INDU        2014           PAREKH
# 1199977        1.00   JOSEPHINE        2014          PARENTE
# 1199978        1.00  ANTOINETTE        2014           PARHAM
# 1199979        1.00       ANITA        2014           PARHAS
# 1199980        1.00      ANJANA        2014           PARIKH
# 1199981        1.00      NAUTAM        2014           PARIKH
# 1199982        1.00      ROHINI        2014           PARIKH
# 1199983        1.00     SHIRISH        2014           PARIKH
# 1199984        1.00         RAY        2014           PARISH
# 1199985        1.00      JOSEPH        2014             PARK
# 1199986        1.00       KYUNG        2014             PARK
# 1199987        1.00          OM        2014          PARKASH
# 1199988        1.00       ADELE        2014           PARKER
# 1199989        1.00       AVRIL        2014           PARKER
# 1199990        1.00       BETTY        2014           PARKER
# 1199991        1.00     CLASSIE        2014           PARKER
# 1199992        1.00   HENRIETTA        2014           PARKER
# 1199993        1.00        INEZ        2014           PARKER
# 1199994        1.00        JOHN        2014           PARKER
# 1199995        1.00         KIM        2014           PARKER
# 1199996        1.00       LYMON        2014           PARKER
# 1199997        1.00     MARLENA        2014           PARKER
# 1199998        1.00     MONIQUE        2014           PARKER
# 1199999        1.00       PATTI        2014           PARKER
#
#         leave_status_as_of_july_31 mid_init ot_hours   pay_basis  \
# 0                           ACTIVE        E     2.25   per Annum
# 1                           ACTIVE      NaN     0.00   per Annum
# 2                         ON LEAVE        L     1.00   per Annum
# 3                           ACTIVE        J     0.00   per Annum
# 4                           CEASED      NaN     0.00    per Hour
# 5                           ACTIVE      NaN     0.00   per Annum
# 6                           ACTIVE        D     0.00   per Annum
# 7                           ACTIVE      NaN     0.00    per Hour
# 8                           CEASED        J     0.00   per Annum
# 9                           ACTIVE        E     0.00   per Annum
# 10                          CEASED        J     0.00   per Annum
# 11                          ACTIVE      NaN     0.00   per Annum
# 12                          ACTIVE        F     0.00   per Annum
# 13                          ACTIVE        J     0.00   per Annum
# 14                          ACTIVE      NaN   716.25   per Annum
# 15                          CEASED      NaN     0.00    per Hour
# 16                          ACTIVE      NaN    51.75   per Annum
# 17                          ACTIVE        H     0.00   per Annum
# 18                          CEASED      NaN     0.00    per Hour
# 19                          ACTIVE      NaN     0.00   per Annum
# 20                          ACTIVE        L     0.00   per Annum
# 21                          ACTIVE        R   408.75     per Day
# 22                          ACTIVE      NaN     0.00    per Hour
# 23                          ACTIVE        A   173.75     per Day
# 24                          ACTIVE        I   276.50   per Annum
# 25                          CEASED        K     1.00   per Annum
# 26                          ACTIVE      NaN     0.00   per Annum
# 27                          ACTIVE        L     0.00   per Annum
# 28                          ACTIVE        K     0.00   per Annum
# 29                          ACTIVE      NaN     0.75   per Annum
# ...                            ...      ...      ...         ...
# 1199970                     ACTIVE      NaN     0.00    per Hour
# 1199971                     ACTIVE        A     0.00    per Hour
# 1199972                     ACTIVE        I     0.00    per Hour
# 1199973                     ACTIVE        P     0.00    per Hour
# 1199974                     ACTIVE      NaN     0.00    per Hour
# 1199975                     ACTIVE      NaN     0.00    per Hour
# 1199976                     ACTIVE        K     0.00    per Hour
# 1199977                     ACTIVE        A     0.00    per Hour
# 1199978                     ACTIVE      NaN     0.00    per Hour
# 1199979                     ACTIVE        M     0.00    per Hour
# 1199980                     ACTIVE        N     0.00    per Hour
# 1199981                     ACTIVE        N     0.00    per Hour
# 1199982                     ACTIVE        V     0.00    per Hour
# 1199983                     ACTIVE        P     0.00    per Hour
# 1199984                     ACTIVE        A     0.00    per Hour
# 1199985                     ACTIVE      NaN     0.00    per Hour
# 1199986                     ACTIVE        Y     0.00    per Hour
# 1199987                     ACTIVE      NaN     0.00    per Hour
# 1199988                     ACTIVE      NaN     0.00    per Hour
# 1199989                     ACTIVE        A     0.00    per Hour
# 1199990                     ACTIVE        E     0.00    per Hour
# 1199991                     ACTIVE      NaN     0.00    per Hour
# 1199992                     ACTIVE      NaN     0.00    per Hour
# 1199993                     ACTIVE      NaN     0.00    per Hour
# 1199994                     ACTIVE      NaN     0.00    per Hour
# 1199995                     ACTIVE        A     0.00    per Hour
# 1199996                     ACTIVE      NaN     0.00    per Hour
# 1199997                     ACTIVE      NaN     0.00    per Hour
# 1199998                     ACTIVE        L     0.00    per Hour
# 1199999                     ACTIVE        L     0.00    per Hour
#
#         regular_gross_paid regular_hours  \
# 0                 47166.03       1830.00
# 1                119042.50       1831.00
# 2                 27452.62       1181.68
# 3                115104.57       1831.00
# 4                  3500.00          0.00
# 5                 71967.34       1831.00
# 6                 87614.01       1831.00
# 7                   500.00          0.00
# 8                  9507.15        349.00
# 9                 64357.12       1830.00
# 10                 6073.13        200.70
# 11                39895.79       1830.00
# 12                65909.63       1830.00
# 13               111806.82       1831.00
# 14                51890.77       1830.00
# 15                 3500.00          0.00
# 16                40052.01       1830.00
# 17                59023.02       1076.00
# 18                 3500.00          0.00
# 19                39866.21       1830.00
# 20                64498.36       1509.00
# 21               139072.14       1830.00
# 22                 1000.00          0.00
# 23                56602.00       1830.00
# 24                46271.84       1829.75
# 25                 4661.03         38.10
# 26                35765.73       1830.00
# 27                64895.59       1830.00
# 28                55411.18       1830.00
# 29                26422.22       1383.00
# ...                    ...           ...
# 1199970             606.00          0.00
# 1199971             781.00          0.00
# 1199972             778.00          0.00
# 1199973             225.00          0.00
# 1199974             660.00          0.00
# 1199975             503.00          0.00
# 1199976             778.00          0.00
# 1199977             775.00          0.00
# 1199978             775.00          0.00
# 1199979             500.00          0.00
# 1199980             775.00          0.00
# 1199981             781.00          0.00
# 1199982             500.00          0.00
# 1199983             775.00          0.00
# 1199984             660.00          0.00
# 1199985             660.00          0.00
# 1199986             660.00          0.00
# 1199987             775.00          0.00
# 1199988             684.64          0.00
# 1199989             300.00          0.00
# 1199990             775.00          0.00
# 1199991            1375.00          0.00
# 1199992             775.00          0.00
# 1199993             778.00          0.00
# 1199994             775.00          0.00
# 1199995            1075.00          0.00
# 1199996             775.00          0.00
# 1199997             425.00          0.00
# 1199998             781.00          0.00
# 1199999             300.00          0.00
#
#                                          title_description total_ot_paid  \
# 0        COMMUNITY ASSOCIATE                           ...         57.28
# 1        ADMINISTRATIVE ACCOUNTANT                     ...          0.00
# 2        COMMUNITY ASSOCIATE                           ...         21.34
# 3        COMPUTER SYSTEMS MANAGER                      ...          0.00
# 4        COLLEGE AIDE                                  ...          0.00
# 5        ASSISTANT DISTRICT ATTORNEY                   ...          0.00
# 6        ASSISTANT DISTRICT ATTORNEY                   ...          0.00
# 7        COLLEGE AIDE                                  ...          0.00
# 8        COMMUNITY ASSOCIATE                           ...          0.00
# 9                   PRINCIPAL ADMINISTRATIVE ASSOCIATE              0.00
# 10       COMMUNITY ASSOCIATE                           ...          0.00
# 11       COMMUNITY ASSOCIATE                           ...          0.00
# 12       COMMUNITY COORDINATOR                         ...          0.00
# 13       PRINCIPAL ACCOUNTANT INVESTIGATOR             ...          0.00
# 14       COMMUNITY ASSOCIATE                           ...      25943.55
# 15       COLLEGE AIDE                                  ...          0.00
# 16       COMMUNITY ASSISTANT                           ...       1413.40
# 17       ASSISTANT DISTRICT ATTORNEY                   ...          0.00
# 18       COLLEGE AIDE                                  ...          0.00
# 19       COMMUNITY ASSOCIATE                           ...          0.00
# 20       ASSISTANT DISTRICT ATTORNEY                   ...          0.00
# 21       CARPENTER                                     ...      50546.28
# 22       COLLEGE AIDE                                  ...          0.00
# 23       ELECTRICIAN'S HELPER                          ...       8991.82
# 24       COMMUNITY ASSOCIATE                           ...       7757.06
# 25       COMMUNITY ASSOCIATE                           ...        169.90
# 26       COMMUNITY ASSISTANT                           ...          0.00
# 27       COMMUNITY COORDINATOR                         ...          0.00
# 28            CLERICAL ASSOCIATE                                    0.00
# 29       COMMUNITY ASSOCIATE                           ...         15.41
# ...                                                    ...           ...
# 1199970  ELECTION WORKER                               ...          0.00
# 1199971  ELECTION WORKER                               ...          0.00
# 1199972  ELECTION WORKER                               ...          0.00
# 1199973  ELECTION WORKER                               ...          0.00
# 1199974  ELECTION WORKER                               ...          0.00
# 1199975  ELECTION WORKER                               ...          0.00
# 1199976  ELECTION WORKER                               ...          0.00
# 1199977  ELECTION WORKER                               ...          0.00
# 1199978  ELECTION WORKER                               ...          0.00
# 1199979  ELECTION WORKER                               ...          0.00
# 1199980  ELECTION WORKER                               ...          0.00
# 1199981  ELECTION WORKER                               ...          0.00
# 1199982  ELECTION WORKER                               ...          0.00
# 1199983  ELECTION WORKER                               ...          0.00
# 1199984  ELECTION WORKER                               ...          0.00
# 1199985  ELECTION WORKER                               ...          0.00
# 1199986  ELECTION WORKER                               ...          0.00
# 1199987  ELECTION WORKER                               ...          0.00
# 1199988  ELECTION WORKER                               ...          0.00
# 1199989  ELECTION WORKER                               ...          0.00
# 1199990  ELECTION WORKER                               ...          0.00
# 1199991  ELECTION WORKER                               ...          0.00
# 1199992  ELECTION WORKER                               ...          0.00
# 1199993  ELECTION WORKER                               ...          0.00
# 1199994  ELECTION WORKER                               ...          0.00
# 1199995  ELECTION WORKER                               ...          0.00
# 1199996  ELECTION WORKER                               ...          0.00
# 1199997  ELECTION WORKER                               ...          0.00
# 1199998  ELECTION WORKER                               ...          0.00
# 1199999  ELECTION WORKER                               ...          0.00
#
#         total_other_pay work_location_borough
# 0                  0.00         MANHATTAN
# 1                  0.00         MANHATTAN
# 2                 33.00         MANHATTAN
# 3                  0.00         MANHATTAN
# 4                  0.00         MANHATTAN
# 5                  0.00         MANHATTAN
# 6                750.00         MANHATTAN
# 7                  0.00         MANHATTAN
# 8                  0.00         MANHATTAN
# 9               3824.72         MANHATTAN
# 10                 8.25         MANHATTAN
# 11                74.25         MANHATTAN
# 12                33.00         MANHATTAN
# 13               500.00         MANHATTAN
# 14               747.93         MANHATTAN
# 15                 0.00         MANHATTAN
# 16               526.11         MANHATTAN
# 17                 0.00         MANHATTAN
# 18                 0.00         MANHATTAN
# 19                 0.00         MANHATTAN
# 20              1750.00         MANHATTAN
# 21              5060.37         MANHATTAN
# 22                 0.00         MANHATTAN
# 23              7424.72         MANHATTAN
# 24               755.84         MANHATTAN
# 25                94.40         MANHATTAN
# 26                 0.00         MANHATTAN
# 27                99.50         MANHATTAN
# 28              4424.50         MANHATTAN
# 29                24.75         MANHATTAN
# ...                 ...                   ...
# 1199970            0.00                   NaN
# 1199971            0.00                   NaN
# 1199972            0.00                   NaN
# 1199973            0.00                   NaN
# 1199974            0.00                   NaN
# 1199975            0.00                   NaN
# 1199976            0.00                   NaN
# 1199977            0.00                   NaN
# 1199978            0.00                   NaN
# 1199979            0.00                   NaN
# 1199980            0.00                   NaN
# 1199981            0.00                   NaN
# 1199982            0.00                   NaN
# 1199983            0.00                   NaN
# 1199984            0.00                   NaN
# 1199985            0.00                   NaN
# 1199986            0.00                   NaN
# 1199987            0.00                   NaN
# 1199988            0.00                   NaN
# 1199989            0.00                   NaN
# 1199990            0.00                   NaN
# 1199991            0.00                   NaN
# 1199992            0.00                   NaN
# 1199993            0.00                   NaN
# 1199994            0.00                   NaN
# 1199995            0.00                   NaN
# 1199996            0.00                   NaN
# 1199997            0.00                   NaN
# 1199998            0.00                   NaN
# 1199999            0.00                   NaN
#
# [1200000 rows x 17 columns]

# %%
del result['index']

# %%
result
# Out:
#                             agency_name    agency_start_date base_salary  \
# 0        DISTRICT ATTORNEY-MANHATTAN     2003-07-14T00:00:00    47678.00
# 1        DISTRICT ATTORNEY-MANHATTAN     1995-06-12T00:00:00   119959.00
# 2        DISTRICT ATTORNEY-MANHATTAN     2011-10-11T00:00:00    39966.00
# 3        DISTRICT ATTORNEY-MANHATTAN     2014-12-01T00:00:00   116000.00
# 4        DISTRICT ATTORNEY-MANHATTAN     2015-05-21T00:00:00        1.00
# 5        DISTRICT ATTORNEY-MANHATTAN     2012-09-04T00:00:00    71500.00
# 6        DISTRICT ATTORNEY-MANHATTAN     2007-09-04T00:00:00    88000.00
# 7        DISTRICT ATTORNEY-MANHATTAN     2016-06-06T00:00:00        1.00
# 8        DISTRICT ATTORNEY-MANHATTAN     2014-09-02T00:00:00    41000.00
# 9        DISTRICT ATTORNEY-MANHATTAN     1978-05-31T00:00:00    66035.00
# 10       DISTRICT ATTORNEY-MANHATTAN     2013-04-22T00:00:00    38869.00
# 11       DISTRICT ATTORNEY-MANHATTAN     2014-08-25T00:00:00    42075.00
# 12       DISTRICT ATTORNEY-MANHATTAN     2014-01-13T00:00:00    66625.00
# 13       DISTRICT ATTORNEY-MANHATTAN     2005-03-28T00:00:00   112592.00
# 14       DISTRICT ATTORNEY-MANHATTAN     2009-11-09T00:00:00    52548.00
# 15       DISTRICT ATTORNEY-MANHATTAN     2015-05-21T00:00:00        1.00
# 16       DISTRICT ATTORNEY-MANHATTAN     2014-04-28T00:00:00    43299.00
# 17       DISTRICT ATTORNEY-MANHATTAN     2004-09-07T00:00:00   102500.00
# 18       DISTRICT ATTORNEY-MANHATTAN     2015-05-21T00:00:00        1.00
# 19       DISTRICT ATTORNEY-MANHATTAN     2007-01-19T00:00:00    40299.00
# 20       DISTRICT ATTORNEY-MANHATTAN     2014-09-02T00:00:00    78000.00
# 21       DISTRICT ATTORNEY-MANHATTAN     2008-09-21T00:00:00      370.16
# 22       DISTRICT ATTORNEY-MANHATTAN     2016-06-06T00:00:00        1.00
# 23       DISTRICT ATTORNEY-MANHATTAN     2009-03-02T00:00:00      217.70
# 24       DISTRICT ATTORNEY-MANHATTAN     2015-06-08T00:00:00    53366.00
# 25       DISTRICT ATTORNEY-MANHATTAN     2010-08-16T00:00:00    45985.00
# 26       DISTRICT ATTORNEY-MANHATTAN     2008-01-14T00:00:00    36154.00
# 27       DISTRICT ATTORNEY-MANHATTAN     2014-10-20T00:00:00    65600.00
# 28       DISTRICT ATTORNEY-MANHATTAN     1980-01-21T00:00:00    56017.00
# 29       DISTRICT ATTORNEY-MANHATTAN     2015-09-28T00:00:00    37541.00
# ...                                 ...                  ...         ...
# 1199970  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 1199971  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 1199972  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 1199973  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 1199974  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 1199975  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 1199976  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 1199977  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 1199978  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 1199979  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 1199980  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 1199981  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 1199982  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 1199983  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 1199984  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 1199985  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 1199986  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 1199987  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 1199988  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 1199989  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 1199990  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 1199991  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 1199992  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 1199993  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 1199994  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 1199995  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 1199996  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 1199997  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 1199998  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
# 1199999  BOARD OF ELECTION POLL WORKERS  2010-01-01T00:00:00        1.00
#
#          first_name fiscal_year        last_name leave_status_as_of_july_31  \
# 0         RAHASHEEM        2016        ABA'AHMID                     ACTIVE
# 1          MARGARET        2016          ABENSUR                     ACTIVE
# 2            ANDREA        2016        ABOUNAOUM                   ON LEAVE
# 3          JONATHAN        2016          ABRAHAM                     ACTIVE
# 4            JOSEPH        2016           ABRAMS                     CEASED
# 5          JENNIFER        2016            ABREU                     ACTIVE
# 6              JUAN        2016            ABREU                     ACTIVE
# 7          JENNIFER        2016          ACEVEDO                     ACTIVE
# 8           MATTHEW        2016         ACOCELLA                     CEASED
# 9              RITA        2016           ACOSTA                     ACTIVE
# 10        KATHERINE        2016            ADAMS                     CEASED
# 11         NEERESHA        2016            ADAMS                     ACTIVE
# 12       OYINDAMOLA        2016         ADEGBORO                     ACTIVE
# 13         SANCHITA        2016         AGGARWAL                     ACTIVE
# 14           YAMIRA        2016          AGUILAR                     ACTIVE
# 15           JORDAN        2016          AGUIRRE                     CEASED
# 16          ARTEMIS        2016          AHMETAJ                     ACTIVE
# 17            HELEN        2016              AHN                     ACTIVE
# 18           SANDRA        2016          ALCAIDE                     CEASED
# 19           DANIEL        2016        ALCANTARA                     ACTIVE
# 20             ERIN        2016        ALEXANDER                     ACTIVE
# 21             PAUL        2016           ALFLEN                     ACTIVE
# 22        SHEHARYAR        2016              ALI                     ACTIVE
# 23            SYEED        2016              ALI                     ACTIVE
# 24          JEFFREY        2016     AL-KAABAH II                     ACTIVE
# 25            ABEER        2016       ALKHAFAJEE                     CEASED
# 26          SHAIMAA        2016       ALKHAFAJEE                     ACTIVE
# 27          BENNETT        2016            ALLEN                     ACTIVE
# 28           ROBERT        2016            ALLEN                     ACTIVE
# 29          MARISOL        2016  ALMONTE-ALMANZA                     ACTIVE
# ...             ...         ...              ...                        ...
# 1199970      LARISA        2014        PARDILOVA                     ACTIVE
# 1199971     ANTHONY        2014          PAREDES                     ACTIVE
# 1199972      GEORGE        2014          PAREDES                     ACTIVE
# 1199973        JOHN        2014          PAREDES                     ACTIVE
# 1199974     MARYANN        2014          PAREDES                     ACTIVE
# 1199975    PATRICIA        2014          PAREDES                     ACTIVE
# 1199976        INDU        2014           PAREKH                     ACTIVE
# 1199977   JOSEPHINE        2014          PARENTE                     ACTIVE
# 1199978  ANTOINETTE        2014           PARHAM                     ACTIVE
# 1199979       ANITA        2014           PARHAS                     ACTIVE
# 1199980      ANJANA        2014           PARIKH                     ACTIVE
# 1199981      NAUTAM        2014           PARIKH                     ACTIVE
# 1199982      ROHINI        2014           PARIKH                     ACTIVE
# 1199983     SHIRISH        2014           PARIKH                     ACTIVE
# 1199984         RAY        2014           PARISH                     ACTIVE
# 1199985      JOSEPH        2014             PARK                     ACTIVE
# 1199986       KYUNG        2014             PARK                     ACTIVE
# 1199987          OM        2014          PARKASH                     ACTIVE
# 1199988       ADELE        2014           PARKER                     ACTIVE
# 1199989       AVRIL        2014           PARKER                     ACTIVE
# 1199990       BETTY        2014           PARKER                     ACTIVE
# 1199991     CLASSIE        2014           PARKER                     ACTIVE
# 1199992   HENRIETTA        2014           PARKER                     ACTIVE
# 1199993        INEZ        2014           PARKER                     ACTIVE
# 1199994        JOHN        2014           PARKER                     ACTIVE
# 1199995         KIM        2014           PARKER                     ACTIVE
# 1199996       LYMON        2014           PARKER                     ACTIVE
# 1199997     MARLENA        2014           PARKER                     ACTIVE
# 1199998     MONIQUE        2014           PARKER                     ACTIVE
# 1199999       PATTI        2014           PARKER                     ACTIVE
#
#         mid_init ot_hours   pay_basis regular_gross_paid regular_hours  \
# 0              E     2.25   per Annum           47166.03       1830.00
# 1            NaN     0.00   per Annum          119042.50       1831.00
# 2              L     1.00   per Annum           27452.62       1181.68
# 3              J     0.00   per Annum          115104.57       1831.00
# 4            NaN     0.00    per Hour            3500.00          0.00
# 5            NaN     0.00   per Annum           71967.34       1831.00
# 6              D     0.00   per Annum           87614.01       1831.00
# 7            NaN     0.00    per Hour             500.00          0.00
# 8              J     0.00   per Annum            9507.15        349.00
# 9              E     0.00   per Annum           64357.12       1830.00
# 10             J     0.00   per Annum            6073.13        200.70
# 11           NaN     0.00   per Annum           39895.79       1830.00
# 12             F     0.00   per Annum           65909.63       1830.00
# 13             J     0.00   per Annum          111806.82       1831.00
# 14           NaN   716.25   per Annum           51890.77       1830.00
# 15           NaN     0.00    per Hour            3500.00          0.00
# 16           NaN    51.75   per Annum           40052.01       1830.00
# 17             H     0.00   per Annum           59023.02       1076.00
# 18           NaN     0.00    per Hour            3500.00          0.00
# 19           NaN     0.00   per Annum           39866.21       1830.00
# 20             L     0.00   per Annum           64498.36       1509.00
# 21             R   408.75     per Day          139072.14       1830.00
# 22           NaN     0.00    per Hour            1000.00          0.00
# 23             A   173.75     per Day           56602.00       1830.00
# 24             I   276.50   per Annum           46271.84       1829.75
# 25             K     1.00   per Annum            4661.03         38.10
# 26           NaN     0.00   per Annum           35765.73       1830.00
# 27             L     0.00   per Annum           64895.59       1830.00
# 28             K     0.00   per Annum           55411.18       1830.00
# 29           NaN     0.75   per Annum           26422.22       1383.00
# ...          ...      ...         ...                ...           ...
# 1199970      NaN     0.00    per Hour             606.00          0.00
# 1199971        A     0.00    per Hour             781.00          0.00
# 1199972        I     0.00    per Hour             778.00          0.00
# 1199973        P     0.00    per Hour             225.00          0.00
# 1199974      NaN     0.00    per Hour             660.00          0.00
# 1199975      NaN     0.00    per Hour             503.00          0.00
# 1199976        K     0.00    per Hour             778.00          0.00
# 1199977        A     0.00    per Hour             775.00          0.00
# 1199978      NaN     0.00    per Hour             775.00          0.00
# 1199979        M     0.00    per Hour             500.00          0.00
# 1199980        N     0.00    per Hour             775.00          0.00
# 1199981        N     0.00    per Hour             781.00          0.00
# 1199982        V     0.00    per Hour             500.00          0.00
# 1199983        P     0.00    per Hour             775.00          0.00
# 1199984        A     0.00    per Hour             660.00          0.00
# 1199985      NaN     0.00    per Hour             660.00          0.00
# 1199986        Y     0.00    per Hour             660.00          0.00
# 1199987      NaN     0.00    per Hour             775.00          0.00
# 1199988      NaN     0.00    per Hour             684.64          0.00
# 1199989        A     0.00    per Hour             300.00          0.00
# 1199990        E     0.00    per Hour             775.00          0.00
# 1199991      NaN     0.00    per Hour            1375.00          0.00
# 1199992      NaN     0.00    per Hour             775.00          0.00
# 1199993      NaN     0.00    per Hour             778.00          0.00
# 1199994      NaN     0.00    per Hour             775.00          0.00
# 1199995        A     0.00    per Hour            1075.00          0.00
# 1199996      NaN     0.00    per Hour             775.00          0.00
# 1199997      NaN     0.00    per Hour             425.00          0.00
# 1199998        L     0.00    per Hour             781.00          0.00
# 1199999        L     0.00    per Hour             300.00          0.00
#
#                                          title_description total_ot_paid  \
# 0        COMMUNITY ASSOCIATE                           ...         57.28
# 1        ADMINISTRATIVE ACCOUNTANT                     ...          0.00
# 2        COMMUNITY ASSOCIATE                           ...         21.34
# 3        COMPUTER SYSTEMS MANAGER                      ...          0.00
# 4        COLLEGE AIDE                                  ...          0.00
# 5        ASSISTANT DISTRICT ATTORNEY                   ...          0.00
# 6        ASSISTANT DISTRICT ATTORNEY                   ...          0.00
# 7        COLLEGE AIDE                                  ...          0.00
# 8        COMMUNITY ASSOCIATE                           ...          0.00
# 9                   PRINCIPAL ADMINISTRATIVE ASSOCIATE              0.00
# 10       COMMUNITY ASSOCIATE                           ...          0.00
# 11       COMMUNITY ASSOCIATE                           ...          0.00
# 12       COMMUNITY COORDINATOR                         ...          0.00
# 13       PRINCIPAL ACCOUNTANT INVESTIGATOR             ...          0.00
# 14       COMMUNITY ASSOCIATE                           ...      25943.55
# 15       COLLEGE AIDE                                  ...          0.00
# 16       COMMUNITY ASSISTANT                           ...       1413.40
# 17       ASSISTANT DISTRICT ATTORNEY                   ...          0.00
# 18       COLLEGE AIDE                                  ...          0.00
# 19       COMMUNITY ASSOCIATE                           ...          0.00
# 20       ASSISTANT DISTRICT ATTORNEY                   ...          0.00
# 21       CARPENTER                                     ...      50546.28
# 22       COLLEGE AIDE                                  ...          0.00
# 23       ELECTRICIAN'S HELPER                          ...       8991.82
# 24       COMMUNITY ASSOCIATE                           ...       7757.06
# 25       COMMUNITY ASSOCIATE                           ...        169.90
# 26       COMMUNITY ASSISTANT                           ...          0.00
# 27       COMMUNITY COORDINATOR                         ...          0.00
# 28            CLERICAL ASSOCIATE                                    0.00
# 29       COMMUNITY ASSOCIATE                           ...         15.41
# ...                                                    ...           ...
# 1199970  ELECTION WORKER                               ...          0.00
# 1199971  ELECTION WORKER                               ...          0.00
# 1199972  ELECTION WORKER                               ...          0.00
# 1199973  ELECTION WORKER                               ...          0.00
# 1199974  ELECTION WORKER                               ...          0.00
# 1199975  ELECTION WORKER                               ...          0.00
# 1199976  ELECTION WORKER                               ...          0.00
# 1199977  ELECTION WORKER                               ...          0.00
# 1199978  ELECTION WORKER                               ...          0.00
# 1199979  ELECTION WORKER                               ...          0.00
# 1199980  ELECTION WORKER                               ...          0.00
# 1199981  ELECTION WORKER                               ...          0.00
# 1199982  ELECTION WORKER                               ...          0.00
# 1199983  ELECTION WORKER                               ...          0.00
# 1199984  ELECTION WORKER                               ...          0.00
# 1199985  ELECTION WORKER                               ...          0.00
# 1199986  ELECTION WORKER                               ...          0.00
# 1199987  ELECTION WORKER                               ...          0.00
# 1199988  ELECTION WORKER                               ...          0.00
# 1199989  ELECTION WORKER                               ...          0.00
# 1199990  ELECTION WORKER                               ...          0.00
# 1199991  ELECTION WORKER                               ...          0.00
# 1199992  ELECTION WORKER                               ...          0.00
# 1199993  ELECTION WORKER                               ...          0.00
# 1199994  ELECTION WORKER                               ...          0.00
# 1199995  ELECTION WORKER                               ...          0.00
# 1199996  ELECTION WORKER                               ...          0.00
# 1199997  ELECTION WORKER                               ...          0.00
# 1199998  ELECTION WORKER                               ...          0.00
# 1199999  ELECTION WORKER                               ...          0.00
#
#         total_other_pay work_location_borough
# 0                  0.00         MANHATTAN
# 1                  0.00         MANHATTAN
# 2                 33.00         MANHATTAN
# 3                  0.00         MANHATTAN
# 4                  0.00         MANHATTAN
# 5                  0.00         MANHATTAN
# 6                750.00         MANHATTAN
# 7                  0.00         MANHATTAN
# 8                  0.00         MANHATTAN
# 9               3824.72         MANHATTAN
# 10                 8.25         MANHATTAN
# 11                74.25         MANHATTAN
# 12                33.00         MANHATTAN
# 13               500.00         MANHATTAN
# 14               747.93         MANHATTAN
# 15                 0.00         MANHATTAN
# 16               526.11         MANHATTAN
# 17                 0.00         MANHATTAN
# 18                 0.00         MANHATTAN
# 19                 0.00         MANHATTAN
# 20              1750.00         MANHATTAN
# 21              5060.37         MANHATTAN
# 22                 0.00         MANHATTAN
# 23              7424.72         MANHATTAN
# 24               755.84         MANHATTAN
# 25                94.40         MANHATTAN
# 26                 0.00         MANHATTAN
# 27                99.50         MANHATTAN
# 28              4424.50         MANHATTAN
# 29                24.75         MANHATTAN
# ...                 ...                   ...
# 1199970            0.00                   NaN
# 1199971            0.00                   NaN
# 1199972            0.00                   NaN
# 1199973            0.00                   NaN
# 1199974            0.00                   NaN
# 1199975            0.00                   NaN
# 1199976            0.00                   NaN
# 1199977            0.00                   NaN
# 1199978            0.00                   NaN
# 1199979            0.00                   NaN
# 1199980            0.00                   NaN
# 1199981            0.00                   NaN
# 1199982            0.00                   NaN
# 1199983            0.00                   NaN
# 1199984            0.00                   NaN
# 1199985            0.00                   NaN
# 1199986            0.00                   NaN
# 1199987            0.00                   NaN
# 1199988            0.00                   NaN
# 1199989            0.00                   NaN
# 1199990            0.00                   NaN
# 1199991            0.00                   NaN
# 1199992            0.00                   NaN
# 1199993            0.00                   NaN
# 1199994            0.00                   NaN
# 1199995            0.00                   NaN
# 1199996            0.00                   NaN
# 1199997            0.00                   NaN
# 1199998            0.00                   NaN
# 1199999            0.00                   NaN
#
# [1200000 rows x 16 columns]

# %%
result.groupby(['year']).agg({'base_salary': np.mean})
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-97-c2a1272d50f3> in <module>()
# ----> 1 result.groupby(['year']).agg({'base_salary': np.mean})
#
# /usr/lib/python3/dist-packages/pandas/core/generic.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, **kwargs)
#    5160         return groupby(self, by=by, axis=axis, level=level, as_index=as_index,
#    5161                        sort=sort, group_keys=group_keys, squeeze=squeeze,
# -> 5162                        **kwargs)
#    5163
#    5164     def asfreq(self, freq, method=None, how=None, normalize=False,
#
# /usr/lib/python3/dist-packages/pandas/core/groupby.py in groupby(obj, by, **kwds)
#    1846         raise TypeError('invalid type: %s' % type(obj))
#    1847
# -> 1848     return klass(obj, by, **kwds)
#    1849
#    1850
#
# /usr/lib/python3/dist-packages/pandas/core/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, **kwargs)
#     514                                                     level=level,
#     515                                                     sort=sort,
# --> 516                                                     mutated=self.mutated)
#     517
#     518         self.obj = obj
#
# /usr/lib/python3/dist-packages/pandas/core/groupby.py in _get_grouper(obj, key, axis, level, sort, mutated, validate)
#    2932                 in_axis, name, level, gpr = False, None, gpr, None
#    2933             else:
# -> 2934                 raise KeyError(gpr)
#    2935         elif isinstance(gpr, Grouper) and gpr.key is not None:
#    2936             # Add key to exclusions
#
# KeyError: 'year'

# %%
result.groupby(['fiscal_year']).agg({'base_salary': np.mean})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-98-0c2c35c266f8> in <module>()
# ----> 1 result.groupby(['fiscal_year']).agg({'base_salary': np.mean})
#
# NameError: name 'np' is not defined

# %%
import numpy as np

# %%
result.groupby(['year']).agg({'base_salary': np.mean})
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-100-c2a1272d50f3> in <module>()
# ----> 1 result.groupby(['year']).agg({'base_salary': np.mean})
#
# /usr/lib/python3/dist-packages/pandas/core/generic.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, **kwargs)
#    5160         return groupby(self, by=by, axis=axis, level=level, as_index=as_index,
#    5161                        sort=sort, group_keys=group_keys, squeeze=squeeze,
# -> 5162                        **kwargs)
#    5163
#    5164     def asfreq(self, freq, method=None, how=None, normalize=False,
#
# /usr/lib/python3/dist-packages/pandas/core/groupby.py in groupby(obj, by, **kwds)
#    1846         raise TypeError('invalid type: %s' % type(obj))
#    1847
# -> 1848     return klass(obj, by, **kwds)
#    1849
#    1850
#
# /usr/lib/python3/dist-packages/pandas/core/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, **kwargs)
#     514                                                     level=level,
#     515                                                     sort=sort,
# --> 516                                                     mutated=self.mutated)
#     517
#     518         self.obj = obj
#
# /usr/lib/python3/dist-packages/pandas/core/groupby.py in _get_grouper(obj, key, axis, level, sort, mutated, validate)
#    2932                 in_axis, name, level, gpr = False, None, gpr, None
#    2933             else:
# -> 2934                 raise KeyError(gpr)
#    2935         elif isinstance(gpr, Grouper) and gpr.key is not None:
#    2936             # Add key to exclusions
#
# KeyError: 'year'

# %%
result.groupby(['fiscal_year']).agg({'base_salary': np.mean})
# Out:
# ---------------------------------------------------------------------------
# DataError                                 Traceback (most recent call last)
# <ipython-input-101-0c2c35c266f8> in <module>()
# ----> 1 result.groupby(['fiscal_year']).agg({'base_salary': np.mean})
#
# /usr/lib/python3/dist-packages/pandas/core/groupby.py in aggregate(self, arg, *args, **kwargs)
#    4289         versionadded=''))
#    4290     def aggregate(self, arg, *args, **kwargs):
# -> 4291         return super(DataFrameGroupBy, self).aggregate(arg, *args, **kwargs)
#    4292
#    4293     agg = aggregate
#
# /usr/lib/python3/dist-packages/pandas/core/groupby.py in aggregate(self, arg, *args, **kwargs)
#    3722
#    3723         _level = kwargs.pop('_level', None)
# -> 3724         result, how = self._aggregate(arg, _level=_level, *args, **kwargs)
#    3725         if how is None:
#    3726             return result
#
# /usr/lib/python3/dist-packages/pandas/core/base.py in _aggregate(self, arg, *args, **kwargs)
#     476
#     477                 try:
# --> 478                     result = _agg(arg, _agg_1dim)
#     479                 except SpecificationError:
#     480
#
# /usr/lib/python3/dist-packages/pandas/core/base.py in _agg(arg, func)
#     427                 result = compat.OrderedDict()
#     428                 for fname, agg_how in compat.iteritems(arg):
# --> 429                     result[fname] = func(fname, agg_how)
#     430                 return result
#     431
#
# /usr/lib/python3/dist-packages/pandas/core/base.py in _agg_1dim(name, how, subset)
#     410                     raise SpecificationError("nested dictionary is ambiguous "
#     411                                              "in aggregation")
# --> 412                 return colg.aggregate(how, _level=(_level or 0) + 1)
#     413
#     414             def _agg_2dim(name, how):
#
# /usr/lib/python3/dist-packages/pandas/core/groupby.py in aggregate(self, func_or_funcs, *args, **kwargs)
#    3127             cyfunc = self._is_cython_func(func_or_funcs)
#    3128             if cyfunc and not args and not kwargs:
# -> 3129                 return getattr(self, cyfunc)()
#    3130
#    3131             if self.grouper.nkeys > 1:
#
# /usr/lib/python3/dist-packages/pandas/core/groupby.py in mean(self, *args, **kwargs)
#    1126         nv.validate_groupby_func('mean', args, kwargs, ['numeric_only'])
#    1127         try:
# -> 1128             return self._cython_agg_general('mean', **kwargs)
#    1129         except GroupByError:
#    1130             raise
#
# /usr/lib/python3/dist-packages/pandas/core/groupby.py in _cython_agg_general(self, how, alt, numeric_only, min_count)
#     925
#     926         if len(output) == 0:
# --> 927             raise DataError('No numeric types to aggregate')
#     928
#     929         return self._wrap_aggregated_output(output, names)
#
# DataError: No numeric types to aggregate

# %%
result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1200000 entries, 0 to 1199999
# Data columns (total 16 columns):
# agency_name                   1200000 non-null object
# agency_start_date             1200000 non-null object
# base_salary                   1200000 non-null object
# first_name                    1199454 non-null object
# fiscal_year                   1200000 non-null object
# last_name                     1199456 non-null object
# leave_status_as_of_july_31    1200000 non-null object
# mid_init                      714721 non-null object
# ot_hours                      1200000 non-null object
# pay_basis                     1200000 non-null object
# regular_gross_paid            1200000 non-null object
# regular_hours                 1200000 non-null object
# title_description             1199991 non-null object
# total_ot_paid                 1200000 non-null object
# total_other_pay               1200000 non-null object
# work_location_borough         1122685 non-null object
# dtypes: object(16)
# memory usage: 146.5+ MB
